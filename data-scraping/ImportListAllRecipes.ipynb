# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
metaDataLocation = 'meta-lists.json'
dataLocation = 'lists.json'

# %%
def extractCategoryId(url):
    prefix = 'http://allrecipes.com'
    if url.startswith(prefix):
        u = url[len(prefix):]
    else:
        u = url
    if (len(u)<2): return -1  
    split = u[1:-1].split('/')
    return int(split[1])

def formUrl(params):
    url = 'https://apps.allrecipes.com/v1/assets/hub-feed?id=[id]&pageNumber=[page]&isSponsored=[sponsored]&sortType=[sort]'
    url = url.replace('[id]', str(params['id']))
    url = url.replace('[page]', str(params['page']))
    url = url.replace('[sponsored]', str(params['sponsored']))
    url = url.replace('[sort]', str(params['sort']))
    return url

def formCatUrl(url):
    prefix = 'http://allrecipes.com'
    return prefix + url

# %% [markdown]
# ## Import data functions

# %%
def importData(path):
    data = []
    # Import existing data
    try:
        with open(path, 'r') as file:
            data = json.load(file)
            file.close()
    except IOError as e:
        print('There is no data to import, a default data structure is created')
    return data

def exportData(data, path):
    with open(path, 'w') as file:
        json.dump(data, file, sort_keys=True, indent=4)

# %% [markdown]
# ## Metadata functions

# %%
def importMD(path):
    
    metadata = []
    # Import existing data
    try:
        with open(path, 'r') as file:
            metadata = json.load(file)
            file.close()
    except IOError as e:
        print('There is no meta-data to import, a default data structure is created')
    return metadata

def exportMD(data, path):
    with open(path, 'w') as file:
        json.dump(data, file, sort_keys=True, indent=4)
    
def isCategoryExist(metadata, id):
    
    # Find the category
    category = None
    for (i, cat) in enumerate(metadata):
        if(cat['id'] == id):
            return True
    return False

def addCategoryMD(metadata, url, title, id):
    # Find the category
    category = None
    for (i, cat) in enumerate(metadata):
        if(cat['id'] == id):
            category = cat
            break;
    if (category != None):
        print('The category already exists')
    else:
        cell = {'url':url, 'title':title, 'id':id, 'max':None, 'pages':[], 'recipeIds':[]}
        metadata.append(cell)

def addEntryMD(metadata, id, page):
    
    # Find the category
    category = None
    for (i, cat) in enumerate(metadata):
        if(cat['id'] == id):
            category = cat
            break;
    
    if (category != None):
        if (page not in category['pages']):
            category['pages'].append(page)
        else:
            pass
    else:
        print('the category does not exist')
        
    
def isPresentMD(metadata, id, page):
    
    # Find the category
    category = None
    for (i, cat) in enumerate(metadata):
        if(cat['id'] == id):
            category = cat
            break;
    
    if (category != None):
        return (page in category['pages'])
    else:
        return False

# %% [markdown]
# ## Tree functions

# %%
def importTree(path):
    tree = None
    try:
        with open(path, 'r') as file:
            tree = json.load(file)
            file.close()
    except IOError as e:
        print('There is no data to import')
    return tree

def fromTreeToMD(tree, metadata, recursive=False):
    
    url = tree['url']
    id = extractCategoryId(url)
    title = tree['title']
    addCategoryMD(metadata, url, title, id)

    if(recursive):
        children = tree['children']
        if(children == None):
            pass
        elif(children == 'EMPTY'):
            pass
        elif(len(children) > 0):
            for (j, child) in enumerate(children):
                fromTreeToMD(child, metadata, True)
    else:
        pass
    
def findSubTreeByUrl(tree, url):
    if (tree == 'EMPTY'):
        return None
    elif (tree == None):
        return None
    else:
        if(tree['url'] == url):
            return tree
        else:
            if (tree['children'] == 'EMPTY'):
                return None
            elif (tree['children'] == None):
                return None
            else:
                for (i, child) in enumerate(tree['children']):
                    sub = findSubTreeByUrl(child, url)
                    if (sub != None): return sub

# %% [markdown]
# ## Data storage functions

# %%
def isRecipePresent(data, recipeId):
    for (i, recipe) in enumerate(data):
        if(recipe['id'] == recipeId):
            return True
    return False

def treatNewData(data, recipeList, category):
    
    for (i, recipe) in enumerate(recipeList):
        
        if(recipe['itemType'] == 'Recipe'):
            
            recipeId = recipe['id']
            
            # Add recipe to list
            if(isRecipePresent(data, recipeId)):
                #print('\t\tDouble entry found')
                pass
            else:
                data.append(recipe)

            # Add id to metadata
            if (recipeId not in category['recipeIds']):
                category['recipeIds'].append(recipeId)
            else:
                pass
       
        else:
            #print('\t\tThis entry is not a recipe')
            pass

# %% [markdown]
# ## Request functions

# %%
def getPage(urlSession, session, params):
    token = session.cookies.get('ARToken')
    headers = {
        'Origin':'http://allrecipes.com',
        'X-Requested-With':'XMLHttpRequest',
        'Authorization':'Bearer ' + token,
        'Accept':'*/*',
        'Referer':urlSession
    }
    url = formUrl(params)
    # REQUEST ----------------------------------------------
    r = requests.get(url, headers=headers)
    # ------------------------------------------------------
    return r

def getPages(data, category, max_requests):
    
    nbRequests = 0
    
    if(category['max'] == None):
        urlSession = formCatUrl(category['url'])
        s = requests.Session()
        # REQUEST ----------------------------------------------
        s.get(urlSession)
        # ------------------------------------------------------
        nbRequests = nbRequests + 1
        print('New session at {url}'.format(url=urlSession))
        
        iteration = 1
        while(category['max'] == None and iteration < 10000):
            if (iteration not in category['pages']):
                
                if (nbRequests < max_requests):
                    params = {'id':category['id'], 'page':iteration, 'sponsored':'true', 'sort':'t'}
                    # REQUEST ----------------------------------------------
                    r = getPage(urlSession, s, params)
                    # ------------------------------------------------------
                    nbRequests = nbRequests + 1
                    print('\tPage {page} provided'.format(page=iteration))
                    
                else:
                    print('Too many requests have been done')
                    break
                if (r.status_code == 200):
                    response = r.json()
                    recipeList = response['cards']
                    
                    if (len(recipeList) == 0):
                        category['max'] = iteration-1
                        
                    else:
                        treatNewData(data, recipeList, category)
                        category['pages'].append(iteration)
                        
            else:
                print('Page {page} already presents'.format(page=iteration))
                pass
            iteration = iteration + 1
            
        
    else:
        print('This category is fully provided')
        pass

    return nbRequests
    
def getCategories(data, metadata, max_requests):
    nb_requests = 0
    for (i, category) in enumerate(metadata):
        if(nb_requests < max_requests):
            nb = getPages(data, category, max_requests-nb_requests)
            nb_requests = nb_requests + nb
        else:
            break
            
    return nb_requests

# %% [markdown]
# ## Let's start !

# %%
metadataPath = 'metadata-WC-byTitle.json'
dataPath = 'recipeList-WC-byTitle.json'
catUrl = '/recipes/86/world-cuisine/'

tree = importTree('categories.json')
metadata = importMD(metadataPath)
data = importData(dataPath)

subtree = findSubTreeByUrl(tree, catUrl)
fromTreeToMD(subtree, metadata, True)
# Out:
# There is no meta-data to import, a default data structure is created
# There is no data to import, a default data structure is created

# %%
# REQUESTS ----------------------------------------------
getCategories(data, metadata, 2000)
# -------------------------------------------------------
# Out:
# New session at http://allrecipes.com/recipes/86/world-cuisine/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# 	Page 25 provided
# 	Page 26 provided
# 	Page 27 provided
# 	Page 28 provided
# 	Page 29 provided
# 	Page 30 provided
# 	Page 31 provided
# 	Page 32 provided
# 	Page 33 provided
# 	Page 34 provided
# 	Page 35 provided
# 	Page 36 provided
# 	Page 37 provided
# 	Page 38 provided
# 	Page 39 provided
# 	Page 40 provided
# 	Page 41 provided
# 	Page 42 provided
# 	Page 43 provided
# 	Page 44 provided
# 	Page 45 provided
# 	Page 46 provided
# 	Page 47 provided
# 	Page 48 provided
# 	Page 49 provided
# 	Page 50 provided
# 	Page 51 provided
# 	Page 52 provided
# 	Page 53 provided
# 	Page 54 provided
# 	Page 55 provided
# 	Page 56 provided
# 	Page 57 provided
# 	Page 58 provided
# 	Page 59 provided
# 	Page 60 provided
# 	Page 61 provided
# 	Page 62 provided
# 	Page 63 provided
# 	Page 64 provided
# 	Page 65 provided
# 	Page 66 provided
# 	Page 67 provided
# 	Page 68 provided
# 	Page 69 provided
# 	Page 70 provided
# 	Page 71 provided
# 	Page 72 provided
# 	Page 73 provided
# 	Page 74 provided
# 	Page 75 provided
# 	Page 76 provided
# 	Page 77 provided
# 	Page 78 provided
# 	Page 79 provided
# 	Page 80 provided
# 	Page 81 provided
# 	Page 82 provided
# 	Page 83 provided
# 	Page 84 provided
# 	Page 85 provided
# 	Page 86 provided
# 	Page 87 provided
# 	Page 88 provided
# 	Page 89 provided
# 	Page 90 provided
# 	Page 91 provided
# 	Page 92 provided
# 	Page 93 provided
# 	Page 94 provided
# 	Page 95 provided
# 	Page 96 provided
# 	Page 97 provided
# 	Page 98 provided
# 	Page 99 provided
# 	Page 100 provided
# 	Page 101 provided
# 	Page 102 provided
# 	Page 103 provided
# 	Page 104 provided
# 	Page 105 provided
# 	Page 106 provided
# 	Page 107 provided
# 	Page 108 provided
# 	Page 109 provided
# 	Page 110 provided
# 	Page 111 provided
# New session at http://allrecipes.com/recipes/226/world-cuisine/african/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# New session at http://allrecipes.com/recipes/17582/world-cuisine/african/north-african/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# New session at http://allrecipes.com/recipes/15039/world-cuisine/african/north-african/egyptian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1827/world-cuisine/african/north-african/moroccan/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/17475/world-cuisine/african/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/17477/world-cuisine/african/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/17845/world-cuisine/african/east-african/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/17476/world-cuisine/african/side-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/15035/world-cuisine/african/south-african/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/227/world-cuisine/asian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# 	Page 25 provided
# 	Page 26 provided
# 	Page 27 provided
# 	Page 28 provided
# 	Page 29 provided
# 	Page 30 provided
# 	Page 31 provided
# 	Page 32 provided
# 	Page 33 provided
# 	Page 34 provided
# 	Page 35 provided
# 	Page 36 provided
# 	Page 37 provided
# 	Page 38 provided
# 	Page 39 provided
# 	Page 40 provided
# 	Page 41 provided
# 	Page 42 provided
# 	Page 43 provided
# 	Page 44 provided
# 	Page 45 provided
# 	Page 46 provided
# 	Page 47 provided
# 	Page 48 provided
# 	Page 49 provided
# 	Page 50 provided
# 	Page 51 provided
# 	Page 52 provided
# 	Page 53 provided
# 	Page 54 provided
# 	Page 55 provided
# 	Page 56 provided
# New session at http://allrecipes.com/recipes/233/world-cuisine/asian/indian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# New session at http://allrecipes.com/recipes/1874/world-cuisine/asian/indian/appetizers/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1876/world-cuisine/asian/indian/bread/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1879/world-cuisine/asian/indian/desserts/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/15935/world-cuisine/asian/indian/drinks/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/17136/world-cuisine/asian/indian/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# New session at http://allrecipes.com/recipes/1878/world-cuisine/asian/indian/main-dishes/chicken/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# New session at http://allrecipes.com/recipes/1873/world-cuisine/asian/indian/main-dishes/curry/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/15973/world-cuisine/asian/indian/main-dishes/rice/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1875/world-cuisine/asian/indian/main-dishes/vegetarian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# New session at http://allrecipes.com/recipes/1877/world-cuisine/asian/indian/side-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# New session at http://allrecipes.com/recipes/695/world-cuisine/asian/chinese/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# New session at http://allrecipes.com/recipes/17135/world-cuisine/asian/chinese/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# New session at http://allrecipes.com/recipes/1902/world-cuisine/asian/chinese/main-dishes/chicken/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/1901/world-cuisine/asian/chinese/main-dishes/pork/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1903/world-cuisine/asian/chinese/main-dishes/seafood/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1900/world-cuisine/asian/chinese/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1899/world-cuisine/asian/chinese/appetizers/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/702/world-cuisine/asian/thai/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# New session at http://allrecipes.com/recipes/1894/world-cuisine/asian/thai/appetizers/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/17137/world-cuisine/asian/thai/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# New session at http://allrecipes.com/recipes/17825/world-cuisine/asian/thai/main-dishes/pad-thai/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1896/world-cuisine/asian/thai/main-dishes/chicken/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/15948/world-cuisine/asian/thai/main-dishes/curry/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1895/world-cuisine/asian/thai/main-dishes/pork/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/1897/world-cuisine/asian/thai/main-dishes/seafood/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1898/world-cuisine/asian/thai/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/699/world-cuisine/asian/japanese/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# New session at http://allrecipes.com/recipes/17490/world-cuisine/asian/japanese/appetizers/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/17491/world-cuisine/asian/japanese/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# New session at http://allrecipes.com/recipes/17498/world-cuisine/asian/japanese/main-dishes/sushi/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/17492/world-cuisine/asian/japanese/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/696/world-cuisine/asian/filipino/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# New session at http://allrecipes.com/recipes/17493/world-cuisine/asian/filipino/desserts/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/17494/world-cuisine/asian/filipino/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/17496/world-cuisine/asian/filipino/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/700/world-cuisine/asian/korean/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# New session at http://allrecipes.com/recipes/17833/world-cuisine/asian/korean/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/17835/world-cuisine/asian/korean/main-dishes/bulgogi/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/17834/world-cuisine/asian/korean/main-dishes/kalbi/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/17832/world-cuisine/asian/korean/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/16100/world-cuisine/asian/bangladeshi/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/15974/world-cuisine/asian/pakistani/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/698/world-cuisine/asian/indonesian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/701/world-cuisine/asian/malaysian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/703/world-cuisine/asian/vietnamese/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/16349/world-cuisine/asian/vietnamese/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/228/world-cuisine/australian-and-new-zealander/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# 	Page 25 provided
# 	Page 26 provided
# 	Page 27 provided
# 	Page 28 provided
# 	Page 29 provided
# New session at http://allrecipes.com/recipes/15040/world-cuisine/australian-and-new-zealander/occasions/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/733/world-cuisine/canadian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/17719/world-cuisine/canadian/allrecipes-allstars/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# New session at http://allrecipes.com/recipes/15041/world-cuisine/canadian/occasions/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# New session at http://allrecipes.com/recipes/16605/world-cuisine/canadian/occasions/canada-day/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/17596/world-cuisine/canadian/occasions/grey-cup/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# New session at http://allrecipes.com/recipes/16104/world-cuisine/canadian/quebec/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/1638/world-cuisine/canadian/toronto/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/16075/world-cuisine/canadian/vancouver/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# New session at http://allrecipes.com/recipes/231/world-cuisine/european/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# 	Page 25 provided
# 	Page 26 provided
# 	Page 27 provided
# 	Page 28 provided
# 	Page 29 provided
# 	Page 30 provided
# 	Page 31 provided
# 	Page 32 provided
# 	Page 33 provided
# 	Page 34 provided
# 	Page 35 provided
# 	Page 36 provided
# 	Page 37 provided
# 	Page 38 provided
# 	Page 39 provided
# 	Page 40 provided
# New session at http://allrecipes.com/recipes/718/world-cuisine/european/austrian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/719/world-cuisine/european/belgian/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/720/world-cuisine/european/dutch/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/712/world-cuisine/european/eastern-european/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# New session at http://allrecipes.com/recipes/713/world-cuisine/european/eastern-european/czech/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/714/world-cuisine/european/eastern-european/hungarian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/715/world-cuisine/european/eastern-european/polish/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# New session at http://allrecipes.com/recipes/716/world-cuisine/european/eastern-european/russian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# New session at http://allrecipes.com/recipes/721/world-cuisine/european/french/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# New session at http://allrecipes.com/recipes/1848/world-cuisine/european/french/appetizers/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/16126/world-cuisine/european/french/french-bread/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/1828/world-cuisine/european/french/desserts/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# New session at http://allrecipes.com/recipes/17138/world-cuisine/european/french/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# New session at http://allrecipes.com/recipes/1858/world-cuisine/european/french/main-dishes/chicken/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/1857/world-cuisine/european/french/main-dishes/pork/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1829/world-cuisine/european/french/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/722/world-cuisine/european/german/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# New session at http://allrecipes.com/recipes/731/world-cuisine/european/greek/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# New session at http://allrecipes.com/recipes/1885/world-cuisine/european/greek/appetizers/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/1888/world-cuisine/european/greek/desserts/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/17152/world-cuisine/european/greek/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# New session at http://allrecipes.com/recipes/1889/world-cuisine/european/greek/main-dishes/beef/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/16137/world-cuisine/european/greek/main-dishes/chicken/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/16136/world-cuisine/european/greek/main-dishes/seafood/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/1887/world-cuisine/european/greek/salads/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/1886/world-cuisine/european/greek/side-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/723/world-cuisine/european/italian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# New session at http://allrecipes.com/recipes/1789/world-cuisine/european/italian/authentic/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# New session at http://allrecipes.com/recipes/1793/world-cuisine/european/italian/appetizers/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# New session at http://allrecipes.com/recipes/1798/world-cuisine/european/italian/bread/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1791/world-cuisine/european/italian/desserts/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# New session at http://allrecipes.com/recipes/17551/world-cuisine/european/italian/drinks/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/16767/world-cuisine/european/italian/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# 	Page 25 provided
# 	Page 26 provided
# 	Page 27 provided
# 	Page 28 provided
# 	Page 29 provided
# 	Page 30 provided
# 	Page 31 provided
# 	Page 32 provided
# 	Page 33 provided
# 	Page 34 provided
# 	Page 35 provided
# 	Page 36 provided
# 	Page 37 provided
# 	Page 38 provided
# 	Page 39 provided
# 	Page 40 provided
# 	Page 41 provided
# 	Page 42 provided
# 	Page 43 provided
# 	Page 44 provided
# 	Page 45 provided
# 	Page 46 provided
# 	Page 47 provided
# 	Page 48 provided
# 	Page 49 provided
# 	Page 50 provided
# 	Page 51 provided
# 	Page 52 provided
# 	Page 53 provided
# 	Page 54 provided
# 	Page 55 provided
# 	Page 56 provided
# 	Page 57 provided
# 	Page 58 provided
# 	Page 59 provided
# 	Page 60 provided
# 	Page 61 provided
# 	Page 62 provided
# 	Page 63 provided
# 	Page 64 provided
# 	Page 65 provided
# New session at http://allrecipes.com/recipes/1796/world-cuisine/european/italian/main-dishes/chicken/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# New session at http://allrecipes.com/recipes/1360/world-cuisine/european/italian/main-dishes/pork/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# New session at http://allrecipes.com/recipes/1794/world-cuisine/european/italian/main-dishes/beef/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/1797/world-cuisine/european/italian/main-dishes/seafood/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# New session at http://allrecipes.com/recipes/1366/world-cuisine/european/italian/main-dishes/turkey/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/1800/world-cuisine/european/italian/salads/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# New session at http://allrecipes.com/recipes/1792/world-cuisine/european/italian/side-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# New session at http://allrecipes.com/recipes/1790/world-cuisine/european/italian/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# New session at http://allrecipes.com/recipes/724/world-cuisine/european/portuguese/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/725/world-cuisine/european/scandinavian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1892/world-cuisine/european/scandinavian/danish/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1893/world-cuisine/european/scandinavian/finnish/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/1891/world-cuisine/european/scandinavian/norwegian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1890/world-cuisine/european/scandinavian/swedish/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# New session at http://allrecipes.com/recipes/726/world-cuisine/european/spanish/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# New session at http://allrecipes.com/recipes/17846/world-cuisine/european/spanish/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/17849/world-cuisine/european/spanish/main-dishes/paella/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/17848/world-cuisine/european/spanish/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/17847/world-cuisine/european/spanish/appetizers/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/727/world-cuisine/european/swiss/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/704/world-cuisine/european/uk-and-ireland/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# New session at http://allrecipes.com/recipes/705/world-cuisine/european/uk-and-ireland/english/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# New session at http://allrecipes.com/recipes/706/world-cuisine/european/uk-and-ireland/irish/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# New session at http://allrecipes.com/recipes/707/world-cuisine/european/uk-and-ireland/scottish/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/14980/world-cuisine/european/uk-and-ireland/occasions/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# New session at http://allrecipes.com/recipes/14985/world-cuisine/european/uk-and-ireland/occasions/burns-night/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/14983/world-cuisine/european/uk-and-ireland/occasions/guy-fawkes-night/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/14984/world-cuisine/european/uk-and-ireland/occasions/stir-up-sunday/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/14982/world-cuisine/european/uk-and-ireland/occasions/hogmanay/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/14981/world-cuisine/european/uk-and-ireland/occasions/boxing-day/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/708/world-cuisine/european/uk-and-ireland/welsh/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/237/world-cuisine/latin-american/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# 	Page 25 provided
# 	Page 26 provided
# 	Page 27 provided
# 	Page 28 provided
# 	Page 29 provided
# 	Page 30 provided
# 	Page 31 provided
# 	Page 32 provided
# 	Page 33 provided
# 	Page 34 provided
# 	Page 35 provided
# 	Page 36 provided
# 	Page 37 provided
# 	Page 38 provided
# 	Page 39 provided
# 	Page 40 provided
# 	Page 41 provided
# 	Page 42 provided
# 	Page 43 provided
# 	Page 44 provided
# 	Page 45 provided
# 	Page 46 provided
# 	Page 47 provided
# 	Page 48 provided
# 	Page 49 provided
# 	Page 50 provided
# 	Page 51 provided
# New session at http://allrecipes.com/recipes/230/world-cuisine/latin-american/caribbean/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# New session at http://allrecipes.com/recipes/709/world-cuisine/latin-american/caribbean/cuban/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/710/world-cuisine/latin-american/caribbean/jamaican/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/711/world-cuisine/latin-american/caribbean/puerto-rican/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/728/world-cuisine/latin-american/mexican/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# 	Page 25 provided
# 	Page 26 provided
# 	Page 27 provided
# 	Page 28 provided
# 	Page 29 provided
# 	Page 30 provided
# 	Page 31 provided
# 	Page 32 provided
# 	Page 33 provided
# 	Page 34 provided
# 	Page 35 provided
# 	Page 36 provided
# 	Page 37 provided
# 	Page 38 provided
# 	Page 39 provided
# 	Page 40 provided
# 	Page 41 provided
# 	Page 42 provided
# 	Page 43 provided
# 	Page 44 provided
# 	Page 45 provided
# 	Page 46 provided
# 	Page 47 provided
# 	Page 48 provided
# 	Page 49 provided
# 	Page 50 provided
# 	Page 51 provided
# 	Page 52 provided
# 	Page 53 provided
# 	Page 54 provided
# 	Page 55 provided
# 	Page 56 provided
# 	Page 57 provided
# 	Page 58 provided
# New session at http://allrecipes.com/recipes/1470/world-cuisine/latin-american/mexican/authentic/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/1214/world-cuisine/latin-american/mexican/appetizers/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# New session at http://allrecipes.com/recipes/1906/world-cuisine/latin-american/mexican/appetizers/beef/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1908/world-cuisine/latin-american/mexican/appetizers/chicken/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/1525/world-cuisine/latin-american/mexican/bread/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1217/world-cuisine/latin-american/mexican/desserts/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# New session at http://allrecipes.com/recipes/15936/world-cuisine/latin-american/mexican/drinks/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# New session at http://allrecipes.com/recipes/17504/world-cuisine/latin-american/mexican/main-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# 	Page 15 provided
# 	Page 16 provided
# 	Page 17 provided
# 	Page 18 provided
# 	Page 19 provided
# 	Page 20 provided
# 	Page 21 provided
# 	Page 22 provided
# 	Page 23 provided
# 	Page 24 provided
# 	Page 25 provided
# 	Page 26 provided
# 	Page 27 provided
# 	Page 28 provided
# New session at http://allrecipes.com/recipes/1527/world-cuisine/latin-american/mexican/main-dishes/chicken/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# New session at http://allrecipes.com/recipes/1521/world-cuisine/latin-american/mexican/main-dishes/beef/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# 	Page 13 provided
# 	Page 14 provided
# New session at http://allrecipes.com/recipes/17499/world-cuisine/latin-american/mexican/main-dishes/casserole/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# New session at http://allrecipes.com/recipes/1218/world-cuisine/latin-american/mexican/main-dishes/enchiladas/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# New session at http://allrecipes.com/recipes/1515/world-cuisine/latin-american/mexican/main-dishes/enchiladas/beef/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/1514/world-cuisine/latin-american/mexican/main-dishes/enchiladas/chicken/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/1219/world-cuisine/latin-american/mexican/main-dishes/tacos/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# New session at http://allrecipes.com/recipes/17745/world-cuisine/latin-american/mexican/main-dishes/tacos/beef/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/17752/world-cuisine/latin-american/mexican/main-dishes/tacos/chicken/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/16562/world-cuisine/latin-american/mexican/main-dishes/tacos/fish/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/16081/world-cuisine/latin-american/mexican/main-dishes/pork/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# New session at http://allrecipes.com/recipes/1216/world-cuisine/latin-american/mexican/main-dishes/burritos/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/16085/world-cuisine/latin-american/mexican/main-dishes/chile-rellenos/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/1220/world-cuisine/latin-american/mexican/main-dishes/fajitas/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/1283/world-cuisine/latin-american/mexican/main-dishes/fajitas/chicken/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/16805/world-cuisine/latin-american/mexican/main-dishes/mexican-lasagna/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/16080/world-cuisine/latin-american/mexican/main-dishes/tamales/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/1905/world-cuisine/latin-american/mexican/main-dishes/quesadillas/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# New session at http://allrecipes.com/recipes/17513/world-cuisine/latin-american/mexican/salads/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# New session at http://allrecipes.com/recipes/1526/world-cuisine/latin-american/mexican/side-dishes/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/16076/world-cuisine/latin-american/mexican/side-dishes/beans/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/16082/world-cuisine/latin-american/mexican/side-dishes/rice/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1215/world-cuisine/latin-american/mexican/soups-and-stews/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# New session at http://allrecipes.com/recipes/1516/world-cuisine/latin-american/mexican/soups-and-stews/beef/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/1517/world-cuisine/latin-american/mexican/soups-and-stews/chicken/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/1520/world-cuisine/latin-american/mexican/soups-and-stews/chili/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1518/world-cuisine/latin-american/mexican/soups-and-stews/pork/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1519/world-cuisine/latin-american/mexican/soups-and-stews/vegetarian/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/730/world-cuisine/latin-american/south-american/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# 	Page 7 provided
# 	Page 8 provided
# 	Page 9 provided
# 	Page 10 provided
# 	Page 11 provided
# 	Page 12 provided
# New session at http://allrecipes.com/recipes/2432/world-cuisine/latin-american/south-american/argentinian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1278/world-cuisine/latin-american/south-american/brazilian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# 	Page 5 provided
# 	Page 6 provided
# New session at http://allrecipes.com/recipes/1277/world-cuisine/latin-american/south-american/chilean/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/14759/world-cuisine/latin-american/south-american/colombian/
# 	Page 1 provided
# 	Page 2 provided
# New session at http://allrecipes.com/recipes/2433/world-cuisine/latin-american/south-american/peruvian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/235/world-cuisine/middle-eastern/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/1826/world-cuisine/middle-eastern/israeli/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1824/world-cuisine/middle-eastern/lebanese/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 	Page 4 provided
# New session at http://allrecipes.com/recipes/15937/world-cuisine/middle-eastern/persian/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# New session at http://allrecipes.com/recipes/1825/world-cuisine/middle-eastern/turkish/
# 	Page 1 provided
# 	Page 2 provided
# 	Page 3 provided
# 1611

# %%
exportMD(metadata, metadataPath)
exportData(data, dataPath)

# %%
len(data)
# Out:
# 11001
