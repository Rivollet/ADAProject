# %% [markdown]
# # Create JSONs with aggregated data from database

# %% [markdown]
# Queries database and gets aggregated data (possible grouped before by country).
# Creates a single JSON that contains all this information.

# %%
# %load_ext autoreload
# %autoreload 2

from pymongo import MongoClient
import datetime
import numpy as np
import pandas as pd
import getpass
from aggregation_functions import * # get all functions used below to communicate with mongodb database
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Be sure you are connect on the **EPFL network** (connection at EPFL or via VPN)

# %% [markdown]
# Note on authentification:
# * Your username-password pair has read-only credentials
# * Use the admin user to insert, modify, or create indexes

# %%
database = 'ada-project'
user = input('MongoDB name: ') #maxmordig
password = getpass.getpass('MongoDB password: ')
# Out:
# MongoDB name: maxmordig
# MongoDB password: ········

# %%
# Mongo Client and authentification
client = MongoClient('www.cocotte-minute.ovh', 27017)
db = client[database]
db.authenticate(user, password)
collection = db['recipes']

# %%
# Number of recipes
serverMongoVersion = client.server_info()['version']
serverMongoVersion
# Out:
# '3.2.10'

# %% [markdown]
# # Example usage of this function

# %%
results = group_and_get_aggregate_of_field(collection, group_by_field_address='$ada-country', 
                                aggregate_field_address='$nutrition.calories.amount', 
                                group_by_field_output_name='country', 
                                aggregate_field_output_name='avgCalories', 
                                aggregationFunction = '$avg' 
                               )

df = pd.DataFrame.from_dict(results)
df = df.set_index(['country'])
df.head(3)
# Out:
#              avgCalories  nbRecipes
# country
# israeli       255.634929         24
# bangladeshi   355.954350         14
# colombian     374.666667         13

# %%
results = group_and_get_aggregate_of_field(collection, group_by_field_address='get_global_aggregation', 
                                aggregate_field_address='$nutrition.calories.amount', 
                                group_by_field_output_name='DummyColumn', 
                                aggregate_field_output_name='avgCalories', 
                                aggregationFunction = '$avg' 
                               )

df1 = pd.DataFrame.from_dict(results)
df1.head(3)
# Out:
#           DummyColumn  avgCalories  nbRecipes
# 0  Global aggregation   350.246799      16242

# %% [markdown]
# # Several Fields

# %% [markdown]
# We now suppose we are interested in several fields, e.g. 'avgCalories' etc. and the goal is to merge this information into a single dataframe.
#
# To first get an idea of what fields we have, we search for a simple recipe.

# %%
oneRecipe = collection.find_one({'recipeID':47564})
oneRecipe
# Out:
# {'_id': ObjectId('5825054ace06e50446084706'),
#  'adUnit': {'adKeys': [7,
#    79,
#    95,
#    125,
#    148,
#    150,
#    169,
#    173,
#    184,
#    201,
#    221,
#    235,
#    241,
#    242,
#    249,
#    254,
#    265,
#    608],
#   'adZone': 'recipes',
#   'contentProviderId': 451,
#   'networkCode': '3865',
#   'site': 'ar.ios.apps.allrecipes.recipes'},
#  'ada-city': [],
#  'ada-continent': ['asian'],
#  'ada-country': ['indian'],
#  'ada-region': [],
#  'ada-subcontinent': [],
#  'ada-tags': ['world-cuisine',
#   'asian',
#   'indian',
#   'main-dishes',
#   'curry',
#   'vegetarian'],
#  'cookMinutes': 45,
#  'description': 'This is a really easy and tasty Indian dish that is sure to stir up your taste buds. Delicious baingan bharta is ready to eat with pita bread, Indian naan, or rice.',
#  'directions': [{'displayValue': 'Preheat oven to 450 degrees F (230 degrees C).',
#    'ordinal': 1,
#    'videoTimestamp': 0},
#   {'displayValue': 'Place eggplant on a medium baking sheet. Bake 20 to 30 minutes in the preheated oven, until tender. Remove from heat, cool, peel, and chop.',
#    'ordinal': 2,
#    'videoTimestamp': 0},
#   {'displayValue': 'Heat oil in a medium saucepan over medium heat. Mix in cumin seeds and onion. Cook and stir until onion is tender.',
#    'ordinal': 3,
#    'videoTimestamp': 0},
#   {'displayValue': 'Mix ginger garlic paste, curry powder, and tomato into the saucepan, and cook about 1 minute. Stir in yogurt. Mix in eggplant and jalapeno pepper, and season with salt. Cover, and cook 10 minutes over high heat. Remove cover, reduce heat to low, and continue cooking about 5 minutes. Garnish with cilantro to serve.',
#    'ordinal': 4,
#    'videoTimestamp': 0}],
#  'footnotes': [{'ordinal': 100, 'text': 'Tip'},
#   {'ordinal': 101,
#    'text': 'Aluminum foil can be used to keep food moist, cook it evenly, and make clean-up easier.'}],
#  'ingredients': [{'displayType': 'Normal',
#    'displayValue': '1 large eggplant',
#    'grams': 548.0,
#    'ingredientID': 4339},
#   {'displayType': 'Normal',
#    'displayValue': '2 tablespoons vegetable oil',
#    'grams': 27.25,
#    'ingredientID': 6305},
#   {'displayType': 'Normal',
#    'displayValue': '1 teaspoon cumin seeds',
#    'grams': 2.1,
#    'ingredientID': 16390},
#   {'displayType': 'Normal',
#    'displayValue': '1 medium onion, thinly sliced',
#    'grams': 110.0,
#    'ingredientID': 4397},
#   {'displayType': 'Normal',
#    'displayValue': '1 tablespoon ginger garlic paste',
#    'grams': 16.5,
#    'ingredientID': 20678},
#   {'displayType': 'Normal',
#    'displayValue': '1 tablespoon curry powder',
#    'grams': 6.3,
#    'ingredientID': 16391},
#   {'displayType': 'Normal',
#    'displayValue': '1 tomato, diced',
#    'grams': 123.0,
#    'ingredientID': 4572},
#   {'displayType': 'Normal',
#    'displayValue': '1/2 cup plain yogurt',
#    'grams': 122.5,
#    'ingredientID': 16158},
#   {'displayType': 'Normal',
#    'displayValue': '1 fresh jalapeno chile pepper, finely chopped',
#    'grams': 14.0,
#    'ingredientID': 3725},
#   {'displayType': 'Normal',
#    'displayValue': '1 teaspoon salt',
#    'grams': 6.0,
#    'ingredientID': 16421},
#   {'displayType': 'Normal',
#    'displayValue': '1/4 bunch cilantro, finely chopped',
#    'grams': 14.0,
#    'ingredientID': 3717}],
#  'isSponsored': False,
#  'links': {'recipeUrl': {'href': 'http://allrecipes.com/recipe/47564/baingan-bharta-eggplant-curry/'},
#   'self': {'href': 'https://apps.allrecipes.com/v1/recipes/47564'}},
#  'nutrition': {'calcium': {'amount': 93.245,
#    'displayValue': '93',
#    'hasCompleteData': False,
#    'name': 'Calcium',
#    'percentDailyValue': '12',
#    'unit': 'mg'},
#   'calories': {'amount': 146.1237,
#    'displayValue': '146',
#    'hasCompleteData': True,
#    'name': 'Calories',
#    'percentDailyValue': '7',
#    'unit': 'kcal'},
#   'caloriesFromFat': {'amount': 72.09731,
#    'displayValue': '72',
#    'hasCompleteData': True,
#    'name': 'Calories from Fat',
#    'percentDailyValue': '-',
#    'unit': 'kcal'},
#   'carbohydrates': {'amount': 15.22197,
#    'displayValue': '15.2',
#    'hasCompleteData': True,
#    'name': 'Carbohydrates',
#    'percentDailyValue': '5',
#    'unit': 'g'},
#   'cholesterol': {'amount': 1.8375,
#    'displayValue': '2',
#    'hasCompleteData': False,
#    'name': 'Cholesterol',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'fat': {'amount': 8.010813,
#    'displayValue': '8',
#    'hasCompleteData': True,
#    'name': 'Fat',
#    'percentDailyValue': '12',
#    'unit': 'g'},
#   'fiber': {'amount': 6.222385,
#    'displayValue': '6.2',
#    'hasCompleteData': False,
#    'name': 'Dietary Fiber',
#    'percentDailyValue': '25',
#    'unit': 'g'},
#   'folate': {'amount': 49.63925,
#    'displayValue': '50',
#    'hasCompleteData': False,
#    'name': 'Folate',
#    'percentDailyValue': '28',
#    'unit': 'mcg'},
#   'iron': {'amount': 1.403314,
#    'displayValue': '1',
#    'hasCompleteData': False,
#    'name': 'Iron',
#    'percentDailyValue': '14',
#    'unit': 'mg'},
#   'magnesium': {'amount': 38.03075,
#    'displayValue': '38',
#    'hasCompleteData': False,
#    'name': 'Magnesium',
#    'percentDailyValue': '14',
#    'unit': 'mg'},
#   'niacin': {'amount': 1.744597,
#    'displayValue': '2',
#    'hasCompleteData': False,
#    'name': 'Niacin Equivalents',
#    'percentDailyValue': '13',
#    'unit': 'mg'},
#   'potassium': {'amount': 559.3593,
#    'displayValue': '559',
#    'hasCompleteData': False,
#    'name': 'Potassium',
#    'percentDailyValue': '16',
#    'unit': 'mg'},
#   'protein': {'amount': 3.97931,
#    'displayValue': '4',
#    'hasCompleteData': True,
#    'name': 'Protein',
#    'percentDailyValue': '8',
#    'unit': 'g'},
#   'saturatedFat': {'amount': 1.485098,
#    'displayValue': '1.5',
#    'hasCompleteData': True,
#    'name': 'Saturated Fat',
#    'percentDailyValue': '7',
#    'unit': 'g'},
#   'sodium': {'amount': 739.406,
#    'displayValue': '739',
#    'hasCompleteData': True,
#    'name': 'Sodium',
#    'percentDailyValue': '30',
#    'unit': 'mg'},
#   'sugars': {'amount': 7.522098,
#    'displayValue': '7.5',
#    'hasCompleteData': True,
#    'name': 'Sugars',
#    'percentDailyValue': '0',
#    'unit': 'g'},
#   'thiamin': {'amount': 0.1289342,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Thiamin',
#    'percentDailyValue': '13',
#    'unit': 'mg'},
#   'vitaminA': {'amount': 595.6483,
#    'displayValue': '596',
#    'hasCompleteData': False,
#    'name': 'Vitamin A - IU',
#    'percentDailyValue': '12',
#    'unit': 'IU'},
#   'vitaminB6': {'amount': 0.2310775,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Vitamin B6',
#    'percentDailyValue': '14',
#    'unit': 'mg'},
#   'vitaminC': {'amount': 11.91473,
#    'displayValue': '12',
#    'hasCompleteData': False,
#    'name': 'Vitamin C',
#    'percentDailyValue': '20',
#    'unit': 'mg'}},
#  'photo': {'description': '',
#   'itemType': 'Photo',
#   'photoDetailUrl': 'http://m.allrecipes.com/photos/14597',
#   'photoID': 14597,
#   'rawItemType': 10,
#   'recipeTitle': None,
#   'title': '',
#   'urls': [{'height': 50,
#     'url': 'http://images.media-allrecipes.com/userphotos/50x50/14597.jpg',
#     'width': 50},
#    {'height': 110,
#     'url': 'http://images.media-allrecipes.com/userphotos/110x110/14597.jpg',
#     'width': 110},
#    {'height': 140,
#     'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/01/45/14597.jpg',
#     'width': 140},
#    {'height': 250,
#     'url': 'http://images.media-allrecipes.com/userphotos/250x250/14597.jpg',
#     'width': 250}]},
#  'prepMinutes': 15,
#  'ratingAverage': 4.305987,
#  'ratingCount': 451,
#  'readyInMinutes': 60,
#  'recipeID': 47564,
#  'reviewCount': 309,
#  'servings': 4,
#  'similarRecipes': {'links': {'self': {'href': 'https://apps.allrecipes.com/v1/recipes/47564'}},
#   'metaData': {'page': 1, 'pagesize': 20, 'totalCount': 20},
#   'recipes': [{'description': 'Make a big batch of eggplant Parmesan in your slow cooker and dinner will be waiting when you get home. No need to heat up your kitchen baking in an oven.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/223360'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/eggplant-parmesan-for-the-slow-cooker/'}},
#     'madeCount': 86,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/3294074',
#      'photoID': 3294074,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/3294074.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/3294074.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/29/40/3294074.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/3294074.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.39,
#     'ratingCount': 64,
#     'rawItemType': 1,
#     'recipeID': 223360,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 48,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 19,
#      'followersCount': 12,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'jboettcher2',
#      'personalRecipeSharedCount': 1,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/556955',
#       'photoID': 556955,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/556955.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/556955.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/55/69/556955.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/556955.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/5752296/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 5752296},
#     'title': 'Eggplant Parmesan For the Slow Cooker',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'These breaded and baked eggplant sandwiches are the perfect make-ahead appetizer for your next potluck.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/231010'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/chef-johns-baked-eggplant-sandwiches/'}},
#     'madeCount': 34,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/3719268',
#      'photoID': 3719268,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/3719268.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/3719268.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/71/92/3719268.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/3719268.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.73,
#     'ratingCount': 30,
#     'rawItemType': 1,
#     'recipeID': 231010,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 22,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 363,
#      'followersCount': 38210,
#      'followingCount': 194,
#      'handle': 'foodwisheswithchefjohn',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 309,
#      'name': 'Chef John',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/2267470',
#       'photoID': 2267470,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/2267470.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/2267470.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/02/26/74/2267470.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/2267470.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/foodwisheswithchefjohn/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 307,
#      'rawItemType': 11,
#      'reciepesCount': 913,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 8601924},
#     'title': "Chef John's Baked Eggplant Sandwiches",
#     'type': 'recipes',
#     'videoID': 3083},
#    {'description': "This is a rich and hearty lentil curry, great as a main meal rather than as a side dish like the more traditional Indian dhal. Don't let the ingredient list faze you, this really is an easy dish to make. This dish is great served with basmati rice.",
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/16641'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/red-lentil-curry/'}},
#     'madeCount': 1173,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/490284',
#      'photoID': 490284,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/490284.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/490284.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/49/02/490284.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/490284.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.5,
#     'ratingCount': 1121,
#     'rawItemType': 1,
#     'recipeID': 16641,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 789,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': None,
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Emma Maher',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 0,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 0},
#     'title': 'Red Lentil Curry',
#     'type': 'recipes',
#     'videoID': 3209},
#    {'description': "This is a home-style South Indian shrimp curry recipe from my husband's family. It is simple and quick to make. It contains no coconut so is not sweet, just mostly juicy and as hot as you like it. Serve with basmati rice or an Indian flatbread.",
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/93597'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/authentic-and-easy-shrimp-curry/'}},
#     'madeCount': 105,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/269404',
#      'photoID': 269404,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/269404.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/269404.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/26/94/269404.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/269404.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.65,
#     'ratingCount': 104,
#     'rawItemType': 1,
#     'recipeID': 93597,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 81,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 27,
#      'followersCount': 3,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 35,
#      'name': 'RK',
#      'personalRecipeSharedCount': 6,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/1119514/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 36,
#      'rawItemType': 11,
#      'reciepesCount': 5,
#      'region': None,
#      'reviewsCount': 36,
#      'userID': 1119514},
#     'title': 'Authentic and Easy Shrimp Curry',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'A side dish, salad, or relish, caponata with eggplant, garlic, tomatoes, herb and spices is delicious on crusty French bread.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/254694'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/ruths-eggplant-caponata/'}},
#     'madeCount': 4,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/3797880',
#      'photoID': 3797880,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/3797880.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/3797880.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/79/78/3797880.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/3797880.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.0,
#     'ratingCount': 6,
#     'rawItemType': 1,
#     'recipeID': 254694,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 6,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 5,
#      'followersCount': 4,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'RuthE',
#      'personalRecipeSharedCount': 5,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/11418461/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 22,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 11418461},
#     'title': "Ruth's Eggplant Caponata",
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Eggplant is stuffed with sauteed eggplant, onion, peppers and bread crumbs, then topped off with some feta cheese and baked. I named it after the long summer nights I spent with my family on the balcony eating this tasty recipe, because at this season in Greece we have plenty of eggplants and cook them in various ways.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/31818'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/summer-nights-eggplants/'}},
#     'madeCount': 91,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/2366',
#      'photoID': 2366,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/2366.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/2366.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/00/23/2366.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/2366.jpg',
#        'width': 250}]},
#     'ratingAverage': 3.92,
#     'ratingCount': 102,
#     'rawItemType': 1,
#     'recipeID': 31818,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 85,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'LIOTAKI',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/208718/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 208718},
#     'title': 'Summer Nights Eggplants',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': "Wonderful directions for preparing eggplant if you've never done it before. The eggplant is layered in a large pan with marinara sauce, mozzarella, ricotta and Parmesan cheese. This it 's baked until the cheese topping is golden.",
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/13981'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/eggplant-parmesan-i/'}},
#     'madeCount': 468,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/235061',
#      'photoID': 235061,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/235061.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/235061.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/23/50/235061.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/235061.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.37,
#     'ratingCount': 495,
#     'rawItemType': 1,
#     'recipeID': 13981,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 360,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': None,
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Karen',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 0,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 0},
#     'title': 'Eggplant Parmesan I',
#     'type': 'recipes',
#     'videoID': 1212},
#    {'description': 'Coconut milk adds creaminess to this vegan dish, while enhancing the spicier notes.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/254692'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/crazy-creamy-chickpea-curry/'}},
#     'madeCount': 7,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/3935276',
#      'photoID': 3935276,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/3935276.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/3935276.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/93/52/3935276.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/3935276.jpg',
#        'width': 250}]},
#     'ratingAverage': 5.0,
#     'ratingCount': 7,
#     'rawItemType': 1,
#     'recipeID': 254692,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 5,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 84,
#      'followersCount': 8,
#      'followingCount': 1,
#      'handle': 'postpunkkitchen',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'isachandra',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/3933577',
#       'photoID': 3933577,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/3933577.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/3933577.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/93/35/3933577.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/3933577.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/postpunkkitchen/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 6,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 7662230},
#     'title': 'Crazy Creamy Chickpea Curry',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Spicy baked white fish fillets are dressed up with a ginger, garlic, onion, and cashew puree in this Bengali recipe.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/213238'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/indian-fish-curry/'}},
#     'madeCount': 176,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/779645',
#      'photoID': 779645,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/779645.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/779645.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/77/96/779645.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/779645.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.57,
#     'ratingCount': 148,
#     'rawItemType': 1,
#     'recipeID': 213238,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 115,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 184,
#      'followersCount': 8,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 55,
#      'name': 'Mantu',
#      'personalRecipeSharedCount': 1,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/1906197/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 55,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 49,
#      'userID': 1906197},
#     'title': 'Indian Fish Curry',
#     'type': 'recipes',
#     'videoID': 3166},
#    {'description': "An easy curry of turkey and garbanzo beans simmers with coconut milk and bottled tomato-based sweet chili sauce to make a savory-sweet dish that's ready in less than an hour.",
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/216111'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/sweet-and-spicy-curry-with-chickpeas/'}},
#     'madeCount': 39,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/499216',
#      'photoID': 499216,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/499216.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/499216.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/49/92/499216.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/499216.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.5,
#     'ratingCount': 42,
#     'rawItemType': 1,
#     'recipeID': 216111,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 32,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 298,
#      'followersCount': 2,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 4,
#      'name': 'Marcia',
#      'personalRecipeSharedCount': 3,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/343084',
#       'photoID': 343084,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/343084.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/343084.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/34/30/343084.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/343084.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/4372543/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 3,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 3,
#      'userID': 4372543},
#     'title': 'Sweet and Spicy Curry with Chickpeas',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This is a traditional North Indian (Punjabi) Bhurtha made with eggplant and tomato, and seasoned with cumin, turmeric garlic and ginger. Serve with fresh roti or naan.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/80686'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/indian-eggplant---bhurtha/'}},
#     'madeCount': 183,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/549170',
#      'photoID': 549170,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/549170.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/549170.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/54/91/549170.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/549170.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.47,
#     'ratingCount': 179,
#     'rawItemType': 1,
#     'recipeID': 80686,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 134,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 159,
#      'followersCount': 23,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 18,
#      'name': 'simmig',
#      'personalRecipeSharedCount': 2,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/562573',
#       'photoID': 562573,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/562573.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/562573.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/56/25/562573.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/562573.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/2474/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 18,
#      'rawItemType': 11,
#      'reciepesCount': 7,
#      'region': None,
#      'reviewsCount': 18,
#      'userID': 2474},
#     'title': 'Indian Eggplant - Bhurtha',
#     'type': 'recipes',
#     'videoID': 2888},
#    {'description': 'Spicy potatoes, tomatoes and onions with an Indian kick! This is super spicy so be aware!',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/14035'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/aloo-phujia/'}},
#     'madeCount': 338,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/695663',
#      'photoID': 695663,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/695663.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/695663.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/69/56/695663.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/695663.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.4,
#     'ratingCount': 421,
#     'rawItemType': 1,
#     'recipeID': 14035,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 289,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 46,
#      'followersCount': 649,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 82,
#      'name': 'CHRISTYJ',
#      'personalRecipeSharedCount': 13,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/features/18.gif',
#         'width': 140}]},
#      'profileUrl': '/cook/63733/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 83,
#      'rawItemType': 11,
#      'reciepesCount': 80,
#      'region': None,
#      'reviewsCount': 83,
#      'userID': 63733},
#     'title': 'Aloo Phujia',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This Indian dish combines fresh spinach and ricotta in a creamy curry. Use paneer if you can find it! It is absolutely wonderful with basmati rice or naan (Indian flat bread). The key is in the spices, which you can find at an Indian grocery.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/20312'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/absolutely-perfect-palak-paneer/'}},
#     'madeCount': 194,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/38052',
#      'photoID': 38052,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/38052.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/38052.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/03/80/38052.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/38052.jpg',
#        'width': 250}]},
#     'ratingAverage': 3.91,
#     'ratingCount': 223,
#     'rawItemType': 1,
#     'recipeID': 20312,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 173,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 13,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 2,
#      'name': 'MCFALONE',
#      'personalRecipeSharedCount': 1,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/27039/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 2,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 2,
#      'userID': 27039},
#     'title': 'Absolutely Perfect Palak Paneer',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Cheese, bread crumbs, parsley, garlic and onion are mixed in with the cooked eggplant and formed into patties. A few minutes in hot oil and you have your croquettes.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/14019'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/eggplant-croquettes/'}},
#     'madeCount': 438,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/506443',
#      'photoID': 506443,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/506443.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/506443.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/50/64/506443.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/506443.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.37,
#     'ratingCount': 481,
#     'rawItemType': 1,
#     'recipeID': 14019,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 353,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': None,
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Kelli Charnes',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 0,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 0},
#     'title': 'Eggplant Croquettes',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Eggplant cubes are stir-fried until browned, then simmered in a spicy Asian-inspired sauce with onion and garlic until meltingly tender. ',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/215026'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/spicy-eggplant/'}},
#     'madeCount': 241,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/666476',
#      'photoID': 666476,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/666476.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/666476.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/66/64/666476.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/666476.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.59,
#     'ratingCount': 174,
#     'rawItemType': 1,
#     'recipeID': 215026,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 131,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 60,
#      'followersCount': 4,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 10,
#      'name': 'venymae',
#      'personalRecipeSharedCount': 6,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/429144',
#       'photoID': 429144,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/429144.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/429144.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/42/91/429144.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/429144.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/4809716/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 12,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 11,
#      'userID': 4809716},
#     'title': 'Spicy Eggplant',
#     'type': 'recipes',
#     'videoID': 0},
# ...
#      'profileUrl': '/cook/2282459/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 2282459},
#     'title': 'Tofu Vindaloo',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': "Eggplant is sauteed, then coated in a spicy sweet sauce. It is simple and delicious! I'm sure you'll enjoy this!",
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/52925'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/hot-and-sour-chinese-eggplant/'}},
#     'madeCount': 275,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/798089',
#      'photoID': 798089,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/798089.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/798089.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/79/80/798089.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/798089.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.43,
#     'ratingCount': 293,
#     'rawItemType': 1,
#     'recipeID': 52925,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 220,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': None,
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Bonnie',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 0,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 0},
#     'title': 'Hot and Sour Chinese Eggplant',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Smothered in sweet and spicy sauce, this Chinese eggplant dish is sure to please even the pickiest eater.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/201964'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/eggplant-with-garlic-sauce/'}},
#     'madeCount': 275,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/618365',
#      'photoID': 618365,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/618365.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/618365.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/61/83/618365.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/618365.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.4,
#     'ratingCount': 183,
#     'rawItemType': 1,
#     'recipeID': 201964,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 143,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 188,
#      'followersCount': 2,
#      'followingCount': 17,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 52,
#      'name': 'Whats that Burning smell?',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/103243',
#       'photoID': 103243,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/103243.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/103243.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/10/32/103243.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/103243.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/2719692/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 53,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 45,
#      'userID': 2719692},
#     'title': 'Eggplant with Garlic Sauce',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Thinly sliced eggplant is lightly fried, then stuffed with a spinach and cheese mixture and baked with pasta sauce and mozzarella cheese.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/20088'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/awesome-eggplant-rollatine/'}},
#     'madeCount': 123,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/456135',
#      'photoID': 456135,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/456135.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/456135.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/45/61/456135.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/456135.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.38,
#     'ratingCount': 128,
#     'rawItemType': 1,
#     'recipeID': 20088,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 102,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 6,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 5,
#      'name': 'DEBNJAMES',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/126229/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 5,
#      'rawItemType': 11,
#      'reciepesCount': 17,
#      'region': None,
#      'reviewsCount': 4,
#      'userID': 126229},
#     'title': 'Awesome Eggplant Rollatine',
#     'type': 'recipes',
#     'videoID': 0}]},
#  'sourceID': 461,
#  'submitter': {'brandedSourceID': 0,
#   'city': None,
#   'country': None,
#   'favoritesCount': 0,
#   'followersCount': 0,
#   'followingCount': 0,
#   'handle': None,
#   'isPro': False,
#   'itemType': 'Cook',
#   'madeRecipesCount': 0,
#   'name': 'Yakuta',
#   'personalRecipeSharedCount': 0,
#   'photo': {'description': None,
#    'itemType': 'Photo',
#    'photoDetailUrl': None,
#    'rawItemType': 10,
#    'recipeTitle': None,
#    'title': None,
#    'urls': [{'height': 50,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#      'width': 50},
#     {'height': 110,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#      'width': 110},
#     {'height': 140,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#      'width': 140},
#     {'height': 250,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#      'width': 250}]},
#   'profileUrl': '',
#   'promotedBrandPixelTrackingUrl': None,
#   'ratingsCount': 0,
#   'rawItemType': 11,
#   'reciepesCount': 0,
#   'region': None,
#   'reviewsCount': 0,
#   'userID': 0},
#  'title': 'Baingan Bharta (Eggplant Curry)',
#  'topReviews': [{'dateLastModified': '2009-03-11T13:33:32.31',
#    'helpfulCount': 361,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/47564/reviews/1815671/increment-helpful-count'}},
#    'rating': 4,
#    'rawItemType': 9,
#    'reviewID': 1815671,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 21,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': False,
#     'itemType': 'Cook',
#     'madeRecipesCount': 15,
#     'name': 'SUSHANK',
#     'personalRecipeSharedCount': 0,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#        'width': 250}]},
#     'profileUrl': '/cook/844246/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 15,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 13,
#     'userID': 844246},
#    'text': "The recipe is almost authentic - i say almost because Indians use garam masala and not curry powder. I don't add yogurt to my baingan bharta, but adding it isn't a sin, i wouldn't heat the dish after adding yogurt. Also, the eggplant is usually fire roasted and the smokey flavor is just outstanding. Also a small teaspoon of lemon juice in the end brings all the flavors out."},
#   {'dateLastModified': '2008-01-21T16:56:31.387',
#    'helpfulCount': 278,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/47564/reviews/1254574/increment-helpful-count'}},
#    'rating': 5,
#    'rawItemType': 9,
#    'reviewID': 1254574,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 109,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': False,
#     'itemType': 'Cook',
#     'madeRecipesCount': 25,
#     'name': 'Shmoopy',
#     'personalRecipeSharedCount': 1,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#        'width': 250}]},
#     'profileUrl': '/cook/747353/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 25,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 25,
#     'userID': 747353},
#    'text': 'great recipe. I am second generation Indian and this is one of my favorite dishes. I made the eggplant the day before just to save time; I cut it in half lengthwise, sprayed the cut side with Pam, and then baked it on a foil lined cookie sheet, cut side down. I baked it for 20 minutes or so and it was so tender that I just scraped it out of the skin with a spoon. I used a can of plum tomatoes instead of a tomato, and cut the tomatoes into a small dice. I saved the liquid and added it to the dish right before I started to simmer it. I also added about a cup of frozen baby peas at the same time as the eggplant. Used ginger paste and minced garlic. Great recipe.'},
#   {'dateLastModified': '2006-05-02T11:08:08.403',
#    'helpfulCount': 129,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/47564/reviews/702661/increment-helpful-count'}},
#    'rating': 5,
#    'rawItemType': 9,
#    'reviewID': 702661,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 4,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': False,
#     'itemType': 'Cook',
#     'madeRecipesCount': 5,
#     'name': 'shiitakehappens',
#     'personalRecipeSharedCount': 4,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#        'width': 250}]},
#     'profileUrl': '/cook/816923/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 5,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 5,
#     'userID': 816923},
#    'text': "This recipe is terrific- I'd give it 6 stars if I could!  This is my new favorite way to use eggplant- I love the combination of veggies. I made it as a side with chicken curry and spinach paneer (frozen entree)and rice- the eggplant stole the show!  I used a medium eggplant- didn't bother peeling, just scooped out the cooked inards and chopped them up with a spoon.  I added 3/4 jalapeno in with the onion, thinking otherwise it would be too spicy, but it was not.  Thought yogurt might separate when cooked so aggressively, but it did not!  I didn't have ginger-garlic paste, just added a little fresh of each.  Easy and healthy!  Serve to all of your vegetarian friends!"}],
#  'type': 'recipes',
#  'video': None}

# %%
showFields(oneRecipe)
# Out:
# > video: None
# > reviewCount: 309
# > readyInMinutes: 60
# > directions: [{'ordinal': 1, 'vid...
# > ada-city: []
# > footnotes: [{'ordinal': 100, 't...
# > similarRecipes
# > ->-recipes: [{'sourceID': 461, '...
# > ->-links
# > ->-->-self
# > ->-->-->-href: https://apps.allreci...
# > ->-metaData
# > ->-->-page: 1
# > ->-->-totalCount: 20
# > ->-->-pagesize: 20
# > submitter
# > ->-favoritesCount: 0
# > ->-followersCount: 0
# > ->-ratingsCount: 0
# > ->-handle: None
# > ->-region: None
# > ->-itemType: Cook
# > ->-promotedBrandPixelTrackingUrl: None
# > ->-name: Yakuta
# > ->-madeRecipesCount: 0
# > ->-country: None
# > ->-city: None
# > ->-userID: 0
# > ->-photo
# > ->-->-photoDetailUrl: None
# > ->-->-rawItemType: 10
# > ->-->-title: None
# > ->-->-itemType: Photo
# > ->-->-recipeTitle: None
# > ->-->-description: None
# > ->-->-urls: [{'height': 50, 'wid...
# > ->-isPro: False
# > ->-reciepesCount: 0
# > ->-profileUrl:
# > ->-followingCount: 0
# > ->-reviewsCount: 0
# > ->-rawItemType: 11
# > ->-brandedSourceID: 0
# > ->-personalRecipeSharedCount: 0
# > ada-subcontinent: []
# > ada-region: []
# > isSponsored: False
# > ratingAverage: 4.305987
# > topReviews: [{'links': {'increme...
# > ingredients: [{'grams': 548.0, 'i...
# > links
# > ->-self
# > ->-->-href: https://apps.allreci...
# > ->-recipeUrl
# > ->-->-href: http://allrecipes.co...
# > type: recipes
# > cookMinutes: 45
# > sourceID: 461
# > ratingCount: 451
# > photo
# > ->-photoDetailUrl: http://m.allrecipes....
# > ->-rawItemType: 10
# > ->-title:
# > ->-itemType: Photo
# > ->-recipeTitle: None
# > ->-description:
# > ->-urls: [{'height': 50, 'wid...
# > ->-photoID: 14597
# > title: Baingan Bharta (Eggp...
# > description: This is a really eas...
# > ada-country: ['indian']
# > ada-tags: ['world-cuisine', 'a...
# > servings: 4
# > recipeID: 47564
# > prepMinutes: 15
# > _id: 5825054ace06e5044608...
# > nutrition
# > ->-potassium
# > ->-->-displayValue: 559
# > ->-->-percentDailyValue: 16
# > ->-->-hasCompleteData: False
# > ->-->-amount: 559.3593
# > ->-->-unit: mg
# > ->-->-name: Potassium
# > ->-saturatedFat
# > ->-->-displayValue: 1.5
# > ->-->-percentDailyValue: 7
# > ->-->-hasCompleteData: True
# > ->-->-amount: 1.485098
# > ->-->-unit: g
# > ->-->-name: Saturated Fat
# > ->-sugars
# > ->-->-displayValue: 7.5
# > ->-->-percentDailyValue: 0
# > ->-->-hasCompleteData: True
# > ->-->-amount: 7.522098
# > ->-->-unit: g
# > ->-->-name: Sugars
# > ->-cholesterol
# > ->-->-displayValue: 2
# > ->-->-percentDailyValue: < 1
# > ->-->-hasCompleteData: False
# > ->-->-amount: 1.8375
# > ->-->-unit: mg
# > ->-->-name: Cholesterol
# > ->-niacin
# > ->-->-displayValue: 2
# > ->-->-percentDailyValue: 13
# > ->-->-hasCompleteData: False
# > ->-->-amount: 1.744597
# > ->-->-unit: mg
# > ->-->-name: Niacin Equivalents
# > ->-fat
# > ->-->-displayValue: 8
# > ->-->-percentDailyValue: 12
# > ->-->-hasCompleteData: True
# > ->-->-amount: 8.010813
# > ->-->-unit: g
# > ->-->-name: Fat
# > ->-sodium
# > ->-->-displayValue: 739
# > ->-->-percentDailyValue: 30
# > ->-->-hasCompleteData: True
# > ->-->-amount: 739.406
# > ->-->-unit: mg
# > ->-->-name: Sodium
# > ->-fiber
# > ->-->-displayValue: 6.2
# > ->-->-percentDailyValue: 25
# > ->-->-hasCompleteData: False
# > ->-->-amount: 6.222385
# > ->-->-unit: g
# > ->-->-name: Dietary Fiber
# > ->-vitaminB6
# > ->-->-displayValue: < 1
# > ->-->-percentDailyValue: 14
# > ->-->-hasCompleteData: False
# > ->-->-amount: 0.2310775
# > ->-->-unit: mg
# > ->-->-name: Vitamin B6
# > ->-calcium
# > ->-->-displayValue: 93
# > ->-->-percentDailyValue: 12
# > ->-->-hasCompleteData: False
# > ->-->-amount: 93.245
# > ->-->-unit: mg
# > ->-->-name: Calcium
# > ->-iron
# > ->-->-displayValue: 1
# > ->-->-percentDailyValue: 14
# > ->-->-hasCompleteData: False
# > ->-->-amount: 1.403314
# > ->-->-unit: mg
# > ->-->-name: Iron
# > ->-magnesium
# > ->-->-displayValue: 38
# > ->-->-percentDailyValue: 14
# > ->-->-hasCompleteData: False
# > ->-->-amount: 38.03075
# > ->-->-unit: mg
# > ->-->-name: Magnesium
# > ->-protein
# > ->-->-displayValue: 4
# > ->-->-percentDailyValue: 8
# > ->-->-hasCompleteData: True
# > ->-->-amount: 3.97931
# > ->-->-unit: g
# > ->-->-name: Protein
# > ->-folate
# > ->-->-displayValue: 50
# > ->-->-percentDailyValue: 28
# > ->-->-hasCompleteData: False
# > ->-->-amount: 49.63925
# > ->-->-unit: mcg
# > ->-->-name: Folate
# > ->-vitaminC
# > ->-->-displayValue: 12
# > ->-->-percentDailyValue: 20
# > ->-->-hasCompleteData: False
# > ->-->-amount: 11.91473
# > ->-->-unit: mg
# > ->-->-name: Vitamin C
# > ->-calories
# > ->-->-displayValue: 146
# > ->-->-percentDailyValue: 7
# > ->-->-hasCompleteData: True
# > ->-->-amount: 146.1237
# > ->-->-unit: kcal
# > ->-->-name: Calories
# > ->-vitaminA
# > ->-->-displayValue: 596
# > ->-->-percentDailyValue: 12
# > ->-->-hasCompleteData: False
# > ->-->-amount: 595.6483
# > ->-->-unit: IU
# > ->-->-name: Vitamin A - IU
# > ->-thiamin
# > ->-->-displayValue: < 1
# > ->-->-percentDailyValue: 13
# > ->-->-hasCompleteData: False
# > ->-->-amount: 0.1289342
# > ->-->-unit: mg
# > ->-->-name: Thiamin
# > ->-carbohydrates
# > ->-->-displayValue: 15.2
# > ->-->-percentDailyValue: 5
# > ->-->-hasCompleteData: True
# > ->-->-amount: 15.22197
# > ->-->-unit: g
# > ->-->-name: Carbohydrates
# > ->-caloriesFromFat
# > ->-->-displayValue: 72
# > ->-->-percentDailyValue: -
# > ->-->-hasCompleteData: True
# > ->-->-amount: 72.09731
# > ->-->-unit: kcal
# > ->-->-name: Calories from Fat
# > ada-continent: ['asian']
# > adUnit
# > ->-adZone: recipes
# > ->-adKeys: [7, 79, 95, 125, 148...
# > ->-site: ar.ios.apps.allrecip...
# > ->-networkCode: 3865
# > ->-contentProviderId: 451

# %%
# contains all parameters to pass to the aggregation function

# group bys
groupBysToQuery = [
    {
        # get global average
        'group_by_field_address': 'get_global_aggregation',
        'group_by_field_output_name': 'DummyColumn' # ignored,
    },
    {
        'group_by_field_address': '$ada-city',
        'group_by_field_output_name': 'city', # as it appears in dataframe
    },
]

# keep in sync with above groupBysToQuery
dataframeNames = ['global', 'per_city']

# what to aggregate for
fieldArgumentsToQuery = [
    {
        'aggregate_field_address': '$nutrition.calories.amount', 
        'aggregate_field_output_name': 'avg_calories', 
        'aggregationFunction': '$avg' 
    },
    {
        'aggregate_field_address': '$nutrition.vitaminA.amount', 
        'aggregate_field_output_name': 'total_vitaminA_Intake', 
        'aggregationFunction': '$sum' 
    },
]

allDfs = getAllDataframes(collection, groupBysToQuery, fieldArgumentsToQuery, dataframeNames)
# Out:
# Query 1/4 with arguments: {'aggregate_field_address': '$nutrition.calories.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_calories', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 2/4 with arguments: {'aggregate_field_address': '$nutrition.vitaminA.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'total_vitaminA_Intake', 'aggregationFunction': '$sum', 'group_by_field_output_name': 'DummyColumn'}
# Query 3/4 with arguments: {'aggregate_field_address': '$nutrition.calories.amount', 'group_by_field_address': '$ada-city', 'aggregate_field_output_name': 'avg_calories', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city'}
# Query 4/4 with arguments: {'aggregate_field_address': '$nutrition.vitaminA.amount', 'group_by_field_address': '$ada-city', 'aggregate_field_output_name': 'total_vitaminA_Intake', 'aggregationFunction': '$sum', 'group_by_field_output_name': 'city'}

# %%
allDfs['global'].head(3)
# Out:
#                     avg_calories  nbRecipes  total_vitaminA_Intake
# DummyColumn
# Global aggregation    350.246799      16242           2.270323e+07

# %%
allDfs['per_city'].head(3)
# Out:
#            avg_calories  nbRecipes  total_vitaminA_Intake
# city
# atlanta      424.314499         28           85023.393070
# baltimore    282.584182         40           27968.763135
# boston       411.666383         12            2768.165049

# %%
import os

json_output_filename = '../website/data/aggregatedDataSmall.json'

os.makedirs(os.path.dirname(json_output_filename), exist_ok=True)
write_dataframes_to_json(json_output_filename, allDfs)

#loadedAllDfs = load_dataframes_from_json(json_output_filename)

# %%
# !cat '../website/data/aggregatedData.json'
# Out:
# {
#     "per_city": {
#         "dallas": {
#             "avg_calories": 281.9190327586,
#             "total_vitaminA_Intake": 62139.256174,
#             "nbRecipes": 29
#         },
#         "new-orleans": {
#             "avg_calories": 445.9402834884,
#             "total_vitaminA_Intake": 42673.55009,
#             "nbRecipes": 46
#         },
#         "cincinnati": {
#             "avg_calories": 424.625025,
#             "total_vitaminA_Intake": 39608.794,
#             "nbRecipes": 12
#         },
#         "washington-dc": {
#             "avg_calories": 291.5897064706,
#             "total_vitaminA_Intake": 9453.05414,
#             "nbRecipes": 17
#         },
#         "indianapolis": {
#             "avg_calories": 425.4122357143,
#             "total_vitaminA_Intake": 12283.5292282,
#             "nbRecipes": 15
#         },
#         "milwaukee": {
#             "avg_calories": 344.2545928571,
#             "total_vitaminA_Intake": 26335.21554,
#             "nbRecipes": 27
#         },
#         "buffalo": {
#             "avg_calories": 274.4892507317,
#             "total_vitaminA_Intake": 24065.911712,
#             "nbRecipes": 41
#         },
#         "seattle": {
#             "avg_calories": 415.338245,
#             "total_vitaminA_Intake": 138905.35251,
#             "nbRecipes": 67
#         },
#         "miami": {
#             "avg_calories": 446.1634,
#             "total_vitaminA_Intake": 5344.37133,
#             "nbRecipes": 12
#         },
#         "san-diego": {
#             "avg_calories": 401.5872333333,
#             "total_vitaminA_Intake": 79246.54578,
#             "nbRecipes": 31
#         },
#         "boston": {
#             "avg_calories": 411.6663833333,
#             "total_vitaminA_Intake": 2768.165049,
#             "nbRecipes": 12
#         },
#         "los-angeles": {
#             "avg_calories": 374.2129283333,
#             "total_vitaminA_Intake": 51044.61844,
#             "nbRecipes": 30
#         },
#         "philadelphia": {
#             "avg_calories": 510.41504,
#             "total_vitaminA_Intake": 46122.68971,
#             "nbRecipes": 50
#         },
#         "san-francisco": {
#             "avg_calories": 291.9175343171,
#             "total_vitaminA_Intake": 48289.644985,
#             "nbRecipes": 41
#         },
#         "kansas-city": {
#             "avg_calories": 300.2158104545,
#             "total_vitaminA_Intake": 36884.11005,
#             "nbRecipes": 24
#         },
#         "houston": {
#             "avg_calories": 366.3758511111,
#             "total_vitaminA_Intake": 23852.887483,
#             "nbRecipes": 18
#         },
#         "georgia": {
#             "avg_calories": 358.6492397143,
#             "total_vitaminA_Intake": 128067.02551,
#             "nbRecipes": 71
#         },
#         "toronto": {
#             "avg_calories": 394.5755590625,
#             "total_vitaminA_Intake": 77310.15675,
#             "nbRecipes": 64
#         },
#         "baltimore": {
#             "avg_calories": 282.5841822308,
#             "total_vitaminA_Intake": 27968.763135,
#             "nbRecipes": 40
#         },
#         "chicago": {
#             "avg_calories": 403.8004090909,
#             "total_vitaminA_Intake": 12753.8676,
#             "nbRecipes": 11
#         },
#         "st-louis": {
#             "avg_calories": 485.8434666667,
#             "total_vitaminA_Intake": 38558.02665,
#             "nbRecipes": 27
#         },
#         "pittsburgh": {
#             "avg_calories": 483.6879928571,
#             "total_vitaminA_Intake": 21015.999857,
#             "nbRecipes": 28
#         },
#         "green-bay": {
#             "avg_calories": 407.6131015385,
#             "total_vitaminA_Intake": 15783.76384,
#             "nbRecipes": 16
#         },
#         "oakland": {
#             "avg_calories": 448.8614230769,
#             "total_vitaminA_Intake": 39844.8466,
#             "nbRecipes": 26
#         },
#         "detroit": {
#             "avg_calories": 311.01333,
#             "total_vitaminA_Intake": 10969.15789,
#             "nbRecipes": 12
#         },
#         "atlanta": {
#             "avg_calories": 424.3144992857,
#             "total_vitaminA_Intake": 85023.39307,
#             "nbRecipes": 28
#         },
#         "minneapolis": {
#             "avg_calories": 426.5461631034,
#             "total_vitaminA_Intake": 54923.347647,
#             "nbRecipes": 29
#         },
#         "tampa-bay": {
#             "avg_calories": 337.8598092308,
#             "total_vitaminA_Intake": 21437.77378,
#             "nbRecipes": 28
#         },
#         "vancouver": {
#             "avg_calories": 342.3823438095,
#             "total_vitaminA_Intake": 102112.4902423,
#             "nbRecipes": 127
#         },
#         "california": {
#             "avg_calories": 361.590713878,
#             "total_vitaminA_Intake": 369048.0162120002,
#             "nbRecipes": 250
#         },
#         "cleveland": {
#             "avg_calories": 429.2601442424,
#             "total_vitaminA_Intake": 36406.27513367,
#             "nbRecipes": 33
#         },
#         "new-york-city": {
#             "avg_calories": 411.8799015702,
#             "total_vitaminA_Intake": 171463.7429213,
#             "nbRecipes": 125
#         }
#     },
#     "global": {
#         "Global aggregation": {
#             "avg_calories": 350.2467986302,
#             "total_vitaminA_Intake": 22703227.41110853,
#             "nbRecipes": 16242
#         }
#     }
# }

# %% [markdown]
# # Get many aggregate values

# %% [markdown]
# We must first find which fields to pick.

# %%
allKeysWithDescription = get_all_field_addresses(oneRecipe, shortenLongStrings=False)
allKeysWithDescription
# Out:
# {'$_id': '5825054ace06e50446084706',
#  '$adUnit.adKeys': '[7, 79, 95, 125, 148, 150, 169, 173, 184, 201, 221, 235, 241, 242, 249, 254, 265, 608]',
#  '$adUnit.adZone': 'recipes',
#  '$adUnit.contentProviderId': '451',
#  '$adUnit.networkCode': '3865',
#  '$adUnit.site': 'ar.ios.apps.allrecipes.recipes',
#  '$ada-city': '[]',
#  '$ada-continent': "['asian']",
#  '$ada-country': "['indian']",
#  '$ada-region': '[]',
#  '$ada-subcontinent': '[]',
#  '$ada-tags': "['world-cuisine', 'asian', 'indian', 'main-dishes', 'curry', 'vegetarian']",
#  '$cookMinutes': '45',
#  '$description': 'This is a really easy and tasty Indian dish that is sure to stir up your taste buds. Delicious baingan bharta is ready to eat with pita bread, Indian naan, or rice.',
#  '$directions': "[{'ordinal': 1, 'videoTimestamp': 0, 'displayValue': 'Preheat oven to 450 degrees F (230 degrees C).'}, {'ordinal': 2, 'videoTimestamp': 0, 'displayValue': 'Place eggplant on a medium baking sheet. Bake 20 to 30 minutes in the preheated oven, until tender. Remove from heat, cool, peel, and chop.'}, {'ordinal': 3, 'videoTimestamp': 0, 'displayValue': 'Heat oil in a medium saucepan over medium heat. Mix in cumin seeds and onion. Cook and stir until onion is tender.'}, {'ordinal': 4, 'videoTimestamp': 0, 'displayValue': 'Mix ginger garlic paste, curry powder, and tomato into the saucepan, and cook about 1 minute. Stir in yogurt. Mix in eggplant and jalapeno pepper, and season with salt. Cover, and cook 10 minutes over high heat. Remove cover, reduce heat to low, and continue cooking about 5 minutes. Garnish with cilantro to serve.'}]",
#  '$footnotes': "[{'ordinal': 100, 'text': 'Tip'}, {'ordinal': 101, 'text': 'Aluminum foil can be used to keep food moist, cook it evenly, and make clean-up easier.'}]",
#  '$ingredients': "[{'grams': 548.0, 'ingredientID': 4339, 'displayValue': '1 large eggplant', 'displayType': 'Normal'}, {'grams': 27.25, 'ingredientID': 6305, 'displayValue': '2 tablespoons vegetable oil', 'displayType': 'Normal'}, {'grams': 2.1, 'ingredientID': 16390, 'displayValue': '1 teaspoon cumin seeds', 'displayType': 'Normal'}, {'grams': 110.0, 'ingredientID': 4397, 'displayValue': '1 medium onion, thinly sliced', 'displayType': 'Normal'}, {'grams': 16.5, 'ingredientID': 20678, 'displayValue': '1 tablespoon ginger garlic paste', 'displayType': 'Normal'}, {'grams': 6.3, 'ingredientID': 16391, 'displayValue': '1 tablespoon curry powder', 'displayType': 'Normal'}, {'grams': 123.0, 'ingredientID': 4572, 'displayValue': '1 tomato, diced', 'displayType': 'Normal'}, {'grams': 122.5, 'ingredientID': 16158, 'displayValue': '1/2 cup plain yogurt', 'displayType': 'Normal'}, {'grams': 14.0, 'ingredientID': 3725, 'displayValue': '1 fresh jalapeno chile pepper, finely chopped', 'displayType': 'Normal'}, {'grams': 6.0, 'ingredientID': 16421, 'displayValue': '1 teaspoon salt', 'displayType': 'Normal'}, {'grams': 14.0, 'ingredientID': 3717, 'displayValue': '1/4 bunch cilantro, finely chopped', 'displayType': 'Normal'}]",
#  '$isSponsored': 'False',
#  '$links.recipeUrl.href': 'http://allrecipes.com/recipe/47564/baingan-bharta-eggplant-curry/',
#  '$links.self.href': 'https://apps.allrecipes.com/v1/recipes/47564',
#  '$nutrition.calcium.amount': '93.245',
#  '$nutrition.calcium.displayValue': '93',
#  '$nutrition.calcium.hasCompleteData': 'False',
#  '$nutrition.calcium.name': 'Calcium',
#  '$nutrition.calcium.percentDailyValue': '12',
#  '$nutrition.calcium.unit': 'mg',
#  '$nutrition.calories.amount': '146.1237',
#  '$nutrition.calories.displayValue': '146',
#  '$nutrition.calories.hasCompleteData': 'True',
#  '$nutrition.calories.name': 'Calories',
#  '$nutrition.calories.percentDailyValue': '7',
#  '$nutrition.calories.unit': 'kcal',
#  '$nutrition.caloriesFromFat.amount': '72.09731',
#  '$nutrition.caloriesFromFat.displayValue': '72',
#  '$nutrition.caloriesFromFat.hasCompleteData': 'True',
#  '$nutrition.caloriesFromFat.name': 'Calories from Fat',
#  '$nutrition.caloriesFromFat.percentDailyValue': '-',
#  '$nutrition.caloriesFromFat.unit': 'kcal',
#  '$nutrition.carbohydrates.amount': '15.22197',
#  '$nutrition.carbohydrates.displayValue': '15.2',
#  '$nutrition.carbohydrates.hasCompleteData': 'True',
#  '$nutrition.carbohydrates.name': 'Carbohydrates',
#  '$nutrition.carbohydrates.percentDailyValue': '5',
#  '$nutrition.carbohydrates.unit': 'g',
#  '$nutrition.cholesterol.amount': '1.8375',
#  '$nutrition.cholesterol.displayValue': '2',
#  '$nutrition.cholesterol.hasCompleteData': 'False',
#  '$nutrition.cholesterol.name': 'Cholesterol',
#  '$nutrition.cholesterol.percentDailyValue': '< 1',
#  '$nutrition.cholesterol.unit': 'mg',
#  '$nutrition.fat.amount': '8.010813',
#  '$nutrition.fat.displayValue': '8',
#  '$nutrition.fat.hasCompleteData': 'True',
#  '$nutrition.fat.name': 'Fat',
#  '$nutrition.fat.percentDailyValue': '12',
#  '$nutrition.fat.unit': 'g',
#  '$nutrition.fiber.amount': '6.222385',
#  '$nutrition.fiber.displayValue': '6.2',
#  '$nutrition.fiber.hasCompleteData': 'False',
#  '$nutrition.fiber.name': 'Dietary Fiber',
#  '$nutrition.fiber.percentDailyValue': '25',
#  '$nutrition.fiber.unit': 'g',
#  '$nutrition.folate.amount': '49.63925',
#  '$nutrition.folate.displayValue': '50',
#  '$nutrition.folate.hasCompleteData': 'False',
#  '$nutrition.folate.name': 'Folate',
#  '$nutrition.folate.percentDailyValue': '28',
#  '$nutrition.folate.unit': 'mcg',
#  '$nutrition.iron.amount': '1.403314',
#  '$nutrition.iron.displayValue': '1',
#  '$nutrition.iron.hasCompleteData': 'False',
#  '$nutrition.iron.name': 'Iron',
#  '$nutrition.iron.percentDailyValue': '14',
#  '$nutrition.iron.unit': 'mg',
#  '$nutrition.magnesium.amount': '38.03075',
#  '$nutrition.magnesium.displayValue': '38',
#  '$nutrition.magnesium.hasCompleteData': 'False',
#  '$nutrition.magnesium.name': 'Magnesium',
#  '$nutrition.magnesium.percentDailyValue': '14',
#  '$nutrition.magnesium.unit': 'mg',
#  '$nutrition.niacin.amount': '1.744597',
#  '$nutrition.niacin.displayValue': '2',
#  '$nutrition.niacin.hasCompleteData': 'False',
#  '$nutrition.niacin.name': 'Niacin Equivalents',
#  '$nutrition.niacin.percentDailyValue': '13',
#  '$nutrition.niacin.unit': 'mg',
#  '$nutrition.potassium.amount': '559.3593',
#  '$nutrition.potassium.displayValue': '559',
#  '$nutrition.potassium.hasCompleteData': 'False',
#  '$nutrition.potassium.name': 'Potassium',
#  '$nutrition.potassium.percentDailyValue': '16',
#  '$nutrition.potassium.unit': 'mg',
#  '$nutrition.protein.amount': '3.97931',
#  '$nutrition.protein.displayValue': '4',
#  '$nutrition.protein.hasCompleteData': 'True',
#  '$nutrition.protein.name': 'Protein',
#  '$nutrition.protein.percentDailyValue': '8',
#  '$nutrition.protein.unit': 'g',
#  '$nutrition.saturatedFat.amount': '1.485098',
#  '$nutrition.saturatedFat.displayValue': '1.5',
#  '$nutrition.saturatedFat.hasCompleteData': 'True',
#  '$nutrition.saturatedFat.name': 'Saturated Fat',
#  '$nutrition.saturatedFat.percentDailyValue': '7',
#  '$nutrition.saturatedFat.unit': 'g',
#  '$nutrition.sodium.amount': '739.406',
#  '$nutrition.sodium.displayValue': '739',
#  '$nutrition.sodium.hasCompleteData': 'True',
#  '$nutrition.sodium.name': 'Sodium',
#  '$nutrition.sodium.percentDailyValue': '30',
#  '$nutrition.sodium.unit': 'mg',
#  '$nutrition.sugars.amount': '7.522098',
#  '$nutrition.sugars.displayValue': '7.5',
#  '$nutrition.sugars.hasCompleteData': 'True',
#  '$nutrition.sugars.name': 'Sugars',
#  '$nutrition.sugars.percentDailyValue': '0',
#  '$nutrition.sugars.unit': 'g',
#  '$nutrition.thiamin.amount': '0.1289342',
#  '$nutrition.thiamin.displayValue': '< 1',
#  '$nutrition.thiamin.hasCompleteData': 'False',
#  '$nutrition.thiamin.name': 'Thiamin',
#  '$nutrition.thiamin.percentDailyValue': '13',
#  '$nutrition.thiamin.unit': 'mg',
#  '$nutrition.vitaminA.amount': '595.6483',
#  '$nutrition.vitaminA.displayValue': '596',
#  '$nutrition.vitaminA.hasCompleteData': 'False',
#  '$nutrition.vitaminA.name': 'Vitamin A - IU',
#  '$nutrition.vitaminA.percentDailyValue': '12',
#  '$nutrition.vitaminA.unit': 'IU',
#  '$nutrition.vitaminB6.amount': '0.2310775',
#  '$nutrition.vitaminB6.displayValue': '< 1',
#  '$nutrition.vitaminB6.hasCompleteData': 'False',
#  '$nutrition.vitaminB6.name': 'Vitamin B6',
#  '$nutrition.vitaminB6.percentDailyValue': '14',
#  '$nutrition.vitaminB6.unit': 'mg',
#  '$nutrition.vitaminC.amount': '11.91473',
#  '$nutrition.vitaminC.displayValue': '12',
#  '$nutrition.vitaminC.hasCompleteData': 'False',
#  '$nutrition.vitaminC.name': 'Vitamin C',
#  '$nutrition.vitaminC.percentDailyValue': '20',
#  '$nutrition.vitaminC.unit': 'mg',
#  '$photo.description': '',
#  '$photo.itemType': 'Photo',
#  '$photo.photoDetailUrl': 'http://m.allrecipes.com/photos/14597',
#  '$photo.photoID': '14597',
#  '$photo.rawItemType': '10',
#  '$photo.recipeTitle': 'None',
#  '$photo.title': '',
#  '$photo.urls': "[{'height': 50, 'width': 50, 'url': 'http://images.media-allrecipes.com/userphotos/50x50/14597.jpg'}, {'height': 110, 'width': 110, 'url': 'http://images.media-allrecipes.com/userphotos/110x110/14597.jpg'}, {'height': 140, 'width': 140, 'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/01/45/14597.jpg'}, {'height': 250, 'width': 250, 'url': 'http://images.media-allrecipes.com/userphotos/250x250/14597.jpg'}]",
#  '$prepMinutes': '15',
#  '$ratingAverage': '4.305987',
#  '$ratingCount': '451',
#  '$readyInMinutes': '60',
#  '$recipeID': '47564',
#  '$reviewCount': '309',
#  '$servings': '4',
#  '$similarRecipes.links.self.href': 'https://apps.allrecipes.com/v1/recipes/47564',
#  '$similarRecipes.metaData.page': '1',
#  '$similarRecipes.metaData.pagesize': '20',
#  '$similarRecipes.metaData.totalCount': '20',
#  '$similarRecipes.recipes': '[{\'sourceID\': 461, \'ratingCount\': 64, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/3294074\', \'rawItemType\': 10, \'title\': \'\', \'itemType\': \'Photo\', \'recipeTitle\': None, \'description\': \'\', \'urls\': [{\'height\': 50, \'width\': 50, \'url\': \'http://images.media-allrecipes.com/userphotos/50x50/3294074.jpg\'}, {\'height\': 110, \'width\': 110, \'url\': \'http://images.media-allrecipes.com/userphotos/110x110/3294074.jpg\'}, {\'height\': 140, \'width\': 140, \'url\': \'http://images.media-allrecipes.com/userphotos/140x140/03/29/40/3294074.jpg\'}, {\'height\': 250, \'width\': 250, \'url\': \'http://images.media-allrecipes.com/userphotos/250x250/3294074.jpg\'}], \'photoID\': 3294074}, \'reviewCount\': 48, \'title\': \'Eggplant Parmesan For the Slow Cooker\', \'itemType\': \'Recipe\', \'description\': \'Make a big batch of eggplant Parmesan in your slow cooker and dinner will be waiting when you get home. No need to heat up your kitchen baking in an oven.\', \'videoID\': 0, \'submitter\': {\'favoritesCount\': 19, \'followersCount\': 12, \'ratingsCount\': 0, \'handle\': \'\', \'region\': None, \'itemType\': \'Cook\', \'promotedBrandPixelTrackingUrl\': None, \'name\': \'jboettcher2\', \'madeRecipesCount\': 0, \'country\': None, \'city\': None, \'userID\': 5752296, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/556955\', \'rawItemType\': 10, \'title\': \'\', \'itemType\': \'Photo\', \'recipeTitle\': None, \'description\': \'\', \'urls\': [{\'height\': 50, \'width\': 50, \'url\': \'http://images.media-allrecipes.com/userphotos/50x50/556955.jpg\'}, {\'height\': 110, \'width\': 110, \'url\': \'http://images.media-allrecipes.com/userphotos/110x110/556955.jpg\'}, {\'height\': 140, \'width\': 140, \'url\': \'http://images.media-allrecipes.com/userphotos/140x140/00/55/69/556955.jpg\'}, {\'height\': 250, \'width\': 250, \'url\': \'http://images.media-allrecipes.com/userphotos/250x250/556955.jpg\'}], \'photoID\': 556955}, \'isPro\': False, \'reciepesCount\': 1, \'profileUrl\': \'/cook/5752296/\', \'followingCount\': 0, \'reviewsCount\': 0, \'rawItemType\': 11, \'brandedSourceID\': 0, \'personalRecipeSharedCount\': 1}, \'recipeID\': 223360, \'recipeTrackingPixelUrl\': None, \'isSponsored\': False, \'ratingAverage\': 4.39, \'rawItemType\': 1, \'madeCount\': 86, \'links\': {\'recipeUrl\': {\'href\': \'http://allrecipes.com/recipe/eggplant-parmesan-for-the-slow-cooker/\'}, \'parent\': {\'href\': \'https://apps.allrecipes.com/v1/recipes/223360\'}}, \'type\': \'recipes\'}, {\'sourceID\': 461, \'ratingCount\': 30, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/3719268\', \'rawItemType\': 10, \'title\': \'\', \'itemType\': \'Photo\', \'recipeTitle\': None, \'description\': \'\', \'urls\': [{\'height\': 50, \'width\': 50, \'url\': \'http://images.media-allrecipes.com/userphotos/50x50/3719268.jpg\'}, {\'height\': 110, \'width\': 110, \'url\': \'http://images.media-allrecipes.com/userphotos/110x110/3719268.jpg\'}, {\'height\': 140, \'width\': 140, \'url\': \'http://images.media-allrecipes.com/userphotos/140x140/03/71/92/3719268.jpg\'}, {\'height\': 250, \'width\': 250, \'url\': \'http://images.media-allrecipes.com/userphotos/250x250/3719268.jpg\'}], \'photoID\': 3719268}, \'reviewCount\': 22, \'title\': "Chef John\'s Baked Eggplant Sandwiches", \'itemType\': \'Recipe\', \'description\': \'These breaded and baked eggplant sandwiches are the perfect make-ahead appetizer for your next potluck.\', \'videoID\': 3083, \'submitter\': {\'favoritesCount\': 363, \'followersCount\': 38210, \'ratingsCount\': 307, \'handle\': \'foodwisheswithchefjohn\', \'region\': None, \'itemType\': \'Cook\', \'promotedBrandPixelTrackingUrl\': None, \'name\': \'Chef John\', \'madeRecipesCount\': 309, \'country\': None, \'city\': None, \'userID\': 8601924, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/2267470\', \'rawItemType\': 10, \'title\': \'\', \'itemType\':  ...
#  '$sourceID': '461',
#  '$submitter.brandedSourceID': '0',
#  '$submitter.city': 'None',
#  '$submitter.country': 'None',
#  '$submitter.favoritesCount': '0',
#  '$submitter.followersCount': '0',
#  '$submitter.followingCount': '0',
#  '$submitter.handle': 'None',
#  '$submitter.isPro': 'False',
#  '$submitter.itemType': 'Cook',
#  '$submitter.madeRecipesCount': '0',
#  '$submitter.name': 'Yakuta',
#  '$submitter.personalRecipeSharedCount': '0',
#  '$submitter.photo.description': 'None',
#  '$submitter.photo.itemType': 'Photo',
#  '$submitter.photo.photoDetailUrl': 'None',
#  '$submitter.photo.rawItemType': '10',
#  '$submitter.photo.recipeTitle': 'None',
#  '$submitter.photo.title': 'None',
#  '$submitter.photo.urls': "[{'height': 50, 'width': 50, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png'}, {'height': 110, 'width': 110, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png'}, {'height': 140, 'width': 140, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png'}, {'height': 250, 'width': 250, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png'}]",
#  '$submitter.profileUrl': '',
#  '$submitter.promotedBrandPixelTrackingUrl': 'None',
#  '$submitter.ratingsCount': '0',
#  '$submitter.rawItemType': '11',
#  '$submitter.reciepesCount': '0',
#  '$submitter.region': 'None',
#  '$submitter.reviewsCount': '0',
#  '$submitter.userID': '0',
#  '$title': 'Baingan Bharta (Eggplant Curry)',
#  '$topReviews': '[{\'links\': {\'incrementHelpfulCount\': {\'href\': \'https://apps.allrecipes.com/v1/recipes/47564/reviews/1815671/increment-helpful-count\'}}, \'helpfulCount\': 361, \'text\': "The recipe is almost authentic - i say almost because Indians use garam masala and not curry powder. I don\'t add yogurt to my baingan bharta, but adding it isn\'t a sin, i wouldn\'t heat the dish after adding yogurt. Also, the eggplant is usually fire roasted and the smokey flavor is just outstanding. Also a small teaspoon of lemon juice in the end brings all the flavors out.", \'rawItemType\': 9, \'dateLastModified\': \'2009-03-11T13:33:32.31\', \'itemType\': \'Review\', \'rating\': 4, \'submitter\': {\'favoritesCount\': 21, \'followersCount\': 0, \'ratingsCount\': 15, \'handle\': \'\', \'region\': None, \'itemType\': \'Cook\', \'promotedBrandPixelTrackingUrl\': None, \'name\': \'SUSHANK\', \'madeRecipesCount\': 15, \'country\': None, \'city\': None, \'userID\': 844246, \'photo\': {\'photoDetailUrl\': None, \'rawItemType\': 10, \'title\': None, \'itemType\': \'Photo\', \'recipeTitle\': None, \'description\': None, \'urls\': [{\'height\': 50, \'width\': 50, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png\'}, {\'height\': 110, \'width\': 110, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png\'}, {\'height\': 140, \'width\': 140, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png\'}, {\'height\': 250, \'width\': 250, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png\'}]}, \'isPro\': False, \'reciepesCount\': 0, \'profileUrl\': \'/cook/844246/\', \'followingCount\': 0, \'reviewsCount\': 13, \'rawItemType\': 11, \'brandedSourceID\': 0, \'personalRecipeSharedCount\': 0}, \'reviewID\': 1815671}, {\'links\': {\'incrementHelpfulCount\': {\'href\': \'https://apps.allrecipes.com/v1/recipes/47564/reviews/1254574/increment-helpful-count\'}}, \'helpfulCount\': 278, \'text\': \'great recipe. I am second generation Indian and this is one of my favorite dishes. I made the eggplant the day before just to save time; I cut it in half lengthwise, sprayed the cut side with Pam, and then baked it on a foil lined cookie sheet, cut side down. I baked it for 20 minutes or so and it was so tender that I just scraped it out of the skin with a spoon. I used a can of plum tomatoes instead of a tomato, and cut the tomatoes into a small dice. I saved the liquid and added it to the dish right before I started to simmer it. I also added about a cup of frozen baby peas at the same time as the eggplant. Used ginger paste and minced garlic. Great recipe.\', \'rawItemType\': 9, \'dateLastModified\': \'2008-01-21T16:56:31.387\', \'itemType\': \'Review\', \'rating\': 5, \'submitter\': {\'favoritesCount\': 109, \'followersCount\': 0, \'ratingsCount\': 25, \'handle\': \'\', \'region\': None, \'itemType\': \'Cook\', \'promotedBrandPixelTrackingUrl\': None, \'name\': \'Shmoopy\', \'madeRecipesCount\': 25, \'country\': None, \'city\': None, \'userID\': 747353, \'photo\': {\'photoDetailUrl\': None, \'rawItemType\': 10, \'title\': None, \'itemType\': \'Photo\', \'recipeTitle\': None, \'description\': None, \'urls\': [{\'height\': 50, \'width\': 50, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png\'}, {\'height\': 110, \'width\': 110, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png\'}, {\'height\': 140, \'width\': 140, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png\'}, {\'height\': 250, \'width\': 250, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png\'}]}, \'isPro\': False, \'reciepesCount\': 0, \'profileUrl\': \'/cook/747353/\', \'followingCount\': 0, \'reviewsCount\': 25, \'rawItemType\': 11, \'brandedSourceID\': 0, \'personalRecipeSharedCount\': 1}, \' ...
#  '$type': 'recipes',
#  '$video': 'None'}

# %%
str.isnumeric('[7, 79, 95, 125, 148]') # false
str.isnumeric('45') # true
# Out:
# True

# %%
{
        'aggregate_field_address': '$nutrition.calories.amount', 
        'aggregate_field_output_name': 'avg_calories', 
        'aggregationFunction': '$avg' 
    }

# %%
'$submitter.followersCount'.endswith(tuple(['percentDailyValue', 'Count']))
# Out:
# True

# %%
allKeysWithDescription
# Out:
# {'$_id': '5825054ace06e50446084706',
#  '$adUnit.adKeys': '[7, 79, 95, 125, 148, 150, 169, 173, 184, 201, 221, 235, 241, 242, 249, 254, 265, 608]',
#  '$adUnit.adZone': 'recipes',
#  '$adUnit.contentProviderId': '451',
#  '$adUnit.networkCode': '3865',
#  '$adUnit.site': 'ar.ios.apps.allrecipes.recipes',
#  '$ada-city': '[]',
#  '$ada-continent': "['asian']",
#  '$ada-country': "['indian']",
#  '$ada-region': '[]',
#  '$ada-subcontinent': '[]',
#  '$ada-tags': "['world-cuisine', 'asian', 'indian', 'main-dishes', 'curry', 'vegetarian']",
#  '$cookMinutes': '45',
#  '$description': 'This is a really easy and tasty Indian dish that is sure to stir up your taste buds. Delicious baingan bharta is ready to eat with pita bread, Indian naan, or rice.',
#  '$directions': "[{'ordinal': 1, 'videoTimestamp': 0, 'displayValue': 'Preheat oven to 450 degrees F (230 degrees C).'}, {'ordinal': 2, 'videoTimestamp': 0, 'displayValue': 'Place eggplant on a medium baking sheet. Bake 20 to 30 minutes in the preheated oven, until tender. Remove from heat, cool, peel, and chop.'}, {'ordinal': 3, 'videoTimestamp': 0, 'displayValue': 'Heat oil in a medium saucepan over medium heat. Mix in cumin seeds and onion. Cook and stir until onion is tender.'}, {'ordinal': 4, 'videoTimestamp': 0, 'displayValue': 'Mix ginger garlic paste, curry powder, and tomato into the saucepan, and cook about 1 minute. Stir in yogurt. Mix in eggplant and jalapeno pepper, and season with salt. Cover, and cook 10 minutes over high heat. Remove cover, reduce heat to low, and continue cooking about 5 minutes. Garnish with cilantro to serve.'}]",
#  '$footnotes': "[{'ordinal': 100, 'text': 'Tip'}, {'ordinal': 101, 'text': 'Aluminum foil can be used to keep food moist, cook it evenly, and make clean-up easier.'}]",
#  '$ingredients': "[{'grams': 548.0, 'ingredientID': 4339, 'displayValue': '1 large eggplant', 'displayType': 'Normal'}, {'grams': 27.25, 'ingredientID': 6305, 'displayValue': '2 tablespoons vegetable oil', 'displayType': 'Normal'}, {'grams': 2.1, 'ingredientID': 16390, 'displayValue': '1 teaspoon cumin seeds', 'displayType': 'Normal'}, {'grams': 110.0, 'ingredientID': 4397, 'displayValue': '1 medium onion, thinly sliced', 'displayType': 'Normal'}, {'grams': 16.5, 'ingredientID': 20678, 'displayValue': '1 tablespoon ginger garlic paste', 'displayType': 'Normal'}, {'grams': 6.3, 'ingredientID': 16391, 'displayValue': '1 tablespoon curry powder', 'displayType': 'Normal'}, {'grams': 123.0, 'ingredientID': 4572, 'displayValue': '1 tomato, diced', 'displayType': 'Normal'}, {'grams': 122.5, 'ingredientID': 16158, 'displayValue': '1/2 cup plain yogurt', 'displayType': 'Normal'}, {'grams': 14.0, 'ingredientID': 3725, 'displayValue': '1 fresh jalapeno chile pepper, finely chopped', 'displayType': 'Normal'}, {'grams': 6.0, 'ingredientID': 16421, 'displayValue': '1 teaspoon salt', 'displayType': 'Normal'}, {'grams': 14.0, 'ingredientID': 3717, 'displayValue': '1/4 bunch cilantro, finely chopped', 'displayType': 'Normal'}]",
#  '$isSponsored': 'False',
#  '$links.recipeUrl.href': 'http://allrecipes.com/recipe/47564/baingan-bharta-eggplant-curry/',
#  '$links.self.href': 'https://apps.allrecipes.com/v1/recipes/47564',
#  '$nutrition.calcium.amount': '93.245',
#  '$nutrition.calcium.displayValue': '93',
#  '$nutrition.calcium.hasCompleteData': 'False',
#  '$nutrition.calcium.name': 'Calcium',
#  '$nutrition.calcium.percentDailyValue': '12',
#  '$nutrition.calcium.unit': 'mg',
#  '$nutrition.calories.amount': '146.1237',
#  '$nutrition.calories.displayValue': '146',
#  '$nutrition.calories.hasCompleteData': 'True',
#  '$nutrition.calories.name': 'Calories',
#  '$nutrition.calories.percentDailyValue': '7',
#  '$nutrition.calories.unit': 'kcal',
#  '$nutrition.caloriesFromFat.amount': '72.09731',
#  '$nutrition.caloriesFromFat.displayValue': '72',
#  '$nutrition.caloriesFromFat.hasCompleteData': 'True',
#  '$nutrition.caloriesFromFat.name': 'Calories from Fat',
#  '$nutrition.caloriesFromFat.percentDailyValue': '-',
#  '$nutrition.caloriesFromFat.unit': 'kcal',
#  '$nutrition.carbohydrates.amount': '15.22197',
#  '$nutrition.carbohydrates.displayValue': '15.2',
#  '$nutrition.carbohydrates.hasCompleteData': 'True',
#  '$nutrition.carbohydrates.name': 'Carbohydrates',
#  '$nutrition.carbohydrates.percentDailyValue': '5',
#  '$nutrition.carbohydrates.unit': 'g',
#  '$nutrition.cholesterol.amount': '1.8375',
#  '$nutrition.cholesterol.displayValue': '2',
#  '$nutrition.cholesterol.hasCompleteData': 'False',
#  '$nutrition.cholesterol.name': 'Cholesterol',
#  '$nutrition.cholesterol.percentDailyValue': '< 1',
#  '$nutrition.cholesterol.unit': 'mg',
#  '$nutrition.fat.amount': '8.010813',
#  '$nutrition.fat.displayValue': '8',
#  '$nutrition.fat.hasCompleteData': 'True',
#  '$nutrition.fat.name': 'Fat',
#  '$nutrition.fat.percentDailyValue': '12',
#  '$nutrition.fat.unit': 'g',
#  '$nutrition.fiber.amount': '6.222385',
#  '$nutrition.fiber.displayValue': '6.2',
#  '$nutrition.fiber.hasCompleteData': 'False',
#  '$nutrition.fiber.name': 'Dietary Fiber',
#  '$nutrition.fiber.percentDailyValue': '25',
#  '$nutrition.fiber.unit': 'g',
#  '$nutrition.folate.amount': '49.63925',
#  '$nutrition.folate.displayValue': '50',
#  '$nutrition.folate.hasCompleteData': 'False',
#  '$nutrition.folate.name': 'Folate',
#  '$nutrition.folate.percentDailyValue': '28',
#  '$nutrition.folate.unit': 'mcg',
#  '$nutrition.iron.amount': '1.403314',
#  '$nutrition.iron.displayValue': '1',
#  '$nutrition.iron.hasCompleteData': 'False',
#  '$nutrition.iron.name': 'Iron',
#  '$nutrition.iron.percentDailyValue': '14',
#  '$nutrition.iron.unit': 'mg',
#  '$nutrition.magnesium.amount': '38.03075',
#  '$nutrition.magnesium.displayValue': '38',
#  '$nutrition.magnesium.hasCompleteData': 'False',
#  '$nutrition.magnesium.name': 'Magnesium',
#  '$nutrition.magnesium.percentDailyValue': '14',
#  '$nutrition.magnesium.unit': 'mg',
#  '$nutrition.niacin.amount': '1.744597',
#  '$nutrition.niacin.displayValue': '2',
#  '$nutrition.niacin.hasCompleteData': 'False',
#  '$nutrition.niacin.name': 'Niacin Equivalents',
#  '$nutrition.niacin.percentDailyValue': '13',
#  '$nutrition.niacin.unit': 'mg',
#  '$nutrition.potassium.amount': '559.3593',
#  '$nutrition.potassium.displayValue': '559',
#  '$nutrition.potassium.hasCompleteData': 'False',
#  '$nutrition.potassium.name': 'Potassium',
#  '$nutrition.potassium.percentDailyValue': '16',
#  '$nutrition.potassium.unit': 'mg',
#  '$nutrition.protein.amount': '3.97931',
#  '$nutrition.protein.displayValue': '4',
#  '$nutrition.protein.hasCompleteData': 'True',
#  '$nutrition.protein.name': 'Protein',
#  '$nutrition.protein.percentDailyValue': '8',
#  '$nutrition.protein.unit': 'g',
#  '$nutrition.saturatedFat.amount': '1.485098',
#  '$nutrition.saturatedFat.displayValue': '1.5',
#  '$nutrition.saturatedFat.hasCompleteData': 'True',
#  '$nutrition.saturatedFat.name': 'Saturated Fat',
#  '$nutrition.saturatedFat.percentDailyValue': '7',
#  '$nutrition.saturatedFat.unit': 'g',
#  '$nutrition.sodium.amount': '739.406',
#  '$nutrition.sodium.displayValue': '739',
#  '$nutrition.sodium.hasCompleteData': 'True',
#  '$nutrition.sodium.name': 'Sodium',
#  '$nutrition.sodium.percentDailyValue': '30',
#  '$nutrition.sodium.unit': 'mg',
#  '$nutrition.sugars.amount': '7.522098',
#  '$nutrition.sugars.displayValue': '7.5',
#  '$nutrition.sugars.hasCompleteData': 'True',
#  '$nutrition.sugars.name': 'Sugars',
#  '$nutrition.sugars.percentDailyValue': '0',
#  '$nutrition.sugars.unit': 'g',
#  '$nutrition.thiamin.amount': '0.1289342',
#  '$nutrition.thiamin.displayValue': '< 1',
#  '$nutrition.thiamin.hasCompleteData': 'False',
#  '$nutrition.thiamin.name': 'Thiamin',
#  '$nutrition.thiamin.percentDailyValue': '13',
#  '$nutrition.thiamin.unit': 'mg',
#  '$nutrition.vitaminA.amount': '595.6483',
#  '$nutrition.vitaminA.displayValue': '596',
#  '$nutrition.vitaminA.hasCompleteData': 'False',
#  '$nutrition.vitaminA.name': 'Vitamin A - IU',
#  '$nutrition.vitaminA.percentDailyValue': '12',
#  '$nutrition.vitaminA.unit': 'IU',
#  '$nutrition.vitaminB6.amount': '0.2310775',
#  '$nutrition.vitaminB6.displayValue': '< 1',
#  '$nutrition.vitaminB6.hasCompleteData': 'False',
#  '$nutrition.vitaminB6.name': 'Vitamin B6',
#  '$nutrition.vitaminB6.percentDailyValue': '14',
#  '$nutrition.vitaminB6.unit': 'mg',
#  '$nutrition.vitaminC.amount': '11.91473',
#  '$nutrition.vitaminC.displayValue': '12',
#  '$nutrition.vitaminC.hasCompleteData': 'False',
#  '$nutrition.vitaminC.name': 'Vitamin C',
#  '$nutrition.vitaminC.percentDailyValue': '20',
#  '$nutrition.vitaminC.unit': 'mg',
#  '$photo.description': '',
#  '$photo.itemType': 'Photo',
#  '$photo.photoDetailUrl': 'http://m.allrecipes.com/photos/14597',
#  '$photo.photoID': '14597',
#  '$photo.rawItemType': '10',
#  '$photo.recipeTitle': 'None',
#  '$photo.title': '',
#  '$photo.urls': "[{'height': 50, 'width': 50, 'url': 'http://images.media-allrecipes.com/userphotos/50x50/14597.jpg'}, {'height': 110, 'width': 110, 'url': 'http://images.media-allrecipes.com/userphotos/110x110/14597.jpg'}, {'height': 140, 'width': 140, 'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/01/45/14597.jpg'}, {'height': 250, 'width': 250, 'url': 'http://images.media-allrecipes.com/userphotos/250x250/14597.jpg'}]",
#  '$prepMinutes': '15',
#  '$ratingAverage': '4.305987',
#  '$ratingCount': '451',
#  '$readyInMinutes': '60',
#  '$recipeID': '47564',
#  '$reviewCount': '309',
#  '$servings': '4',
#  '$similarRecipes.links.self.href': 'https://apps.allrecipes.com/v1/recipes/47564',
#  '$similarRecipes.metaData.page': '1',
#  '$similarRecipes.metaData.pagesize': '20',
#  '$similarRecipes.metaData.totalCount': '20',
#  '$similarRecipes.recipes': '[{\'sourceID\': 461, \'ratingCount\': 64, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/3294074\', \'rawItemType\': 10, \'title\': \'\', \'itemType\': \'Photo\', \'recipeTitle\': None, \'description\': \'\', \'urls\': [{\'height\': 50, \'width\': 50, \'url\': \'http://images.media-allrecipes.com/userphotos/50x50/3294074.jpg\'}, {\'height\': 110, \'width\': 110, \'url\': \'http://images.media-allrecipes.com/userphotos/110x110/3294074.jpg\'}, {\'height\': 140, \'width\': 140, \'url\': \'http://images.media-allrecipes.com/userphotos/140x140/03/29/40/3294074.jpg\'}, {\'height\': 250, \'width\': 250, \'url\': \'http://images.media-allrecipes.com/userphotos/250x250/3294074.jpg\'}], \'photoID\': 3294074}, \'reviewCount\': 48, \'title\': \'Eggplant Parmesan For the Slow Cooker\', \'itemType\': \'Recipe\', \'description\': \'Make a big batch of eggplant Parmesan in your slow cooker and dinner will be waiting when you get home. No need to heat up your kitchen baking in an oven.\', \'videoID\': 0, \'submitter\': {\'favoritesCount\': 19, \'followersCount\': 12, \'ratingsCount\': 0, \'handle\': \'\', \'region\': None, \'itemType\': \'Cook\', \'promotedBrandPixelTrackingUrl\': None, \'name\': \'jboettcher2\', \'madeRecipesCount\': 0, \'country\': None, \'city\': None, \'userID\': 5752296, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/556955\', \'rawItemType\': 10, \'title\': \'\', \'itemType\': \'Photo\', \'recipeTitle\': None, \'description\': \'\', \'urls\': [{\'height\': 50, \'width\': 50, \'url\': \'http://images.media-allrecipes.com/userphotos/50x50/556955.jpg\'}, {\'height\': 110, \'width\': 110, \'url\': \'http://images.media-allrecipes.com/userphotos/110x110/556955.jpg\'}, {\'height\': 140, \'width\': 140, \'url\': \'http://images.media-allrecipes.com/userphotos/140x140/00/55/69/556955.jpg\'}, {\'height\': 250, \'width\': 250, \'url\': \'http://images.media-allrecipes.com/userphotos/250x250/556955.jpg\'}], \'photoID\': 556955}, \'isPro\': False, \'reciepesCount\': 1, \'profileUrl\': \'/cook/5752296/\', \'followingCount\': 0, \'reviewsCount\': 0, \'rawItemType\': 11, \'brandedSourceID\': 0, \'personalRecipeSharedCount\': 1}, \'recipeID\': 223360, \'recipeTrackingPixelUrl\': None, \'isSponsored\': False, \'ratingAverage\': 4.39, \'rawItemType\': 1, \'madeCount\': 86, \'links\': {\'recipeUrl\': {\'href\': \'http://allrecipes.com/recipe/eggplant-parmesan-for-the-slow-cooker/\'}, \'parent\': {\'href\': \'https://apps.allrecipes.com/v1/recipes/223360\'}}, \'type\': \'recipes\'}, {\'sourceID\': 461, \'ratingCount\': 30, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/3719268\', \'rawItemType\': 10, \'title\': \'\', \'itemType\': \'Photo\', \'recipeTitle\': None, \'description\': \'\', \'urls\': [{\'height\': 50, \'width\': 50, \'url\': \'http://images.media-allrecipes.com/userphotos/50x50/3719268.jpg\'}, {\'height\': 110, \'width\': 110, \'url\': \'http://images.media-allrecipes.com/userphotos/110x110/3719268.jpg\'}, {\'height\': 140, \'width\': 140, \'url\': \'http://images.media-allrecipes.com/userphotos/140x140/03/71/92/3719268.jpg\'}, {\'height\': 250, \'width\': 250, \'url\': \'http://images.media-allrecipes.com/userphotos/250x250/3719268.jpg\'}], \'photoID\': 3719268}, \'reviewCount\': 22, \'title\': "Chef John\'s Baked Eggplant Sandwiches", \'itemType\': \'Recipe\', \'description\': \'These breaded and baked eggplant sandwiches are the perfect make-ahead appetizer for your next potluck.\', \'videoID\': 3083, \'submitter\': {\'favoritesCount\': 363, \'followersCount\': 38210, \'ratingsCount\': 307, \'handle\': \'foodwisheswithchefjohn\', \'region\': None, \'itemType\': \'Cook\', \'promotedBrandPixelTrackingUrl\': None, \'name\': \'Chef John\', \'madeRecipesCount\': 309, \'country\': None, \'city\': None, \'userID\': 8601924, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/2267470\', \'rawItemType\': 10, \'title\': \'\', \'itemType\':  ...
#  '$sourceID': '461',
#  '$submitter.brandedSourceID': '0',
#  '$submitter.city': 'None',
#  '$submitter.country': 'None',
#  '$submitter.favoritesCount': '0',
#  '$submitter.followersCount': '0',
#  '$submitter.followingCount': '0',
#  '$submitter.handle': 'None',
#  '$submitter.isPro': 'False',
#  '$submitter.itemType': 'Cook',
#  '$submitter.madeRecipesCount': '0',
#  '$submitter.name': 'Yakuta',
#  '$submitter.personalRecipeSharedCount': '0',
#  '$submitter.photo.description': 'None',
#  '$submitter.photo.itemType': 'Photo',
#  '$submitter.photo.photoDetailUrl': 'None',
#  '$submitter.photo.rawItemType': '10',
#  '$submitter.photo.recipeTitle': 'None',
#  '$submitter.photo.title': 'None',
#  '$submitter.photo.urls': "[{'height': 50, 'width': 50, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png'}, {'height': 110, 'width': 110, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png'}, {'height': 140, 'width': 140, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png'}, {'height': 250, 'width': 250, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png'}]",
#  '$submitter.profileUrl': '',
#  '$submitter.promotedBrandPixelTrackingUrl': 'None',
#  '$submitter.ratingsCount': '0',
#  '$submitter.rawItemType': '11',
#  '$submitter.reciepesCount': '0',
#  '$submitter.region': 'None',
#  '$submitter.reviewsCount': '0',
#  '$submitter.userID': '0',
#  '$title': 'Baingan Bharta (Eggplant Curry)',
#  '$topReviews': '[{\'links\': {\'incrementHelpfulCount\': {\'href\': \'https://apps.allrecipes.com/v1/recipes/47564/reviews/1815671/increment-helpful-count\'}}, \'helpfulCount\': 361, \'text\': "The recipe is almost authentic - i say almost because Indians use garam masala and not curry powder. I don\'t add yogurt to my baingan bharta, but adding it isn\'t a sin, i wouldn\'t heat the dish after adding yogurt. Also, the eggplant is usually fire roasted and the smokey flavor is just outstanding. Also a small teaspoon of lemon juice in the end brings all the flavors out.", \'rawItemType\': 9, \'dateLastModified\': \'2009-03-11T13:33:32.31\', \'itemType\': \'Review\', \'rating\': 4, \'submitter\': {\'favoritesCount\': 21, \'followersCount\': 0, \'ratingsCount\': 15, \'handle\': \'\', \'region\': None, \'itemType\': \'Cook\', \'promotedBrandPixelTrackingUrl\': None, \'name\': \'SUSHANK\', \'madeRecipesCount\': 15, \'country\': None, \'city\': None, \'userID\': 844246, \'photo\': {\'photoDetailUrl\': None, \'rawItemType\': 10, \'title\': None, \'itemType\': \'Photo\', \'recipeTitle\': None, \'description\': None, \'urls\': [{\'height\': 50, \'width\': 50, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png\'}, {\'height\': 110, \'width\': 110, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png\'}, {\'height\': 140, \'width\': 140, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png\'}, {\'height\': 250, \'width\': 250, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png\'}]}, \'isPro\': False, \'reciepesCount\': 0, \'profileUrl\': \'/cook/844246/\', \'followingCount\': 0, \'reviewsCount\': 13, \'rawItemType\': 11, \'brandedSourceID\': 0, \'personalRecipeSharedCount\': 0}, \'reviewID\': 1815671}, {\'links\': {\'incrementHelpfulCount\': {\'href\': \'https://apps.allrecipes.com/v1/recipes/47564/reviews/1254574/increment-helpful-count\'}}, \'helpfulCount\': 278, \'text\': \'great recipe. I am second generation Indian and this is one of my favorite dishes. I made the eggplant the day before just to save time; I cut it in half lengthwise, sprayed the cut side with Pam, and then baked it on a foil lined cookie sheet, cut side down. I baked it for 20 minutes or so and it was so tender that I just scraped it out of the skin with a spoon. I used a can of plum tomatoes instead of a tomato, and cut the tomatoes into a small dice. I saved the liquid and added it to the dish right before I started to simmer it. I also added about a cup of frozen baby peas at the same time as the eggplant. Used ginger paste and minced garlic. Great recipe.\', \'rawItemType\': 9, \'dateLastModified\': \'2008-01-21T16:56:31.387\', \'itemType\': \'Review\', \'rating\': 5, \'submitter\': {\'favoritesCount\': 109, \'followersCount\': 0, \'ratingsCount\': 25, \'handle\': \'\', \'region\': None, \'itemType\': \'Cook\', \'promotedBrandPixelTrackingUrl\': None, \'name\': \'Shmoopy\', \'madeRecipesCount\': 25, \'country\': None, \'city\': None, \'userID\': 747353, \'photo\': {\'photoDetailUrl\': None, \'rawItemType\': 10, \'title\': None, \'itemType\': \'Photo\', \'recipeTitle\': None, \'description\': None, \'urls\': [{\'height\': 50, \'width\': 50, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png\'}, {\'height\': 110, \'width\': 110, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png\'}, {\'height\': 140, \'width\': 140, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png\'}, {\'height\': 250, \'width\': 250, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png\'}]}, \'isPro\': False, \'reciepesCount\': 0, \'profileUrl\': \'/cook/747353/\', \'followingCount\': 0, \'reviewsCount\': 25, \'rawItemType\': 11, \'brandedSourceID\': 0, \'personalRecipeSharedCount\': 1}, \' ...
#  '$type': 'recipes',
#  '$video': 'None'}

# %%
def is_number(myStr):
    # str as input, returns true if is int or float
    try:
        float(myStr)
        return True
    except ValueError:
        return False
    
def make_column_name(myName):
    # creates a name inspired from myName removing leading '$' sign (for mongodb) and '.' because of Pandas
    return myName[1:].replace('.', '_') 
    
is_number(allKeysWithDescription['$nutrition.potassium.amount'])
#allKeysWithDescription['$nutrition.potassium.amount']
# Out:
# True

# %%
def get_keys_to_take_with_args(allKeysWithDescription):
    # only takes keys that are ints and make some sense
    
    acceptedKeysWithArguments = dict() # arguments for function

    for keyName, value in allKeysWithDescription.items():

        # only recognizes single integers, not lists
        if is_number(value):
            
            #if 'submitter' in keyName:
            #    print(keyName)
            
            

                
            if (keyName.startswith(tuple(['$adUnit', '$photo.']))
                or keyName.endswith(tuple(['.displayValue']))
                or (keyName in ['$similarRecipes.metaData.page'])
                or any((word in keyName) for word in ['.rawItemType', 'ID', 
                                                      'percentDailyValue'])): 
                # ignore percentDailyValue
                
                # displayValue not relevant
                continue

            aggregFunction = None
            if (keyName.endswith(tuple(['Count', '.amount']))
                or (keyName in ['$prepMinutes', '$cookMinutes', '$servings', '$readyInMinutes',
                                '$ratingAverage', '$similarRecipes.metaData.pagesize', 
                               ])):
                aggregFunction = '$avg'
                outputName = 'avg_' + make_column_name(keyName)
            else:
                print("Ignoring ok? {}: {}".format(keyName, value))
                continue

            args = {
                'aggregate_field_address': keyName, 
                'aggregate_field_output_name': outputName,
                'aggregationFunction': aggregFunction
            }
            acceptedKeysWithArguments[keyName] = args
    
    return acceptedKeysWithArguments

acceptedKeysWithArguments = get_keys_to_take_with_args(allKeysWithDescription)
acceptedKeysWithArguments
#list(acceptedKeysWithArguments.values())
# Out:
# {'$cookMinutes': {'aggregate_field_address': '$cookMinutes',
#   'aggregate_field_output_name': 'avg_cookMinutes',
#   'aggregationFunction': '$avg'},
#  '$nutrition.calcium.amount': {'aggregate_field_address': '$nutrition.calcium.amount',
#   'aggregate_field_output_name': 'avg_nutrition_calcium_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.calories.amount': {'aggregate_field_address': '$nutrition.calories.amount',
#   'aggregate_field_output_name': 'avg_nutrition_calories_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.caloriesFromFat.amount': {'aggregate_field_address': '$nutrition.caloriesFromFat.amount',
#   'aggregate_field_output_name': 'avg_nutrition_caloriesFromFat_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.carbohydrates.amount': {'aggregate_field_address': '$nutrition.carbohydrates.amount',
#   'aggregate_field_output_name': 'avg_nutrition_carbohydrates_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.cholesterol.amount': {'aggregate_field_address': '$nutrition.cholesterol.amount',
#   'aggregate_field_output_name': 'avg_nutrition_cholesterol_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.fat.amount': {'aggregate_field_address': '$nutrition.fat.amount',
#   'aggregate_field_output_name': 'avg_nutrition_fat_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.fiber.amount': {'aggregate_field_address': '$nutrition.fiber.amount',
#   'aggregate_field_output_name': 'avg_nutrition_fiber_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.folate.amount': {'aggregate_field_address': '$nutrition.folate.amount',
#   'aggregate_field_output_name': 'avg_nutrition_folate_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.iron.amount': {'aggregate_field_address': '$nutrition.iron.amount',
#   'aggregate_field_output_name': 'avg_nutrition_iron_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.magnesium.amount': {'aggregate_field_address': '$nutrition.magnesium.amount',
#   'aggregate_field_output_name': 'avg_nutrition_magnesium_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.niacin.amount': {'aggregate_field_address': '$nutrition.niacin.amount',
#   'aggregate_field_output_name': 'avg_nutrition_niacin_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.potassium.amount': {'aggregate_field_address': '$nutrition.potassium.amount',
#   'aggregate_field_output_name': 'avg_nutrition_potassium_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.protein.amount': {'aggregate_field_address': '$nutrition.protein.amount',
#   'aggregate_field_output_name': 'avg_nutrition_protein_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.saturatedFat.amount': {'aggregate_field_address': '$nutrition.saturatedFat.amount',
#   'aggregate_field_output_name': 'avg_nutrition_saturatedFat_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.sodium.amount': {'aggregate_field_address': '$nutrition.sodium.amount',
#   'aggregate_field_output_name': 'avg_nutrition_sodium_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.sugars.amount': {'aggregate_field_address': '$nutrition.sugars.amount',
#   'aggregate_field_output_name': 'avg_nutrition_sugars_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.thiamin.amount': {'aggregate_field_address': '$nutrition.thiamin.amount',
#   'aggregate_field_output_name': 'avg_nutrition_thiamin_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.vitaminA.amount': {'aggregate_field_address': '$nutrition.vitaminA.amount',
#   'aggregate_field_output_name': 'avg_nutrition_vitaminA_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.vitaminB6.amount': {'aggregate_field_address': '$nutrition.vitaminB6.amount',
#   'aggregate_field_output_name': 'avg_nutrition_vitaminB6_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.vitaminC.amount': {'aggregate_field_address': '$nutrition.vitaminC.amount',
#   'aggregate_field_output_name': 'avg_nutrition_vitaminC_amount',
#   'aggregationFunction': '$avg'},
#  '$prepMinutes': {'aggregate_field_address': '$prepMinutes',
#   'aggregate_field_output_name': 'avg_prepMinutes',
#   'aggregationFunction': '$avg'},
#  '$ratingAverage': {'aggregate_field_address': '$ratingAverage',
#   'aggregate_field_output_name': 'avg_ratingAverage',
#   'aggregationFunction': '$avg'},
#  '$ratingCount': {'aggregate_field_address': '$ratingCount',
#   'aggregate_field_output_name': 'avg_ratingCount',
#   'aggregationFunction': '$avg'},
#  '$readyInMinutes': {'aggregate_field_address': '$readyInMinutes',
#   'aggregate_field_output_name': 'avg_readyInMinutes',
#   'aggregationFunction': '$avg'},
#  '$reviewCount': {'aggregate_field_address': '$reviewCount',
#   'aggregate_field_output_name': 'avg_reviewCount',
#   'aggregationFunction': '$avg'},
#  '$servings': {'aggregate_field_address': '$servings',
#   'aggregate_field_output_name': 'avg_servings',
#   'aggregationFunction': '$avg'},
#  '$similarRecipes.metaData.pagesize': {'aggregate_field_address': '$similarRecipes.metaData.pagesize',
#   'aggregate_field_output_name': 'avg_similarRecipes_metaData_pagesize',
#   'aggregationFunction': '$avg'},
#  '$similarRecipes.metaData.totalCount': {'aggregate_field_address': '$similarRecipes.metaData.totalCount',
#   'aggregate_field_output_name': 'avg_similarRecipes_metaData_totalCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.favoritesCount': {'aggregate_field_address': '$submitter.favoritesCount',
#   'aggregate_field_output_name': 'avg_submitter_favoritesCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.followersCount': {'aggregate_field_address': '$submitter.followersCount',
#   'aggregate_field_output_name': 'avg_submitter_followersCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.followingCount': {'aggregate_field_address': '$submitter.followingCount',
#   'aggregate_field_output_name': 'avg_submitter_followingCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.madeRecipesCount': {'aggregate_field_address': '$submitter.madeRecipesCount',
#   'aggregate_field_output_name': 'avg_submitter_madeRecipesCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.personalRecipeSharedCount': {'aggregate_field_address': '$submitter.personalRecipeSharedCount',
#   'aggregate_field_output_name': 'avg_submitter_personalRecipeSharedCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.ratingsCount': {'aggregate_field_address': '$submitter.ratingsCount',
#   'aggregate_field_output_name': 'avg_submitter_ratingsCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.reciepesCount': {'aggregate_field_address': '$submitter.reciepesCount',
#   'aggregate_field_output_name': 'avg_submitter_reciepesCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.reviewsCount': {'aggregate_field_address': '$submitter.reviewsCount',
#   'aggregate_field_output_name': 'avg_submitter_reviewsCount',
#   'aggregationFunction': '$avg'}}

# %%
# group bys
groupBysToQuery = [
    {
        # get global average
        'group_by_field_address': 'get_global_aggregation',
        'group_by_field_output_name': 'DummyColumn' # ignored,
    },
    {
        'group_by_field_address': '$ada-country',
        'group_by_field_output_name': 'country', # as it appears in dataframe
    }
    {
        'group_by_field_address': '$ada-city',
        'group_by_field_output_name': 'city', # as it appears in dataframe
    },
]

# keep in sync with above groupBys
dataframeNames = ['global', 'per_country', 'per_city']

# what to aggregate for, from valid keys extracted above
fieldArgumentsToQuery = list(acceptedKeysWithArguments.values())

allDfs = getAllDataframes(collection, groupBysToQuery, fieldArgumentsToQuery, dataframeNames)
# Out:
# Query 1/74 with arguments: {'aggregate_field_address': '$nutrition.caloriesFromFat.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_caloriesFromFat_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 2/74 with arguments: {'aggregate_field_address': '$submitter.madeRecipesCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_submitter_madeRecipesCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 3/74 with arguments: {'aggregate_field_address': '$submitter.reciepesCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_submitter_reciepesCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 4/74 with arguments: {'aggregate_field_address': '$submitter.personalRecipeSharedCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_submitter_personalRecipeSharedCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 5/74 with arguments: {'aggregate_field_address': '$nutrition.cholesterol.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_cholesterol_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 6/74 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.pagesize', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_pagesize', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 7/74 with arguments: {'aggregate_field_address': '$cookMinutes', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_cookMinutes', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 8/74 with arguments: {'aggregate_field_address': '$nutrition.sugars.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_sugars_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 9/74 with arguments: {'aggregate_field_address': '$prepMinutes', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_prepMinutes', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 10/74 with arguments: {'aggregate_field_address': '$nutrition.vitaminB6.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_vitaminB6_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 11/74 with arguments: {'aggregate_field_address': '$nutrition.fiber.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_fiber_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 12/74 with arguments: {'aggregate_field_address': '$nutrition.saturatedFat.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_saturatedFat_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 13/74 with arguments: {'aggregate_field_address': '$nutrition.magnesium.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_magnesium_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 14/74 with arguments: {'aggregate_field_address': '$nutrition.calories.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_calories_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 15/74 with arguments: {'aggregate_field_address': '$submitter.ratingsCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_submitter_ratingsCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 16/74 with arguments: {'aggregate_field_address': '$reviewCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_reviewCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 17/74 with arguments: {'aggregate_field_address': '$nutrition.thiamin.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_thiamin_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 18/74 with arguments: {'aggregate_field_address': '$nutrition.vitaminC.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_vitaminC_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 19/74 with arguments: {'aggregate_field_address': '$nutrition.sodium.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_sodium_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 20/74 with arguments: {'aggregate_field_address': '$ratingAverage', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_ratingAverage', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 21/74 with arguments: {'aggregate_field_address': '$nutrition.calcium.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_calcium_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 22/74 with arguments: {'aggregate_field_address': '$nutrition.folate.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_folate_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 23/74 with arguments: {'aggregate_field_address': '$nutrition.vitaminA.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_vitaminA_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 24/74 with arguments: {'aggregate_field_address': '$ratingCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_ratingCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 25/74 with arguments: {'aggregate_field_address': '$nutrition.potassium.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_potassium_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 26/74 with arguments: {'aggregate_field_address': '$nutrition.fat.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_fat_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 27/74 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.totalCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_totalCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 28/74 with arguments: {'aggregate_field_address': '$submitter.followersCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_submitter_followersCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 29/74 with arguments: {'aggregate_field_address': '$servings', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_servings', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 30/74 with arguments: {'aggregate_field_address': '$readyInMinutes', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_readyInMinutes', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 31/74 with arguments: {'aggregate_field_address': '$submitter.reviewsCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_submitter_reviewsCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 32/74 with arguments: {'aggregate_field_address': '$submitter.followingCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_submitter_followingCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 33/74 with arguments: {'aggregate_field_address': '$nutrition.iron.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_iron_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 34/74 with arguments: {'aggregate_field_address': '$nutrition.protein.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_protein_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 35/74 with arguments: {'aggregate_field_address': '$submitter.favoritesCount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_submitter_favoritesCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 36/74 with arguments: {'aggregate_field_address': '$nutrition.niacin.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_niacin_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 37/74 with arguments: {'aggregate_field_address': '$nutrition.carbohydrates.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregate_field_output_name': 'avg_nutrition_carbohydrates_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn'}
# Query 38/74 with arguments: {'aggregate_field_address': '$nutrition.caloriesFromFat.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_caloriesFromFat_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 39/74 with arguments: {'aggregate_field_address': '$submitter.madeRecipesCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_submitter_madeRecipesCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 40/74 with arguments: {'aggregate_field_address': '$submitter.reciepesCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_submitter_reciepesCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 41/74 with arguments: {'aggregate_field_address': '$submitter.personalRecipeSharedCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_submitter_personalRecipeSharedCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 42/74 with arguments: {'aggregate_field_address': '$nutrition.cholesterol.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_cholesterol_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 43/74 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.pagesize', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_pagesize', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 44/74 with arguments: {'aggregate_field_address': '$cookMinutes', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_cookMinutes', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 45/74 with arguments: {'aggregate_field_address': '$nutrition.sugars.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_sugars_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 46/74 with arguments: {'aggregate_field_address': '$prepMinutes', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_prepMinutes', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 47/74 with arguments: {'aggregate_field_address': '$nutrition.vitaminB6.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_vitaminB6_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 48/74 with arguments: {'aggregate_field_address': '$nutrition.fiber.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_fiber_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 49/74 with arguments: {'aggregate_field_address': '$nutrition.saturatedFat.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_saturatedFat_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 50/74 with arguments: {'aggregate_field_address': '$nutrition.magnesium.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_magnesium_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 51/74 with arguments: {'aggregate_field_address': '$nutrition.calories.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_calories_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 52/74 with arguments: {'aggregate_field_address': '$submitter.ratingsCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_submitter_ratingsCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 53/74 with arguments: {'aggregate_field_address': '$reviewCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_reviewCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 54/74 with arguments: {'aggregate_field_address': '$nutrition.thiamin.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_thiamin_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 55/74 with arguments: {'aggregate_field_address': '$nutrition.vitaminC.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_vitaminC_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 56/74 with arguments: {'aggregate_field_address': '$nutrition.sodium.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_sodium_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 57/74 with arguments: {'aggregate_field_address': '$ratingAverage', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_ratingAverage', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 58/74 with arguments: {'aggregate_field_address': '$nutrition.calcium.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_calcium_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 59/74 with arguments: {'aggregate_field_address': '$nutrition.folate.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_folate_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 60/74 with arguments: {'aggregate_field_address': '$nutrition.vitaminA.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_vitaminA_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 61/74 with arguments: {'aggregate_field_address': '$ratingCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_ratingCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 62/74 with arguments: {'aggregate_field_address': '$nutrition.potassium.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_potassium_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 63/74 with arguments: {'aggregate_field_address': '$nutrition.fat.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_fat_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 64/74 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.totalCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_totalCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 65/74 with arguments: {'aggregate_field_address': '$submitter.followersCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_submitter_followersCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 66/74 with arguments: {'aggregate_field_address': '$servings', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_servings', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 67/74 with arguments: {'aggregate_field_address': '$readyInMinutes', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_readyInMinutes', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 68/74 with arguments: {'aggregate_field_address': '$submitter.reviewsCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_submitter_reviewsCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 69/74 with arguments: {'aggregate_field_address': '$submitter.followingCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_submitter_followingCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 70/74 with arguments: {'aggregate_field_address': '$nutrition.iron.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_iron_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 71/74 with arguments: {'aggregate_field_address': '$nutrition.protein.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_protein_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 72/74 with arguments: {'aggregate_field_address': '$submitter.favoritesCount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_submitter_favoritesCount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 73/74 with arguments: {'aggregate_field_address': '$nutrition.niacin.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_niacin_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}
# Query 74/74 with arguments: {'aggregate_field_address': '$nutrition.carbohydrates.amount', 'group_by_field_address': '$ada-country', 'aggregate_field_output_name': 'avg_nutrition_carbohydrates_amount', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country'}

# %%
import os

json_output_filename = '../website/data/aggregatedData.json'

os.makedirs(os.path.dirname(json_output_filename), exist_ok=True)
write_dataframes_to_json(json_output_filename, allDfs)

# %%
# !cat '../website/data/aggregatedData.json'
# Out:
# {
#     "per_city": {
#         "dallas": {
#             "avg_submitter_ratingsCount": 10.3103448276,
#             "avg_submitter_reciepesCount": 2.1724137931,
#             "avg_nutrition_fiber_amount": 3.3479804724,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.1641491599,
#             "avg_similarRecipes_metaData_pagesize": 17.2413793103,
#             "avg_readyInMinutes": 113.9310344828,
#             "avg_submitter_favoritesCount": 95.724137931,
#             "avg_cookMinutes": 16.5172413793,
#             "avg_nutrition_saturatedFat_amount": 4.5802688862,
#             "avg_reviewCount": 85.7586206897,
#             "avg_nutrition_potassium_amount": 347.4378434483,
#             "avg_submitter_madeRecipesCount": 10.7931034483,
#             "avg_nutrition_calcium_amount": 84.7029391034,
#             "avg_submitter_personalRecipeSharedCount": 4.7931034483,
#             "avg_nutrition_vitaminA_amount": 2142.7329715172,
#             "avg_nutrition_carbohydrates_amount": 29.1065187586,
#             "avg_similarRecipes_metaData_totalCount": 17.2413793103,
#             "avg_nutrition_fat_amount": 14.259867369,
#             "avg_nutrition_iron_amount": 1.9520466376,
#             "avg_nutrition_vitaminC_amount": 21.5955942847,
#             "avg_ratingCount": 107.7586206897,
#             "avg_nutrition_sodium_amount": 555.5156519655,
#             "avg_nutrition_cholesterol_amount": 48.2601582759,
#             "avg_ratingAverage": 4.5723076031,
#             "avg_prepMinutes": 17.8275862069,
#             "nbRecipes": 29,
#             "avg_nutrition_protein_amount": 9.7854165345,
#             "avg_nutrition_niacin_amount": 3.7490150276,
#             "avg_nutrition_vitaminB6_amount": 0.2289084511,
#             "avg_nutrition_caloriesFromFat_amount": 128.338812069,
#             "avg_nutrition_sugars_amount": 12.2154127862,
#             "avg_servings": 14.724137931,
#             "avg_nutrition_calories_amount": 281.9190327586,
#             "avg_submitter_followersCount": 1.1034482759,
#             "avg_submitter_reviewsCount": 6.2068965517,
#             "avg_nutrition_magnesium_amount": 31.8671556552,
#             "avg_nutrition_folate_amount": 48.1794948276
#         },
#         "new-orleans": {
#             "avg_submitter_ratingsCount": 52.4565217391,
#             "avg_submitter_reciepesCount": 75.3695652174,
#             "avg_nutrition_fiber_amount": 2.5569047091,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.3470168237,
#             "avg_similarRecipes_metaData_pagesize": 14.152173913,
#             "avg_readyInMinutes": 1050.3260869565,
#             "avg_submitter_favoritesCount": 258.3043478261,
#             "avg_cookMinutes": 28.5434782609,
#             "avg_nutrition_saturatedFat_amount": 9.5023519814,
#             "avg_reviewCount": 32.3913043478,
#             "avg_nutrition_potassium_amount": 395.3045097674,
#             "avg_submitter_madeRecipesCount": 56.4347826087,
#             "avg_nutrition_calcium_amount": 128.9259451163,
#             "avg_submitter_personalRecipeSharedCount": 6.8260869565,
#             "avg_nutrition_vitaminA_amount": 992.4081416279,
#             "avg_nutrition_carbohydrates_amount": 37.0686305279,
#             "avg_similarRecipes_metaData_totalCount": 14.152173913,
#             "avg_nutrition_fat_amount": 22.267603107,
#             "avg_nutrition_iron_amount": 3.7052496693,
#             "avg_nutrition_vitaminC_amount": 18.2565974605,
#             "avg_ratingCount": 40.6086956522,
#             "avg_nutrition_sodium_amount": 845.9362781395,
#             "avg_nutrition_cholesterol_amount": 112.8882237209,
#             "avg_ratingAverage": 4.3605372796,
#             "avg_prepMinutes": 21.4565217391,
#             "nbRecipes": 46,
#             "avg_nutrition_protein_amount": 17.4942017521,
#             "avg_nutrition_niacin_amount": 6.4543105844,
#             "avg_nutrition_vitaminB6_amount": 0.2601072309,
#             "avg_nutrition_caloriesFromFat_amount": 200.4084444419,
#             "avg_nutrition_sugars_amount": 10.9223112407,
#             "avg_servings": 10.347826087,
#             "avg_nutrition_calories_amount": 445.9402834884,
#             "avg_submitter_followersCount": 137098.2173913044,
#             "avg_submitter_reviewsCount": 7.5217391304,
#             "avg_nutrition_magnesium_amount": 46.5328142558,
#             "avg_nutrition_folate_amount": 78.3735415814
#         },
#         "cincinnati": {
#             "avg_submitter_ratingsCount": 2.9166666667,
#             "avg_submitter_reciepesCount": 30.25,
#             "avg_nutrition_fiber_amount": 5.79568,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.3062611983,
#             "avg_similarRecipes_metaData_pagesize": 14.75,
#             "avg_readyInMinutes": 140.0,
#             "avg_submitter_favoritesCount": 65.6666666667,
#             "avg_cookMinutes": 53.3333333333,
#             "avg_nutrition_saturatedFat_amount": 7.5697554833,
#             "avg_reviewCount": 62.9166666667,
#             "avg_nutrition_potassium_amount": 563.3410333333,
#             "avg_submitter_madeRecipesCount": 3.0,
#             "avg_nutrition_calcium_amount": 120.0086608333,
#             "avg_submitter_personalRecipeSharedCount": 5.75,
#             "avg_nutrition_vitaminA_amount": 3300.7328333333,
#             "avg_nutrition_carbohydrates_amount": 35.1568405,
#             "avg_similarRecipes_metaData_totalCount": 14.75,
#             "avg_nutrition_fat_amount": 19.712018,
#             "avg_nutrition_iron_amount": 4.81320185,
#             "avg_nutrition_vitaminC_amount": 16.8670281667,
#             "avg_ratingCount": 78.5833333333,
#             "avg_nutrition_sodium_amount": 755.1521833333,
#             "avg_nutrition_cholesterol_amount": 65.80625,
#             "avg_ratingAverage": 4.21401596,
#             "avg_prepMinutes": 35.0,
#             "nbRecipes": 12,
#             "avg_nutrition_protein_amount": 28.6368300833,
#             "avg_nutrition_niacin_amount": 10.1573376667,
#             "avg_nutrition_vitaminB6_amount": 0.409118955,
#             "avg_nutrition_caloriesFromFat_amount": 177.4081733333,
#             "avg_nutrition_sugars_amount": 8.8096128083,
#             "avg_servings": 9.3333333333,
#             "avg_nutrition_calories_amount": 424.625025,
#             "avg_submitter_followersCount": 3097.8333333333,
#             "avg_submitter_reviewsCount": 2.25,
#             "avg_nutrition_magnesium_amount": 54.6861808333,
#             "avg_nutrition_folate_amount": 85.2405008333
#         },
#         "washington-dc": {
#             "avg_submitter_ratingsCount": 46.2941176471,
#             "avg_submitter_reciepesCount": 3.9411764706,
#             "avg_nutrition_fiber_amount": 2.5143586588,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.2183516822,
#             "avg_similarRecipes_metaData_pagesize": 13.8823529412,
#             "avg_readyInMinutes": 82.4117647059,
#             "avg_submitter_favoritesCount": 149.0,
#             "avg_cookMinutes": 28.8823529412,
#             "avg_nutrition_saturatedFat_amount": 5.1949467889,
#             "avg_reviewCount": 36.8823529412,
#             "avg_nutrition_potassium_amount": 263.0176747059,
#             "avg_submitter_madeRecipesCount": 45.1764705882,
#             "avg_nutrition_calcium_amount": 85.1309185882,
#             "avg_submitter_personalRecipeSharedCount": 7.0588235294,
#             "avg_nutrition_vitaminA_amount": 556.0620082353,
#             "avg_nutrition_carbohydrates_amount": 30.1448429412,
#             "avg_similarRecipes_metaData_totalCount": 13.8823529412,
#             "avg_nutrition_fat_amount": 11.7323213282,
#             "avg_nutrition_iron_amount": 1.8306628629,
#             "avg_nutrition_vitaminC_amount": 4.8250190312,
#             "avg_ratingCount": 47.3529411765,
#             "avg_nutrition_sodium_amount": 520.0368023529,
#             "avg_nutrition_cholesterol_amount": 36.9518935294,
#             "avg_ratingAverage": 4.1564743029,
#             "avg_prepMinutes": 8.8235294118,
#             "nbRecipes": 17,
#             "avg_nutrition_protein_amount": 11.3334982882,
#             "avg_nutrition_niacin_amount": 4.13972622,
#             "avg_nutrition_vitaminB6_amount": 0.1639603912,
#             "avg_nutrition_caloriesFromFat_amount": 105.5908827176,
#             "avg_nutrition_sugars_amount": 15.6633245235,
#             "avg_servings": 15.8235294118,
#             "avg_nutrition_calories_amount": 291.5897064706,
#             "avg_submitter_followersCount": 21.9411764706,
#             "avg_submitter_reviewsCount": 13.9411764706,
#             "avg_nutrition_magnesium_amount": 27.6724211765,
#             "avg_nutrition_folate_amount": 41.3091746471
#         },
#         "indianapolis": {
#             "avg_submitter_ratingsCount": 34.0,
#             "avg_submitter_reciepesCount": 22.2,
#             "avg_nutrition_fiber_amount": 1.8113013571,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.4542568831,
#             "avg_similarRecipes_metaData_pagesize": 15.2,
#             "avg_readyInMinutes": 66.8666666667,
#             "avg_submitter_favoritesCount": 95.2666666667,
#             "avg_cookMinutes": 51.0,
#             "avg_nutrition_saturatedFat_amount": 7.5749152914,
#             "avg_reviewCount": 67.6666666667,
#             "avg_nutrition_potassium_amount": 432.0371707143,
#             "avg_submitter_madeRecipesCount": 34.4,
#             "avg_nutrition_calcium_amount": 106.6231562143,
#             "avg_submitter_personalRecipeSharedCount": 6.2666666667,
#             "avg_nutrition_vitaminA_amount": 877.3949448714,
#             "avg_nutrition_carbohydrates_amount": 35.2995767143,
#             "avg_similarRecipes_metaData_totalCount": 15.2,
#             "avg_nutrition_fat_amount": 20.78013555,
#             "avg_nutrition_iron_amount": 2.8803651857,
#             "avg_nutrition_vitaminC_amount": 7.7831920016,
#             "avg_ratingCount": 87.0666666667,
#             "avg_nutrition_sodium_amount": 641.9893585714,
#             "avg_nutrition_cholesterol_amount": 77.7785842857,
#             "avg_ratingAverage": 3.8851282473,
#             "avg_prepMinutes": 10.8666666667,
#             "nbRecipes": 15,
#             "avg_nutrition_protein_amount": 20.4746948193,
#             "avg_nutrition_niacin_amount": 7.5555770779,
#             "avg_nutrition_vitaminB6_amount": 0.3967395311,
#             "avg_nutrition_caloriesFromFat_amount": 187.0212205714,
#             "avg_nutrition_sugars_amount": 15.7910325714,
#             "avg_servings": 7.9333333333,
#             "avg_nutrition_calories_amount": 425.4122357143,
#             "avg_submitter_followersCount": 13.4666666667,
#             "avg_submitter_reviewsCount": 30.8666666667,
#             "avg_nutrition_magnesium_amount": 32.4746160714,
#             "avg_nutrition_folate_amount": 38.1160503714
#         },
#         "milwaukee": {
#             "avg_submitter_ratingsCount": 217.5555555556,
#             "avg_submitter_reciepesCount": 2.2592592593,
#             "avg_nutrition_fiber_amount": 2.3278076571,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.1554577799,
#             "avg_similarRecipes_metaData_pagesize": 12.9259259259,
#             "avg_readyInMinutes": 158.8888888889,
#             "avg_submitter_favoritesCount": 201.4814814815,
#             "avg_cookMinutes": 43.5185185185,
#             "avg_nutrition_saturatedFat_amount": 7.4278637206,
#             "avg_reviewCount": 56.9259259259,
#             "avg_nutrition_potassium_amount": 303.862565381,
#             "avg_submitter_madeRecipesCount": 211.6296296296,
#             "avg_nutrition_calcium_amount": 122.7239127619,
#             "avg_submitter_personalRecipeSharedCount": 1.8888888889,
#             "avg_nutrition_vitaminA_amount": 1254.0578828571,
#             "avg_nutrition_carbohydrates_amount": 31.8670666333,
#             "avg_similarRecipes_metaData_totalCount": 12.9259259259,
#             "avg_nutrition_fat_amount": 16.6411957538,
#             "avg_nutrition_iron_amount": 2.3519146581,
#             "avg_nutrition_vitaminC_amount": 4.0750595929,
#             "avg_ratingCount": 72.7777777778,
#             "avg_nutrition_sodium_amount": 473.4390500905,
#             "avg_nutrition_cholesterol_amount": 71.0539208571,
#             "avg_ratingAverage": 4.3539763722,
#             "avg_prepMinutes": 18.7037037037,
#             "nbRecipes": 27,
#             "avg_nutrition_protein_amount": 16.8256470076,
#             "avg_nutrition_niacin_amount": 6.3474277967,
#             "avg_nutrition_vitaminB6_amount": 0.2583515574,
#             "avg_nutrition_caloriesFromFat_amount": 149.7707734524,
#             "avg_nutrition_sugars_amount": 17.4172225381,
#             "avg_servings": 19.7407407407,
#             "avg_nutrition_calories_amount": 344.2545928571,
#             "avg_submitter_followersCount": 294.6296296296,
#             "avg_submitter_reviewsCount": 214.3703703704,
#             "avg_nutrition_magnesium_amount": 30.9155015095,
#             "avg_nutrition_folate_amount": 41.4845067857
#         },
#         "buffalo": {
#             "avg_submitter_ratingsCount": 23.7073170732,
#             "avg_submitter_reciepesCount": 46.6097560976,
#             "avg_nutrition_fiber_amount": 1.4754392502,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.1099706034,
#             "avg_similarRecipes_metaData_pagesize": 15.6585365854,
#             "avg_readyInMinutes": 58.9512195122,
#             "avg_submitter_favoritesCount": 110.8292682927,
#             "avg_cookMinutes": 27.243902439,
#             "avg_nutrition_saturatedFat_amount": 6.653792509,
#             "avg_reviewCount": 36.2682926829,
#             "avg_nutrition_potassium_amount": 249.2301235854,
#             "avg_submitter_madeRecipesCount": 25.0731707317,
#             "avg_nutrition_calcium_amount": 65.7200556195,
#             "avg_submitter_personalRecipeSharedCount": 9.8536585366,
#             "avg_nutrition_vitaminA_amount": 586.9734563902,
#             "avg_nutrition_carbohydrates_amount": 18.7452494951,
#             "avg_similarRecipes_metaData_totalCount": 15.6585365854,
#             "avg_nutrition_fat_amount": 17.3080967829,
#             "avg_nutrition_iron_amount": 1.9006710515,
#             "avg_nutrition_vitaminC_amount": 18.0834784651,
#             "avg_ratingCount": 46.2682926829,
#             "avg_nutrition_sodium_amount": 751.4575639024,
#             "avg_nutrition_cholesterol_amount": 63.7754877317,
#             "avg_ratingAverage": 3.9525303493,
#             "avg_prepMinutes": 12.5609756098,
#             "nbRecipes": 41,
#             "avg_nutrition_protein_amount": 11.4925765829,
#             "avg_nutrition_niacin_amount": 4.2063185402,
#             "avg_nutrition_vitaminB6_amount": 0.1978445112,
#             "avg_nutrition_caloriesFromFat_amount": 155.7728659024,
#             "avg_nutrition_sugars_amount": 6.7007981976,
#             "avg_servings": 11.5365853659,
#             "avg_nutrition_calories_amount": 274.4892507317,
#             "avg_submitter_followersCount": 1913.7804878049,
#             "avg_submitter_reviewsCount": 7.8048780488,
#             "avg_nutrition_magnesium_amount": 26.2155527951,
#             "avg_nutrition_folate_amount": 33.2850871244
#         },
#         "seattle": {
#             "avg_submitter_ratingsCount": 62.7014925373,
#             "avg_submitter_reciepesCount": 19.3432835821,
#             "avg_nutrition_fiber_amount": 3.0802562672,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.2829692072,
#             "avg_similarRecipes_metaData_pagesize": 15.4776119403,
#             "avg_readyInMinutes": 223.2835820896,
#             "avg_submitter_favoritesCount": 362.6119402985,
#             "avg_cookMinutes": 22.7164179104,
#             "avg_nutrition_saturatedFat_amount": 7.2110913953,
#             "avg_reviewCount": 219.6865671642,
#             "avg_nutrition_potassium_amount": 517.2492336719,
#             "avg_submitter_madeRecipesCount": 71.9402985075,
#             "avg_nutrition_calcium_amount": 104.2027518906,
#             "avg_submitter_personalRecipeSharedCount": 12.6417910448,
#             "avg_nutrition_vitaminA_amount": 2170.3961329688,
#             "avg_nutrition_carbohydrates_amount": 28.9806050203,
#             "avg_similarRecipes_metaData_totalCount": 15.4776119403,
#             "avg_nutrition_fat_amount": 23.9424004797,
#             "avg_nutrition_iron_amount": 4.2691250437,
#             "avg_nutrition_vitaminC_amount": 21.9334769783,
#             "avg_ratingCount": 307.8507462687,
#             "avg_nutrition_sodium_amount": 809.3939725312,
#             "avg_nutrition_cholesterol_amount": 81.3847190141,
#             "avg_ratingAverage": 4.323805857,
#             "avg_prepMinutes": 15.8805970149,
#             "nbRecipes": 67,
#             "avg_nutrition_protein_amount": 20.5943655992,
#             "avg_nutrition_niacin_amount": 8.757527289,
#             "avg_nutrition_vitaminB6_amount": 0.4587975699,
#             "avg_nutrition_caloriesFromFat_amount": 215.4816058281,
#             "avg_nutrition_sugars_amount": 8.5214698198,
#             "avg_servings": 8.3432835821,
#             "avg_nutrition_calories_amount": 415.338245,
#             "avg_submitter_followersCount": 154042.9402985075,
#             "avg_submitter_reviewsCount": 31.8805970149,
#             "avg_nutrition_magnesium_amount": 52.0927064688,
#             "avg_nutrition_folate_amount": 62.2402307969
#         },
#         "miami": {
#             "avg_submitter_ratingsCount": 10.0,
#             "avg_submitter_reciepesCount": 1.0,
#             "avg_nutrition_fiber_amount": 2.58598826,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.35442256,
#             "avg_similarRecipes_metaData_pagesize": 14.5,
#             "avg_readyInMinutes": 44.5,
#             "avg_submitter_favoritesCount": 88.9166666667,
#             "avg_cookMinutes": 28.5,
#             "avg_nutrition_saturatedFat_amount": 10.7349728,
#             "avg_reviewCount": 50.6666666667,
#             "avg_nutrition_potassium_amount": 483.65946,
#             "avg_submitter_madeRecipesCount": 10.25,
#             "avg_nutrition_calcium_amount": 148.4840393,
#             "avg_submitter_personalRecipeSharedCount": 1.8333333333,
#             "avg_nutrition_vitaminA_amount": 534.437133,
#             "avg_nutrition_carbohydrates_amount": 33.1075542,
#             "avg_similarRecipes_metaData_totalCount": 14.5,
#             "avg_nutrition_fat_amount": 24.3905374,
#             "avg_nutrition_iron_amount": 2.63113087,
#             "avg_nutrition_vitaminC_amount": 13.775039369,
#             "avg_ratingCount": 68.8333333333,
#             "avg_nutrition_sodium_amount": 1137.50395,
#             "avg_nutrition_cholesterol_amount": 82.972396,
#             "avg_ratingAverage": 4.3271377575,
#             "avg_prepMinutes": 13.0833333333,
#             "nbRecipes": 12,
#             "avg_nutrition_protein_amount": 23.5617041,
#             "avg_nutrition_niacin_amount": 7.92152196,
#             "avg_nutrition_vitaminB6_amount": 0.385380114,
#             "avg_nutrition_caloriesFromFat_amount": 219.514829,
#             "avg_nutrition_sugars_amount": 13.9112817,
#             "avg_servings": 6.6666666667,
#             "avg_nutrition_calories_amount": 446.1634,
#             "avg_submitter_followersCount": 3.0,
#             "avg_submitter_reviewsCount": 9.6666666667,
#             "avg_nutrition_magnesium_amount": 51.583778,
#             "avg_nutrition_folate_amount": 53.802855
#         },
#         "san-diego": {
#             "avg_submitter_ratingsCount": 12.8709677419,
#             "avg_submitter_reciepesCount": 16.0322580645,
#             "avg_nutrition_fiber_amount": 5.1018845483,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.2542885452,
#             "avg_similarRecipes_metaData_pagesize": 17.5483870968,
#             "avg_readyInMinutes": 69.5483870968,
#             "avg_submitter_favoritesCount": 99.4838709677,
#             "avg_cookMinutes": 19.3870967742,
#             "avg_nutrition_saturatedFat_amount": 3.8838472067,
#             "avg_reviewCount": 131.2258064516,
#             "avg_nutrition_potassium_amount": 711.033659,
#             "avg_submitter_madeRecipesCount": 14.3225806452,
#             "avg_nutrition_calcium_amount": 123.9850940333,
#             "avg_submitter_personalRecipeSharedCount": 5.7741935484,
#             "avg_nutrition_vitaminA_amount": 2641.551526,
#             "avg_nutrition_carbohydrates_amount": 41.5719148133,
#             "avg_similarRecipes_metaData_totalCount": 17.5483870968,
#             "avg_nutrition_fat_amount": 16.9143911333,
#             "avg_nutrition_iron_amount": 2.6139855823,
#             "avg_nutrition_vitaminC_amount": 35.2134353,
#             "avg_ratingCount": 176.4516129032,
#             "avg_nutrition_sodium_amount": 743.090265,
#             "avg_nutrition_cholesterol_amount": 55.5185,
#             "avg_ratingAverage": 3.8715675723,
#             "avg_prepMinutes": 22.4193548387,
#             "nbRecipes": 31,
#             "avg_nutrition_protein_amount": 22.6181271967,
#             "avg_nutrition_niacin_amount": 7.2018205693,
#             "avg_nutrition_vitaminB6_amount": 0.4836998991,
#             "avg_nutrition_caloriesFromFat_amount": 152.2295126667,
#             "avg_nutrition_sugars_amount": 8.9109309767,
#             "avg_servings": 7.7419354839,
#             "avg_nutrition_calories_amount": 401.5872333333,
#             "avg_submitter_followersCount": 2748.935483871,
#             "avg_submitter_reviewsCount": 12.0322580645,
#             "avg_nutrition_magnesium_amount": 71.6664576667,
#             "avg_nutrition_folate_amount": 73.1248744333
#         },
#         "boston": {
#             "avg_submitter_ratingsCount": 35.75,
#             "avg_submitter_reciepesCount": 110.5833333333,
#             "avg_nutrition_fiber_amount": 3.7532331133,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.240348669,
#             "avg_similarRecipes_metaData_pagesize": 16.5833333333,
#             "avg_readyInMinutes": 249.1666666667,
#             "avg_submitter_favoritesCount": 67.25,
#             "avg_cookMinutes": 126.25,
#             "avg_nutrition_saturatedFat_amount": 5.1985809667,
#             "avg_reviewCount": 123.25,
#             "avg_nutrition_potassium_amount": 457.4909183333,
#             "avg_submitter_madeRecipesCount": 36.0,
#             "avg_nutrition_calcium_amount": 96.3790575,
#             "avg_submitter_personalRecipeSharedCount": 3.1666666667,
#             "avg_nutrition_vitaminA_amount": 230.68042075,
#             "avg_nutrition_carbohydrates_amount": 61.6097666667,
#             "avg_similarRecipes_metaData_totalCount": 16.5833333333,
#             "avg_nutrition_fat_amount": 14.48347025,
#             "avg_nutrition_iron_amount": 2.4268407383,
#             "avg_nutrition_vitaminC_amount": 4.8695579583,
#             "avg_ratingCount": 153.3333333333,
#             "avg_nutrition_sodium_amount": 493.0753570833,
#             "avg_nutrition_cholesterol_amount": 60.9165060833,
#             "avg_ratingAverage": 4.1276258017,
#             "avg_prepMinutes": 26.25,
#             "nbRecipes": 12,
#             "avg_nutrition_protein_amount": 10.7414880592,
#             "avg_nutrition_niacin_amount": 4.3486284642,
#             "avg_nutrition_vitaminB6_amount": 0.2608668275,
#             "avg_nutrition_caloriesFromFat_amount": 130.3512266667,
#             "avg_nutrition_sugars_amount": 34.4743725,
#             "avg_servings": 9.8333333333,
#             "avg_nutrition_calories_amount": 411.6663833333,
#             "avg_submitter_followersCount": 3200.9166666667,
#             "avg_submitter_reviewsCount": 9.75,
#             "avg_nutrition_magnesium_amount": 56.7193199167,
#             "avg_nutrition_folate_amount": 69.1808425
#         },
#         "los-angeles": {
#             "avg_submitter_ratingsCount": 5.5333333333,
#             "avg_submitter_reciepesCount": 17.1333333333,
#             "avg_nutrition_fiber_amount": 4.5759873967,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.2499014367,
#             "avg_similarRecipes_metaData_pagesize": 12.9666666667,
#             "avg_readyInMinutes": 117.8,
#             "avg_submitter_favoritesCount": 262.6,
#             "avg_cookMinutes": 53.9666666667,
#             "avg_nutrition_saturatedFat_amount": 6.9379219367,
#             "avg_reviewCount": 36.3666666667,
#             "avg_nutrition_potassium_amount": 614.5194593333,
#             "avg_submitter_madeRecipesCount": 12.0,
#             "avg_nutrition_calcium_amount": 144.626957,
#             "avg_submitter_personalRecipeSharedCount": 9.4333333333,
#             "avg_nutrition_vitaminA_amount": 1701.4872813333,
#             "avg_nutrition_carbohydrates_amount": 27.0084856667,
#             "avg_similarRecipes_metaData_totalCount": 12.9666666667,
#             "avg_nutrition_fat_amount": 19.4823559003,
#             "avg_nutrition_iron_amount": 2.9128851667,
#             "avg_nutrition_vitaminC_amount": 51.5466371667,
#             "avg_ratingCount": 48.8333333333,
#             "avg_nutrition_sodium_amount": 671.3785358,
#             "avg_nutrition_cholesterol_amount": 70.7815406667,
#             "avg_ratingAverage": 3.8786580587,
#             "avg_prepMinutes": 21.0,
#             "nbRecipes": 30,
#             "avg_nutrition_protein_amount": 19.6331104167,
#             "avg_nutrition_niacin_amount": 7.9396035703,
#             "avg_nutrition_vitaminB6_amount": 0.5078947378,
#             "avg_nutrition_caloriesFromFat_amount": 175.34119787,
#             "avg_nutrition_sugars_amount": 5.8711526333,
#             "avg_servings": 6.7333333333,
#             "avg_nutrition_calories_amount": 374.2129283333,
#             "avg_submitter_followersCount": 206368.8333333333,
#             "avg_submitter_reviewsCount": 5.1333333333,
#             "avg_nutrition_magnesium_amount": 55.4423327333,
#             "avg_nutrition_folate_amount": 67.6437203333
#         },
#         "philadelphia": {
#             "avg_submitter_ratingsCount": 59.68,
#             "avg_submitter_reciepesCount": 68.12,
#             "avg_nutrition_fiber_amount": 2.629553508,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.2211141053,
#             "avg_similarRecipes_metaData_pagesize": 14.5,
#             "avg_readyInMinutes": 75.32,
#             "avg_submitter_favoritesCount": 221.14,
#             "avg_cookMinutes": 25.9,
#             "avg_nutrition_saturatedFat_amount": 11.22191714,
#             "avg_reviewCount": 36.82,
#             "avg_nutrition_potassium_amount": 400.41947886,
#             "avg_submitter_madeRecipesCount": 61.18,
#             "avg_nutrition_calcium_amount": 256.67036744,
#             "avg_submitter_personalRecipeSharedCount": 9.26,
#             "avg_nutrition_vitaminA_amount": 922.4537942,
#             "avg_nutrition_carbohydrates_amount": 41.94946146,
#             "avg_similarRecipes_metaData_totalCount": 14.5,
#             "avg_nutrition_fat_amount": 26.79897344,
#             "avg_nutrition_iron_amount": 3.120636906,
#             "avg_nutrition_vitaminC_amount": 18.4969734301,
#             "avg_ratingCount": 47.72,
#             "avg_nutrition_sodium_amount": 969.3789018,
#             "avg_nutrition_cholesterol_amount": 91.16037164,
#             "avg_ratingAverage": 4.2303322426,
#             "avg_prepMinutes": 15.6,
#             "nbRecipes": 50,
#             "avg_nutrition_protein_amount": 24.51036292,
#             "avg_nutrition_niacin_amount": 7.709990388,
#             "avg_nutrition_vitaminB6_amount": 0.3141011734,
#             "avg_nutrition_caloriesFromFat_amount": 241.1907634,
#             "avg_nutrition_sugars_amount": 10.181250826,
#             "avg_servings": 7.82,
#             "avg_nutrition_calories_amount": 510.41504,
#             "avg_submitter_followersCount": 43661.24,
#             "avg_submitter_reviewsCount": 40.48,
#             "avg_nutrition_magnesium_amount": 42.76173593,
#             "avg_nutrition_folate_amount": 66.51275544
#         },
#         "san-francisco": {
#             "avg_submitter_ratingsCount": 108.7073170732,
#             "avg_submitter_reciepesCount": 269.3170731707,
#             "avg_nutrition_fiber_amount": 2.9773086473,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.1696685185,
#             "avg_similarRecipes_metaData_pagesize": 15.8536585366,
#             "avg_readyInMinutes": 98.9756097561,
#             "avg_submitter_favoritesCount": 164.0731707317,
#             "avg_cookMinutes": 39.8780487805,
#             "avg_nutrition_saturatedFat_amount": 4.4407462082,
#             "avg_reviewCount": 68.8780487805,
#             "avg_nutrition_potassium_amount": 498.6124517317,
#             "avg_submitter_madeRecipesCount": 111.9756097561,
#             "avg_nutrition_calcium_amount": 85.1226340244,
#             "avg_submitter_personalRecipeSharedCount": 6.2926829268,
#             "avg_nutrition_vitaminA_amount": 1177.7962191463,
#             "avg_nutrition_carbohydrates_amount": 25.6473037854,
#             "avg_similarRecipes_metaData_totalCount": 15.8536585366,
#             "avg_nutrition_fat_amount": 12.0556219332,
#             "avg_nutrition_iron_amount": 3.743290641,
#             "avg_nutrition_vitaminC_amount": 19.2749906017,
#             "avg_ratingCount": 88.1463414634,
#             "avg_nutrition_sodium_amount": 575.5371249512,
#             "avg_nutrition_cholesterol_amount": 66.2578526171,
#             "avg_ratingAverage": 3.8753884834,
#             "avg_prepMinutes": 18.4146341463,
#             "nbRecipes": 41,
#             "avg_nutrition_protein_amount": 17.9521666288,
#             "avg_nutrition_niacin_amount": 6.4557232849,
#             "avg_nutrition_vitaminB6_amount": 0.2709673187,
#             "avg_nutrition_caloriesFromFat_amount": 108.500598678,
#             "avg_nutrition_sugars_amount": 8.0171513306,
#             "avg_servings": 12.6829268293,
#             "avg_nutrition_calories_amount": 291.9175343171,
#             "avg_submitter_followersCount": 11199.1219512195,
#             "avg_submitter_reviewsCount": 18.0487804878,
#             "avg_nutrition_magnesium_amount": 58.4659303537,
#             "avg_nutrition_folate_amount": 58.5151527912
#         },
#         "kansas-city": {
#             "avg_submitter_ratingsCount": 19.125,
#             "avg_submitter_reciepesCount": 1.4583333333,
#             "avg_nutrition_fiber_amount": 2.1658508545,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.1217278914,
#             "avg_similarRecipes_metaData_pagesize": 12.5416666667,
#             "avg_readyInMinutes": 42.7083333333,
#             "avg_submitter_favoritesCount": 98.4166666667,
#             "avg_cookMinutes": 25.125,
#             "avg_nutrition_saturatedFat_amount": 6.1034923091,
#             "avg_reviewCount": 60.625,
#             "avg_nutrition_potassium_amount": 243.5239927273,
#             "avg_submitter_madeRecipesCount": 19.625,
#             "avg_nutrition_calcium_amount": 88.0432716818,
#             "avg_submitter_personalRecipeSharedCount": 3.0416666667,
#             "avg_nutrition_vitaminA_amount": 1676.5504568182,
#             "avg_nutrition_carbohydrates_amount": 33.1955072273,
#             "avg_similarRecipes_metaData_totalCount": 12.5416666667,
#             "avg_nutrition_fat_amount": 15.0364464455,
#             "avg_nutrition_iron_amount": 1.7319653,
#             "avg_nutrition_vitaminC_amount": 7.8234801123,
#             "avg_ratingCount": 76.25,
#             "avg_nutrition_sodium_amount": 421.2166277273,
#             "avg_nutrition_cholesterol_amount": 42.0874889091,
#             "avg_ratingAverage": 4.2158064117,
#             "avg_prepMinutes": 10.9166666667,
#             "nbRecipes": 24,
#             "avg_nutrition_protein_amount": 9.5829484818,
#             "avg_nutrition_niacin_amount": 3.974544735,
#             "avg_nutrition_vitaminB6_amount": 0.1577434245,
#             "avg_nutrition_caloriesFromFat_amount": 135.3280215909,
#             "avg_nutrition_sugars_amount": 11.7726006045,
#             "avg_servings": 13.6666666667,
#             "avg_nutrition_calories_amount": 300.2158104545,
#             "avg_submitter_followersCount": 2.0416666667,
#             "avg_submitter_reviewsCount": 18.125,
#             "avg_nutrition_magnesium_amount": 32.0467021364,
#             "avg_nutrition_folate_amount": 47.5829189091
#         },
#         "houston": {
#             "avg_submitter_ratingsCount": 13.9444444444,
#             "avg_submitter_reciepesCount": 19.3333333333,
#             "avg_nutrition_fiber_amount": 2.6954533056,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.4833365948,
#             "avg_similarRecipes_metaData_pagesize": 14.2222222222,
#             "avg_readyInMinutes": 130.2777777778,
#             "avg_submitter_favoritesCount": 91.0555555556,
#             "avg_cookMinutes": 60.7222222222,
#             "avg_nutrition_saturatedFat_amount": 6.6243364278,
#             "avg_reviewCount": 58.5555555556,
#             "avg_nutrition_potassium_amount": 542.9018705556,
#             "avg_submitter_madeRecipesCount": 14.0555555556,
#             "avg_nutrition_calcium_amount": 107.5836688889,
#             "avg_submitter_personalRecipeSharedCount": 4.7222222222,
#             "avg_nutrition_vitaminA_amount": 1325.1604157222,
#             "avg_nutrition_carbohydrates_amount": 18.0047835556,
#             "avg_similarRecipes_metaData_totalCount": 14.2222222222,
#             "avg_nutrition_fat_amount": 21.2493087111,
#             "avg_nutrition_iron_amount": 2.9635454278,
#             "avg_nutrition_vitaminC_amount": 21.3800209278,
#             "avg_ratingCount": 71.8333333333,
#             "avg_nutrition_sodium_amount": 705.3128685,
#             "avg_nutrition_cholesterol_amount": 111.187795,
#             "avg_ratingAverage": 3.9081002267,
#             "avg_prepMinutes": 27.5,
#             "nbRecipes": 18,
#             "avg_nutrition_protein_amount": 25.2114449222,
#             "avg_nutrition_niacin_amount": 8.2419543556,
#             "avg_nutrition_vitaminB6_amount": 0.4164473133,
#             "avg_nutrition_caloriesFromFat_amount": 191.2437795556,
#             "avg_nutrition_sugars_amount": 4.3589591333,
#             "avg_servings": 10.5555555556,
#             "avg_nutrition_calories_amount": 366.3758511111,
#             "avg_submitter_followersCount": 8.0,
#             "avg_submitter_reviewsCount": 13.2777777778,
#             "avg_nutrition_magnesium_amount": 51.5887053889,
#             "avg_nutrition_folate_amount": 42.5995917778
#         },
#         "georgia": {
#             "avg_submitter_ratingsCount": 17.3802816901,
#             "avg_submitter_reciepesCount": 6.5915492958,
#             "avg_nutrition_fiber_amount": 2.5095388411,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.1861195221,
#             "avg_similarRecipes_metaData_pagesize": 14.8591549296,
#             "avg_readyInMinutes": 95.7887323944,
#             "avg_submitter_favoritesCount": 139.5633802817,
#             "avg_cookMinutes": 49.1126760563,
#             "avg_nutrition_saturatedFat_amount": 7.3237251565,
#             "avg_reviewCount": 106.5211267606,
#             "avg_nutrition_potassium_amount": 343.1151770429,
#             "avg_submitter_madeRecipesCount": 17.661971831,
#             "avg_nutrition_calcium_amount": 99.2761648714,
#             "avg_submitter_personalRecipeSharedCount": 9.7042253521,
#             "avg_nutrition_vitaminA_amount": 1829.5289358571,
#             "avg_nutrition_carbohydrates_amount": 34.2082966414,
#             "avg_similarRecipes_metaData_totalCount": 14.8591549296,
#             "avg_nutrition_fat_amount": 20.2815547511,
#             "avg_nutrition_iron_amount": 1.8700171199,
#             "avg_nutrition_vitaminC_amount": 12.11751674,
#             "avg_ratingCount": 135.338028169,
#             "avg_nutrition_sodium_amount": 595.0686917429,
#             "avg_nutrition_cholesterol_amount": 58.2635068286,
#             "avg_ratingAverage": 4.158777641,
#             "avg_prepMinutes": 15.5915492958,
#             "nbRecipes": 71,
#             "avg_nutrition_protein_amount": 11.0973724957,
#             "avg_nutrition_niacin_amount": 4.391119622,
#             "avg_nutrition_vitaminB6_amount": 0.2146132011,
#             "avg_nutrition_caloriesFromFat_amount": 182.5339954329,
#             "avg_nutrition_sugars_amount": 18.6805322896,
#             "avg_servings": 15.7183098592,
#             "avg_nutrition_calories_amount": 358.6492397143,
#             "avg_submitter_followersCount": 5.6901408451,
#             "avg_submitter_reviewsCount": 15.9154929577,
#             "avg_nutrition_magnesium_amount": 36.8129842571,
#             "avg_nutrition_folate_amount": 52.4274617571
#         },
#         "toronto": {
#             "avg_submitter_ratingsCount": 6.296875,
#             "avg_submitter_reciepesCount": 7.390625,
#             "avg_nutrition_fiber_amount": 2.8988628192,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.3077651906,
#             "avg_similarRecipes_metaData_pagesize": 17.65625,
#             "avg_readyInMinutes": 118.5,
#             "avg_submitter_favoritesCount": 122.0625,
#             "avg_cookMinutes": 46.078125,
#             "avg_nutrition_saturatedFat_amount": 7.7902010578,
#             "avg_reviewCount": 316.03125,
#             "avg_nutrition_potassium_amount": 448.8280103125,
#             "avg_submitter_madeRecipesCount": 7.234375,
#             "avg_nutrition_calcium_amount": 107.4745086094,
#             "avg_submitter_personalRecipeSharedCount": 2.484375,
#             "avg_nutrition_vitaminA_amount": 1207.9711992188,
#             "avg_nutrition_carbohydrates_amount": 39.3388236094,
#             "avg_similarRecipes_metaData_totalCount": 17.65625,
#             "avg_nutrition_fat_amount": 19.1312834687,
#             "avg_nutrition_iron_amount": 2.6198838781,
#             "avg_nutrition_vitaminC_amount": 20.1302307266,
#             "avg_ratingCount": 411.625,
#             "avg_nutrition_sodium_amount": 822.6015922656,
#             "avg_nutrition_cholesterol_amount": 71.3078094688,
#             "avg_ratingAverage": 4.2610662689,
#             "avg_prepMinutes": 20.15625,
#             "nbRecipes": 64,
#             "avg_nutrition_protein_amount": 17.0540378156,
#             "avg_nutrition_niacin_amount": 7.4227091578,
#             "avg_nutrition_vitaminB6_amount": 0.351701125,
#             "avg_nutrition_caloriesFromFat_amount": 172.1815514531,
#             "avg_nutrition_sugars_amount": 14.3039433875,
#             "avg_servings": 9.40625,
#             "avg_nutrition_calories_amount": 394.5755590625,
#             "avg_submitter_followersCount": 6.0,
#             "avg_submitter_reviewsCount": 5.984375,
#             "avg_nutrition_magnesium_amount": 42.6208075938,
#             "avg_nutrition_folate_amount": 55.7518492969
#         },
#         "baltimore": {
#             "avg_submitter_ratingsCount": 8.8,
#             "avg_submitter_reciepesCount": 2.3,
#             "avg_nutrition_fiber_amount": 1.4585683298,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.1763905158,
#             "avg_similarRecipes_metaData_pagesize": 16.35,
#             "avg_readyInMinutes": 340.175,
#             "avg_submitter_favoritesCount": 79.25,
#             "avg_cookMinutes": 27.375,
#             "avg_nutrition_saturatedFat_amount": 5.40006226,
#             "avg_reviewCount": 80.375,
#             "avg_nutrition_potassium_amount": 366.0909587436,
#             "avg_submitter_madeRecipesCount": 8.85,
#             "avg_nutrition_calcium_amount": 97.5182042744,
#             "avg_submitter_personalRecipeSharedCount": 5.525,
#             "avg_nutrition_vitaminA_amount": 717.1477726923,
#             "avg_nutrition_carbohydrates_amount": 21.2793264667,
#             "avg_similarRecipes_metaData_totalCount": 16.35,
#             "avg_nutrition_fat_amount": 14.7702118631,
#             "avg_nutrition_iron_amount": 2.0725230292,
#             "avg_nutrition_vitaminC_amount": 6.1599226656,
#             "avg_ratingCount": 98.975,
#             "avg_nutrition_sodium_amount": 922.6234240769,
#             "avg_nutrition_cholesterol_amount": 77.6547251282,
#             "avg_ratingAverage": 4.119503283,
#             "avg_prepMinutes": 14.175,
#             "nbRecipes": 40,
#             "avg_nutrition_protein_amount": 15.2652843533,
#             "avg_nutrition_niacin_amount": 6.0732088472,
#             "avg_nutrition_vitaminB6_amount": 0.2259791803,
#             "avg_nutrition_caloriesFromFat_amount": 132.9319115974,
#             "avg_nutrition_sugars_amount": 8.5506484808,
#             "avg_servings": 14.9,
#             "avg_nutrition_calories_amount": 282.5841822308,
#             "avg_submitter_followersCount": 4.8,
#             "avg_submitter_reviewsCount": 7.4,
#             "avg_nutrition_magnesium_amount": 47.9311626872,
#             "avg_nutrition_folate_amount": 64.73690206
#         },
#         "chicago": {
#             "avg_submitter_ratingsCount": 30.4545454545,
#             "avg_submitter_reciepesCount": 84.5454545455,
#             "avg_nutrition_fiber_amount": 3.3221818182,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.3377867473,
#             "avg_similarRecipes_metaData_pagesize": 17.0,
#             "avg_readyInMinutes": 130.0,
#             "avg_submitter_favoritesCount": 115.1818181818,
#             "avg_cookMinutes": 45.9090909091,
#             "avg_nutrition_saturatedFat_amount": 6.2244856364,
#             "avg_reviewCount": 93.5454545455,
#             "avg_nutrition_potassium_amount": 406.8057072727,
#             "avg_submitter_madeRecipesCount": 31.1818181818,
#             "avg_nutrition_calcium_amount": 145.0406539091,
#             "avg_submitter_personalRecipeSharedCount": 10.9090909091,
#             "avg_nutrition_vitaminA_amount": 1159.4425090909,
#             "avg_nutrition_carbohydrates_amount": 32.4189234545,
#             "avg_similarRecipes_metaData_totalCount": 17.0,
#             "avg_nutrition_fat_amount": 19.7759342727,
#             "avg_nutrition_iron_amount": 4.0340229091,
#             "avg_nutrition_vitaminC_amount": 9.1900536364,
#             "avg_ratingCount": 126.1818181818,
#             "avg_nutrition_sodium_amount": 1152.7164454545,
#             "avg_nutrition_cholesterol_amount": 57.7919054545,
#             "avg_ratingAverage": 4.2650518455,
#             "avg_prepMinutes": 21.3636363636,
#             "nbRecipes": 11,
#             "avg_nutrition_protein_amount": 22.7507469091,
#             "avg_nutrition_niacin_amount": 8.4149930909,
#             "avg_nutrition_vitaminB6_amount": 0.3570065909,
#             "avg_nutrition_caloriesFromFat_amount": 177.9834209091,
#             "avg_nutrition_sugars_amount": 5.8000551273,
#             "avg_servings": 5.8181818182,
#             "avg_nutrition_calories_amount": 403.8004090909,
#             "avg_submitter_followersCount": 3476.1818181818,
#             "avg_submitter_reviewsCount": 2.0909090909,
#             "avg_nutrition_magnesium_amount": 35.6325027273,
#             "avg_nutrition_folate_amount": 78.5223227273
#         },
#         "st-louis": {
#             "avg_submitter_ratingsCount": 105.8148148148,
#             "avg_submitter_reciepesCount": 1.2962962963,
#             "avg_nutrition_fiber_amount": 2.7868702321,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.5404099809,
#             "avg_similarRecipes_metaData_pagesize": 15.8888888889,
#             "avg_readyInMinutes": 113.4074074074,
#             "avg_submitter_favoritesCount": 297.5185185185,
#             "avg_cookMinutes": 84.0,
#             "avg_nutrition_saturatedFat_amount": 10.6463396704,
#             "avg_reviewCount": 72.1481481481,
#             "avg_nutrition_potassium_amount": 473.9753051852,
#             "avg_submitter_madeRecipesCount": 106.2222222222,
#             "avg_nutrition_calcium_amount": 108.1172686296,
#             "avg_submitter_personalRecipeSharedCount": 3.5925925926,
#             "avg_nutrition_vitaminA_amount": 1428.0750611111,
#             "avg_nutrition_carbohydrates_amount": 39.3335362222,
#             "avg_similarRecipes_metaData_totalCount": 15.8888888889,
#             "avg_nutrition_fat_amount": 28.6261497778,
#             "avg_nutrition_iron_amount": 3.1187290704,
#             "avg_nutrition_vitaminC_amount": 11.8623023581,
#             "avg_ratingCount": 92.0740740741,
#             "avg_nutrition_sodium_amount": 1665.9185703704,
#             "avg_nutrition_cholesterol_amount": 87.1776358148,
#             "avg_ratingAverage": 4.3339577211,
#             "avg_prepMinutes": 16.2592592593,
#             "nbRecipes": 27,
#             "avg_nutrition_protein_amount": 17.6499616778,
#             "avg_nutrition_niacin_amount": 8.2253497778,
#             "avg_nutrition_vitaminB6_amount": 0.4252018348,
#             "avg_nutrition_caloriesFromFat_amount": 257.6353418519,
#             "avg_nutrition_sugars_amount": 20.0582743259,
#             "avg_servings": 10.6296296296,
#             "avg_nutrition_calories_amount": 485.8434666667,
#             "avg_submitter_followersCount": 24.5555555556,
#             "avg_submitter_reviewsCount": 104.7777777778,
#             "avg_nutrition_magnesium_amount": 41.3972659259,
#             "avg_nutrition_folate_amount": 58.530613
#         },
#         "pittsburgh": {
#             "avg_submitter_ratingsCount": 9.8571428571,
#             "avg_submitter_reciepesCount": 15.0,
#             "avg_nutrition_fiber_amount": 3.7168764329,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.3739265813,
#             "avg_similarRecipes_metaData_pagesize": 15.1785714286,
#             "avg_readyInMinutes": 130.1785714286,
#             "avg_submitter_favoritesCount": 63.0714285714,
#             "avg_cookMinutes": 63.0357142857,
#             "avg_nutrition_saturatedFat_amount": 9.1614294643,
#             "avg_reviewCount": 148.4285714286,
#             "avg_nutrition_potassium_amount": 553.1527578571,
#             "avg_submitter_madeRecipesCount": 9.9285714286,
#             "avg_nutrition_calcium_amount": 176.3509592857,
#             "avg_submitter_personalRecipeSharedCount": 1.9642857143,
#             "avg_nutrition_vitaminA_amount": 750.5714234643,
#             "avg_nutrition_carbohydrates_amount": 44.8913861786,
#             "avg_similarRecipes_metaData_totalCount": 15.1785714286,
#             "avg_nutrition_fat_amount": 23.9406550357,
#             "avg_nutrition_iron_amount": 3.181308925,
#             "avg_nutrition_vitaminC_amount": 24.3195612929,
#             "avg_ratingCount": 193.6428571429,
#             "avg_nutrition_sodium_amount": 1177.559305,
#             "avg_nutrition_cholesterol_amount": 76.4513171429,
#             "avg_ratingAverage": 4.3639157029,
#             "avg_prepMinutes": 16.7857142857,
#             "nbRecipes": 28,
#             "avg_nutrition_protein_amount": 22.6650185714,
#             "avg_nutrition_niacin_amount": 8.0869232025,
#             "avg_nutrition_vitaminB6_amount": 0.3713053325,
#             "avg_nutrition_caloriesFromFat_amount": 215.4658885714,
#             "avg_nutrition_sugars_amount": 10.2933764357,
#             "avg_servings": 8.0357142857,
#             "avg_nutrition_calories_amount": 483.6879928571,
#             "avg_submitter_followersCount": 3.3571428571,
#             "avg_submitter_reviewsCount": 8.9285714286,
#             "avg_nutrition_magnesium_amount": 46.9784233571,
#             "avg_nutrition_folate_amount": 87.593270625
#         },
#         "green-bay": {
#             "avg_submitter_ratingsCount": 1.5625,
#             "avg_submitter_reciepesCount": 1.0625,
#             "avg_nutrition_fiber_amount": 1.7425228762,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.2769959485,
#             "avg_similarRecipes_metaData_pagesize": 14.25,
#             "avg_readyInMinutes": 6382.5,
#             "avg_submitter_favoritesCount": 21.4375,
#             "avg_cookMinutes": 40.625,
#             "avg_nutrition_saturatedFat_amount": 6.8581744877,
#             "avg_reviewCount": 49.6875,
#             "avg_nutrition_potassium_amount": 496.9851723077,
#             "avg_submitter_madeRecipesCount": 1.6875,
# ...
#             "avg_nutrition_cholesterol_amount": 78.3939721071,
#             "avg_ratingAverage": 4.4145081739,
#             "avg_prepMinutes": 19.8214285714,
#             "nbRecipes": 28,
#             "avg_nutrition_protein_amount": 14.9179720036,
#             "avg_nutrition_niacin_amount": 6.04422843,
#             "avg_nutrition_vitaminB6_amount": 0.2941749989,
#             "avg_nutrition_caloriesFromFat_amount": 214.0845010821,
#             "avg_nutrition_sugars_amount": 20.341919475,
#             "avg_servings": 19.6785714286,
#             "avg_nutrition_calories_amount": 424.3144992857,
#             "avg_submitter_followersCount": 2.4642857143,
#             "avg_submitter_reviewsCount": 20.8571428571,
#             "avg_nutrition_magnesium_amount": 44.0108625,
#             "avg_nutrition_folate_amount": 48.5445705714
#         },
#         "minneapolis": {
#             "avg_submitter_ratingsCount": 12.275862069,
#             "avg_submitter_reciepesCount": 34.0689655172,
#             "avg_nutrition_fiber_amount": 3.2539545241,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.2159119795,
#             "avg_similarRecipes_metaData_pagesize": 15.0344827586,
#             "avg_readyInMinutes": 71.2068965517,
#             "avg_submitter_favoritesCount": 108.0344827586,
#             "avg_cookMinutes": 49.8965517241,
#             "avg_nutrition_saturatedFat_amount": 9.010628,
#             "avg_reviewCount": 46.5517241379,
#             "avg_nutrition_potassium_amount": 575.8242837931,
#             "avg_submitter_madeRecipesCount": 12.4482758621,
#             "avg_nutrition_calcium_amount": 95.8436251724,
#             "avg_submitter_personalRecipeSharedCount": 9.6896551724,
#             "avg_nutrition_vitaminA_amount": 1893.9085395517,
#             "avg_nutrition_carbohydrates_amount": 34.0948805172,
#             "avg_similarRecipes_metaData_totalCount": 15.0344827586,
#             "avg_nutrition_fat_amount": 24.9028292069,
#             "avg_nutrition_iron_amount": 2.6665336345,
#             "avg_nutrition_vitaminC_amount": 13.4663282014,
#             "avg_ratingCount": 58.7931034483,
#             "avg_nutrition_sodium_amount": 842.8650586207,
#             "avg_nutrition_cholesterol_amount": 61.7396821379,
#             "avg_ratingAverage": 4.2164214128,
#             "avg_prepMinutes": 18.4482758621,
#             "nbRecipes": 29,
#             "avg_nutrition_protein_amount": 18.7169525828,
#             "avg_nutrition_niacin_amount": 8.1992381276,
#             "avg_nutrition_vitaminB6_amount": 0.3978801269,
#             "avg_nutrition_caloriesFromFat_amount": 224.125457931,
#             "avg_nutrition_sugars_amount": 7.7990003241,
#             "avg_servings": 13.6896551724,
#             "avg_nutrition_calories_amount": 426.5461631034,
#             "avg_submitter_followersCount": 14.1379310345,
#             "avg_submitter_reviewsCount": 10.724137931,
#             "avg_nutrition_magnesium_amount": 51.2976915517,
#             "avg_nutrition_folate_amount": 51.7617023448
#         },
#         "tampa-bay": {
#             "avg_submitter_ratingsCount": 58.4285714286,
#             "avg_submitter_reciepesCount": 3.0714285714,
#             "avg_nutrition_fiber_amount": 3.0053724042,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.15919606,
#             "avg_similarRecipes_metaData_pagesize": 14.2857142857,
#             "avg_readyInMinutes": 248.4642857143,
#             "avg_submitter_favoritesCount": 162.8571428571,
#             "avg_cookMinutes": 27.7142857143,
#             "avg_nutrition_saturatedFat_amount": 6.3030932525,
#             "avg_reviewCount": 31.6785714286,
#             "avg_nutrition_potassium_amount": 566.1650784615,
#             "avg_submitter_madeRecipesCount": 57.5714285714,
#             "avg_nutrition_calcium_amount": 64.9977474231,
#             "avg_submitter_personalRecipeSharedCount": 3.8214285714,
#             "avg_nutrition_vitaminA_amount": 824.5297607692,
#             "avg_nutrition_carbohydrates_amount": 23.0454681538,
#             "avg_similarRecipes_metaData_totalCount": 14.2857142857,
#             "avg_nutrition_fat_amount": 17.0666026423,
#             "avg_nutrition_iron_amount": 3.2166487,
#             "avg_nutrition_vitaminC_amount": 26.4787104077,
#             "avg_ratingCount": 38.25,
#             "avg_nutrition_sodium_amount": 681.6722751731,
#             "avg_nutrition_cholesterol_amount": 63.4716067308,
#             "avg_ratingAverage": 4.3635902436,
#             "avg_prepMinutes": 16.4642857143,
#             "nbRecipes": 28,
#             "avg_nutrition_protein_amount": 23.3928072692,
#             "avg_nutrition_niacin_amount": 7.4860326192,
#             "avg_nutrition_vitaminB6_amount": 0.4602584225,
#             "avg_nutrition_caloriesFromFat_amount": 153.5994239231,
#             "avg_nutrition_sugars_amount": 6.7900519954,
#             "avg_servings": 10.0,
#             "avg_nutrition_calories_amount": 337.8598092308,
#             "avg_submitter_followersCount": 40.3928571429,
#             "avg_submitter_reviewsCount": 57.6785714286,
#             "avg_nutrition_magnesium_amount": 57.6145626538,
#             "avg_nutrition_folate_amount": 47.5221723846
#         },
#         "vancouver": {
#             "avg_submitter_ratingsCount": 19.6850393701,
#             "avg_submitter_reciepesCount": 4.0393700787,
#             "avg_nutrition_fiber_amount": 2.4105628283,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.1973573406,
#             "avg_similarRecipes_metaData_pagesize": 14.031496063,
#             "avg_readyInMinutes": 301.3622047244,
#             "avg_submitter_favoritesCount": 172.2598425197,
#             "avg_cookMinutes": 35.9842519685,
#             "avg_nutrition_saturatedFat_amount": 6.8086557517,
#             "avg_reviewCount": 35.1496062992,
#             "avg_nutrition_potassium_amount": 389.5275147302,
#             "avg_submitter_madeRecipesCount": 21.5118110236,
#             "avg_nutrition_calcium_amount": 82.7725916587,
#             "avg_submitter_personalRecipeSharedCount": 13.0157480315,
#             "avg_nutrition_vitaminA_amount": 810.4165892246,
#             "avg_nutrition_carbohydrates_amount": 34.4544898103,
#             "avg_similarRecipes_metaData_totalCount": 14.031496063,
#             "avg_nutrition_fat_amount": 16.2504720899,
#             "avg_nutrition_iron_amount": 2.5025073252,
#             "avg_nutrition_vitaminC_amount": 12.7607153502,
#             "avg_ratingCount": 44.8661417323,
#             "avg_nutrition_sodium_amount": 546.5264371206,
#             "avg_nutrition_cholesterol_amount": 62.7981470476,
#             "avg_ratingAverage": 4.1240063483,
#             "avg_prepMinutes": 21.4803149606,
#             "nbRecipes": 127,
#             "avg_nutrition_protein_amount": 15.136433368,
#             "avg_nutrition_niacin_amount": 5.92065496,
#             "avg_nutrition_vitaminB6_amount": 0.2804936542,
#             "avg_nutrition_caloriesFromFat_amount": 146.2542457849,
#             "avg_nutrition_sugars_amount": 15.3392824762,
#             "avg_servings": 11.6535433071,
#             "avg_nutrition_calories_amount": 342.3823438095,
#             "avg_submitter_followersCount": 9.5511811024,
#             "avg_submitter_reviewsCount": 17.3543307087,
#             "avg_nutrition_magnesium_amount": 38.5106154627,
#             "avg_nutrition_folate_amount": 44.3598037056
#         },
#         "california": {
#             "avg_submitter_ratingsCount": 36.336,
#             "avg_submitter_reciepesCount": 65.068,
#             "avg_nutrition_fiber_amount": 3.7913148069,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.2142060071,
#             "avg_similarRecipes_metaData_pagesize": 14.5,
#             "avg_readyInMinutes": 132.472,
#             "avg_submitter_favoritesCount": 191.792,
#             "avg_cookMinutes": 31.172,
#             "avg_nutrition_saturatedFat_amount": 5.9080431716,
#             "avg_reviewCount": 67.324,
#             "avg_nutrition_potassium_amount": 509.1961640285,
#             "avg_submitter_madeRecipesCount": 39.412,
#             "avg_nutrition_calcium_amount": 124.1717093821,
#             "avg_submitter_personalRecipeSharedCount": 16.852,
#             "avg_nutrition_vitaminA_amount": 1500.1951878537,
#             "avg_nutrition_carbohydrates_amount": 31.139750222,
#             "avg_similarRecipes_metaData_totalCount": 14.5,
#             "avg_nutrition_fat_amount": 18.5514870699,
#             "avg_nutrition_iron_amount": 2.78399907,
#             "avg_nutrition_vitaminC_amount": 24.7245447284,
#             "avg_ratingCount": 88.84,
#             "avg_nutrition_sodium_amount": 648.544411902,
#             "avg_nutrition_cholesterol_amount": 58.8283987134,
#             "avg_ratingAverage": 4.0030013945,
#             "avg_prepMinutes": 19.7,
#             "nbRecipes": 250,
#             "avg_nutrition_protein_amount": 17.1335965784,
#             "avg_nutrition_niacin_amount": 6.4451584148,
#             "avg_nutrition_vitaminB6_amount": 0.3467345465,
#             "avg_nutrition_caloriesFromFat_amount": 166.9633836325,
#             "avg_nutrition_sugars_amount": 9.3683412646,
#             "avg_servings": 9.484,
#             "avg_nutrition_calories_amount": 361.590713878,
#             "avg_submitter_followersCount": 69033.26,
#             "avg_submitter_reviewsCount": 17.132,
#             "avg_nutrition_magnesium_amount": 51.7179932675,
#             "avg_nutrition_folate_amount": 65.8570558583
#         },
#         "cleveland": {
#             "avg_submitter_ratingsCount": 8.3333333333,
#             "avg_submitter_reciepesCount": 1.6060606061,
#             "avg_nutrition_fiber_amount": 3.0080272485,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.3449261991,
#             "avg_similarRecipes_metaData_pagesize": 14.9696969697,
#             "avg_readyInMinutes": 91.7575757576,
#             "avg_submitter_favoritesCount": 27.6666666667,
#             "avg_cookMinutes": 36.1515151515,
#             "avg_nutrition_saturatedFat_amount": 9.2561569848,
#             "avg_reviewCount": 63.0909090909,
#             "avg_nutrition_potassium_amount": 344.2120930303,
#             "avg_submitter_madeRecipesCount": 8.4242424242,
#             "avg_nutrition_calcium_amount": 100.1309782121,
#             "avg_submitter_personalRecipeSharedCount": 2.4242424242,
#             "avg_nutrition_vitaminA_amount": 1103.2204585961,
#             "avg_nutrition_carbohydrates_amount": 39.4166334545,
#             "avg_similarRecipes_metaData_totalCount": 14.9696969697,
#             "avg_nutrition_fat_amount": 23.1051369091,
#             "avg_nutrition_iron_amount": 2.7811271091,
#             "avg_nutrition_vitaminC_amount": 11.7181878182,
#             "avg_ratingCount": 76.3636363636,
#             "avg_nutrition_sodium_amount": 523.6588359697,
#             "avg_nutrition_cholesterol_amount": 99.5148733636,
#             "avg_ratingAverage": 4.2665948664,
#             "avg_prepMinutes": 12.9393939394,
#             "nbRecipes": 33,
#             "avg_nutrition_protein_amount": 16.4890986364,
#             "avg_nutrition_niacin_amount": 7.0798285636,
#             "avg_nutrition_vitaminB6_amount": 0.2845104261,
#             "avg_nutrition_caloriesFromFat_amount": 207.9462324242,
#             "avg_nutrition_sugars_amount": 14.4876601697,
#             "avg_servings": 11.3636363636,
#             "avg_nutrition_calories_amount": 429.2601442424,
#             "avg_submitter_followersCount": 2.696969697,
#             "avg_submitter_reviewsCount": 8.2424242424,
#             "avg_nutrition_magnesium_amount": 33.3385739697,
#             "avg_nutrition_folate_amount": 70.7054735152
#         },
#         "new-york-city": {
#             "avg_submitter_ratingsCount": 55.24,
#             "avg_submitter_reciepesCount": 104.256,
#             "avg_nutrition_fiber_amount": 2.2644520866,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.1932303072,
#             "avg_similarRecipes_metaData_pagesize": 15.072,
#             "avg_readyInMinutes": 160.368,
#             "avg_submitter_favoritesCount": 199.608,
#             "avg_cookMinutes": 35.288,
#             "avg_nutrition_saturatedFat_amount": 8.9740257264,
#             "avg_reviewCount": 88.52,
#             "avg_nutrition_potassium_amount": 418.2511784711,
#             "avg_submitter_madeRecipesCount": 57.272,
#             "avg_nutrition_calcium_amount": 95.5071747438,
#             "avg_submitter_personalRecipeSharedCount": 6.608,
#             "avg_nutrition_vitaminA_amount": 1417.0557266223,
#             "avg_nutrition_carbohydrates_amount": 33.5271574231,
#             "avg_similarRecipes_metaData_totalCount": 15.072,
#             "avg_nutrition_fat_amount": 21.9647443719,
#             "avg_nutrition_iron_amount": 2.4951306835,
#             "avg_nutrition_vitaminC_amount": 16.3531299945,
#             "avg_ratingCount": 111.336,
#             "avg_nutrition_sodium_amount": 700.8915924711,
#             "avg_nutrition_cholesterol_amount": 85.2771413719,
#             "avg_ratingAverage": 4.1732518509,
#             "avg_prepMinutes": 16.76,
#             "nbRecipes": 125,
#             "avg_nutrition_protein_amount": 17.8896237174,
#             "avg_nutrition_niacin_amount": 7.206435757,
#             "avg_nutrition_vitaminB6_amount": 0.3385195889,
#             "avg_nutrition_caloriesFromFat_amount": 197.6827069587,
#             "avg_nutrition_sugars_amount": 13.1172453805,
#             "avg_servings": 9.48,
#             "avg_nutrition_calories_amount": 411.8799015702,
#             "avg_submitter_followersCount": 70765.312,
#             "avg_submitter_reviewsCount": 24.2,
#             "avg_nutrition_magnesium_amount": 36.3795383471,
#             "avg_nutrition_folate_amount": 50.1536934959
#         }
#     },
#     "global": {
#         "Global aggregation": {
#             "avg_submitter_ratingsCount": 29.7984238394,
#             "avg_submitter_reciepesCount": 22.6657431351,
#             "avg_nutrition_fiber_amount": 3.1178096283,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_thiamin_amount": 0.2271286606,
#             "avg_similarRecipes_metaData_pagesize": 14.7297130895,
#             "avg_readyInMinutes": 157.1372367935,
#             "avg_submitter_favoritesCount": 151.0502401182,
#             "avg_cookMinutes": 41.1077453516,
#             "avg_nutrition_saturatedFat_amount": 6.5396016803,
#             "avg_reviewCount": 77.7717029922,
#             "avg_nutrition_potassium_amount": 434.1991336157,
#             "avg_submitter_madeRecipesCount": 30.7689939663,
#             "avg_nutrition_calcium_amount": 114.9318745406,
#             "avg_submitter_personalRecipeSharedCount": 8.0709272257,
#             "avg_nutrition_vitaminA_amount": 1418.1540015684,
#             "avg_nutrition_carbohydrates_amount": 31.5380632211,
#             "avg_similarRecipes_metaData_totalCount": 14.7297130895,
#             "avg_nutrition_fat_amount": 17.7817337376,
#             "avg_nutrition_iron_amount": 2.6678069684,
#             "avg_nutrition_vitaminC_amount": 18.3412098224,
#             "avg_ratingCount": 102.3711981283,
#             "avg_nutrition_sodium_amount": 661.4516873115,
#             "avg_nutrition_cholesterol_amount": 66.2203374766,
#             "avg_ratingAverage": 4.0803297995,
#             "avg_prepMinutes": 20.2409186061,
#             "nbRecipes": 16242,
#             "avg_nutrition_protein_amount": 16.2278095183,
#             "avg_nutrition_niacin_amount": 6.5819486949,
#             "avg_nutrition_vitaminB6_amount": 0.3188769283,
#             "avg_nutrition_caloriesFromFat_amount": 160.0322171934,
#             "avg_nutrition_sugars_amount": 9.8466210198,
#             "avg_servings": 10.2102573575,
#             "avg_nutrition_calories_amount": 350.2467986302,
#             "avg_submitter_followersCount": 7870.611685753,
#             "avg_submitter_reviewsCount": 23.1030045561,
#             "avg_nutrition_magnesium_amount": 42.7467841021,
#             "avg_nutrition_folate_amount": 60.2745651289
#         }
#     }
# }

# %% [markdown]
# # A Safety Check for the Data

# %% [markdown]
# Check that the number of calories (for instance) is roughly constant per serving, i.e. the values (e.g. calories) do not need to be divided by the number of servings.

# %%
res = group_and_get_aggregate_of_field(
        collection, 
        group_by_field_address='$servings', 
        aggregate_field_address = '$nutrition.calories.amount', 
        group_by_field_output_name = 'servings', 
        aggregate_field_output_name = 'calories', 
        aggregationFunction = '$addToSet' 
)
res = pd.DataFrame.from_dict(res)
res
# Out:
#                                              calories  nbRecipes  servings
# 0                                          [130.5006]          1        39
# 1                                          [182.1069]          1        26
# 2                                          [60.56655]          1        44
# 3                                                  []          1        55
# 4                                                  []          1        51
# 5                                          [45.91531]          1       240
# 6                                          [85.97153]          1       108
# 7                                                  []          1        34
# 8                                          [24.79369]          1       150
# 9                        [23.77281, 45.6426, 14.3961]          3       128
# 10                                         [111.7612]          1        46
# 11                                         [88.90604]          1       168
# 12                                         [83.06197]          1        52
# 13                                         [245.9868]          2        27
# 14                                         [118.1973]          1       188
# 15                                         [1.082667]          1       180
# 16           [553.7616, 89.51984, 138.4701, 49.18591]          5        22
# 17                                [126.779, 204.2182]          2        70
# 18                                         [37.96547]          1       176
# 19            [47.6082, 163.9411, 32.63125, 70.84042]          4       144
# 20                                         [26.56602]          1       112
# 21  [198.6911, 232.9029, 82.512, 167.4065, 81.1915...         49        25
# 22           [18.57844, 31.82872, 7.364165, 9.795709]          4       192
# 23  [134.2202, 138.3028, 12.70047, 39.18739, 46.28...         72        40
# 24  [145.2776, 439.429, 180.9212, 96.0702, 130.581...        146        36
# 25  [20.72586, 4.344675, 75.38726, 123.6011, 94.50...        126        48
# 26  [121.9303, 6.316399, 66.82409, 123.7397, 80.63...        117        32
# 27  [30.7259, 117.7393, 409.1838, 1076.825, 165.77...         66        14
# 28  [7.663048, 114.8627, 152.9864, 96.72525, 73.0,...        752        10
# 29                                         [207.0472]          1        65
# ..                                                ...        ...       ...
# 43  [469.1374, 317.9422, 582.0063, 67.08359, 414.7...       3128         6
# 44  [114.443, 82.19115, 307.4062, 43.11347, 76.940...          6        75
# 45  [253.275, 24.12324, 131.3087, 227.8033, 308.63...       1526        12
# 46                                         [94.29924]          1        33
# 47  [716.6111, 484.9653, 526.5847, 82.27547, 198.8...       3646         4
# 48  [292.6306, 152.7332, 95.02695, 162.4777, 140.6...        127        30
# 49  [481.9153, 277.8476, 202.239, 722.0485, 337.65...        169        15
# 50                               [31.68689, 19.08656]          2       200
# 51  [426.7951, 352.1058, 448.8103, 278.8677, 30.08...        164         3
# 52                                         [29.93435]          1       156
# 53  [100.9441, 11.73561, 71.22124, 255.3046, 74.15...         12        56
# 54  [462.0907, 101.1815, 121.8431, 73.0893, 225.87...         27        50
# 55  [346.9427, 797.5046, 490.7751, 297.3842, 599.2...        335         5
# 56  [285.3711, 195.6704, 204.3525, 547.737, 226.94...        102         9
# 57  [111.0815, 281.2605, 326.4283, 11.23209, 60.10...         14        80
# 58                                         [7.135911]          1       106
# 59  [315.4269, 217.5262, 66.03377, 317.5177, 177.0...          5        13
# 60  [31.58308, 13.97796, 357.2463, 36.93991, 7.095...         12       100
# 61  [224.7159, 139.4581, 176.799, 243.1457, 61.840...         11        35
# 62  [27.45224, 65.17031, 53.16695, 41.59035, 28.63...         28        64
# 63  [162.3118, 145.2513, 84.04626, 136.3571, 91.31...         11        42
# 64  [55.53514, 45.99966, 191.3994, 60.56768, 76.47...         37        72
# 65  [120.033, 146.4241, 23.85058, 154.4817, 88.46658]          5        84
# 66                               [92.39835, 96.39452]          2        90
# 67  [385.3093, 465.1614, 483.5129, 192.3791, 849.2...         21        11
# 68  [58.47144, 77.10946, 93.6153, 68.68914, 74.529...         13        96
# 69  [103.2124, 103.2559, 167.7179, 135.2504, 242.9...         23        28
# 70           [3.697356, 8.356837, 196.2644, 207.7329]          4        21
# 71                                         [42.62327]          1       140
# 72                               [372.5897, 493.2743]          2        17
#
# [73 rows x 3 columns]

# %%
res['averageCalories'] = res['calories'].map(lambda x: np.mean(x))
res[res['servings'] < 20]
# Out:
# /home/maximilian/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
#                                              calories  nbRecipes  servings  \
# 27  [30.7259, 117.7393, 409.1838, 1076.825, 165.77...         66        14
# 28  [7.663048, 114.8627, 152.9864, 96.72525, 73.0,...        752        10
# 33  [378.8421, 666.5646, 610.725, 439.9805, 472.83...        599         2
# 35  [87.89926, 58.68952, 574.4297, 10.7974, 11.35,...        501        16
# 36  [845.1532, 321.1483, 805.8989, 47.271, 381.285...        306         1
# 38  [424.8909, 397.6094, 199.6972, 217.3545, 466.8...         99         7
# 40  [120.9205, 92.85124, 152.5559, 376.8631, 280.1...        170        18
# 42  [314.1674, 290.44, 19.44138, 33.27737, 524.404...       2919         8
# 43  [469.1374, 317.9422, 582.0063, 67.08359, 414.7...       3128         6
# 45  [253.275, 24.12324, 131.3087, 227.8033, 308.63...       1526        12
# 47  [716.6111, 484.9653, 526.5847, 82.27547, 198.8...       3646         4
# 49  [481.9153, 277.8476, 202.239, 722.0485, 337.65...        169        15
# 51  [426.7951, 352.1058, 448.8103, 278.8677, 30.08...        164         3
# 55  [346.9427, 797.5046, 490.7751, 297.3842, 599.2...        335         5
# 56  [285.3711, 195.6704, 204.3525, 547.737, 226.94...        102         9
# 59  [315.4269, 217.5262, 66.03377, 317.5177, 177.0...          5        13
# 67  [385.3093, 465.1614, 483.5129, 192.3791, 849.2...         21        11
# 72                               [372.5897, 493.2743]          2        17
#
#     averageCalories
# 27       287.960521
# 28       327.745643
# 33       494.605193
# 35       238.532929
# 36       392.117609
# 38       386.462684
# 40       256.450726
# 42       356.316380
# 43       388.387100
# 45       298.971966
# 47       419.950414
# 49       265.296943
# 51       411.312202
# 55       432.738707
# 56       384.274449
# 59       218.702194
# 67       364.763819
# 72       432.932000

# %% [markdown]
# We observe there exist recipes for 240 servings !

# %%
anotherRecipe = collection.find_one({'servings':240})
anotherRecipe
# Out:
# {'_id': ObjectId('5825c738b779830612cba06d'),
#  'adUnit': {'adKeys': [2,
#    59,
#    64,
#    106,
#    109,
#    125,
#    135,
#    139,
#    148,
#    173,
#    184,
#    201,
#    203,
#    221,
#    228,
#    241,
#    244,
#    264,
#    265,
#    268,
#    586,
#    639,
#    680],
#   'adZone': 'recipe',
#   'networkCode': '3865',
#   'site': 'ar.ios.apps.allrecipes.recipes'},
#  'ada-city': [],
#  'ada-continent': [],
#  'ada-country': ['us-recipes', 'australian-and-new-zealander'],
#  'ada-region': ['hawaii'],
#  'ada-subcontinent': ['north-american'],
#  'ada-tags': ['us-recipes',
#   'us-recipes-by-state',
#   'hawaii',
#   'world-cuisine',
#   'australian-and-new-zealander'],
#  'cookMinutes': 90,
#  'description': 'A Hawaiian chutney, excellent with pork or lamb. Also a treat with peanut butter on bread. Note: Common mangos are small and sweet even when half-ripe, not juicy.',
#  'directions': [{'displayValue': 'In a large saucepan combine vinegar, white sugar, brown sugar, cinnamon, ground ginger, allspice, cloves, nutmeg, chile peppers and salt. Bring to a boil; boil for 1/2 hour.',
#    'ordinal': 1,
#    'videoTimestamp': 0},
#   {'displayValue': 'Stir in onions, garlic, golden raisins, raisins and ginger and boil for another 1/2 hour.',
#    'ordinal': 2,
#    'videoTimestamp': 0},
#   {'displayValue': 'Stir in mangos (and almonds if using), reduce heat to low and simmer for 1/2 hour. Pour mixture into sterilized jars, to 1/2 inch below lid level, and seal.',
#    'ordinal': 3,
#    'videoTimestamp': 0}],
#  'footnotes': [],
#  'ingredients': [{'displayType': 'Normal',
#    'displayValue': '3 cups distilled white vinegar',
#    'grams': 720.0,
#    'ingredientID': 7842},
#   {'displayType': 'Normal',
#    'displayValue': '6 cups white sugar',
#    'grams': 1200.0,
#    'ingredientID': 1526},
#   {'displayType': 'Normal',
#    'displayValue': '6 cups brown sugar',
#    'grams': 870.0,
#    'ingredientID': 1525},
#   {'displayType': 'Normal',
#    'displayValue': '1 teaspoon ground cinnamon',
#    'grams': 2.3,
#    'ingredientID': 16386},
#   {'displayType': 'Normal',
#    'displayValue': '2 teaspoons ground ginger',
#    'grams': 3.6,
#    'ingredientID': 16397},
#   {'displayType': 'Normal',
#    'displayValue': '4 teaspoons ground allspice',
#    'grams': 7.6,
#    'ingredientID': 16377},
#   {'displayType': 'Normal',
#    'displayValue': '1 teaspoon ground cloves',
#    'grams': 2.1,
#    'ingredientID': 16387},
#   {'displayType': 'Normal',
#    'displayValue': '2 teaspoons ground nutmeg',
#    'grams': 6.0,
#    'ingredientID': 16401},
#   {'displayType': 'Normal',
#    'displayValue': '5 small red hot chile peppers, seeded and chopped',
#    'grams': 225.0,
#    'ingredientID': 4784},
#   {'displayType': 'Normal',
#    'displayValue': '1 teaspoon kosher salt',
#    'grams': 4.8,
#    'ingredientID': 18866},
#   {'displayType': 'Normal',
#    'displayValue': '2 large onions, chopped',
#    'grams': 300.0,
#    'ingredientID': 4397},
#   {'displayType': 'Normal',
#    'displayValue': '3 cloves garlic, chopped',
#    'grams': 9.0,
#    'ingredientID': 4342},
#   {'displayType': 'Normal',
#    'displayValue': '1 cup golden raisins',
#    'grams': 165.0,
#    'ingredientID': 5218},
#   {'displayType': 'Normal',
#    'displayValue': '1 cup raisins',
#    'grams': 165.0,
#    'ingredientID': 5219},
#   {'displayType': 'Normal',
#    'displayValue': '1/2 cup fresh ginger root, chopped',
#    'grams': 44.79984,
#    'ingredientID': 4343},
#   {'displayType': 'Normal',
#    'displayValue': '16 cups sliced, semi-ripe mangos',
#    'grams': 2640.0,
#    'ingredientID': 5121},
#   {'displayType': 'OptionalIngredient',
#    'displayValue': '1/2 cup sliced almonds (optional)',
#    'grams': 47.5,
#    'ingredientID': 3767}],
#  'isSponsored': False,
#  'links': {'recipeUrl': {'href': 'http://allrecipes.com/recipe/19842/mango-chutney/'},
#   'self': {'href': 'https://apps.allrecipes.com/v1/recipes/19842'}},
#  'nutrition': {'calcium': {'amount': 5.899712,
#    'displayValue': '6',
#    'hasCompleteData': False,
#    'name': 'Calcium',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'calories': {'amount': 45.91531,
#    'displayValue': '46',
#    'hasCompleteData': True,
#    'name': 'Calories',
#    'percentDailyValue': '2',
#    'unit': 'kcal'},
#   'caloriesFromFat': {'amount': 1.399966,
#    'displayValue': '1',
#    'hasCompleteData': True,
#    'name': 'Calories from Fat',
#    'percentDailyValue': '-',
#    'unit': 'kcal'},
#   'carbohydrates': {'amount': 11.55886,
#    'displayValue': '11.6',
#    'hasCompleteData': True,
#    'name': 'Carbohydrates',
#    'percentDailyValue': '4',
#    'unit': 'g'},
#   'cholesterol': {'amount': 0.0,
#    'displayValue': '0',
#    'hasCompleteData': True,
#    'name': 'Cholesterol',
#    'percentDailyValue': '0',
#    'unit': 'mg'},
#   'fat': {'amount': 0.1555518,
#    'displayValue': '0.2',
#    'hasCompleteData': True,
#    'name': 'Fat',
#    'percentDailyValue': '< 1',
#    'unit': 'g'},
#   'fiber': {'amount': 0.3050362,
#    'displayValue': '0.3',
#    'hasCompleteData': True,
#    'name': 'Dietary Fiber',
#    'percentDailyValue': '1',
#    'unit': 'g'},
#   'folate': {'amount': 2.113952,
#    'displayValue': '2',
#    'hasCompleteData': False,
#    'name': 'Folate',
#    'percentDailyValue': '1',
#    'unit': 'mcg'},
#   'iron': {'amount': 0.08332716,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Iron',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'magnesium': {'amount': 2.669516,
#    'displayValue': '3',
#    'hasCompleteData': False,
#    'name': 'Magnesium',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'niacin': {'amount': 0.1260433,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Niacin Equivalents',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'potassium': {'amount': 34.63036,
#    'displayValue': '35',
#    'hasCompleteData': False,
#    'name': 'Potassium',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'protein': {'amount': 0.169114,
#    'displayValue': '0.2',
#    'hasCompleteData': True,
#    'name': 'Protein',
#    'percentDailyValue': '< 1',
#    'unit': 'g'},
#   'saturatedFat': {'amount': 0.02518959,
#    'displayValue': '0',
#    'hasCompleteData': True,
#    'name': 'Saturated Fat',
#    'percentDailyValue': '< 1',
#    'unit': 'g'},
#   'sodium': {'amount': 12.50464,
#    'displayValue': '13',
#    'hasCompleteData': True,
#    'name': 'Sodium',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'sugars': {'amount': 10.27038,
#    'displayValue': '10.3',
#    'hasCompleteData': False,
#    'name': 'Sugars',
#    'percentDailyValue': '0',
#    'unit': 'g'},
#   'thiamin': {'amount': 0.008776487,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Thiamin',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'vitaminA': {'amount': 93.43557,
#    'displayValue': '93',
#    'hasCompleteData': False,
#    'name': 'Vitamin A - IU',
#    'percentDailyValue': '2',
#    'unit': 'IU'},
#   'vitaminB6': {'amount': 0.02533283,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Vitamin B6',
#    'percentDailyValue': '2',
#    'unit': 'mg'},
#   'vitaminC': {'amount': 4.51665,
#    'displayValue': '5',
#    'hasCompleteData': False,
#    'name': 'Vitamin C',
#    'percentDailyValue': '8',
#    'unit': 'mg'}},
#  'photo': {'description': '',
#   'itemType': 'Photo',
#   'photoDetailUrl': 'http://m.allrecipes.com/photos/12507',
#   'photoID': 12507,
#   'rawItemType': 10,
#   'recipeTitle': None,
#   'title': '',
#   'urls': [{'height': 50,
#     'url': 'http://images.media-allrecipes.com/userphotos/50x50/12507.jpg',
#     'width': 50},
#    {'height': 110,
#     'url': 'http://images.media-allrecipes.com/userphotos/110x110/12507.jpg',
#     'width': 110},
#    {'height': 140,
#     'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/01/25/12507.jpg',
#     'width': 140},
#    {'height': 250,
#     'url': 'http://images.media-allrecipes.com/userphotos/250x250/12507.jpg',
#     'width': 250}]},
#  'prepMinutes': 10,
#  'ratingAverage': 4.364865,
#  'ratingCount': 74,
#  'readyInMinutes': 100,
#  'recipeID': 19842,
#  'reviewCount': 62,
#  'servings': 240,
#  'similarRecipes': {'links': {'self': {'href': 'https://apps.allrecipes.com/v1/recipes/19842'}},
#   'metaData': {'page': 1, 'pagesize': 20, 'totalCount': 20},
#   'recipes': [{'description': 'This chutney recipe comes direct from the Pakistani friend of an American living in an international community in Saudi Arabia. The zesty condiment combines green mangoes, garlic, ginger, cumin, cardamom, cinnamon, cloves, sugar and vinegar in a magical blend of spices to accompany meats, vegetables, and curries.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/150337'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/kokubs-mango-chutney-from-pakistan/'}},
#     'madeCount': 36,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/50104',
#      'photoID': 50104,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/50104.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/50104.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/05/01/50104.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/50104.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.74,
#     'ratingCount': 35,
#     'rawItemType': 1,
#     'recipeID': 150337,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 29,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 1204,
#      'followersCount': 127,
#      'followingCount': 58,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 49,
#      'name': 'PREGOCOOK',
#      'personalRecipeSharedCount': 44,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/2615883',
#       'photoID': 2615883,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/2615883.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/2615883.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/02/61/58/2615883.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/2615883.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/1155018/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 49,
#      'rawItemType': 11,
#      'reciepesCount': 8,
#      'region': None,
#      'reviewsCount': 49,
#      'userID': 1155018},
#     'title': "Kokub's Mango Chutney from Pakistan",
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'My mom makes this chutney during the summer to serve as a garnish for fish or steak. It is great as a gift too. Scrumptious!',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/165396'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/magues-green-mango-chutney/'}},
#     'madeCount': 2,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 2.0,
#     'ratingCount': 1,
#     'rawItemType': 1,
#     'recipeID': 165396,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 1,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 206,
#      'followersCount': 0,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 4,
#      'name': 'zuallemfahig',
#      'personalRecipeSharedCount': 1,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/2901379/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 4,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 4,
#      'userID': 2901379},
#     'title': "Mague's Green Mango Chutney",
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This refreshing mango chutney is quick and easy and perfect to top schnitzel.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/222329'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/refreshing-mango-chutney/'}},
#     'madeCount': 0,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 0.0,
#     'ratingCount': 0,
#     'rawItemType': 1,
#     'recipeID': 222329,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 0,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 40,
#      'followersCount': 0,
#      'followingCount': 3,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 4,
#      'name': 'Elliot Porter',
#      'personalRecipeSharedCount': 3,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/3849946',
#       'photoID': 3849946,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/3849946.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/3849946.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/84/99/3849946.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/3849946.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/1368661/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 4,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 4,
#      'userID': 1368661},
#     'title': 'Refreshing Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Make your own Indian-style mango chutney with dates and raisins. This recipe makes enough for freezing or canning.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/237069'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/real-indian-mango-chutney/'}},
#     'madeCount': 1,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 5.0,
#     'ratingCount': 1,
#     'rawItemType': 1,
#     'recipeID': 237069,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 0,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 166,
#      'followersCount': 6,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 60,
#      'name': 'Michelle Mackey',
#      'personalRecipeSharedCount': 2,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/1759291',
#       'photoID': 1759291,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/1759291.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/1759291.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/75/92/1759291.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/1759291.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/1950405/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 59,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 58,
#      'userID': 1950405},
#     'title': 'Real Indian Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This chutney with pears, mangos, dried cherries and lots of spice is a perfect addition to your holiday table.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/56219'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/roasted-pear-mango-chutney/'}},
#     'madeCount': 7,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 4.25,
#     'ratingCount': 4,
#     'rawItemType': 1,
#     'recipeID': 56219,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 4,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 1570,
#      'followersCount': 1,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 23,
#      'name': 'BASTET',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/87249',
#       'photoID': 87249,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/87249.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/87249.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/08/72/87249.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/87249.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/61705/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 23,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 14,
#      'userID': 61705},
#     'title': 'Roasted Pear Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This quick and easy mango chutney is ready in minutes after blending mango, habanero pepper, garlic, and lime juice together for a tasty accompaniment to many meals.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/222326'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/island-mango-chutney/'}},
#     'madeCount': 0,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 0.0,
#     'ratingCount': 0,
#     'rawItemType': 1,
#     'recipeID': 222326,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 0,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 1,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 5,
#      'name': 'KathyFL',
#      'personalRecipeSharedCount': 1,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/3731988/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 5,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 3,
#      'userID': 3731988},
#     'title': 'Island Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This sweet and spicy chutney combines pineapple, mango, cucumber, and jalapeno for a colorful topping for scallops or chicken.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/222324'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/pineapple-mango-chutney/'}},
#     'madeCount': 12,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/1128127',
#      'photoID': 1128127,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/1128127.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/1128127.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/12/81/1128127.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/1128127.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.5,
#     'ratingCount': 6,
#     'rawItemType': 1,
#     'recipeID': 222324,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 6,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 518,
#      'followersCount': 1,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 12,
#      'name': 'Yorkville_Mom',
#      'personalRecipeSharedCount': 3,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/643570',
#       'photoID': 643570,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/643570.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/643570.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/64/35/643570.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/643570.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/3739943/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 9,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 9,
#      'userID': 3739943},
#     'title': 'Pineapple Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Traditional naan dough is formed into bread twists and served with mango chutney made with lots of traditional spices and seasonings.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/239423'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/salted-naan-sticks-with-mango-chutney/'}},
#     'madeCount': 0,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/1474027',
#      'photoID': 1474027,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/1474027.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/1474027.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/47/40/1474027.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/1474027.jpg',
#        'width': 250}]},
#     'ratingAverage': 0.0,
#     'ratingCount': 0,
#     'rawItemType': 1,
#     'recipeID': 239423,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 0,
#     'sourceID': 482,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 30,
#      'followersCount': 1,
#      'followingCount': 0,
#      'handle': 'diamondcrystalsalt',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Diamond Crystal Salt',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/1381229',
#       'photoID': 1381229,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/1381229.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/1381229.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/38/12/1381229.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/1381229.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/diamondcrystalsalt/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 30,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 20505315},
#     'title': 'Salted Naan Sticks with Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Chicken salad with an Indian-inspired twist of mango chutney and curry powder is quick and easy to prepare. Dried cranberries, raisins, or pineapple chunks can also be added.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/222328'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/chicken-salad-with-mango-chutney/'}},
#     'madeCount': 5,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/963770',
#      'photoID': 963770,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/963770.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/963770.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/96/37/963770.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/963770.jpg',
#        'width': 250}]},
#     'ratingAverage': 5.0,
#     'ratingCount': 5,
#     'rawItemType': 1,
#     'recipeID': 222328,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 4,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 10,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'simone stevin',
#      'personalRecipeSharedCount': 10,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/1835422/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 4,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 1835422},
#     'title': 'Chicken Salad with Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Mango chutney tops off this magnificent cheese ball with bacon, onion and golden raisins. Simple, simple recipe and the dish is emptied EVERY time!!',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/84389'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/mango-chutney-cheese-ball/'}},
#     'madeCount': 58,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/240116',
#      'photoID': 240116,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/240116.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/240116.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/24/01/240116.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/240116.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.58,
#     'ratingCount': 64,
#     'rawItemType': 1,
#     'recipeID': 84389,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 54,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 1,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 2,
#      'name': 'PHROGGI19',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/1385861/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 2,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 2,
#      'userID': 1385861},
#     'title': 'Mango Chutney Cheese Ball',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'The sweetness of mango, pineapple and red pepper is given a zing from fresh ginger and a kick from hot chile pepper. Serve this chutney with grilled chicken or seafood for an exciting burst of flavor!',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/166016'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/mango-pineapple-chutney/'}},
#     'madeCount': 31,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/230419',
#      'photoID': 230419,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/230419.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/230419.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/23/04/230419.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/230419.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.68,
#     'ratingCount': 31,
#     'rawItemType': 1,
#     'recipeID': 166016,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 23,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 243,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 38,
#      'name': 'MATHTUTORRITA',
#      'personalRecipeSharedCount': 2,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/1444417/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 38,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 17,
#      'userID': 1444417},
#     'title': 'Mango-Pineapple Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This chutney recipe comes direct from the Pakistani friend of an American living in an international community in Saudi Arabia. The zesty condiment combines green mangoes, garlic, ginger, cumin, cardamom, cinnamon, cloves, sugar and vinegar in a magical blend of spices to accompany meats, vegetables, and curries.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/150337'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/kokubs-mango-chutney-from-pakistan/'}},
#     'madeCount': 36,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/50104',
#      'photoID': 50104,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/50104.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/50104.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/05/01/50104.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/50104.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.74,
#     'ratingCount': 35,
#     'rawItemType': 1,
#     'recipeID': 150337,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 29,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 1204,
#      'followersCount': 127,
#      'followingCount': 58,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 49,
#      'name': 'PREGOCOOK',
#      'personalRecipeSharedCount': 44,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/2615883',
#       'photoID': 2615883,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/2615883.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/2615883.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/02/61/58/2615883.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/2615883.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/1155018/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 49,
#      'rawItemType': 11,
#      'reciepesCount': 8,
#      'region': None,
#      'reviewsCount': 49,
#      'userID': 1155018},
#     'title': "Kokub's Mango Chutney from Pakistan",
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This sweet and spicy chutney combines pineapple, mango, cucumber, and jalapeno for a colorful topping for scallops or chicken.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/222324'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/pineapple-mango-chutney/'}},
#     'madeCount': 12,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/1128127',
#      'photoID': 1128127,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/1128127.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/1128127.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/12/81/1128127.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/1128127.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.5,
#     'ratingCount': 6,
#     'rawItemType': 1,
#     'recipeID': 222324,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 6,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 518,
#      'followersCount': 1,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 12,
#      'name': 'Yorkville_Mom',
#      'personalRecipeSharedCount': 3,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/643570',
#       'photoID': 643570,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/643570.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/643570.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/64/35/643570.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/643570.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/3739943/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 9,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 9,
#      'userID': 3739943},
#     'title': 'Pineapple Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Make your own Indian-style mango chutney with dates and raisins. This recipe makes enough for freezing or canning.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/237069'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/real-indian-mango-chutney/'}},
#     'madeCount': 1,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 5.0,
#     'ratingCount': 1,
#     'rawItemType': 1,
#     'recipeID': 237069,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 0,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 166,
#      'followersCount': 6,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 60,
#      'name': 'Michelle Mackey',
#      'personalRecipeSharedCount': 2,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/1759291',
#       'photoID': 1759291,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/1759291.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/1759291.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/75/92/1759291.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/1759291.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/1950405/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 59,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 58,
#      'userID': 1950405},
#     'title': 'Real Indian Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This easy chutney is a great companion for so many dishes from turkey sandwiches to pork chops.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/70037'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/apple-chutney/'}},
#     'madeCount': 47,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/318537',
#      'photoID': 318537,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/318537.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/318537.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/31/85/318537.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/318537.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.49,
#     'ratingCount': 45,
#     'rawItemType': 1,
#     'recipeID': 70037,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 38,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 3,
#      'followersCount': 3,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 3,
#      'name': 'CATSEO',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
# ...
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/161436'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/omas-rhubarb-cake/'}},
#     'madeCount': 483,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/1017615',
#      'photoID': 1017615,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/1017615.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/1017615.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/01/76/1017615.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/1017615.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.77,
#     'ratingCount': 320,
#     'rawItemType': 1,
#     'recipeID': 161436,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 259,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 229,
#      'followersCount': 10,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 17,
#      'name': 'Alea',
#      'personalRecipeSharedCount': 7,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/861466',
#       'photoID': 861466,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/861466.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/861466.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/86/14/861466.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/861466.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/2808356/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 17,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 15,
#      'userID': 2808356},
#     'title': "Oma's Rhubarb Cake",
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This is a moist fudgy type cake. Sweet but not extremely sweet and makes good use of zucchini! You can frost it with chocolate frosting or cream cheese icing.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/17643'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/chocolate-zucchini-cake-iii/'}},
#     'madeCount': 954,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/969089',
#      'photoID': 969089,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/969089.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/969089.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/96/90/969089.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/969089.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.71,
#     'ratingCount': 683,
#     'rawItemType': 1,
#     'recipeID': 17643,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 569,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': None,
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Sandy',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 0,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 0},
#     'title': 'Chocolate Zucchini Cake III',
#     'type': 'recipes',
#     'videoID': 2981},
#    {'description': 'These crispy shrimp are rolled in a coconut beer batter before frying. For dipping sauce, I use orange marmalade, mustard and horseradish mixed to taste.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/17753'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/coconut-shrimp-i/'}},
#     'madeCount': 1592,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/693130',
#      'photoID': 693130,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/693130.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/693130.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/69/31/693130.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/693130.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.79,
#     'ratingCount': 1819,
#     'rawItemType': 1,
#     'recipeID': 17753,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 1354,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 4,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'LINDAV10',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/338308/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 338308},
#     'title': 'Coconut Shrimp I',
#     'type': 'recipes',
#     'videoID': 1126}]},
#  'sourceID': 0,
#  'submitter': {'brandedSourceID': 0,
#   'city': None,
#   'country': None,
#   'favoritesCount': 0,
#   'followersCount': 0,
#   'followingCount': 0,
#   'handle': None,
#   'isPro': False,
#   'itemType': 'Cook',
#   'madeRecipesCount': 0,
#   'name': 'Shirley Crowley',
#   'personalRecipeSharedCount': 0,
#   'photo': {'description': None,
#    'itemType': 'Photo',
#    'photoDetailUrl': None,
#    'rawItemType': 10,
#    'recipeTitle': None,
#    'title': None,
#    'urls': [{'height': 50,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#      'width': 50},
#     {'height': 110,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#      'width': 110},
#     {'height': 140,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#      'width': 140},
#     {'height': 250,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#      'width': 250}]},
#   'profileUrl': '',
#   'promotedBrandPixelTrackingUrl': None,
#   'ratingsCount': 0,
#   'rawItemType': 11,
#   'reciepesCount': 0,
#   'region': None,
#   'reviewsCount': 0,
#   'userID': 0},
#  'title': 'Mango Chutney',
#  'topReviews': [{'dateLastModified': '2007-02-02T20:32:25.88',
#    'helpfulCount': 138,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/19842/reviews/907416/increment-helpful-count'}},
#    'rating': 4,
#    'rawItemType': 9,
#    'reviewID': 907416,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 2,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': False,
#     'itemType': 'Cook',
#     'madeRecipesCount': 1,
#     'name': 'KIRCHY7',
#     'personalRecipeSharedCount': 0,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#        'width': 250}]},
#     'profileUrl': '/cook/2189581/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 1,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 1,
#     'userID': 2189581},
#    'text': 'If you prefer a thicker, more fruit preserve-like consistency for your chutney, you can modify the cooking method on this excellent recipe and its blend of flavors as I did: Using the 30 serving size recipe, use all ingredients as measured, except: Adjust sugar to 1/2 cup each white and brown, add 1 TBSP butter to your ingredient list, and try 2 TBSPs each white vinegar and lemon juice (vs. 1/4 cup vinegar).  For the cooking method: Set saucepan on medium heat (I used a 2.5 quart Le Creuset saucepan, which heats more evenly than any pan I have used, so medium high will be too high). Melt butter, and add dry spices, stirring with a silicone spatula or spoon, 2 mins. til fragrant.  Add all other ingredients (except nuts; you will add them at the end).  Stir gently until combined. It will take appr. 10 mins. for the mixture to come to a simmer.  Once the simmer has begun, set timer for 60 minutes, and cook, maintaining a gentle but consistent simmer (in my saucepan there were 10 pockets of nickel - size bubble groups across the top).  Stir gently with spatula every 5 mins. or so.  After 60 mins., turn off the heat and let cool in the saucepan.  The chutney will be reduced in volume, and will be the consistency of a fruit preserve.  Stir in 1/4 cup chopped slivered almonds or macadamia nuts.  Store in air tight container, refrigerate, and enjoy!  Great on Wasa crackers with cream cheese, or mixed with diced chicken for a salad!'},
#   {'dateLastModified': '2003-11-14T02:29:45.42',
#    'helpfulCount': 75,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/19842/reviews/194757/increment-helpful-count'}},
#    'rating': 3,
#    'rawItemType': 9,
#    'reviewID': 194757,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 145,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': False,
#     'itemType': 'Cook',
#     'madeRecipesCount': 13,
#     'name': 'CAROL POGIE',
#     'personalRecipeSharedCount': 2,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#        'width': 250}]},
#     'profileUrl': '/cook/449153/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 13,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 13,
#     'userID': 449153},
#    'text': 'I downsized this recipe to serve 30, you must also downsized cooking times as you can easily overcook. I love chutney with a pork roast, this one is good but not a favorite, I would cut out the allspice or just a pinch as it is a predominate taste in this chutney.'},
#   {'dateLastModified': '2003-11-14T02:29:34.61',
#    'helpfulCount': 42,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/19842/reviews/293315/increment-helpful-count'}},
#    'rating': 5,
#    'rawItemType': 9,
#    'reviewID': 293315,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 141,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': True,
#     'itemType': 'Cook',
#     'madeRecipesCount': 10,
#     'name': 'PATTRICIA',
#     'personalRecipeSharedCount': 0,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/1113564',
#      'photoID': 1113564,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/1113564.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/1113564.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/11/35/1113564.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/1113564.jpg',
#        'width': 250}]},
#     'profileUrl': '/cook/551727/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 11,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 11,
#     'userID': 551727},
#    'text': 'I am a chutney lover, and this is the best of all.  It is a wonderful chicken marinade.  \r\n\r\nMy favorite way of serving, is on top of cream cheese with triskets.\r\n\r\nI made this last summer, and gave away as Christmas gifts.  Everyone LOVED it!\r\n\r\nIt came out more juicy than I thought.  I thought it would thicken as it cooled.  Next time I would add more mango.'}],
#  'type': 'recipes',
#  'video': None}

# %% [markdown]
# ## Check that unit is the same for all same nutrients

# %%
allKeysWithDescription = get_all_field_addresses(oneRecipe, shortenLongStrings=False)
keyAddressesToCheck = []
for key in allKeysWithDescription:
    if key.endswith('.unit'):
        keyAddressesToCheck.append(key)

# %%
df_units = pd.DataFrame(columns = ['nutrition' , 'observed units'])
for keyName in keyAddressesToCheck:

    results = group_and_get_aggregate_of_field(
        collection, 
        group_by_field_address='get_global_aggregation', 
        aggregate_field_address=keyName,
        group_by_field_output_name='DummyName', 
        aggregate_field_output_name='units', 
        aggregationFunction = '$addToSet' 
    )
    #print(results[0])
    #df2.loc[-1] = 
    df_units = df_units.append(pd.DataFrame({'nutrition': make_column_name(keyName), 'observed units': results[0]['units']}))
    #a = results
    
df_units = df_units.reset_index()
df_units
# Out:
#                         nutrition observed units
# 0        nutrition_potassium_unit             mg
# 0     nutrition_saturatedFat_unit              g
# 0    nutrition_carbohydrates_unit              g
# 0           nutrition_sodium_unit             mg
# 0           nutrition_sugars_unit              g
# 0          nutrition_thiamin_unit             mg
# 0         nutrition_vitaminA_unit             IU
# 0             nutrition_iron_unit             mg
# 0        nutrition_vitaminB6_unit             mg
# 0              nutrition_fat_unit              g
# 0         nutrition_vitaminC_unit             mg
# 0  nutrition_caloriesFromFat_unit           kcal
# 0          nutrition_calcium_unit             mg
# 0        nutrition_magnesium_unit             mg
# 0         nutrition_calories_unit           kcal
# 0          nutrition_protein_unit              g
# 0           nutrition_niacin_unit             mg
# 0            nutrition_fiber_unit              g
# 0           nutrition_folate_unit            mcg
# 0      nutrition_cholesterol_unit             mg

# %%
df_units.reset_index()
# Out:
#     index                       nutrition observed units
# 0       0        nutrition_potassium_unit             mg
# 1       0     nutrition_saturatedFat_unit              g
# 2       0    nutrition_carbohydrates_unit              g
# 3       0           nutrition_sodium_unit             mg
# 4       0           nutrition_sugars_unit              g
# 5       0          nutrition_thiamin_unit             mg
# 6       0         nutrition_vitaminA_unit             IU
# 7       0             nutrition_iron_unit             mg
# 8       0        nutrition_vitaminB6_unit             mg
# 9       0              nutrition_fat_unit              g
# 10      0         nutrition_vitaminC_unit             mg
# 11      0  nutrition_caloriesFromFat_unit           kcal
# 12      0          nutrition_calcium_unit             mg
# 13      0        nutrition_magnesium_unit             mg
# 14      0         nutrition_calories_unit           kcal
# 15      0          nutrition_protein_unit              g
# 16      0           nutrition_niacin_unit             mg
# 17      0            nutrition_fiber_unit              g
# 18      0           nutrition_folate_unit            mcg
# 19      0      nutrition_cholesterol_unit             mg

# %% [markdown]
# Hence we see that each ingredient is only given in a single unit in all recipes.

# %%
json_output_filename = '../website/data/nutritionAmountUnits.json'

os.makedirs(os.path.dirname(json_output_filename), exist_ok=True)
write_dataframes_to_json(json_output_filename, df_units)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-201-1160720bedfd> in <module>()
#       2
#       3 os.makedirs(os.path.dirname(json_output_filename), exist_ok=True)
# ----> 4 write_dataframes_to_json(json_output_filename, [df_units])
#       5
#
# /home/maximilian/Desktop/Projects/ADAProject/mongo-example/aggregation_functions.py in write_dataframes_to_json(json_filename, allDataframes)
#     145         # indent = spaces per tab for pretty printing
#     146         json.dump(allDataframes, file, indent=4,
# --> 147                   default=lambda df: json.loads(df.to_json(orient='index'))) # default gets called when cannot be serialized
#     148
#     149
#
# /home/maximilian/anaconda3/lib/python3.5/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     176     # could accelerate with writelines in some versions of Python, at
#     177     # a debuggability cost
# --> 178     for chunk in iterable:
#     179         fp.write(chunk)
#     180
#
# /home/maximilian/anaconda3/lib/python3.5/json/encoder.py in _iterencode(o, _current_indent_level)
#     425             yield _floatstr(o)
#     426         elif isinstance(o, (list, tuple)):
# --> 427             yield from _iterencode_list(o, _current_indent_level)
#     428         elif isinstance(o, dict):
#     429             yield from _iterencode_dict(o, _current_indent_level)
#
# /home/maximilian/anaconda3/lib/python3.5/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     322                 else:
#     323                     chunks = _iterencode(value, _current_indent_level)
# --> 324                 yield from chunks
#     325         if newline_indent is not None:
#     326             _current_indent_level -= 1
#
# /home/maximilian/anaconda3/lib/python3.5/json/encoder.py in _iterencode(o, _current_indent_level)
#     434                     raise ValueError("Circular reference detected")
#     435                 markers[markerid] = o
# --> 436             o = _default(o)
#     437             yield from _iterencode(o, _current_indent_level)
#     438             if markers is not None:
#
# /home/maximilian/Desktop/Projects/ADAProject/mongo-example/aggregation_functions.py in <lambda>(df)
#     145         # indent = spaces per tab for pretty printing
#     146         json.dump(allDataframes, file, indent=4,
# --> 147                   default=lambda df: json.loads(df.to_json(orient='index'))) # default gets called when cannot be serialized
#     148
#     149
#
# /home/maximilian/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler)
#    1054                             double_precision=double_precision,
#    1055                             force_ascii=force_ascii, date_unit=date_unit,
# -> 1056                             default_handler=default_handler)
#    1057
#    1058     def to_hdf(self, path_or_buf, key, **kwargs):
#
# /home/maximilian/anaconda3/lib/python3.5/site-packages/pandas/io/json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler)
#      34             obj, orient=orient, date_format=date_format,
#      35             double_precision=double_precision, ensure_ascii=force_ascii,
# ---> 36             date_unit=date_unit, default_handler=default_handler).write()
#      37     else:
#      38         raise NotImplementedError("'obj' should be a Series or a DataFrame")
#
# /home/maximilian/anaconda3/lib/python3.5/site-packages/pandas/io/json.py in __init__(self, obj, orient, date_format, double_precision, ensure_ascii, date_unit, default_handler)
#      64
#      65         self.is_copy = None
# ---> 66         self._format_axes()
#      67
#      68     def _format_axes(self):
#
# /home/maximilian/anaconda3/lib/python3.5/site-packages/pandas/io/json.py in _format_axes(self)
#      97                 'index', 'columns'):
#      98             raise ValueError("DataFrame index must be unique for orient="
# ---> 99                              "'%s'." % self.orient)
#     100         if not self.obj.columns.is_unique and self.orient in (
#     101                 'index', 'columns', 'records'):
#
# ValueError: DataFrame index must be unique for orient='index'.

# %% [markdown]
# # Stubs

# %% [markdown]
# To be removed in the very end

# %%
# old: not currently used
def prettifyCities(cities):
    # cities is an array of arrays of cities
    # flattens this array
    return [city for citiesList in cities for city in citiesList]

# %%
def getAverageOfFieldPerRegion(fieldName, fieldAddress):
    # groups by continent, subcontinent, ... and computes the average
    # fieldName used in output, fieldAddress: path to access field in the collection

    results = collection.aggregate( [ 
            { '$group': 
                {
                    '_id': { 'continent': "$ada-continent", 'subcontinent': "$ada-subcontinent", 
                            'country': "$ada-country", 'region': '$ada-region', 'city': '$ada-city'},
                    # e.g. 'avgCalories': { '$avg': '$nutrition.calories.amount' },
                    fieldName: {'$avg': ('$' + fieldAddress)}, 
                    'nbRecipes': { "$sum": 1},
                }
            },
            { '$project': 
                {
                    '_id': 0,
                    # e.g. 'avgCalories': "$avgCalories",
                    fieldName: ("$" + fieldName),
                    'nbRecipes': "$nbRecipes",
                    'continent': "$_id.continent",
                    'subcontinent': "$_id.subcontinent",
                    'country': "$_id.country",
                    'region': "$_id.region",
                    'city': "$_id.city",
                }    
            }
        ]
    )
    
    return results

results = getAverageOfFieldPerRegion(fieldName='avgCalories', fieldAddress='nutrition.calories.amount')

# %%
#~ # group bys
#~ groupBysToQuery = [
    #~ {
        #~ # get global average
        #~ 'group_by_field_address': 'get_global_aggregation',
        #~ 'group_by_field_output_name': 'DummyColumn' # ignored,
    #~ },
    #~ {
        #~ 'group_by_field_address': '$ada-city',
        #~ 'group_by_field_output_name': 'city', # as it appears in dataframe
    #~ },
#~ ]

#~ # keep in sync with above groupBys
#~ dataframeNames = ['global', 'per_city']

#~ # what to aggregate for
#~ fieldArgumentsToQuery = [
    #~ {
        #~ 'aggregate_field_address': '$nutrition.calories.amount', 
        #~ 'aggregate_field_output_name': 'avg_calories', 
        #~ 'aggregationFunction': '$avg' 
    #~ },
    #~ {
        #~ 'aggregate_field_address': '$nutrition.vitaminA.amount', 
        #~ 'aggregate_field_output_name': 'total_vitaminA_Intake', 
        #~ 'aggregationFunction': '$sum' 
    #~ },
#~ ]



#~ for keyName, value in allKeysWithDescription.items():
    #~ if keyName == '_id':
        #~ continue
    
    #~ res = group_and_get_aggregate_of_field(collection, group_by_field_address='get_global_aggregation',
                                    #~ aggregate_field_address=keyName, 
                                    #~ group_by_field_output_name='outputField', 
                                    #~ aggregate_field_output_name=keyName, 
                                    #~ aggregationFunction = '$type' )
    
    #~ print(res)
    #~ break
    
    #~ #getAllDataframes(collection, groupBysToQuery, fieldArgumentsToQuery, dataframeNames)

# %% [markdown]
# # What is below is not yet done

# %% [markdown]
# Need to add one entry per row when there are multiple countries.

# %%
import itertools


for i, document in enumerate(results):
    fieldnames = ['continent', 'subcontinent', 'country', 'region', 'city']
    fieldVals = []
    for field in fieldnames:
        fieldVals.append(document[field] or ['NA'])
    combinations = list(itertools.product(*fieldVals))
    localDf = pd.DataFrame.from_records(combinations, columns=fieldnames)
    pd.DataFrame.add(localDf, axis=document.keys())
    
    remainingFields = list(set(document.keys()) - set(fieldnames))
    
    localDf.fillna(value={key: document[key] for key in remainingFields})
    
    if i >= 0:
        break
        
list(combinations)
localDf

# %%
# if there occurs an error "NoCursorFound", rerun the above query or set the property 'noCursorTimeout'
#df = pd.DataFrame(columns={'continent', 'country', 'avgCalories', 'nbRecipes'})


allData = []
for i, document in enumerate(results):
    #print(document)
    #df = df.append(document, ignore_index=True)
    allData.append(document)
    #if i >= 3:
    #    break

#allData
df = pd.DataFrame.from_dict(allData)

applyDataTransf = False

if applyDataTransf:
    joinList = lambda myList: ", ".join(myList)
    df['country'] = df['country'].apply(joinList)
    df['continent'] = df['continent'].apply(joinList)
    df['subcontinent'] = df['subcontinent'].apply(joinList)
    df['region'] = df['region'].apply(joinList)
    df['city'] = df['city'].apply(joinList)
    
    
df.head(3)

# %%
for i, do

# %%
df['continent'].apply(len).value_counts()

df[df['continent'].apply(len) == 2]

# %%
df = df.set_index(['continent', 'subcontinent', 'country'])
df.head(3)

# %%
df.groupby(level=[0,1])[['nbRecipes']].sum()

# %%
# Find an element by ID
oneRecipe = collection.find_one({'recipeID':47564})
oneRecipe

# %%
#started from http://stackoverflow.com/a/23282291

from bson.code import Code

# only emit the key of the field, no values
mapper = Code("""
    function() {
    
        function isObject(val) {
            if (val === null) { return false;}
            return ( (typeof val === 'function') || (typeof val === 'object') );
        }
        function getSubkeys(obj) {
            var subKeys = [];
            for (subKey in obj) {
                if (isObject(obj[subKey])) {
                    subKeys.push(subKey);
                }
                
            }
            return subKeys;
        }
        for (var key in this) { 
            subkeys = getSubkeys(this[key])
            emit(key, subkeys); 
        }
    }
""")

# keep the key, do nothing
reducer = Code("""
    function(key, values) {
        //return values.toString() + "END";
        /*
        function onlyUnique(value, index, self) { 
            return self.indexOf(value) === index;
        }
        return values.filter( onlyUnique ).toString();
        */
        return Array.from(new Set(values)).toString();
        //return new Set(values);
        
        
    }
    
    
""")

distinctThingFields = collection.map_reduce(mapper, reducer, 
    out = {'inline' : 1}, query = {'recipeID': { '$in': [47564, 98310]} }, full_response = True) #
distinctThingFields

# %%
collection.aggregate( [ 
        { 
            '$project': {
                '_id': 0
            }
        }
    ]
)

# %%
oneRecipe['nutrition']['sugars']

# %%
distinctThingFields

# %%
distinctThingFields.ok == 1.0

# %% [markdown]
# Resources:
# * [PyMongo Tutorial](https://api.mongodb.com/python/current/tutorial.html)
# * [Mongo Documentation](https://docs.mongodb.com/ecosystem/drivers/python/)
