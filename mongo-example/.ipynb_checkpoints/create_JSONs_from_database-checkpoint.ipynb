# %% [markdown]
# # Create JSONs with aggregated data from database

# %% [markdown]
# Queries database and gets aggregated data (possible grouped before by country).
# Creates a single JSON that contains all this information.

# %%
# %load_ext autoreload
# %autoreload 2

from pymongo import MongoClient
import datetime
import numpy as np
import pandas as pd
import getpass
from aggregation_functions import * # get all functions used below to communicate with mongodb database

# %% [markdown]
# Be sure you are connect on the **EPFL network** (connection at EPFL or via VPN)

# %% [markdown]
# Note on authentification:
# * Your username-password pair has read-only credentials
# * Use the admin user to insert, modify, or create indexes

# %%
database = 'ada-project'
user = input('MongoDB name: ') #maxmordig
password = getpass.getpass('MongoDB password: ')
# Out:
# MongoDB name: maxmordig
# MongoDB password: ········

# %%
# Mongo Client and authentification
client = MongoClient('www.cocotte-minute.ovh', 27017)
db = client[database]
db.authenticate(user, password)
collection = db['recipes']

# %%
# Number of recipes
serverMongoVersion = client.server_info()['version']
serverMongoVersion
# Out:
# '3.2.10'

# %% [markdown]
# # Example usage of the aggregation function

# %%
results = group_and_get_aggregate_of_field(collection, group_by_field_address='$ada-country', 
                                aggregate_field_address='$nutrition.calories.amount', 
                                group_by_field_output_name='country', 
                                aggregate_field_output_name='avgCalories', 
                                aggregationFunction = '$avg' 
                               )

df = pd.DataFrame.from_dict(results)
df = df.set_index(['country'])
df.head(3)
# Out:
#              avgCalories  nbRecipes
# country
# israeli       255.634929         24
# bangladeshi   355.954350         14
# colombian     374.666667         13

# %%
# Get global average
results = group_and_get_aggregate_of_field(collection, group_by_field_address='get_global_aggregation', 
                                aggregate_field_address='$nutrition.calories.amount', 
                                group_by_field_output_name='DummyColumn', 
                                aggregate_field_output_name='avgCalories', 
                                aggregationFunction = '$avg' 
                               )

df1 = pd.DataFrame.from_dict(results)
df1.head(3)
# Out:
#           DummyColumn  avgCalories  nbRecipes
# 0  Global aggregation   350.246799      16242

# %% [markdown]
# # Several Fields

# %% [markdown]
# To produce the JSONs, we have the following setup.
#
# We are interested in several fields per grouping, e.g. 'avgCalories' and 'avgIronIntake' and the goal is to merge this information into a single dataframe, one row per group. For instance, if a group corresponds to all recipes in a country, the row associated to this group contains averages of some quantities along its columns. In other words, it is the same as above, but we have columns 'avgCalories', 'avgIronIntake' and so on.
#
# To first get an idea of what fields we have, we search for a simple recipe and see its attributes.

# %%
oneRecipe = collection.find_one({'recipeID':47564})
oneRecipe
# Out:
# {'_id': ObjectId('5825054ace06e50446084706'),
#  'adUnit': {'adKeys': [7,
#    79,
#    95,
#    125,
#    148,
#    150,
#    169,
#    173,
#    184,
#    201,
#    221,
#    235,
#    241,
#    242,
#    249,
#    254,
#    265,
#    608],
#   'adZone': 'recipes',
#   'contentProviderId': 451,
#   'networkCode': '3865',
#   'site': 'ar.ios.apps.allrecipes.recipes'},
#  'ada-city': [],
#  'ada-continent': ['asian'],
#  'ada-country': ['indian'],
#  'ada-region': [],
#  'ada-subcontinent': [],
#  'ada-tags': ['world-cuisine',
#   'asian',
#   'indian',
#   'main-dishes',
#   'curry',
#   'vegetarian'],
#  'cookMinutes': 45,
#  'description': 'This is a really easy and tasty Indian dish that is sure to stir up your taste buds. Delicious baingan bharta is ready to eat with pita bread, Indian naan, or rice.',
#  'directions': [{'displayValue': 'Preheat oven to 450 degrees F (230 degrees C).',
#    'ordinal': 1,
#    'videoTimestamp': 0},
#   {'displayValue': 'Place eggplant on a medium baking sheet. Bake 20 to 30 minutes in the preheated oven, until tender. Remove from heat, cool, peel, and chop.',
#    'ordinal': 2,
#    'videoTimestamp': 0},
#   {'displayValue': 'Heat oil in a medium saucepan over medium heat. Mix in cumin seeds and onion. Cook and stir until onion is tender.',
#    'ordinal': 3,
#    'videoTimestamp': 0},
#   {'displayValue': 'Mix ginger garlic paste, curry powder, and tomato into the saucepan, and cook about 1 minute. Stir in yogurt. Mix in eggplant and jalapeno pepper, and season with salt. Cover, and cook 10 minutes over high heat. Remove cover, reduce heat to low, and continue cooking about 5 minutes. Garnish with cilantro to serve.',
#    'ordinal': 4,
#    'videoTimestamp': 0}],
#  'footnotes': [{'ordinal': 100, 'text': 'Tip'},
#   {'ordinal': 101,
#    'text': 'Aluminum foil can be used to keep food moist, cook it evenly, and make clean-up easier.'}],
#  'ingredients': [{'displayType': 'Normal',
#    'displayValue': '1 large eggplant',
#    'grams': 548.0,
#    'ingredientID': 4339},
#   {'displayType': 'Normal',
#    'displayValue': '2 tablespoons vegetable oil',
#    'grams': 27.25,
#    'ingredientID': 6305},
#   {'displayType': 'Normal',
#    'displayValue': '1 teaspoon cumin seeds',
#    'grams': 2.1,
#    'ingredientID': 16390},
#   {'displayType': 'Normal',
#    'displayValue': '1 medium onion, thinly sliced',
#    'grams': 110.0,
#    'ingredientID': 4397},
#   {'displayType': 'Normal',
#    'displayValue': '1 tablespoon ginger garlic paste',
#    'grams': 16.5,
#    'ingredientID': 20678},
#   {'displayType': 'Normal',
#    'displayValue': '1 tablespoon curry powder',
#    'grams': 6.3,
#    'ingredientID': 16391},
#   {'displayType': 'Normal',
#    'displayValue': '1 tomato, diced',
#    'grams': 123.0,
#    'ingredientID': 4572},
#   {'displayType': 'Normal',
#    'displayValue': '1/2 cup plain yogurt',
#    'grams': 122.5,
#    'ingredientID': 16158},
#   {'displayType': 'Normal',
#    'displayValue': '1 fresh jalapeno chile pepper, finely chopped',
#    'grams': 14.0,
#    'ingredientID': 3725},
#   {'displayType': 'Normal',
#    'displayValue': '1 teaspoon salt',
#    'grams': 6.0,
#    'ingredientID': 16421},
#   {'displayType': 'Normal',
#    'displayValue': '1/4 bunch cilantro, finely chopped',
#    'grams': 14.0,
#    'ingredientID': 3717}],
#  'isSponsored': False,
#  'links': {'recipeUrl': {'href': 'http://allrecipes.com/recipe/47564/baingan-bharta-eggplant-curry/'},
#   'self': {'href': 'https://apps.allrecipes.com/v1/recipes/47564'}},
#  'nutrition': {'calcium': {'amount': 93.245,
#    'displayValue': '93',
#    'hasCompleteData': False,
#    'name': 'Calcium',
#    'percentDailyValue': '12',
#    'unit': 'mg'},
#   'calories': {'amount': 146.1237,
#    'displayValue': '146',
#    'hasCompleteData': True,
#    'name': 'Calories',
#    'percentDailyValue': '7',
#    'unit': 'kcal'},
#   'caloriesFromFat': {'amount': 72.09731,
#    'displayValue': '72',
#    'hasCompleteData': True,
#    'name': 'Calories from Fat',
#    'percentDailyValue': '-',
#    'unit': 'kcal'},
#   'carbohydrates': {'amount': 15.22197,
#    'displayValue': '15.2',
#    'hasCompleteData': True,
#    'name': 'Carbohydrates',
#    'percentDailyValue': '5',
#    'unit': 'g'},
#   'cholesterol': {'amount': 1.8375,
#    'displayValue': '2',
#    'hasCompleteData': False,
#    'name': 'Cholesterol',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'fat': {'amount': 8.010813,
#    'displayValue': '8',
#    'hasCompleteData': True,
#    'name': 'Fat',
#    'percentDailyValue': '12',
#    'unit': 'g'},
#   'fiber': {'amount': 6.222385,
#    'displayValue': '6.2',
#    'hasCompleteData': False,
#    'name': 'Dietary Fiber',
#    'percentDailyValue': '25',
#    'unit': 'g'},
#   'folate': {'amount': 49.63925,
#    'displayValue': '50',
#    'hasCompleteData': False,
#    'name': 'Folate',
#    'percentDailyValue': '28',
#    'unit': 'mcg'},
#   'iron': {'amount': 1.403314,
#    'displayValue': '1',
#    'hasCompleteData': False,
#    'name': 'Iron',
#    'percentDailyValue': '14',
#    'unit': 'mg'},
#   'magnesium': {'amount': 38.03075,
#    'displayValue': '38',
#    'hasCompleteData': False,
#    'name': 'Magnesium',
#    'percentDailyValue': '14',
#    'unit': 'mg'},
#   'niacin': {'amount': 1.744597,
#    'displayValue': '2',
#    'hasCompleteData': False,
#    'name': 'Niacin Equivalents',
#    'percentDailyValue': '13',
#    'unit': 'mg'},
#   'potassium': {'amount': 559.3593,
#    'displayValue': '559',
#    'hasCompleteData': False,
#    'name': 'Potassium',
#    'percentDailyValue': '16',
#    'unit': 'mg'},
#   'protein': {'amount': 3.97931,
#    'displayValue': '4',
#    'hasCompleteData': True,
#    'name': 'Protein',
#    'percentDailyValue': '8',
#    'unit': 'g'},
#   'saturatedFat': {'amount': 1.485098,
#    'displayValue': '1.5',
#    'hasCompleteData': True,
#    'name': 'Saturated Fat',
#    'percentDailyValue': '7',
#    'unit': 'g'},
#   'sodium': {'amount': 739.406,
#    'displayValue': '739',
#    'hasCompleteData': True,
#    'name': 'Sodium',
#    'percentDailyValue': '30',
#    'unit': 'mg'},
#   'sugars': {'amount': 7.522098,
#    'displayValue': '7.5',
#    'hasCompleteData': True,
#    'name': 'Sugars',
#    'percentDailyValue': '0',
#    'unit': 'g'},
#   'thiamin': {'amount': 0.1289342,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Thiamin',
#    'percentDailyValue': '13',
#    'unit': 'mg'},
#   'vitaminA': {'amount': 595.6483,
#    'displayValue': '596',
#    'hasCompleteData': False,
#    'name': 'Vitamin A - IU',
#    'percentDailyValue': '12',
#    'unit': 'IU'},
#   'vitaminB6': {'amount': 0.2310775,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Vitamin B6',
#    'percentDailyValue': '14',
#    'unit': 'mg'},
#   'vitaminC': {'amount': 11.91473,
#    'displayValue': '12',
#    'hasCompleteData': False,
#    'name': 'Vitamin C',
#    'percentDailyValue': '20',
#    'unit': 'mg'}},
#  'photo': {'description': '',
#   'itemType': 'Photo',
#   'photoDetailUrl': 'http://m.allrecipes.com/photos/14597',
#   'photoID': 14597,
#   'rawItemType': 10,
#   'recipeTitle': None,
#   'title': '',
#   'urls': [{'height': 50,
#     'url': 'http://images.media-allrecipes.com/userphotos/50x50/14597.jpg',
#     'width': 50},
#    {'height': 110,
#     'url': 'http://images.media-allrecipes.com/userphotos/110x110/14597.jpg',
#     'width': 110},
#    {'height': 140,
#     'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/01/45/14597.jpg',
#     'width': 140},
#    {'height': 250,
#     'url': 'http://images.media-allrecipes.com/userphotos/250x250/14597.jpg',
#     'width': 250}]},
#  'prepMinutes': 15,
#  'ratingAverage': 4.305987,
#  'ratingCount': 451,
#  'readyInMinutes': 60,
#  'recipeID': 47564,
#  'reviewCount': 309,
#  'servings': 4,
#  'similarRecipes': {'links': {'self': {'href': 'https://apps.allrecipes.com/v1/recipes/47564'}},
#   'metaData': {'page': 1, 'pagesize': 20, 'totalCount': 20},
#   'recipes': [{'description': 'Make a big batch of eggplant Parmesan in your slow cooker and dinner will be waiting when you get home. No need to heat up your kitchen baking in an oven.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/223360'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/eggplant-parmesan-for-the-slow-cooker/'}},
#     'madeCount': 86,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/3294074',
#      'photoID': 3294074,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/3294074.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/3294074.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/29/40/3294074.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/3294074.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.39,
#     'ratingCount': 64,
#     'rawItemType': 1,
#     'recipeID': 223360,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 48,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 19,
#      'followersCount': 12,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'jboettcher2',
#      'personalRecipeSharedCount': 1,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/556955',
#       'photoID': 556955,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/556955.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/556955.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/55/69/556955.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/556955.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/5752296/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 5752296},
#     'title': 'Eggplant Parmesan For the Slow Cooker',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'These breaded and baked eggplant sandwiches are the perfect make-ahead appetizer for your next potluck.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/231010'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/chef-johns-baked-eggplant-sandwiches/'}},
#     'madeCount': 34,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/3719268',
#      'photoID': 3719268,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/3719268.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/3719268.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/71/92/3719268.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/3719268.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.73,
#     'ratingCount': 30,
#     'rawItemType': 1,
#     'recipeID': 231010,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 22,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 363,
#      'followersCount': 38210,
#      'followingCount': 194,
#      'handle': 'foodwisheswithchefjohn',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 309,
#      'name': 'Chef John',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/2267470',
#       'photoID': 2267470,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/2267470.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/2267470.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/02/26/74/2267470.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/2267470.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/foodwisheswithchefjohn/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 307,
#      'rawItemType': 11,
#      'reciepesCount': 913,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 8601924},
#     'title': "Chef John's Baked Eggplant Sandwiches",
#     'type': 'recipes',
#     'videoID': 3083},
#    {'description': "This is a rich and hearty lentil curry, great as a main meal rather than as a side dish like the more traditional Indian dhal. Don't let the ingredient list faze you, this really is an easy dish to make. This dish is great served with basmati rice.",
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/16641'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/red-lentil-curry/'}},
#     'madeCount': 1173,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/490284',
#      'photoID': 490284,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/490284.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/490284.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/49/02/490284.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/490284.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.5,
#     'ratingCount': 1121,
#     'rawItemType': 1,
#     'recipeID': 16641,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 789,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': None,
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Emma Maher',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 0,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 0},
#     'title': 'Red Lentil Curry',
#     'type': 'recipes',
#     'videoID': 3209},
#    {'description': "This is a home-style South Indian shrimp curry recipe from my husband's family. It is simple and quick to make. It contains no coconut so is not sweet, just mostly juicy and as hot as you like it. Serve with basmati rice or an Indian flatbread.",
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/93597'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/authentic-and-easy-shrimp-curry/'}},
#     'madeCount': 105,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/269404',
#      'photoID': 269404,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/269404.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/269404.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/26/94/269404.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/269404.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.65,
#     'ratingCount': 104,
#     'rawItemType': 1,
#     'recipeID': 93597,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 81,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 27,
#      'followersCount': 3,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 35,
#      'name': 'RK',
#      'personalRecipeSharedCount': 6,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/1119514/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 36,
#      'rawItemType': 11,
#      'reciepesCount': 5,
#      'region': None,
#      'reviewsCount': 36,
#      'userID': 1119514},
#     'title': 'Authentic and Easy Shrimp Curry',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'A side dish, salad, or relish, caponata with eggplant, garlic, tomatoes, herb and spices is delicious on crusty French bread.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/254694'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/ruths-eggplant-caponata/'}},
#     'madeCount': 4,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/3797880',
#      'photoID': 3797880,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/3797880.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/3797880.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/79/78/3797880.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/3797880.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.0,
#     'ratingCount': 6,
#     'rawItemType': 1,
#     'recipeID': 254694,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 6,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 5,
#      'followersCount': 4,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'RuthE',
#      'personalRecipeSharedCount': 5,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/11418461/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 22,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 11418461},
#     'title': "Ruth's Eggplant Caponata",
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Eggplant is stuffed with sauteed eggplant, onion, peppers and bread crumbs, then topped off with some feta cheese and baked. I named it after the long summer nights I spent with my family on the balcony eating this tasty recipe, because at this season in Greece we have plenty of eggplants and cook them in various ways.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/31818'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/summer-nights-eggplants/'}},
#     'madeCount': 91,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/2366',
#      'photoID': 2366,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/2366.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/2366.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/00/23/2366.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/2366.jpg',
#        'width': 250}]},
#     'ratingAverage': 3.92,
#     'ratingCount': 102,
#     'rawItemType': 1,
#     'recipeID': 31818,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 85,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'LIOTAKI',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/208718/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 208718},
#     'title': 'Summer Nights Eggplants',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': "Wonderful directions for preparing eggplant if you've never done it before. The eggplant is layered in a large pan with marinara sauce, mozzarella, ricotta and Parmesan cheese. This it 's baked until the cheese topping is golden.",
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/13981'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/eggplant-parmesan-i/'}},
#     'madeCount': 468,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/235061',
#      'photoID': 235061,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/235061.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/235061.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/23/50/235061.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/235061.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.37,
#     'ratingCount': 495,
#     'rawItemType': 1,
#     'recipeID': 13981,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 360,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': None,
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Karen',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 0,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 0},
#     'title': 'Eggplant Parmesan I',
#     'type': 'recipes',
#     'videoID': 1212},
#    {'description': 'Coconut milk adds creaminess to this vegan dish, while enhancing the spicier notes.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/254692'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/crazy-creamy-chickpea-curry/'}},
#     'madeCount': 7,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/3935276',
#      'photoID': 3935276,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/3935276.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/3935276.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/93/52/3935276.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/3935276.jpg',
#        'width': 250}]},
#     'ratingAverage': 5.0,
#     'ratingCount': 7,
#     'rawItemType': 1,
#     'recipeID': 254692,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 5,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 84,
#      'followersCount': 8,
#      'followingCount': 1,
#      'handle': 'postpunkkitchen',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'isachandra',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/3933577',
#       'photoID': 3933577,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/3933577.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/3933577.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/93/35/3933577.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/3933577.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/postpunkkitchen/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 6,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 7662230},
#     'title': 'Crazy Creamy Chickpea Curry',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Spicy baked white fish fillets are dressed up with a ginger, garlic, onion, and cashew puree in this Bengali recipe.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/213238'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/indian-fish-curry/'}},
#     'madeCount': 176,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/779645',
#      'photoID': 779645,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/779645.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/779645.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/77/96/779645.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/779645.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.57,
#     'ratingCount': 148,
#     'rawItemType': 1,
#     'recipeID': 213238,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 115,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 184,
#      'followersCount': 8,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 55,
#      'name': 'Mantu',
#      'personalRecipeSharedCount': 1,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/1906197/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 55,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 49,
#      'userID': 1906197},
#     'title': 'Indian Fish Curry',
#     'type': 'recipes',
#     'videoID': 3166},
#    {'description': "An easy curry of turkey and garbanzo beans simmers with coconut milk and bottled tomato-based sweet chili sauce to make a savory-sweet dish that's ready in less than an hour.",
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/216111'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/sweet-and-spicy-curry-with-chickpeas/'}},
#     'madeCount': 39,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/499216',
#      'photoID': 499216,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/499216.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/499216.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/49/92/499216.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/499216.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.5,
#     'ratingCount': 42,
#     'rawItemType': 1,
#     'recipeID': 216111,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 32,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 298,
#      'followersCount': 2,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 4,
#      'name': 'Marcia',
#      'personalRecipeSharedCount': 3,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/343084',
#       'photoID': 343084,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/343084.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/343084.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/34/30/343084.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/343084.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/4372543/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 3,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 3,
#      'userID': 4372543},
#     'title': 'Sweet and Spicy Curry with Chickpeas',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This is a traditional North Indian (Punjabi) Bhurtha made with eggplant and tomato, and seasoned with cumin, turmeric garlic and ginger. Serve with fresh roti or naan.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/80686'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/indian-eggplant---bhurtha/'}},
#     'madeCount': 183,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/549170',
#      'photoID': 549170,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/549170.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/549170.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/54/91/549170.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/549170.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.47,
#     'ratingCount': 179,
#     'rawItemType': 1,
#     'recipeID': 80686,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 134,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 159,
#      'followersCount': 23,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 18,
#      'name': 'simmig',
#      'personalRecipeSharedCount': 2,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/562573',
#       'photoID': 562573,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/562573.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/562573.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/56/25/562573.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/562573.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/2474/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 18,
#      'rawItemType': 11,
#      'reciepesCount': 7,
#      'region': None,
#      'reviewsCount': 18,
#      'userID': 2474},
#     'title': 'Indian Eggplant - Bhurtha',
#     'type': 'recipes',
#     'videoID': 2888},
#    {'description': 'Spicy potatoes, tomatoes and onions with an Indian kick! This is super spicy so be aware!',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/14035'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/aloo-phujia/'}},
#     'madeCount': 338,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/695663',
#      'photoID': 695663,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/695663.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/695663.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/69/56/695663.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/695663.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.4,
#     'ratingCount': 421,
#     'rawItemType': 1,
#     'recipeID': 14035,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 289,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 46,
#      'followersCount': 649,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 82,
#      'name': 'CHRISTYJ',
#      'personalRecipeSharedCount': 13,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/features/18.gif',
#         'width': 140}]},
#      'profileUrl': '/cook/63733/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 83,
#      'rawItemType': 11,
#      'reciepesCount': 80,
#      'region': None,
#      'reviewsCount': 83,
#      'userID': 63733},
#     'title': 'Aloo Phujia',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This Indian dish combines fresh spinach and ricotta in a creamy curry. Use paneer if you can find it! It is absolutely wonderful with basmati rice or naan (Indian flat bread). The key is in the spices, which you can find at an Indian grocery.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/20312'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/absolutely-perfect-palak-paneer/'}},
#     'madeCount': 194,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/38052',
#      'photoID': 38052,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/38052.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/38052.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/03/80/38052.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/38052.jpg',
#        'width': 250}]},
#     'ratingAverage': 3.91,
#     'ratingCount': 223,
#     'rawItemType': 1,
#     'recipeID': 20312,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 173,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 13,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 2,
#      'name': 'MCFALONE',
#      'personalRecipeSharedCount': 1,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/27039/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 2,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 2,
#      'userID': 27039},
#     'title': 'Absolutely Perfect Palak Paneer',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Cheese, bread crumbs, parsley, garlic and onion are mixed in with the cooked eggplant and formed into patties. A few minutes in hot oil and you have your croquettes.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/14019'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/eggplant-croquettes/'}},
#     'madeCount': 438,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/506443',
#      'photoID': 506443,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/506443.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/506443.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/50/64/506443.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/506443.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.37,
#     'ratingCount': 481,
#     'rawItemType': 1,
#     'recipeID': 14019,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 353,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': None,
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Kelli Charnes',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 0,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 0},
#     'title': 'Eggplant Croquettes',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Eggplant cubes are stir-fried until browned, then simmered in a spicy Asian-inspired sauce with onion and garlic until meltingly tender. ',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/215026'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/spicy-eggplant/'}},
#     'madeCount': 241,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/666476',
#      'photoID': 666476,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/666476.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/666476.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/66/64/666476.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/666476.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.59,
#     'ratingCount': 174,
#     'rawItemType': 1,
#     'recipeID': 215026,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 131,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 60,
#      'followersCount': 4,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 10,
#      'name': 'venymae',
#      'personalRecipeSharedCount': 6,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/429144',
#       'photoID': 429144,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/429144.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/429144.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/42/91/429144.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/429144.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/4809716/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 12,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 11,
#      'userID': 4809716},
#     'title': 'Spicy Eggplant',
#     'type': 'recipes',
#     'videoID': 0},
# ...
#      'profileUrl': '/cook/2282459/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 2282459},
#     'title': 'Tofu Vindaloo',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': "Eggplant is sauteed, then coated in a spicy sweet sauce. It is simple and delicious! I'm sure you'll enjoy this!",
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/52925'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/hot-and-sour-chinese-eggplant/'}},
#     'madeCount': 275,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/798089',
#      'photoID': 798089,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/798089.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/798089.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/79/80/798089.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/798089.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.43,
#     'ratingCount': 293,
#     'rawItemType': 1,
#     'recipeID': 52925,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 220,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': None,
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Bonnie',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 0,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 0},
#     'title': 'Hot and Sour Chinese Eggplant',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Smothered in sweet and spicy sauce, this Chinese eggplant dish is sure to please even the pickiest eater.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/201964'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/eggplant-with-garlic-sauce/'}},
#     'madeCount': 275,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/618365',
#      'photoID': 618365,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/618365.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/618365.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/61/83/618365.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/618365.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.4,
#     'ratingCount': 183,
#     'rawItemType': 1,
#     'recipeID': 201964,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 143,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 188,
#      'followersCount': 2,
#      'followingCount': 17,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 52,
#      'name': 'Whats that Burning smell?',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/103243',
#       'photoID': 103243,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/103243.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/103243.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/10/32/103243.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/103243.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/2719692/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 53,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 45,
#      'userID': 2719692},
#     'title': 'Eggplant with Garlic Sauce',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Thinly sliced eggplant is lightly fried, then stuffed with a spinach and cheese mixture and baked with pasta sauce and mozzarella cheese.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/20088'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/awesome-eggplant-rollatine/'}},
#     'madeCount': 123,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/456135',
#      'photoID': 456135,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/456135.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/456135.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/45/61/456135.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/456135.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.38,
#     'ratingCount': 128,
#     'rawItemType': 1,
#     'recipeID': 20088,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 102,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 6,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 5,
#      'name': 'DEBNJAMES',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/126229/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 5,
#      'rawItemType': 11,
#      'reciepesCount': 17,
#      'region': None,
#      'reviewsCount': 4,
#      'userID': 126229},
#     'title': 'Awesome Eggplant Rollatine',
#     'type': 'recipes',
#     'videoID': 0}]},
#  'sourceID': 461,
#  'submitter': {'brandedSourceID': 0,
#   'city': None,
#   'country': None,
#   'favoritesCount': 0,
#   'followersCount': 0,
#   'followingCount': 0,
#   'handle': None,
#   'isPro': False,
#   'itemType': 'Cook',
#   'madeRecipesCount': 0,
#   'name': 'Yakuta',
#   'personalRecipeSharedCount': 0,
#   'photo': {'description': None,
#    'itemType': 'Photo',
#    'photoDetailUrl': None,
#    'rawItemType': 10,
#    'recipeTitle': None,
#    'title': None,
#    'urls': [{'height': 50,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#      'width': 50},
#     {'height': 110,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#      'width': 110},
#     {'height': 140,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#      'width': 140},
#     {'height': 250,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#      'width': 250}]},
#   'profileUrl': '',
#   'promotedBrandPixelTrackingUrl': None,
#   'ratingsCount': 0,
#   'rawItemType': 11,
#   'reciepesCount': 0,
#   'region': None,
#   'reviewsCount': 0,
#   'userID': 0},
#  'title': 'Baingan Bharta (Eggplant Curry)',
#  'topReviews': [{'dateLastModified': '2009-03-11T13:33:32.31',
#    'helpfulCount': 361,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/47564/reviews/1815671/increment-helpful-count'}},
#    'rating': 4,
#    'rawItemType': 9,
#    'reviewID': 1815671,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 21,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': False,
#     'itemType': 'Cook',
#     'madeRecipesCount': 15,
#     'name': 'SUSHANK',
#     'personalRecipeSharedCount': 0,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#        'width': 250}]},
#     'profileUrl': '/cook/844246/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 15,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 13,
#     'userID': 844246},
#    'text': "The recipe is almost authentic - i say almost because Indians use garam masala and not curry powder. I don't add yogurt to my baingan bharta, but adding it isn't a sin, i wouldn't heat the dish after adding yogurt. Also, the eggplant is usually fire roasted and the smokey flavor is just outstanding. Also a small teaspoon of lemon juice in the end brings all the flavors out."},
#   {'dateLastModified': '2008-01-21T16:56:31.387',
#    'helpfulCount': 278,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/47564/reviews/1254574/increment-helpful-count'}},
#    'rating': 5,
#    'rawItemType': 9,
#    'reviewID': 1254574,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 109,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': False,
#     'itemType': 'Cook',
#     'madeRecipesCount': 25,
#     'name': 'Shmoopy',
#     'personalRecipeSharedCount': 1,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#        'width': 250}]},
#     'profileUrl': '/cook/747353/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 25,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 25,
#     'userID': 747353},
#    'text': 'great recipe. I am second generation Indian and this is one of my favorite dishes. I made the eggplant the day before just to save time; I cut it in half lengthwise, sprayed the cut side with Pam, and then baked it on a foil lined cookie sheet, cut side down. I baked it for 20 minutes or so and it was so tender that I just scraped it out of the skin with a spoon. I used a can of plum tomatoes instead of a tomato, and cut the tomatoes into a small dice. I saved the liquid and added it to the dish right before I started to simmer it. I also added about a cup of frozen baby peas at the same time as the eggplant. Used ginger paste and minced garlic. Great recipe.'},
#   {'dateLastModified': '2006-05-02T11:08:08.403',
#    'helpfulCount': 129,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/47564/reviews/702661/increment-helpful-count'}},
#    'rating': 5,
#    'rawItemType': 9,
#    'reviewID': 702661,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 4,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': False,
#     'itemType': 'Cook',
#     'madeRecipesCount': 5,
#     'name': 'shiitakehappens',
#     'personalRecipeSharedCount': 4,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#        'width': 250}]},
#     'profileUrl': '/cook/816923/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 5,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 5,
#     'userID': 816923},
#    'text': "This recipe is terrific- I'd give it 6 stars if I could!  This is my new favorite way to use eggplant- I love the combination of veggies. I made it as a side with chicken curry and spinach paneer (frozen entree)and rice- the eggplant stole the show!  I used a medium eggplant- didn't bother peeling, just scooped out the cooked inards and chopped them up with a spoon.  I added 3/4 jalapeno in with the onion, thinking otherwise it would be too spicy, but it was not.  Thought yogurt might separate when cooked so aggressively, but it did not!  I didn't have ginger-garlic paste, just added a little fresh of each.  Easy and healthy!  Serve to all of your vegetarian friends!"}],
#  'type': 'recipes',
#  'video': None}

# %% [markdown]
# Here is an easier view of the dict structure indented by '->-'.

# %%
show_fields(oneRecipe)
# Out:
# > sourceID: 461
# > adUnit
# > ->-contentProviderId: 451
# > ->-site: ar.ios.apps.allrecip...
# > ->-networkCode: 3865
# > ->-adZone: recipes
# > ->-adKeys: [7, 79, 95, 125, 148...
# > directions: [{'ordinal': 1, 'vid...
# > servings: 4
# > type: recipes
# > ada-continent: ['asian']
# > ada-country: ['indian']
# > ingredients: [{'ingredientID': 43...
# > nutrition
# > ->-fiber
# > ->-->-unit: g
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: 6.2
# > ->-->-amount: 6.222385
# > ->-->-percentDailyValue: 25
# > ->-->-name: Dietary Fiber
# > ->-caloriesFromFat
# > ->-->-unit: kcal
# > ->-->-hasCompleteData: True
# > ->-->-displayValue: 72
# > ->-->-amount: 72.09731
# > ->-->-percentDailyValue: -
# > ->-->-name: Calories from Fat
# > ->-saturatedFat
# > ->-->-unit: g
# > ->-->-hasCompleteData: True
# > ->-->-displayValue: 1.5
# > ->-->-amount: 1.485098
# > ->-->-percentDailyValue: 7
# > ->-->-name: Saturated Fat
# > ->-magnesium
# > ->-->-unit: mg
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: 38
# > ->-->-amount: 38.03075
# > ->-->-percentDailyValue: 14
# > ->-->-name: Magnesium
# > ->-iron
# > ->-->-unit: mg
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: 1
# > ->-->-amount: 1.403314
# > ->-->-percentDailyValue: 14
# > ->-->-name: Iron
# > ->-sodium
# > ->-->-unit: mg
# > ->-->-hasCompleteData: True
# > ->-->-displayValue: 739
# > ->-->-amount: 739.406
# > ->-->-percentDailyValue: 30
# > ->-->-name: Sodium
# > ->-folate
# > ->-->-unit: mcg
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: 50
# > ->-->-amount: 49.63925
# > ->-->-percentDailyValue: 28
# > ->-->-name: Folate
# > ->-carbohydrates
# > ->-->-unit: g
# > ->-->-hasCompleteData: True
# > ->-->-displayValue: 15.2
# > ->-->-amount: 15.22197
# > ->-->-percentDailyValue: 5
# > ->-->-name: Carbohydrates
# > ->-vitaminB6
# > ->-->-unit: mg
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: < 1
# > ->-->-amount: 0.2310775
# > ->-->-percentDailyValue: 14
# > ->-->-name: Vitamin B6
# > ->-niacin
# > ->-->-unit: mg
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: 2
# > ->-->-amount: 1.744597
# > ->-->-percentDailyValue: 13
# > ->-->-name: Niacin Equivalents
# > ->-fat
# > ->-->-unit: g
# > ->-->-hasCompleteData: True
# > ->-->-displayValue: 8
# > ->-->-amount: 8.010813
# > ->-->-percentDailyValue: 12
# > ->-->-name: Fat
# > ->-cholesterol
# > ->-->-unit: mg
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: 2
# > ->-->-amount: 1.8375
# > ->-->-percentDailyValue: < 1
# > ->-->-name: Cholesterol
# > ->-sugars
# > ->-->-unit: g
# > ->-->-hasCompleteData: True
# > ->-->-displayValue: 7.5
# > ->-->-amount: 7.522098
# > ->-->-percentDailyValue: 0
# > ->-->-name: Sugars
# > ->-vitaminC
# > ->-->-unit: mg
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: 12
# > ->-->-amount: 11.91473
# > ->-->-percentDailyValue: 20
# > ->-->-name: Vitamin C
# > ->-vitaminA
# > ->-->-unit: IU
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: 596
# > ->-->-amount: 595.6483
# > ->-->-percentDailyValue: 12
# > ->-->-name: Vitamin A - IU
# > ->-protein
# > ->-->-unit: g
# > ->-->-hasCompleteData: True
# > ->-->-displayValue: 4
# > ->-->-amount: 3.97931
# > ->-->-percentDailyValue: 8
# > ->-->-name: Protein
# > ->-thiamin
# > ->-->-unit: mg
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: < 1
# > ->-->-amount: 0.1289342
# > ->-->-percentDailyValue: 13
# > ->-->-name: Thiamin
# > ->-calcium
# > ->-->-unit: mg
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: 93
# > ->-->-amount: 93.245
# > ->-->-percentDailyValue: 12
# > ->-->-name: Calcium
# > ->-calories
# > ->-->-unit: kcal
# > ->-->-hasCompleteData: True
# > ->-->-displayValue: 146
# > ->-->-amount: 146.1237
# > ->-->-percentDailyValue: 7
# > ->-->-name: Calories
# > ->-potassium
# > ->-->-unit: mg
# > ->-->-hasCompleteData: False
# > ->-->-displayValue: 559
# > ->-->-amount: 559.3593
# > ->-->-percentDailyValue: 16
# > ->-->-name: Potassium
# > video: None
# > ratingAverage: 4.305987
# > topReviews: [{'dateLastModified'...
# > readyInMinutes: 60
# > similarRecipes
# > ->-metaData
# > ->-->-pagesize: 20
# > ->-->-page: 1
# > ->-->-totalCount: 20
# > ->-recipes: [{'reviewCount': 48,...
# > ->-links
# > ->-->-self
# > ->-->-->-href: https://apps.allreci...
# > submitter
# > ->-reciepesCount: 0
# > ->-city: None
# > ->-followersCount: 0
# > ->-itemType: Cook
# > ->-isPro: False
# > ->-profileUrl:
# > ->-userID: 0
# > ->-name: Yakuta
# > ->-reviewsCount: 0
# > ->-brandedSourceID: 0
# > ->-favoritesCount: 0
# > ->-handle: None
# > ->-region: None
# > ->-photo
# > ->-->-photoDetailUrl: None
# > ->-->-urls: [{'width': 50, 'url'...
# > ->-->-title: None
# > ->-->-recipeTitle: None
# > ->-->-itemType: Photo
# > ->-->-description: None
# > ->-->-rawItemType: 10
# > ->-followingCount: 0
# > ->-country: None
# > ->-rawItemType: 11
# > ->-ratingsCount: 0
# > ->-madeRecipesCount: 0
# > ->-promotedBrandPixelTrackingUrl: None
# > ->-personalRecipeSharedCount: 0
# > reviewCount: 309
# > ratingCount: 451
# > ada-region: []
# > ada-city: []
# > ada-subcontinent: []
# > recipeID: 47564
# > _id: 5825054ace06e5044608...
# > prepMinutes: 15
# > title: Baingan Bharta (Eggp...
# > footnotes: [{'text': 'Tip', 'or...
# > isSponsored: False
# > photo
# > ->-photoDetailUrl: http://m.allrecipes....
# > ->-urls: [{'width': 50, 'url'...
# > ->-title:
# > ->-recipeTitle: None
# > ->-itemType: Photo
# > ->-photoID: 14597
# > ->-description:
# > ->-rawItemType: 10
# > cookMinutes: 45
# > description: This is a really eas...
# > links
# > ->-self
# > ->-->-href: https://apps.allreci...
# > ->-recipeUrl
# > ->-->-href: http://allrecipes.co...
# > ada-tags: ['world-cuisine', 'a...

# %% [markdown]
# We will now create two dataframes (combined into a single dict).
# The second dataframe will group the recipes by city.
#
# For each dataframe, we will have four columns per group as below (for city name)
#
# city    nbRecipes     avgCalories    totalVitaminAIntake
#
# The last two columns contain respectively the average calories and the total vitamin A among all recipes in that group (one aggregation function is 'avg', the other is 'sum').

# %%
# contains all parameters to pass to the aggregation function

# group bys
groupBy_fields_toQuery = [
    {
        # get global average
        'group_by_field_address': 'get_global_aggregation',
        'group_by_field_output_name': 'DummyColumn',
    },
    {
        'group_by_field_address': '$ada-city', # as it appears in the database
        'group_by_field_output_name': 'city', # as it appears in dataframe
    },
]

# keep in sync with above groupBysToQuery, keys in the dict of dataframes
dataframe_names = ['global', 'per_city']

# what to aggregate for
aggregation_fields_toQuery = [
    {
        'aggregate_field_address': '$nutrition.calories.amount', # which field to aggregate
        'aggregate_field_output_name': 'avg_calories', # output name in result dict
        'aggregationFunction': '$avg' # how to compute the data for each group
    },
    {
        'aggregate_field_address': '$nutrition.vitaminA.amount', 
        'aggregate_field_output_name': 'total_vitaminA_Intake', 
        'aggregationFunction': '$sum' 
    },
]

all_dataframes_small = get_dataframe_per_groupby(collection, groupBy_fields_toQuery, aggregation_fields_toQuery, dataframe_names)
# Out:
# Query 1/4 with arguments: {'aggregate_field_address': '$nutrition.calories.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_calories'}
# Query 2/4 with arguments: {'aggregate_field_address': '$nutrition.vitaminA.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$sum', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'total_vitaminA_Intake'}
# Query 3/4 with arguments: {'aggregate_field_address': '$nutrition.calories.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_calories'}
# Query 4/4 with arguments: {'aggregate_field_address': '$nutrition.vitaminA.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$sum', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'total_vitaminA_Intake'}

# %% [markdown]
# Here are the dataframes we get.

# %%
all_dataframes_small['global'].head(3)
# Out:
#                     avg_calories  nbRecipes  total_vitaminA_Intake
# DummyColumn
# Global aggregation    350.246799      16242           2.270323e+07

# %%
all_dataframes_small['per_city'].head(3)
# Out:
#            avg_calories  nbRecipes  total_vitaminA_Intake
# city
# atlanta      424.314499         28           85023.393070
# baltimore    282.584182         40           27968.763135
# boston       411.666383         12            2768.165049

# %% [markdown]
# Let us save these dataframes.

# %%
import os

json_output_filename_small = '../website/data/aggregatedDataSmall.json'

os.makedirs(os.path.dirname(json_output_filename_small), exist_ok=True)
write_dataframes_to_json(json_output_filename_small, all_dataframes_small)

#loadedAllDfs = load_dataframes_from_json(json_output_filename)

# %%
# see content of file
# !cat '../website/data/aggregatedDataSmall.json'
# Out:
# {
#     "global": {
#         "Global aggregation": {
#             "total_vitaminA_Intake": 22703227.41110853,
#             "avg_calories": 350.2467986302,
#             "nbRecipes": 16242
#         }
#     },
#     "per_city": {
#         "cincinnati": {
#             "total_vitaminA_Intake": 39608.794,
#             "avg_calories": 424.625025,
#             "nbRecipes": 12
#         },
#         "philadelphia": {
#             "total_vitaminA_Intake": 46122.68971,
#             "avg_calories": 510.41504,
#             "nbRecipes": 50
#         },
#         "seattle": {
#             "total_vitaminA_Intake": 138905.35251,
#             "avg_calories": 415.338245,
#             "nbRecipes": 67
#         },
#         "new-york-city": {
#             "total_vitaminA_Intake": 171463.7429213,
#             "avg_calories": 411.8799015702,
#             "nbRecipes": 125
#         },
#         "tampa-bay": {
#             "total_vitaminA_Intake": 21437.77378,
#             "avg_calories": 337.8598092308,
#             "nbRecipes": 28
#         },
#         "buffalo": {
#             "total_vitaminA_Intake": 24065.911712,
#             "avg_calories": 274.4892507317,
#             "nbRecipes": 41
#         },
#         "kansas-city": {
#             "total_vitaminA_Intake": 36884.11005,
#             "avg_calories": 300.2158104545,
#             "nbRecipes": 24
#         },
#         "milwaukee": {
#             "total_vitaminA_Intake": 26335.21554,
#             "avg_calories": 344.2545928571,
#             "nbRecipes": 27
#         },
#         "oakland": {
#             "total_vitaminA_Intake": 39844.8466,
#             "avg_calories": 448.8614230769,
#             "nbRecipes": 26
#         },
#         "pittsburgh": {
#             "total_vitaminA_Intake": 21015.999857,
#             "avg_calories": 483.6879928571,
#             "nbRecipes": 28
#         },
#         "green-bay": {
#             "total_vitaminA_Intake": 15783.76384,
#             "avg_calories": 407.6131015385,
#             "nbRecipes": 16
#         },
#         "chicago": {
#             "total_vitaminA_Intake": 12753.8676,
#             "avg_calories": 403.8004090909,
#             "nbRecipes": 11
#         },
#         "boston": {
#             "total_vitaminA_Intake": 2768.165049,
#             "avg_calories": 411.6663833333,
#             "nbRecipes": 12
#         },
#         "miami": {
#             "total_vitaminA_Intake": 5344.37133,
#             "avg_calories": 446.1634,
#             "nbRecipes": 12
#         },
#         "georgia": {
#             "total_vitaminA_Intake": 128067.02551,
#             "avg_calories": 358.6492397143,
#             "nbRecipes": 71
#         },
#         "indianapolis": {
#             "total_vitaminA_Intake": 12283.5292282,
#             "avg_calories": 425.4122357143,
#             "nbRecipes": 15
#         },
#         "san-francisco": {
#             "total_vitaminA_Intake": 48289.644985,
#             "avg_calories": 291.9175343171,
#             "nbRecipes": 41
#         },
#         "baltimore": {
#             "total_vitaminA_Intake": 27968.763135,
#             "avg_calories": 282.5841822308,
#             "nbRecipes": 40
#         },
#         "california": {
#             "total_vitaminA_Intake": 369048.0162120002,
#             "avg_calories": 361.590713878,
#             "nbRecipes": 250
#         },
#         "dallas": {
#             "total_vitaminA_Intake": 62139.256174,
#             "avg_calories": 281.9190327586,
#             "nbRecipes": 29
#         },
#         "st-louis": {
#             "total_vitaminA_Intake": 38558.02665,
#             "avg_calories": 485.8434666667,
#             "nbRecipes": 27
#         },
#         "atlanta": {
#             "total_vitaminA_Intake": 85023.39307,
#             "avg_calories": 424.3144992857,
#             "nbRecipes": 28
#         },
#         "los-angeles": {
#             "total_vitaminA_Intake": 51044.61844,
#             "avg_calories": 374.2129283333,
#             "nbRecipes": 30
#         },
#         "washington-dc": {
#             "total_vitaminA_Intake": 9453.05414,
#             "avg_calories": 291.5897064706,
#             "nbRecipes": 17
#         },
#         "vancouver": {
#             "total_vitaminA_Intake": 102112.4902423,
#             "avg_calories": 342.3823438095,
#             "nbRecipes": 127
#         },
#         "new-orleans": {
#             "total_vitaminA_Intake": 42673.55009,
#             "avg_calories": 445.9402834884,
#             "nbRecipes": 46
#         },
#         "minneapolis": {
#             "total_vitaminA_Intake": 54923.347647,
#             "avg_calories": 426.5461631034,
#             "nbRecipes": 29
#         },
#         "detroit": {
#             "total_vitaminA_Intake": 10969.15789,
#             "avg_calories": 311.01333,
#             "nbRecipes": 12
#         },
#         "san-diego": {
#             "total_vitaminA_Intake": 79246.54578,
#             "avg_calories": 401.5872333333,
#             "nbRecipes": 31
#         },
#         "cleveland": {
#             "total_vitaminA_Intake": 36406.27513367,
#             "avg_calories": 429.2601442424,
#             "nbRecipes": 33
#         },
#         "houston": {
#             "total_vitaminA_Intake": 23852.887483,
#             "avg_calories": 366.3758511111,
#             "nbRecipes": 18
#         },
#         "toronto": {
#             "total_vitaminA_Intake": 77310.15675,
#             "avg_calories": 394.5755590625,
#             "nbRecipes": 64
#         }
#     }
# }

# %% [markdown]
# # Get many aggregation fields

# %% [markdown]
# We have demonstrated how to put several aggregations into a single dataframe.
#
# We must pick more aggregation fields and we now choose the fields that make sense.

# %%
# First get all keys in the database and a description (an example value for each key)
all_keys_with_description = get_all_field_addresses_with_description(oneRecipe, shortenLongStrings=False)
all_keys_with_description
# Out:
# {'$_id': '5825054ace06e50446084706',
#  '$adUnit.adKeys': '[7, 79, 95, 125, 148, 150, 169, 173, 184, 201, 221, 235, 241, 242, 249, 254, 265, 608]',
#  '$adUnit.adZone': 'recipes',
#  '$adUnit.contentProviderId': '451',
#  '$adUnit.networkCode': '3865',
#  '$adUnit.site': 'ar.ios.apps.allrecipes.recipes',
#  '$ada-city': '[]',
#  '$ada-continent': "['asian']",
#  '$ada-country': "['indian']",
#  '$ada-region': '[]',
#  '$ada-subcontinent': '[]',
#  '$ada-tags': "['world-cuisine', 'asian', 'indian', 'main-dishes', 'curry', 'vegetarian']",
#  '$cookMinutes': '45',
#  '$description': 'This is a really easy and tasty Indian dish that is sure to stir up your taste buds. Delicious baingan bharta is ready to eat with pita bread, Indian naan, or rice.',
#  '$directions': "[{'ordinal': 1, 'videoTimestamp': 0, 'displayValue': 'Preheat oven to 450 degrees F (230 degrees C).'}, {'ordinal': 2, 'videoTimestamp': 0, 'displayValue': 'Place eggplant on a medium baking sheet. Bake 20 to 30 minutes in the preheated oven, until tender. Remove from heat, cool, peel, and chop.'}, {'ordinal': 3, 'videoTimestamp': 0, 'displayValue': 'Heat oil in a medium saucepan over medium heat. Mix in cumin seeds and onion. Cook and stir until onion is tender.'}, {'ordinal': 4, 'videoTimestamp': 0, 'displayValue': 'Mix ginger garlic paste, curry powder, and tomato into the saucepan, and cook about 1 minute. Stir in yogurt. Mix in eggplant and jalapeno pepper, and season with salt. Cover, and cook 10 minutes over high heat. Remove cover, reduce heat to low, and continue cooking about 5 minutes. Garnish with cilantro to serve.'}]",
#  '$footnotes': "[{'text': 'Tip', 'ordinal': 100}, {'text': 'Aluminum foil can be used to keep food moist, cook it evenly, and make clean-up easier.', 'ordinal': 101}]",
#  '$ingredients': "[{'ingredientID': 4339, 'displayType': 'Normal', 'grams': 548.0, 'displayValue': '1 large eggplant'}, {'ingredientID': 6305, 'displayType': 'Normal', 'grams': 27.25, 'displayValue': '2 tablespoons vegetable oil'}, {'ingredientID': 16390, 'displayType': 'Normal', 'grams': 2.1, 'displayValue': '1 teaspoon cumin seeds'}, {'ingredientID': 4397, 'displayType': 'Normal', 'grams': 110.0, 'displayValue': '1 medium onion, thinly sliced'}, {'ingredientID': 20678, 'displayType': 'Normal', 'grams': 16.5, 'displayValue': '1 tablespoon ginger garlic paste'}, {'ingredientID': 16391, 'displayType': 'Normal', 'grams': 6.3, 'displayValue': '1 tablespoon curry powder'}, {'ingredientID': 4572, 'displayType': 'Normal', 'grams': 123.0, 'displayValue': '1 tomato, diced'}, {'ingredientID': 16158, 'displayType': 'Normal', 'grams': 122.5, 'displayValue': '1/2 cup plain yogurt'}, {'ingredientID': 3725, 'displayType': 'Normal', 'grams': 14.0, 'displayValue': '1 fresh jalapeno chile pepper, finely chopped'}, {'ingredientID': 16421, 'displayType': 'Normal', 'grams': 6.0, 'displayValue': '1 teaspoon salt'}, {'ingredientID': 3717, 'displayType': 'Normal', 'grams': 14.0, 'displayValue': '1/4 bunch cilantro, finely chopped'}]",
#  '$isSponsored': 'False',
#  '$links.recipeUrl.href': 'http://allrecipes.com/recipe/47564/baingan-bharta-eggplant-curry/',
#  '$links.self.href': 'https://apps.allrecipes.com/v1/recipes/47564',
#  '$nutrition.calcium.amount': '93.245',
#  '$nutrition.calcium.displayValue': '93',
#  '$nutrition.calcium.hasCompleteData': 'False',
#  '$nutrition.calcium.name': 'Calcium',
#  '$nutrition.calcium.percentDailyValue': '12',
#  '$nutrition.calcium.unit': 'mg',
#  '$nutrition.calories.amount': '146.1237',
#  '$nutrition.calories.displayValue': '146',
#  '$nutrition.calories.hasCompleteData': 'True',
#  '$nutrition.calories.name': 'Calories',
#  '$nutrition.calories.percentDailyValue': '7',
#  '$nutrition.calories.unit': 'kcal',
#  '$nutrition.caloriesFromFat.amount': '72.09731',
#  '$nutrition.caloriesFromFat.displayValue': '72',
#  '$nutrition.caloriesFromFat.hasCompleteData': 'True',
#  '$nutrition.caloriesFromFat.name': 'Calories from Fat',
#  '$nutrition.caloriesFromFat.percentDailyValue': '-',
#  '$nutrition.caloriesFromFat.unit': 'kcal',
#  '$nutrition.carbohydrates.amount': '15.22197',
#  '$nutrition.carbohydrates.displayValue': '15.2',
#  '$nutrition.carbohydrates.hasCompleteData': 'True',
#  '$nutrition.carbohydrates.name': 'Carbohydrates',
#  '$nutrition.carbohydrates.percentDailyValue': '5',
#  '$nutrition.carbohydrates.unit': 'g',
#  '$nutrition.cholesterol.amount': '1.8375',
#  '$nutrition.cholesterol.displayValue': '2',
#  '$nutrition.cholesterol.hasCompleteData': 'False',
#  '$nutrition.cholesterol.name': 'Cholesterol',
#  '$nutrition.cholesterol.percentDailyValue': '< 1',
#  '$nutrition.cholesterol.unit': 'mg',
#  '$nutrition.fat.amount': '8.010813',
#  '$nutrition.fat.displayValue': '8',
#  '$nutrition.fat.hasCompleteData': 'True',
#  '$nutrition.fat.name': 'Fat',
#  '$nutrition.fat.percentDailyValue': '12',
#  '$nutrition.fat.unit': 'g',
#  '$nutrition.fiber.amount': '6.222385',
#  '$nutrition.fiber.displayValue': '6.2',
#  '$nutrition.fiber.hasCompleteData': 'False',
#  '$nutrition.fiber.name': 'Dietary Fiber',
#  '$nutrition.fiber.percentDailyValue': '25',
#  '$nutrition.fiber.unit': 'g',
#  '$nutrition.folate.amount': '49.63925',
#  '$nutrition.folate.displayValue': '50',
#  '$nutrition.folate.hasCompleteData': 'False',
#  '$nutrition.folate.name': 'Folate',
#  '$nutrition.folate.percentDailyValue': '28',
#  '$nutrition.folate.unit': 'mcg',
#  '$nutrition.iron.amount': '1.403314',
#  '$nutrition.iron.displayValue': '1',
#  '$nutrition.iron.hasCompleteData': 'False',
#  '$nutrition.iron.name': 'Iron',
#  '$nutrition.iron.percentDailyValue': '14',
#  '$nutrition.iron.unit': 'mg',
#  '$nutrition.magnesium.amount': '38.03075',
#  '$nutrition.magnesium.displayValue': '38',
#  '$nutrition.magnesium.hasCompleteData': 'False',
#  '$nutrition.magnesium.name': 'Magnesium',
#  '$nutrition.magnesium.percentDailyValue': '14',
#  '$nutrition.magnesium.unit': 'mg',
#  '$nutrition.niacin.amount': '1.744597',
#  '$nutrition.niacin.displayValue': '2',
#  '$nutrition.niacin.hasCompleteData': 'False',
#  '$nutrition.niacin.name': 'Niacin Equivalents',
#  '$nutrition.niacin.percentDailyValue': '13',
#  '$nutrition.niacin.unit': 'mg',
#  '$nutrition.potassium.amount': '559.3593',
#  '$nutrition.potassium.displayValue': '559',
#  '$nutrition.potassium.hasCompleteData': 'False',
#  '$nutrition.potassium.name': 'Potassium',
#  '$nutrition.potassium.percentDailyValue': '16',
#  '$nutrition.potassium.unit': 'mg',
#  '$nutrition.protein.amount': '3.97931',
#  '$nutrition.protein.displayValue': '4',
#  '$nutrition.protein.hasCompleteData': 'True',
#  '$nutrition.protein.name': 'Protein',
#  '$nutrition.protein.percentDailyValue': '8',
#  '$nutrition.protein.unit': 'g',
#  '$nutrition.saturatedFat.amount': '1.485098',
#  '$nutrition.saturatedFat.displayValue': '1.5',
#  '$nutrition.saturatedFat.hasCompleteData': 'True',
#  '$nutrition.saturatedFat.name': 'Saturated Fat',
#  '$nutrition.saturatedFat.percentDailyValue': '7',
#  '$nutrition.saturatedFat.unit': 'g',
#  '$nutrition.sodium.amount': '739.406',
#  '$nutrition.sodium.displayValue': '739',
#  '$nutrition.sodium.hasCompleteData': 'True',
#  '$nutrition.sodium.name': 'Sodium',
#  '$nutrition.sodium.percentDailyValue': '30',
#  '$nutrition.sodium.unit': 'mg',
#  '$nutrition.sugars.amount': '7.522098',
#  '$nutrition.sugars.displayValue': '7.5',
#  '$nutrition.sugars.hasCompleteData': 'True',
#  '$nutrition.sugars.name': 'Sugars',
#  '$nutrition.sugars.percentDailyValue': '0',
#  '$nutrition.sugars.unit': 'g',
#  '$nutrition.thiamin.amount': '0.1289342',
#  '$nutrition.thiamin.displayValue': '< 1',
#  '$nutrition.thiamin.hasCompleteData': 'False',
#  '$nutrition.thiamin.name': 'Thiamin',
#  '$nutrition.thiamin.percentDailyValue': '13',
#  '$nutrition.thiamin.unit': 'mg',
#  '$nutrition.vitaminA.amount': '595.6483',
#  '$nutrition.vitaminA.displayValue': '596',
#  '$nutrition.vitaminA.hasCompleteData': 'False',
#  '$nutrition.vitaminA.name': 'Vitamin A - IU',
#  '$nutrition.vitaminA.percentDailyValue': '12',
#  '$nutrition.vitaminA.unit': 'IU',
#  '$nutrition.vitaminB6.amount': '0.2310775',
#  '$nutrition.vitaminB6.displayValue': '< 1',
#  '$nutrition.vitaminB6.hasCompleteData': 'False',
#  '$nutrition.vitaminB6.name': 'Vitamin B6',
#  '$nutrition.vitaminB6.percentDailyValue': '14',
#  '$nutrition.vitaminB6.unit': 'mg',
#  '$nutrition.vitaminC.amount': '11.91473',
#  '$nutrition.vitaminC.displayValue': '12',
#  '$nutrition.vitaminC.hasCompleteData': 'False',
#  '$nutrition.vitaminC.name': 'Vitamin C',
#  '$nutrition.vitaminC.percentDailyValue': '20',
#  '$nutrition.vitaminC.unit': 'mg',
#  '$photo.description': '',
#  '$photo.itemType': 'Photo',
#  '$photo.photoDetailUrl': 'http://m.allrecipes.com/photos/14597',
#  '$photo.photoID': '14597',
#  '$photo.rawItemType': '10',
#  '$photo.recipeTitle': 'None',
#  '$photo.title': '',
#  '$photo.urls': "[{'width': 50, 'url': 'http://images.media-allrecipes.com/userphotos/50x50/14597.jpg', 'height': 50}, {'width': 110, 'url': 'http://images.media-allrecipes.com/userphotos/110x110/14597.jpg', 'height': 110}, {'width': 140, 'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/01/45/14597.jpg', 'height': 140}, {'width': 250, 'url': 'http://images.media-allrecipes.com/userphotos/250x250/14597.jpg', 'height': 250}]",
#  '$prepMinutes': '15',
#  '$ratingAverage': '4.305987',
#  '$ratingCount': '451',
#  '$readyInMinutes': '60',
#  '$recipeID': '47564',
#  '$reviewCount': '309',
#  '$servings': '4',
#  '$similarRecipes.links.self.href': 'https://apps.allrecipes.com/v1/recipes/47564',
#  '$similarRecipes.metaData.page': '1',
#  '$similarRecipes.metaData.pagesize': '20',
#  '$similarRecipes.metaData.totalCount': '20',
#  '$similarRecipes.recipes': '[{\'reviewCount\': 48, \'ratingCount\': 64, \'sourceID\': 461, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/3294074\', \'urls\': [{\'width\': 50, \'url\': \'http://images.media-allrecipes.com/userphotos/50x50/3294074.jpg\', \'height\': 50}, {\'width\': 110, \'url\': \'http://images.media-allrecipes.com/userphotos/110x110/3294074.jpg\', \'height\': 110}, {\'width\': 140, \'url\': \'http://images.media-allrecipes.com/userphotos/140x140/03/29/40/3294074.jpg\', \'height\': 140}, {\'width\': 250, \'url\': \'http://images.media-allrecipes.com/userphotos/250x250/3294074.jpg\', \'height\': 250}], \'title\': \'\', \'recipeTitle\': None, \'itemType\': \'Photo\', \'photoID\': 3294074, \'description\': \'\', \'rawItemType\': 10}, \'itemType\': \'Recipe\', \'type\': \'recipes\', \'recipeID\': 223360, \'madeCount\': 86, \'recipeTrackingPixelUrl\': None, \'ratingAverage\': 4.39, \'links\': {\'recipeUrl\': {\'href\': \'http://allrecipes.com/recipe/eggplant-parmesan-for-the-slow-cooker/\'}, \'parent\': {\'href\': \'https://apps.allrecipes.com/v1/recipes/223360\'}}, \'isSponsored\': False, \'description\': \'Make a big batch of eggplant Parmesan in your slow cooker and dinner will be waiting when you get home. No need to heat up your kitchen baking in an oven.\', \'rawItemType\': 1, \'title\': \'Eggplant Parmesan For the Slow Cooker\', \'submitter\': {\'reciepesCount\': 1, \'city\': None, \'followersCount\': 12, \'itemType\': \'Cook\', \'isPro\': False, \'profileUrl\': \'/cook/5752296/\', \'userID\': 5752296, \'name\': \'jboettcher2\', \'reviewsCount\': 0, \'brandedSourceID\': 0, \'favoritesCount\': 19, \'handle\': \'\', \'region\': None, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/556955\', \'urls\': [{\'width\': 50, \'url\': \'http://images.media-allrecipes.com/userphotos/50x50/556955.jpg\', \'height\': 50}, {\'width\': 110, \'url\': \'http://images.media-allrecipes.com/userphotos/110x110/556955.jpg\', \'height\': 110}, {\'width\': 140, \'url\': \'http://images.media-allrecipes.com/userphotos/140x140/00/55/69/556955.jpg\', \'height\': 140}, {\'width\': 250, \'url\': \'http://images.media-allrecipes.com/userphotos/250x250/556955.jpg\', \'height\': 250}], \'title\': \'\', \'recipeTitle\': None, \'itemType\': \'Photo\', \'photoID\': 556955, \'description\': \'\', \'rawItemType\': 10}, \'followingCount\': 0, \'country\': None, \'rawItemType\': 11, \'ratingsCount\': 0, \'madeRecipesCount\': 0, \'promotedBrandPixelTrackingUrl\': None, \'personalRecipeSharedCount\': 1}, \'videoID\': 0}, {\'reviewCount\': 22, \'ratingCount\': 30, \'sourceID\': 461, \'photo\': {\'photoDetailUrl\': \'http://m.allrecipes.com/photos/3719268\', \'urls\': [{\'width\': 50, \'url\': \'http://images.media-allrecipes.com/userphotos/50x50/3719268.jpg\', \'height\': 50}, {\'width\': 110, \'url\': \'http://images.media-allrecipes.com/userphotos/110x110/3719268.jpg\', \'height\': 110}, {\'width\': 140, \'url\': \'http://images.media-allrecipes.com/userphotos/140x140/03/71/92/3719268.jpg\', \'height\': 140}, {\'width\': 250, \'url\': \'http://images.media-allrecipes.com/userphotos/250x250/3719268.jpg\', \'height\': 250}], \'title\': \'\', \'recipeTitle\': None, \'itemType\': \'Photo\', \'photoID\': 3719268, \'description\': \'\', \'rawItemType\': 10}, \'itemType\': \'Recipe\', \'type\': \'recipes\', \'recipeID\': 231010, \'madeCount\': 34, \'recipeTrackingPixelUrl\': None, \'ratingAverage\': 4.73, \'links\': {\'recipeUrl\': {\'href\': \'http://allrecipes.com/recipe/chef-johns-baked-eggplant-sandwiches/\'}, \'parent\': {\'href\': \'https://apps.allrecipes.com/v1/recipes/231010\'}}, \'isSponsored\': False, \'description\': \'These breaded and baked eggplant sandwiches are the perfect make-ahead appetizer for your next potluck.\', \'rawItemType\': 1, \'title\': "Chef John\'s Baked Eggplant Sandwiches", \'submitter\': {\'reciepesCount\': 913, \'city\': None, \'followersCount\': 38210, \'itemType\': \'Cook\', \'isPro\ ...
#  '$sourceID': '461',
#  '$submitter.brandedSourceID': '0',
#  '$submitter.city': 'None',
#  '$submitter.country': 'None',
#  '$submitter.favoritesCount': '0',
#  '$submitter.followersCount': '0',
#  '$submitter.followingCount': '0',
#  '$submitter.handle': 'None',
#  '$submitter.isPro': 'False',
#  '$submitter.itemType': 'Cook',
#  '$submitter.madeRecipesCount': '0',
#  '$submitter.name': 'Yakuta',
#  '$submitter.personalRecipeSharedCount': '0',
#  '$submitter.photo.description': 'None',
#  '$submitter.photo.itemType': 'Photo',
#  '$submitter.photo.photoDetailUrl': 'None',
#  '$submitter.photo.rawItemType': '10',
#  '$submitter.photo.recipeTitle': 'None',
#  '$submitter.photo.title': 'None',
#  '$submitter.photo.urls': "[{'width': 50, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png', 'height': 50}, {'width': 110, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png', 'height': 110}, {'width': 140, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png', 'height': 140}, {'width': 250, 'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png', 'height': 250}]",
#  '$submitter.profileUrl': '',
#  '$submitter.promotedBrandPixelTrackingUrl': 'None',
#  '$submitter.ratingsCount': '0',
#  '$submitter.rawItemType': '11',
#  '$submitter.reciepesCount': '0',
#  '$submitter.region': 'None',
#  '$submitter.reviewsCount': '0',
#  '$submitter.userID': '0',
#  '$title': 'Baingan Bharta (Eggplant Curry)',
#  '$topReviews': '[{\'dateLastModified\': \'2009-03-11T13:33:32.31\', \'helpfulCount\': 361, \'rating\': 4, \'itemType\': \'Review\', \'rawItemType\': 9, \'text\': "The recipe is almost authentic - i say almost because Indians use garam masala and not curry powder. I don\'t add yogurt to my baingan bharta, but adding it isn\'t a sin, i wouldn\'t heat the dish after adding yogurt. Also, the eggplant is usually fire roasted and the smokey flavor is just outstanding. Also a small teaspoon of lemon juice in the end brings all the flavors out.", \'reviewID\': 1815671, \'submitter\': {\'reciepesCount\': 0, \'city\': None, \'followersCount\': 0, \'itemType\': \'Cook\', \'isPro\': False, \'profileUrl\': \'/cook/844246/\', \'userID\': 844246, \'name\': \'SUSHANK\', \'reviewsCount\': 13, \'brandedSourceID\': 0, \'favoritesCount\': 21, \'handle\': \'\', \'region\': None, \'photo\': {\'photoDetailUrl\': None, \'urls\': [{\'width\': 50, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png\', \'height\': 50}, {\'width\': 110, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png\', \'height\': 110}, {\'width\': 140, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png\', \'height\': 140}, {\'width\': 250, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png\', \'height\': 250}], \'title\': None, \'recipeTitle\': None, \'itemType\': \'Photo\', \'description\': None, \'rawItemType\': 10}, \'followingCount\': 0, \'country\': None, \'rawItemType\': 11, \'ratingsCount\': 15, \'madeRecipesCount\': 15, \'promotedBrandPixelTrackingUrl\': None, \'personalRecipeSharedCount\': 0}, \'links\': {\'incrementHelpfulCount\': {\'href\': \'https://apps.allrecipes.com/v1/recipes/47564/reviews/1815671/increment-helpful-count\'}}}, {\'dateLastModified\': \'2008-01-21T16:56:31.387\', \'helpfulCount\': 278, \'rating\': 5, \'itemType\': \'Review\', \'rawItemType\': 9, \'text\': \'great recipe. I am second generation Indian and this is one of my favorite dishes. I made the eggplant the day before just to save time; I cut it in half lengthwise, sprayed the cut side with Pam, and then baked it on a foil lined cookie sheet, cut side down. I baked it for 20 minutes or so and it was so tender that I just scraped it out of the skin with a spoon. I used a can of plum tomatoes instead of a tomato, and cut the tomatoes into a small dice. I saved the liquid and added it to the dish right before I started to simmer it. I also added about a cup of frozen baby peas at the same time as the eggplant. Used ginger paste and minced garlic. Great recipe.\', \'reviewID\': 1254574, \'submitter\': {\'reciepesCount\': 0, \'city\': None, \'followersCount\': 0, \'itemType\': \'Cook\', \'isPro\': False, \'profileUrl\': \'/cook/747353/\', \'userID\': 747353, \'name\': \'Shmoopy\', \'reviewsCount\': 25, \'brandedSourceID\': 0, \'favoritesCount\': 109, \'handle\': \'\', \'region\': None, \'photo\': {\'photoDetailUrl\': None, \'urls\': [{\'width\': 50, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png\', \'height\': 50}, {\'width\': 110, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png\', \'height\': 110}, {\'width\': 140, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png\', \'height\': 140}, {\'width\': 250, \'url\': \'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png\', \'height\': 250}], \'title\': None, \'recipeTitle\': None, \'itemType\': \'Photo\', \'description\': None, \'rawItemType\': 10}, \'followingCount\': 0, \'country\': None, \'rawItemType\': 11, \'ratingsCount\': 25, \'madeRecipesCount\': 25, \'promotedBrandPixelTrackingUrl\': None, \'personalRecipeSharedCount\': 1}, \'links\': {\'incrementHelpfulCount\': {\'href\': \'https://apps.allrecipes.com/v1/recipes/47564/reviews/1254574/incremen ...
#  '$type': 'recipes',
#  '$video': 'None'}

# %%
str.isnumeric('[7, 79, 95, 125, 148]') # false
str.isnumeric('45') # true
is_number(all_keys_with_description['$nutrition.potassium.amount']) # True
is_number('[1,2]') # False
# Out:
# False

# %% [markdown]
# We pick the fields that are numbers (and hence can be computed in an average or sum).

# %%
def get_keys_to_take_with_args(all_keys_with_description):
    # input: the keys with description (description = example of value of key)
    # finds all keys that are number fields, removes certain useless keys (e.g. ID)
    # then returns a dict with these keys as keys and each entry referring to 
    # the argument list to pass to the aggregate query
    
    accepted_keys_with_arguments = dict() # arguments for function

    for keyName, value in all_keys_with_description.items():

        # only recognizes single integers, not lists of integers (in strings) as wished
        if is_number(value):
              
            # ignore some keys
            if (keyName.startswith(tuple(['$adUnit', '$photo.']))
                or keyName.endswith(tuple(['.displayValue']))
                or (keyName in [])
                or any((word in keyName) for word in ['.rawItemType', 'ID','percentDailyValue'])):                
                
                continue

            aggregFunction = None
            if (keyName.endswith(tuple(['Count', '.amount']))
                or (keyName in ['$prepMinutes', '$cookMinutes', '$servings', '$readyInMinutes',
                                '$ratingAverage', '$similarRecipes.metaData.pagesize', 
                                '$similarRecipes.metaData.page'
                               ])):
                aggregFunction = '$avg'
                outputName = 'avg_' + make_column_name(keyName)
            else:
                print("Ignoring ok? {}: {}".format(keyName, value))
                continue

            args = {
                'aggregate_field_address': keyName, 
                'aggregate_field_output_name': outputName,
                'aggregationFunction': aggregFunction
            }
            accepted_keys_with_arguments[keyName] = args
    
    return accepted_keys_with_arguments

accepted_keys_with_arguments = get_keys_to_take_with_args(all_keys_with_description)
accepted_keys_with_arguments
# Out:
# {'$cookMinutes': {'aggregate_field_address': '$cookMinutes',
#   'aggregate_field_output_name': 'avg_cookMinutes',
#   'aggregationFunction': '$avg'},
#  '$nutrition.calcium.amount': {'aggregate_field_address': '$nutrition.calcium.amount',
#   'aggregate_field_output_name': 'avg_nutrition_calcium_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.calories.amount': {'aggregate_field_address': '$nutrition.calories.amount',
#   'aggregate_field_output_name': 'avg_nutrition_calories_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.caloriesFromFat.amount': {'aggregate_field_address': '$nutrition.caloriesFromFat.amount',
#   'aggregate_field_output_name': 'avg_nutrition_caloriesFromFat_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.carbohydrates.amount': {'aggregate_field_address': '$nutrition.carbohydrates.amount',
#   'aggregate_field_output_name': 'avg_nutrition_carbohydrates_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.cholesterol.amount': {'aggregate_field_address': '$nutrition.cholesterol.amount',
#   'aggregate_field_output_name': 'avg_nutrition_cholesterol_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.fat.amount': {'aggregate_field_address': '$nutrition.fat.amount',
#   'aggregate_field_output_name': 'avg_nutrition_fat_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.fiber.amount': {'aggregate_field_address': '$nutrition.fiber.amount',
#   'aggregate_field_output_name': 'avg_nutrition_fiber_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.folate.amount': {'aggregate_field_address': '$nutrition.folate.amount',
#   'aggregate_field_output_name': 'avg_nutrition_folate_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.iron.amount': {'aggregate_field_address': '$nutrition.iron.amount',
#   'aggregate_field_output_name': 'avg_nutrition_iron_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.magnesium.amount': {'aggregate_field_address': '$nutrition.magnesium.amount',
#   'aggregate_field_output_name': 'avg_nutrition_magnesium_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.niacin.amount': {'aggregate_field_address': '$nutrition.niacin.amount',
#   'aggregate_field_output_name': 'avg_nutrition_niacin_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.potassium.amount': {'aggregate_field_address': '$nutrition.potassium.amount',
#   'aggregate_field_output_name': 'avg_nutrition_potassium_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.protein.amount': {'aggregate_field_address': '$nutrition.protein.amount',
#   'aggregate_field_output_name': 'avg_nutrition_protein_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.saturatedFat.amount': {'aggregate_field_address': '$nutrition.saturatedFat.amount',
#   'aggregate_field_output_name': 'avg_nutrition_saturatedFat_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.sodium.amount': {'aggregate_field_address': '$nutrition.sodium.amount',
#   'aggregate_field_output_name': 'avg_nutrition_sodium_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.sugars.amount': {'aggregate_field_address': '$nutrition.sugars.amount',
#   'aggregate_field_output_name': 'avg_nutrition_sugars_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.thiamin.amount': {'aggregate_field_address': '$nutrition.thiamin.amount',
#   'aggregate_field_output_name': 'avg_nutrition_thiamin_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.vitaminA.amount': {'aggregate_field_address': '$nutrition.vitaminA.amount',
#   'aggregate_field_output_name': 'avg_nutrition_vitaminA_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.vitaminB6.amount': {'aggregate_field_address': '$nutrition.vitaminB6.amount',
#   'aggregate_field_output_name': 'avg_nutrition_vitaminB6_amount',
#   'aggregationFunction': '$avg'},
#  '$nutrition.vitaminC.amount': {'aggregate_field_address': '$nutrition.vitaminC.amount',
#   'aggregate_field_output_name': 'avg_nutrition_vitaminC_amount',
#   'aggregationFunction': '$avg'},
#  '$prepMinutes': {'aggregate_field_address': '$prepMinutes',
#   'aggregate_field_output_name': 'avg_prepMinutes',
#   'aggregationFunction': '$avg'},
#  '$ratingAverage': {'aggregate_field_address': '$ratingAverage',
#   'aggregate_field_output_name': 'avg_ratingAverage',
#   'aggregationFunction': '$avg'},
#  '$ratingCount': {'aggregate_field_address': '$ratingCount',
#   'aggregate_field_output_name': 'avg_ratingCount',
#   'aggregationFunction': '$avg'},
#  '$readyInMinutes': {'aggregate_field_address': '$readyInMinutes',
#   'aggregate_field_output_name': 'avg_readyInMinutes',
#   'aggregationFunction': '$avg'},
#  '$reviewCount': {'aggregate_field_address': '$reviewCount',
#   'aggregate_field_output_name': 'avg_reviewCount',
#   'aggregationFunction': '$avg'},
#  '$servings': {'aggregate_field_address': '$servings',
#   'aggregate_field_output_name': 'avg_servings',
#   'aggregationFunction': '$avg'},
#  '$similarRecipes.metaData.page': {'aggregate_field_address': '$similarRecipes.metaData.page',
#   'aggregate_field_output_name': 'avg_similarRecipes_metaData_page',
#   'aggregationFunction': '$avg'},
#  '$similarRecipes.metaData.pagesize': {'aggregate_field_address': '$similarRecipes.metaData.pagesize',
#   'aggregate_field_output_name': 'avg_similarRecipes_metaData_pagesize',
#   'aggregationFunction': '$avg'},
#  '$similarRecipes.metaData.totalCount': {'aggregate_field_address': '$similarRecipes.metaData.totalCount',
#   'aggregate_field_output_name': 'avg_similarRecipes_metaData_totalCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.favoritesCount': {'aggregate_field_address': '$submitter.favoritesCount',
#   'aggregate_field_output_name': 'avg_submitter_favoritesCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.followersCount': {'aggregate_field_address': '$submitter.followersCount',
#   'aggregate_field_output_name': 'avg_submitter_followersCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.followingCount': {'aggregate_field_address': '$submitter.followingCount',
#   'aggregate_field_output_name': 'avg_submitter_followingCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.madeRecipesCount': {'aggregate_field_address': '$submitter.madeRecipesCount',
#   'aggregate_field_output_name': 'avg_submitter_madeRecipesCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.personalRecipeSharedCount': {'aggregate_field_address': '$submitter.personalRecipeSharedCount',
#   'aggregate_field_output_name': 'avg_submitter_personalRecipeSharedCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.ratingsCount': {'aggregate_field_address': '$submitter.ratingsCount',
#   'aggregate_field_output_name': 'avg_submitter_ratingsCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.reciepesCount': {'aggregate_field_address': '$submitter.reciepesCount',
#   'aggregate_field_output_name': 'avg_submitter_reciepesCount',
#   'aggregationFunction': '$avg'},
#  '$submitter.reviewsCount': {'aggregate_field_address': '$submitter.reviewsCount',
#   'aggregate_field_output_name': 'avg_submitter_reviewsCount',
#   'aggregationFunction': '$avg'}}

# %%
# group bys
groupBy_fields_toQuery = [
    {
        # get global average
        'group_by_field_address': 'get_global_aggregation',
        'group_by_field_output_name': 'DummyColumn' # ignored,
    },
    {
        'group_by_field_address': '$ada-country',
        'group_by_field_output_name': 'country', # as it appears in dataframe
    },
    {
        'group_by_field_address': '$ada-city',
        'group_by_field_output_name': 'city', # as it appears in dataframe
    },
]

# keep in sync with above groupBys
dataframe_names = ['global', 'per_country', 'per_city']

# what to aggregate for, from valid keys extracted above
aggregation_fields_toQuery = list(accepted_keys_with_arguments.values())

all_dataframes = get_dataframe_per_groupby(collection, groupBy_fields_toQuery, aggregation_fields_toQuery, dataframe_names)
print('Done')
# Out:
# Query 1/114 with arguments: {'aggregate_field_address': '$reviewCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_reviewCount'}
# Query 2/114 with arguments: {'aggregate_field_address': '$ratingCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_ratingCount'}
# Query 3/114 with arguments: {'aggregate_field_address': '$servings', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_servings'}
# Query 4/114 with arguments: {'aggregate_field_address': '$nutrition.vitaminC.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_vitaminC_amount'}
# Query 5/114 with arguments: {'aggregate_field_address': '$nutrition.potassium.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_potassium_amount'}
# Query 6/114 with arguments: {'aggregate_field_address': '$submitter.reviewsCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_submitter_reviewsCount'}
# Query 7/114 with arguments: {'aggregate_field_address': '$submitter.followersCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_submitter_followersCount'}
# Query 8/114 with arguments: {'aggregate_field_address': '$nutrition.cholesterol.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_cholesterol_amount'}
# Query 9/114 with arguments: {'aggregate_field_address': '$nutrition.carbohydrates.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_carbohydrates_amount'}
# Query 10/114 with arguments: {'aggregate_field_address': '$nutrition.vitaminB6.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_vitaminB6_amount'}
# Query 11/114 with arguments: {'aggregate_field_address': '$nutrition.iron.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_iron_amount'}
# Query 12/114 with arguments: {'aggregate_field_address': '$nutrition.calcium.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_calcium_amount'}
# Query 13/114 with arguments: {'aggregate_field_address': '$prepMinutes', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_prepMinutes'}
# Query 14/114 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.pagesize', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_pagesize'}
# Query 15/114 with arguments: {'aggregate_field_address': '$nutrition.sodium.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_sodium_amount'}
# Query 16/114 with arguments: {'aggregate_field_address': '$submitter.reciepesCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_submitter_reciepesCount'}
# Query 17/114 with arguments: {'aggregate_field_address': '$nutrition.magnesium.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_magnesium_amount'}
# Query 18/114 with arguments: {'aggregate_field_address': '$nutrition.niacin.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_niacin_amount'}
# Query 19/114 with arguments: {'aggregate_field_address': '$nutrition.fiber.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_fiber_amount'}
# Query 20/114 with arguments: {'aggregate_field_address': '$submitter.madeRecipesCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_submitter_madeRecipesCount'}
# Query 21/114 with arguments: {'aggregate_field_address': '$submitter.ratingsCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_submitter_ratingsCount'}
# Query 22/114 with arguments: {'aggregate_field_address': '$nutrition.protein.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_protein_amount'}
# Query 23/114 with arguments: {'aggregate_field_address': '$readyInMinutes', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_readyInMinutes'}
# Query 24/114 with arguments: {'aggregate_field_address': '$nutrition.caloriesFromFat.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_caloriesFromFat_amount'}
# Query 25/114 with arguments: {'aggregate_field_address': '$nutrition.folate.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_folate_amount'}
# Query 26/114 with arguments: {'aggregate_field_address': '$submitter.favoritesCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_submitter_favoritesCount'}
# Query 27/114 with arguments: {'aggregate_field_address': '$nutrition.sugars.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_sugars_amount'}
# Query 28/114 with arguments: {'aggregate_field_address': '$nutrition.calories.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_calories_amount'}
# Query 29/114 with arguments: {'aggregate_field_address': '$ratingAverage', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_ratingAverage'}
# Query 30/114 with arguments: {'aggregate_field_address': '$submitter.followingCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_submitter_followingCount'}
# Query 31/114 with arguments: {'aggregate_field_address': '$nutrition.fat.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_fat_amount'}
# Query 32/114 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.totalCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_totalCount'}
# Query 33/114 with arguments: {'aggregate_field_address': '$nutrition.thiamin.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_thiamin_amount'}
# Query 34/114 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.page', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_page'}
# Query 35/114 with arguments: {'aggregate_field_address': '$cookMinutes', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_cookMinutes'}
# Query 36/114 with arguments: {'aggregate_field_address': '$nutrition.saturatedFat.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_saturatedFat_amount'}
# Query 37/114 with arguments: {'aggregate_field_address': '$submitter.personalRecipeSharedCount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_submitter_personalRecipeSharedCount'}
# Query 38/114 with arguments: {'aggregate_field_address': '$nutrition.vitaminA.amount', 'group_by_field_address': 'get_global_aggregation', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'DummyColumn', 'aggregate_field_output_name': 'avg_nutrition_vitaminA_amount'}
# Query 39/114 with arguments: {'aggregate_field_address': '$reviewCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_reviewCount'}
# Query 40/114 with arguments: {'aggregate_field_address': '$ratingCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_ratingCount'}
# Query 41/114 with arguments: {'aggregate_field_address': '$servings', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_servings'}
# Query 42/114 with arguments: {'aggregate_field_address': '$nutrition.vitaminC.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_vitaminC_amount'}
# Query 43/114 with arguments: {'aggregate_field_address': '$nutrition.potassium.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_potassium_amount'}
# Query 44/114 with arguments: {'aggregate_field_address': '$submitter.reviewsCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_submitter_reviewsCount'}
# Query 45/114 with arguments: {'aggregate_field_address': '$submitter.followersCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_submitter_followersCount'}
# Query 46/114 with arguments: {'aggregate_field_address': '$nutrition.cholesterol.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_cholesterol_amount'}
# Query 47/114 with arguments: {'aggregate_field_address': '$nutrition.carbohydrates.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_carbohydrates_amount'}
# Query 48/114 with arguments: {'aggregate_field_address': '$nutrition.vitaminB6.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_vitaminB6_amount'}
# Query 49/114 with arguments: {'aggregate_field_address': '$nutrition.iron.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_iron_amount'}
# Query 50/114 with arguments: {'aggregate_field_address': '$nutrition.calcium.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_calcium_amount'}
# Query 51/114 with arguments: {'aggregate_field_address': '$prepMinutes', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_prepMinutes'}
# Query 52/114 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.pagesize', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_pagesize'}
# Query 53/114 with arguments: {'aggregate_field_address': '$nutrition.sodium.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_sodium_amount'}
# Query 54/114 with arguments: {'aggregate_field_address': '$submitter.reciepesCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_submitter_reciepesCount'}
# Query 55/114 with arguments: {'aggregate_field_address': '$nutrition.magnesium.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_magnesium_amount'}
# Query 56/114 with arguments: {'aggregate_field_address': '$nutrition.niacin.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_niacin_amount'}
# Query 57/114 with arguments: {'aggregate_field_address': '$nutrition.fiber.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_fiber_amount'}
# Query 58/114 with arguments: {'aggregate_field_address': '$submitter.madeRecipesCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_submitter_madeRecipesCount'}
# Query 59/114 with arguments: {'aggregate_field_address': '$submitter.ratingsCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_submitter_ratingsCount'}
# Query 60/114 with arguments: {'aggregate_field_address': '$nutrition.protein.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_protein_amount'}
# Query 61/114 with arguments: {'aggregate_field_address': '$readyInMinutes', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_readyInMinutes'}
# Query 62/114 with arguments: {'aggregate_field_address': '$nutrition.caloriesFromFat.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_caloriesFromFat_amount'}
# Query 63/114 with arguments: {'aggregate_field_address': '$nutrition.folate.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_folate_amount'}
# Query 64/114 with arguments: {'aggregate_field_address': '$submitter.favoritesCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_submitter_favoritesCount'}
# Query 65/114 with arguments: {'aggregate_field_address': '$nutrition.sugars.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_sugars_amount'}
# Query 66/114 with arguments: {'aggregate_field_address': '$nutrition.calories.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_calories_amount'}
# Query 67/114 with arguments: {'aggregate_field_address': '$ratingAverage', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_ratingAverage'}
# Query 68/114 with arguments: {'aggregate_field_address': '$submitter.followingCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_submitter_followingCount'}
# Query 69/114 with arguments: {'aggregate_field_address': '$nutrition.fat.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_fat_amount'}
# Query 70/114 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.totalCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_totalCount'}
# Query 71/114 with arguments: {'aggregate_field_address': '$nutrition.thiamin.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_thiamin_amount'}
# Query 72/114 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.page', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_page'}
# Query 73/114 with arguments: {'aggregate_field_address': '$cookMinutes', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_cookMinutes'}
# Query 74/114 with arguments: {'aggregate_field_address': '$nutrition.saturatedFat.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_saturatedFat_amount'}
# Query 75/114 with arguments: {'aggregate_field_address': '$submitter.personalRecipeSharedCount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_submitter_personalRecipeSharedCount'}
# Query 76/114 with arguments: {'aggregate_field_address': '$nutrition.vitaminA.amount', 'group_by_field_address': '$ada-country', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'country', 'aggregate_field_output_name': 'avg_nutrition_vitaminA_amount'}
# Query 77/114 with arguments: {'aggregate_field_address': '$reviewCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_reviewCount'}
# Query 78/114 with arguments: {'aggregate_field_address': '$ratingCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_ratingCount'}
# Query 79/114 with arguments: {'aggregate_field_address': '$servings', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_servings'}
# Query 80/114 with arguments: {'aggregate_field_address': '$nutrition.vitaminC.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_vitaminC_amount'}
# Query 81/114 with arguments: {'aggregate_field_address': '$nutrition.potassium.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_potassium_amount'}
# Query 82/114 with arguments: {'aggregate_field_address': '$submitter.reviewsCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_submitter_reviewsCount'}
# Query 83/114 with arguments: {'aggregate_field_address': '$submitter.followersCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_submitter_followersCount'}
# Query 84/114 with arguments: {'aggregate_field_address': '$nutrition.cholesterol.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_cholesterol_amount'}
# Query 85/114 with arguments: {'aggregate_field_address': '$nutrition.carbohydrates.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_carbohydrates_amount'}
# Query 86/114 with arguments: {'aggregate_field_address': '$nutrition.vitaminB6.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_vitaminB6_amount'}
# Query 87/114 with arguments: {'aggregate_field_address': '$nutrition.iron.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_iron_amount'}
# Query 88/114 with arguments: {'aggregate_field_address': '$nutrition.calcium.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_calcium_amount'}
# Query 89/114 with arguments: {'aggregate_field_address': '$prepMinutes', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_prepMinutes'}
# Query 90/114 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.pagesize', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_pagesize'}
# Query 91/114 with arguments: {'aggregate_field_address': '$nutrition.sodium.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_sodium_amount'}
# Query 92/114 with arguments: {'aggregate_field_address': '$submitter.reciepesCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_submitter_reciepesCount'}
# Query 93/114 with arguments: {'aggregate_field_address': '$nutrition.magnesium.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_magnesium_amount'}
# Query 94/114 with arguments: {'aggregate_field_address': '$nutrition.niacin.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_niacin_amount'}
# Query 95/114 with arguments: {'aggregate_field_address': '$nutrition.fiber.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_fiber_amount'}
# Query 96/114 with arguments: {'aggregate_field_address': '$submitter.madeRecipesCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_submitter_madeRecipesCount'}
# Query 97/114 with arguments: {'aggregate_field_address': '$submitter.ratingsCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_submitter_ratingsCount'}
# Query 98/114 with arguments: {'aggregate_field_address': '$nutrition.protein.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_protein_amount'}
# Query 99/114 with arguments: {'aggregate_field_address': '$readyInMinutes', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_readyInMinutes'}
# Query 100/114 with arguments: {'aggregate_field_address': '$nutrition.caloriesFromFat.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_caloriesFromFat_amount'}
# Query 101/114 with arguments: {'aggregate_field_address': '$nutrition.folate.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_folate_amount'}
# Query 102/114 with arguments: {'aggregate_field_address': '$submitter.favoritesCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_submitter_favoritesCount'}
# Query 103/114 with arguments: {'aggregate_field_address': '$nutrition.sugars.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_sugars_amount'}
# Query 104/114 with arguments: {'aggregate_field_address': '$nutrition.calories.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_calories_amount'}
# Query 105/114 with arguments: {'aggregate_field_address': '$ratingAverage', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_ratingAverage'}
# Query 106/114 with arguments: {'aggregate_field_address': '$submitter.followingCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_submitter_followingCount'}
# Query 107/114 with arguments: {'aggregate_field_address': '$nutrition.fat.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_fat_amount'}
# Query 108/114 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.totalCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_totalCount'}
# Query 109/114 with arguments: {'aggregate_field_address': '$nutrition.thiamin.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_thiamin_amount'}
# Query 110/114 with arguments: {'aggregate_field_address': '$similarRecipes.metaData.page', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_similarRecipes_metaData_page'}
# Query 111/114 with arguments: {'aggregate_field_address': '$cookMinutes', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_cookMinutes'}
# Query 112/114 with arguments: {'aggregate_field_address': '$nutrition.saturatedFat.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_saturatedFat_amount'}
# Query 113/114 with arguments: {'aggregate_field_address': '$submitter.personalRecipeSharedCount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_submitter_personalRecipeSharedCount'}
# Query 114/114 with arguments: {'aggregate_field_address': '$nutrition.vitaminA.amount', 'group_by_field_address': '$ada-city', 'aggregationFunction': '$avg', 'group_by_field_output_name': 'city', 'aggregate_field_output_name': 'avg_nutrition_vitaminA_amount'}

# %% [markdown]
# Save them to JSON.

# %%
import os

json_output_filename = '../website/data/aggregatedData.json'

os.makedirs(os.path.dirname(json_output_filename), exist_ok=True)
write_dataframes_to_json(json_output_filename, all_dataframes)

# %%
# !cat '../website/data/aggregatedData.json'
# Out:
# {
#     "global": {
#         "Global aggregation": {
#             "avg_nutrition_niacin_amount": 6.5819486949,
#             "avg_servings": 10.2102573575,
#             "avg_submitter_personalRecipeSharedCount": 8.0709272257,
#             "avg_nutrition_fat_amount": 17.7817337376,
#             "avg_nutrition_magnesium_amount": 42.7467841021,
#             "avg_nutrition_vitaminA_amount": 1418.1540015684,
#             "avg_nutrition_vitaminB6_amount": 0.3188769283,
#             "avg_nutrition_fiber_amount": 3.1178096283,
#             "avg_similarRecipes_metaData_totalCount": 14.7297130895,
#             "avg_nutrition_saturatedFat_amount": 6.5396016803,
#             "avg_submitter_ratingsCount": 29.7984238394,
#             "avg_submitter_followersCount": 7870.611685753,
#             "avg_reviewCount": 77.7717029922,
#             "avg_cookMinutes": 41.1077453516,
#             "avg_submitter_reviewsCount": 23.1030045561,
#             "avg_nutrition_caloriesFromFat_amount": 160.0322171934,
#             "avg_nutrition_cholesterol_amount": 66.2203374766,
#             "avg_nutrition_carbohydrates_amount": 31.5380632211,
#             "avg_submitter_reciepesCount": 22.6657431351,
#             "avg_nutrition_calcium_amount": 114.9318745406,
#             "avg_nutrition_potassium_amount": 434.1991336157,
#             "avg_submitter_madeRecipesCount": 30.7689939663,
#             "avg_nutrition_folate_amount": 60.2745651289,
#             "avg_prepMinutes": 20.2409186061,
#             "avg_nutrition_protein_amount": 16.2278095183,
#             "avg_similarRecipes_metaData_pagesize": 14.7297130895,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 16242,
#             "avg_nutrition_sodium_amount": 661.4516873115,
#             "avg_nutrition_vitaminC_amount": 18.3412098224,
#             "avg_ratingCount": 102.3711981283,
#             "avg_submitter_favoritesCount": 151.0502401182,
#             "avg_nutrition_calories_amount": 350.2467986302,
#             "avg_nutrition_thiamin_amount": 0.2271286606,
#             "avg_ratingAverage": 4.0803297995,
#             "avg_nutrition_sugars_amount": 9.8466210198,
#             "avg_nutrition_iron_amount": 2.6678069684,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 157.1372367935
#         }
#     },
#     "per_city": {
#         "cincinnati": {
#             "avg_nutrition_niacin_amount": 10.1573376667,
#             "avg_servings": 9.3333333333,
#             "avg_submitter_personalRecipeSharedCount": 5.75,
#             "avg_nutrition_fat_amount": 19.712018,
#             "avg_nutrition_magnesium_amount": 54.6861808333,
#             "avg_nutrition_vitaminA_amount": 3300.7328333333,
#             "avg_nutrition_vitaminB6_amount": 0.409118955,
#             "avg_nutrition_fiber_amount": 5.79568,
#             "avg_similarRecipes_metaData_totalCount": 14.75,
#             "avg_nutrition_saturatedFat_amount": 7.5697554833,
#             "avg_submitter_ratingsCount": 2.9166666667,
#             "avg_submitter_followersCount": 3097.8333333333,
#             "avg_reviewCount": 62.9166666667,
#             "avg_cookMinutes": 53.3333333333,
#             "avg_submitter_reviewsCount": 2.25,
#             "avg_nutrition_caloriesFromFat_amount": 177.4081733333,
#             "avg_nutrition_cholesterol_amount": 65.80625,
#             "avg_nutrition_carbohydrates_amount": 35.1568405,
#             "avg_submitter_reciepesCount": 30.25,
#             "avg_nutrition_calcium_amount": 120.0086608333,
#             "avg_nutrition_potassium_amount": 563.3410333333,
#             "avg_submitter_madeRecipesCount": 3.0,
#             "avg_nutrition_folate_amount": 85.2405008333,
#             "avg_prepMinutes": 35.0,
#             "avg_nutrition_protein_amount": 28.6368300833,
#             "avg_similarRecipes_metaData_pagesize": 14.75,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 12,
#             "avg_nutrition_sodium_amount": 755.1521833333,
#             "avg_nutrition_vitaminC_amount": 16.8670281667,
#             "avg_ratingCount": 78.5833333333,
#             "avg_submitter_favoritesCount": 65.6666666667,
#             "avg_nutrition_calories_amount": 424.625025,
#             "avg_nutrition_thiamin_amount": 0.3062611983,
#             "avg_ratingAverage": 4.21401596,
#             "avg_nutrition_sugars_amount": 8.8096128083,
#             "avg_nutrition_iron_amount": 4.81320185,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 140.0
#         },
#         "philadelphia": {
#             "avg_nutrition_niacin_amount": 7.709990388,
#             "avg_servings": 7.82,
#             "avg_submitter_personalRecipeSharedCount": 9.26,
#             "avg_nutrition_fat_amount": 26.79897344,
#             "avg_nutrition_magnesium_amount": 42.76173593,
#             "avg_nutrition_vitaminA_amount": 922.4537942,
#             "avg_nutrition_vitaminB6_amount": 0.3141011734,
#             "avg_nutrition_fiber_amount": 2.629553508,
#             "avg_similarRecipes_metaData_totalCount": 14.5,
#             "avg_nutrition_saturatedFat_amount": 11.22191714,
#             "avg_submitter_ratingsCount": 59.68,
#             "avg_submitter_followersCount": 43661.24,
#             "avg_reviewCount": 36.82,
#             "avg_cookMinutes": 25.9,
#             "avg_submitter_reviewsCount": 40.48,
#             "avg_nutrition_caloriesFromFat_amount": 241.1907634,
#             "avg_nutrition_cholesterol_amount": 91.16037164,
#             "avg_nutrition_carbohydrates_amount": 41.94946146,
#             "avg_submitter_reciepesCount": 68.12,
#             "avg_nutrition_calcium_amount": 256.67036744,
#             "avg_nutrition_potassium_amount": 400.41947886,
#             "avg_submitter_madeRecipesCount": 61.18,
#             "avg_nutrition_folate_amount": 66.51275544,
#             "avg_prepMinutes": 15.6,
#             "avg_nutrition_protein_amount": 24.51036292,
#             "avg_similarRecipes_metaData_pagesize": 14.5,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 50,
#             "avg_nutrition_sodium_amount": 969.3789018,
#             "avg_nutrition_vitaminC_amount": 18.4969734301,
#             "avg_ratingCount": 47.72,
#             "avg_submitter_favoritesCount": 221.14,
#             "avg_nutrition_calories_amount": 510.41504,
#             "avg_nutrition_thiamin_amount": 0.2211141053,
#             "avg_ratingAverage": 4.2303322426,
#             "avg_nutrition_sugars_amount": 10.181250826,
#             "avg_nutrition_iron_amount": 3.120636906,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 75.32
#         },
#         "seattle": {
#             "avg_nutrition_niacin_amount": 8.757527289,
#             "avg_servings": 8.3432835821,
#             "avg_submitter_personalRecipeSharedCount": 12.6417910448,
#             "avg_nutrition_fat_amount": 23.9424004797,
#             "avg_nutrition_magnesium_amount": 52.0927064688,
#             "avg_nutrition_vitaminA_amount": 2170.3961329688,
#             "avg_nutrition_vitaminB6_amount": 0.4587975699,
#             "avg_nutrition_fiber_amount": 3.0802562672,
#             "avg_similarRecipes_metaData_totalCount": 15.4776119403,
#             "avg_nutrition_saturatedFat_amount": 7.2110913953,
#             "avg_submitter_ratingsCount": 62.7014925373,
#             "avg_submitter_followersCount": 154042.9402985075,
#             "avg_reviewCount": 219.6865671642,
#             "avg_cookMinutes": 22.7164179104,
#             "avg_submitter_reviewsCount": 31.8805970149,
#             "avg_nutrition_caloriesFromFat_amount": 215.4816058281,
#             "avg_nutrition_cholesterol_amount": 81.3847190141,
#             "avg_nutrition_carbohydrates_amount": 28.9806050203,
#             "avg_submitter_reciepesCount": 19.3432835821,
#             "avg_nutrition_calcium_amount": 104.2027518906,
#             "avg_nutrition_potassium_amount": 517.2492336719,
#             "avg_submitter_madeRecipesCount": 71.9402985075,
#             "avg_nutrition_folate_amount": 62.2402307969,
#             "avg_prepMinutes": 15.8805970149,
#             "avg_nutrition_protein_amount": 20.5943655992,
#             "avg_similarRecipes_metaData_pagesize": 15.4776119403,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 67,
#             "avg_nutrition_sodium_amount": 809.3939725312,
#             "avg_nutrition_vitaminC_amount": 21.9334769783,
#             "avg_ratingCount": 307.8507462687,
#             "avg_submitter_favoritesCount": 362.6119402985,
#             "avg_nutrition_calories_amount": 415.338245,
#             "avg_nutrition_thiamin_amount": 0.2829692072,
#             "avg_ratingAverage": 4.323805857,
#             "avg_nutrition_sugars_amount": 8.5214698198,
#             "avg_nutrition_iron_amount": 4.2691250437,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 223.2835820896
#         },
#         "new-york-city": {
#             "avg_nutrition_niacin_amount": 7.206435757,
#             "avg_servings": 9.48,
#             "avg_submitter_personalRecipeSharedCount": 6.608,
#             "avg_nutrition_fat_amount": 21.9647443719,
#             "avg_nutrition_magnesium_amount": 36.3795383471,
#             "avg_nutrition_vitaminA_amount": 1417.0557266223,
#             "avg_nutrition_vitaminB6_amount": 0.3385195889,
#             "avg_nutrition_fiber_amount": 2.2644520866,
#             "avg_similarRecipes_metaData_totalCount": 15.072,
#             "avg_nutrition_saturatedFat_amount": 8.9740257264,
#             "avg_submitter_ratingsCount": 55.24,
#             "avg_submitter_followersCount": 70765.312,
#             "avg_reviewCount": 88.52,
#             "avg_cookMinutes": 35.288,
#             "avg_submitter_reviewsCount": 24.2,
#             "avg_nutrition_caloriesFromFat_amount": 197.6827069587,
#             "avg_nutrition_cholesterol_amount": 85.2771413719,
#             "avg_nutrition_carbohydrates_amount": 33.5271574231,
#             "avg_submitter_reciepesCount": 104.256,
#             "avg_nutrition_calcium_amount": 95.5071747438,
#             "avg_nutrition_potassium_amount": 418.2511784711,
#             "avg_submitter_madeRecipesCount": 57.272,
#             "avg_nutrition_folate_amount": 50.1536934959,
#             "avg_prepMinutes": 16.76,
#             "avg_nutrition_protein_amount": 17.8896237174,
#             "avg_similarRecipes_metaData_pagesize": 15.072,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 125,
#             "avg_nutrition_sodium_amount": 700.8915924711,
#             "avg_nutrition_vitaminC_amount": 16.3531299945,
#             "avg_ratingCount": 111.336,
#             "avg_submitter_favoritesCount": 199.608,
#             "avg_nutrition_calories_amount": 411.8799015702,
#             "avg_nutrition_thiamin_amount": 0.1932303072,
#             "avg_ratingAverage": 4.1732518509,
#             "avg_nutrition_sugars_amount": 13.1172453805,
#             "avg_nutrition_iron_amount": 2.4951306835,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 160.368
#         },
#         "tampa-bay": {
#             "avg_nutrition_niacin_amount": 7.4860326192,
#             "avg_servings": 10.0,
#             "avg_submitter_personalRecipeSharedCount": 3.8214285714,
#             "avg_nutrition_fat_amount": 17.0666026423,
#             "avg_nutrition_magnesium_amount": 57.6145626538,
#             "avg_nutrition_vitaminA_amount": 824.5297607692,
#             "avg_nutrition_vitaminB6_amount": 0.4602584225,
#             "avg_nutrition_fiber_amount": 3.0053724042,
#             "avg_similarRecipes_metaData_totalCount": 14.2857142857,
#             "avg_nutrition_saturatedFat_amount": 6.3030932525,
#             "avg_submitter_ratingsCount": 58.4285714286,
#             "avg_submitter_followersCount": 40.3928571429,
#             "avg_reviewCount": 31.6785714286,
#             "avg_cookMinutes": 27.7142857143,
#             "avg_submitter_reviewsCount": 57.6785714286,
#             "avg_nutrition_caloriesFromFat_amount": 153.5994239231,
#             "avg_nutrition_cholesterol_amount": 63.4716067308,
#             "avg_nutrition_carbohydrates_amount": 23.0454681538,
#             "avg_submitter_reciepesCount": 3.0714285714,
#             "avg_nutrition_calcium_amount": 64.9977474231,
#             "avg_nutrition_potassium_amount": 566.1650784615,
#             "avg_submitter_madeRecipesCount": 57.5714285714,
#             "avg_nutrition_folate_amount": 47.5221723846,
#             "avg_prepMinutes": 16.4642857143,
#             "avg_nutrition_protein_amount": 23.3928072692,
#             "avg_similarRecipes_metaData_pagesize": 14.2857142857,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 28,
#             "avg_nutrition_sodium_amount": 681.6722751731,
#             "avg_nutrition_vitaminC_amount": 26.4787104077,
#             "avg_ratingCount": 38.25,
#             "avg_submitter_favoritesCount": 162.8571428571,
#             "avg_nutrition_calories_amount": 337.8598092308,
#             "avg_nutrition_thiamin_amount": 0.15919606,
#             "avg_ratingAverage": 4.3635902436,
#             "avg_nutrition_sugars_amount": 6.7900519954,
#             "avg_nutrition_iron_amount": 3.2166487,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 248.4642857143
#         },
#         "buffalo": {
#             "avg_nutrition_niacin_amount": 4.2063185402,
#             "avg_servings": 11.5365853659,
#             "avg_submitter_personalRecipeSharedCount": 9.8536585366,
#             "avg_nutrition_fat_amount": 17.3080967829,
#             "avg_nutrition_magnesium_amount": 26.2155527951,
#             "avg_nutrition_vitaminA_amount": 586.9734563902,
#             "avg_nutrition_vitaminB6_amount": 0.1978445112,
#             "avg_nutrition_fiber_amount": 1.4754392502,
#             "avg_similarRecipes_metaData_totalCount": 15.6585365854,
#             "avg_nutrition_saturatedFat_amount": 6.653792509,
#             "avg_submitter_ratingsCount": 23.7073170732,
#             "avg_submitter_followersCount": 1913.7804878049,
#             "avg_reviewCount": 36.2682926829,
#             "avg_cookMinutes": 27.243902439,
#             "avg_submitter_reviewsCount": 7.8048780488,
#             "avg_nutrition_caloriesFromFat_amount": 155.7728659024,
#             "avg_nutrition_cholesterol_amount": 63.7754877317,
#             "avg_nutrition_carbohydrates_amount": 18.7452494951,
#             "avg_submitter_reciepesCount": 46.6097560976,
#             "avg_nutrition_calcium_amount": 65.7200556195,
#             "avg_nutrition_potassium_amount": 249.2301235854,
#             "avg_submitter_madeRecipesCount": 25.0731707317,
#             "avg_nutrition_folate_amount": 33.2850871244,
#             "avg_prepMinutes": 12.5609756098,
#             "avg_nutrition_protein_amount": 11.4925765829,
#             "avg_similarRecipes_metaData_pagesize": 15.6585365854,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 41,
#             "avg_nutrition_sodium_amount": 751.4575639024,
#             "avg_nutrition_vitaminC_amount": 18.0834784651,
#             "avg_ratingCount": 46.2682926829,
#             "avg_submitter_favoritesCount": 110.8292682927,
#             "avg_nutrition_calories_amount": 274.4892507317,
#             "avg_nutrition_thiamin_amount": 0.1099706034,
#             "avg_ratingAverage": 3.9525303493,
#             "avg_nutrition_sugars_amount": 6.7007981976,
#             "avg_nutrition_iron_amount": 1.9006710515,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 58.9512195122
#         },
#         "kansas-city": {
#             "avg_nutrition_niacin_amount": 3.974544735,
#             "avg_servings": 13.6666666667,
#             "avg_submitter_personalRecipeSharedCount": 3.0416666667,
#             "avg_nutrition_fat_amount": 15.0364464455,
#             "avg_nutrition_magnesium_amount": 32.0467021364,
#             "avg_nutrition_vitaminA_amount": 1676.5504568182,
#             "avg_nutrition_vitaminB6_amount": 0.1577434245,
#             "avg_nutrition_fiber_amount": 2.1658508545,
#             "avg_similarRecipes_metaData_totalCount": 12.5416666667,
#             "avg_nutrition_saturatedFat_amount": 6.1034923091,
#             "avg_submitter_ratingsCount": 19.125,
#             "avg_submitter_followersCount": 2.0416666667,
#             "avg_reviewCount": 60.625,
#             "avg_cookMinutes": 25.125,
#             "avg_submitter_reviewsCount": 18.125,
#             "avg_nutrition_caloriesFromFat_amount": 135.3280215909,
#             "avg_nutrition_cholesterol_amount": 42.0874889091,
#             "avg_nutrition_carbohydrates_amount": 33.1955072273,
#             "avg_submitter_reciepesCount": 1.4583333333,
#             "avg_nutrition_calcium_amount": 88.0432716818,
#             "avg_nutrition_potassium_amount": 243.5239927273,
#             "avg_submitter_madeRecipesCount": 19.625,
#             "avg_nutrition_folate_amount": 47.5829189091,
#             "avg_prepMinutes": 10.9166666667,
#             "avg_nutrition_protein_amount": 9.5829484818,
#             "avg_similarRecipes_metaData_pagesize": 12.5416666667,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 24,
#             "avg_nutrition_sodium_amount": 421.2166277273,
#             "avg_nutrition_vitaminC_amount": 7.8234801123,
#             "avg_ratingCount": 76.25,
#             "avg_submitter_favoritesCount": 98.4166666667,
#             "avg_nutrition_calories_amount": 300.2158104545,
#             "avg_nutrition_thiamin_amount": 0.1217278914,
#             "avg_ratingAverage": 4.2158064117,
#             "avg_nutrition_sugars_amount": 11.7726006045,
#             "avg_nutrition_iron_amount": 1.7319653,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 42.7083333333
#         },
#         "milwaukee": {
#             "avg_nutrition_niacin_amount": 6.3474277967,
#             "avg_servings": 19.7407407407,
#             "avg_submitter_personalRecipeSharedCount": 1.8888888889,
#             "avg_nutrition_fat_amount": 16.6411957538,
#             "avg_nutrition_magnesium_amount": 30.9155015095,
#             "avg_nutrition_vitaminA_amount": 1254.0578828571,
#             "avg_nutrition_vitaminB6_amount": 0.2583515574,
#             "avg_nutrition_fiber_amount": 2.3278076571,
#             "avg_similarRecipes_metaData_totalCount": 12.9259259259,
#             "avg_nutrition_saturatedFat_amount": 7.4278637206,
#             "avg_submitter_ratingsCount": 217.5555555556,
#             "avg_submitter_followersCount": 294.6296296296,
#             "avg_reviewCount": 56.9259259259,
#             "avg_cookMinutes": 43.5185185185,
#             "avg_submitter_reviewsCount": 214.3703703704,
#             "avg_nutrition_caloriesFromFat_amount": 149.7707734524,
#             "avg_nutrition_cholesterol_amount": 71.0539208571,
#             "avg_nutrition_carbohydrates_amount": 31.8670666333,
#             "avg_submitter_reciepesCount": 2.2592592593,
#             "avg_nutrition_calcium_amount": 122.7239127619,
#             "avg_nutrition_potassium_amount": 303.862565381,
#             "avg_submitter_madeRecipesCount": 211.6296296296,
#             "avg_nutrition_folate_amount": 41.4845067857,
#             "avg_prepMinutes": 18.7037037037,
#             "avg_nutrition_protein_amount": 16.8256470076,
#             "avg_similarRecipes_metaData_pagesize": 12.9259259259,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 27,
#             "avg_nutrition_sodium_amount": 473.4390500905,
#             "avg_nutrition_vitaminC_amount": 4.0750595929,
#             "avg_ratingCount": 72.7777777778,
#             "avg_submitter_favoritesCount": 201.4814814815,
#             "avg_nutrition_calories_amount": 344.2545928571,
#             "avg_nutrition_thiamin_amount": 0.1554577799,
#             "avg_ratingAverage": 4.3539763722,
#             "avg_nutrition_sugars_amount": 17.4172225381,
#             "avg_nutrition_iron_amount": 2.3519146581,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 158.8888888889
#         },
#         "oakland": {
#             "avg_nutrition_niacin_amount": 8.3302825088,
#             "avg_servings": 8.4230769231,
#             "avg_submitter_personalRecipeSharedCount": 4.7692307692,
#             "avg_nutrition_fat_amount": 24.3226906923,
#             "avg_nutrition_magnesium_amount": 60.1629373077,
#             "avg_nutrition_vitaminA_amount": 1532.4941,
#             "avg_nutrition_vitaminB6_amount": 0.3636194046,
#             "avg_nutrition_fiber_amount": 2.8158160346,
#             "avg_similarRecipes_metaData_totalCount": 12.0769230769,
#             "avg_nutrition_saturatedFat_amount": 7.0818176654,
#             "avg_submitter_ratingsCount": 11.1538461538,
#             "avg_submitter_followersCount": 3.5,
#             "avg_reviewCount": 18.3076923077,
#             "avg_cookMinutes": 37.6923076923,
#             "avg_submitter_reviewsCount": 10.5384615385,
#             "avg_nutrition_caloriesFromFat_amount": 218.9042311538,
#             "avg_nutrition_cholesterol_amount": 79.1141545462,
#             "avg_nutrition_carbohydrates_amount": 35.2154799923,
#             "avg_submitter_reciepesCount": 1.3846153846,
#             "avg_nutrition_calcium_amount": 145.6520065385,
#             "avg_nutrition_potassium_amount": 579.9714888462,
#             "avg_submitter_madeRecipesCount": 11.4615384615,
#             "avg_nutrition_folate_amount": 65.1093506538,
#             "avg_prepMinutes": 16.9230769231,
#             "avg_nutrition_protein_amount": 22.2931578462,
#             "avg_similarRecipes_metaData_pagesize": 12.0769230769,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 26,
#             "avg_nutrition_sodium_amount": 706.4344396154,
#             "avg_nutrition_vitaminC_amount": 17.7529579577,
#             "avg_ratingCount": 22.1538461538,
#             "avg_submitter_favoritesCount": 127.2692307692,
#             "avg_nutrition_calories_amount": 448.8614230769,
#             "avg_nutrition_thiamin_amount": 0.2790700631,
#             "avg_ratingAverage": 4.0684482792,
#             "avg_nutrition_sugars_amount": 14.7109440923,
#             "avg_nutrition_iron_amount": 3.6042783192,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 65.3846153846
#         },
#         "pittsburgh": {
#             "avg_nutrition_niacin_amount": 8.0869232025,
#             "avg_servings": 8.0357142857,
#             "avg_submitter_personalRecipeSharedCount": 1.9642857143,
#             "avg_nutrition_fat_amount": 23.9406550357,
#             "avg_nutrition_magnesium_amount": 46.9784233571,
#             "avg_nutrition_vitaminA_amount": 750.5714234643,
#             "avg_nutrition_vitaminB6_amount": 0.3713053325,
#             "avg_nutrition_fiber_amount": 3.7168764329,
#             "avg_similarRecipes_metaData_totalCount": 15.1785714286,
#             "avg_nutrition_saturatedFat_amount": 9.1614294643,
#             "avg_submitter_ratingsCount": 9.8571428571,
#             "avg_submitter_followersCount": 3.3571428571,
#             "avg_reviewCount": 148.4285714286,
#             "avg_cookMinutes": 63.0357142857,
#             "avg_submitter_reviewsCount": 8.9285714286,
#             "avg_nutrition_caloriesFromFat_amount": 215.4658885714,
#             "avg_nutrition_cholesterol_amount": 76.4513171429,
#             "avg_nutrition_carbohydrates_amount": 44.8913861786,
#             "avg_submitter_reciepesCount": 15.0,
#             "avg_nutrition_calcium_amount": 176.3509592857,
#             "avg_nutrition_potassium_amount": 553.1527578571,
#             "avg_submitter_madeRecipesCount": 9.9285714286,
#             "avg_nutrition_folate_amount": 87.593270625,
#             "avg_prepMinutes": 16.7857142857,
#             "avg_nutrition_protein_amount": 22.6650185714,
#             "avg_similarRecipes_metaData_pagesize": 15.1785714286,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 28,
#             "avg_nutrition_sodium_amount": 1177.559305,
#             "avg_nutrition_vitaminC_amount": 24.3195612929,
#             "avg_ratingCount": 193.6428571429,
#             "avg_submitter_favoritesCount": 63.0714285714,
#             "avg_nutrition_calories_amount": 483.6879928571,
#             "avg_nutrition_thiamin_amount": 0.3739265813,
#             "avg_ratingAverage": 4.3639157029,
#             "avg_nutrition_sugars_amount": 10.2933764357,
#             "avg_nutrition_iron_amount": 3.181308925,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 130.1785714286
#         },
#         "green-bay": {
#             "avg_nutrition_niacin_amount": 9.271571,
#             "avg_servings": 14.6875,
#             "avg_submitter_personalRecipeSharedCount": 2.375,
#             "avg_nutrition_fat_amount": 20.5199484154,
#             "avg_nutrition_magnesium_amount": 44.7756590769,
#             "avg_nutrition_vitaminA_amount": 1214.13568,
#             "avg_nutrition_vitaminB6_amount": 0.4712018831,
#             "avg_nutrition_fiber_amount": 1.7425228762,
#             "avg_similarRecipes_metaData_totalCount": 14.25,
#             "avg_nutrition_saturatedFat_amount": 6.8581744877,
#             "avg_submitter_ratingsCount": 1.5625,
#             "avg_submitter_followersCount": 1.3125,
#             "avg_reviewCount": 49.6875,
#             "avg_cookMinutes": 40.625,
#             "avg_submitter_reviewsCount": 1.5,
#             "avg_nutrition_caloriesFromFat_amount": 184.6795501923,
#             "avg_nutrition_cholesterol_amount": 90.0401742308,
#             "avg_nutrition_carbohydrates_amount": 26.8232490538,
#             "avg_submitter_reciepesCount": 1.0625,
#             "avg_nutrition_calcium_amount": 107.8039268462,
#             "avg_nutrition_potassium_amount": 496.9851723077,
#             "avg_submitter_madeRecipesCount": 1.6875,
#             "avg_nutrition_folate_amount": 56.2237626923,
#             "avg_prepMinutes": 34.375,
#             "avg_nutrition_protein_amount": 25.2286861538,
#             "avg_similarRecipes_metaData_pagesize": 14.25,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 16,
#             "avg_nutrition_sodium_amount": 764.01584,
#             "avg_nutrition_vitaminC_amount": 6.9153687846,
#             "avg_ratingCount": 64.5625,
#             "avg_submitter_favoritesCount": 21.4375,
#             "avg_nutrition_calories_amount": 407.6131015385,
#             "avg_nutrition_thiamin_amount": 0.2769959485,
#             "avg_ratingAverage": 4.2604424237,
#             "avg_nutrition_sugars_amount": 3.2473853846,
#             "avg_nutrition_iron_amount": 3.7296937538,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 6382.5
#         },
#         "chicago": {
#             "avg_nutrition_niacin_amount": 8.4149930909,
#             "avg_servings": 5.8181818182,
#             "avg_submitter_personalRecipeSharedCount": 10.9090909091,
#             "avg_nutrition_fat_amount": 19.7759342727,
#             "avg_nutrition_magnesium_amount": 35.6325027273,
#             "avg_nutrition_vitaminA_amount": 1159.4425090909,
#             "avg_nutrition_vitaminB6_amount": 0.3570065909,
#             "avg_nutrition_fiber_amount": 3.3221818182,
#             "avg_similarRecipes_metaData_totalCount": 17.0,
#             "avg_nutrition_saturatedFat_amount": 6.2244856364,
#             "avg_submitter_ratingsCount": 30.4545454545,
#             "avg_submitter_followersCount": 3476.1818181818,
#             "avg_reviewCount": 93.5454545455,
#             "avg_cookMinutes": 45.9090909091,
#             "avg_submitter_reviewsCount": 2.0909090909,
#             "avg_nutrition_caloriesFromFat_amount": 177.9834209091,
#             "avg_nutrition_cholesterol_amount": 57.7919054545,
#             "avg_nutrition_carbohydrates_amount": 32.4189234545,
#             "avg_submitter_reciepesCount": 84.5454545455,
#             "avg_nutrition_calcium_amount": 145.0406539091,
#             "avg_nutrition_potassium_amount": 406.8057072727,
#             "avg_submitter_madeRecipesCount": 31.1818181818,
#             "avg_nutrition_folate_amount": 78.5223227273,
#             "avg_prepMinutes": 21.3636363636,
#             "avg_nutrition_protein_amount": 22.7507469091,
#             "avg_similarRecipes_metaData_pagesize": 17.0,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 11,
#             "avg_nutrition_sodium_amount": 1152.7164454545,
#             "avg_nutrition_vitaminC_amount": 9.1900536364,
#             "avg_ratingCount": 126.1818181818,
#             "avg_submitter_favoritesCount": 115.1818181818,
#             "avg_nutrition_calories_amount": 403.8004090909,
#             "avg_nutrition_thiamin_amount": 0.3377867473,
#             "avg_ratingAverage": 4.2650518455,
#             "avg_nutrition_sugars_amount": 5.8000551273,
#             "avg_nutrition_iron_amount": 4.0340229091,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 130.0
#         },
#         "boston": {
#             "avg_nutrition_niacin_amount": 4.3486284642,
#             "avg_servings": 9.8333333333,
#             "avg_submitter_personalRecipeSharedCount": 3.1666666667,
#             "avg_nutrition_fat_amount": 14.48347025,
#             "avg_nutrition_magnesium_amount": 56.7193199167,
#             "avg_nutrition_vitaminA_amount": 230.68042075,
#             "avg_nutrition_vitaminB6_amount": 0.2608668275,
#             "avg_nutrition_fiber_amount": 3.7532331133,
#             "avg_similarRecipes_metaData_totalCount": 16.5833333333,
#             "avg_nutrition_saturatedFat_amount": 5.1985809667,
#             "avg_submitter_ratingsCount": 35.75,
#             "avg_submitter_followersCount": 3200.9166666667,
#             "avg_reviewCount": 123.25,
#             "avg_cookMinutes": 126.25,
#             "avg_submitter_reviewsCount": 9.75,
#             "avg_nutrition_caloriesFromFat_amount": 130.3512266667,
#             "avg_nutrition_cholesterol_amount": 60.9165060833,
#             "avg_nutrition_carbohydrates_amount": 61.6097666667,
#             "avg_submitter_reciepesCount": 110.5833333333,
#             "avg_nutrition_calcium_amount": 96.3790575,
#             "avg_nutrition_potassium_amount": 457.4909183333,
#             "avg_submitter_madeRecipesCount": 36.0,
#             "avg_nutrition_folate_amount": 69.1808425,
#             "avg_prepMinutes": 26.25,
#             "avg_nutrition_protein_amount": 10.7414880592,
#             "avg_similarRecipes_metaData_pagesize": 16.5833333333,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 12,
#             "avg_nutrition_sodium_amount": 493.0753570833,
#             "avg_nutrition_vitaminC_amount": 4.8695579583,
#             "avg_ratingCount": 153.3333333333,
#             "avg_submitter_favoritesCount": 67.25,
#             "avg_nutrition_calories_amount": 411.6663833333,
#             "avg_nutrition_thiamin_amount": 0.240348669,
#             "avg_ratingAverage": 4.1276258017,
#             "avg_nutrition_sugars_amount": 34.4743725,
#             "avg_nutrition_iron_amount": 2.4268407383,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 249.1666666667
#         },
#         "miami": {
#             "avg_nutrition_niacin_amount": 7.92152196,
#             "avg_servings": 6.6666666667,
#             "avg_submitter_personalRecipeSharedCount": 1.8333333333,
#             "avg_nutrition_fat_amount": 24.3905374,
#             "avg_nutrition_magnesium_amount": 51.583778,
#             "avg_nutrition_vitaminA_amount": 534.437133,
#             "avg_nutrition_vitaminB6_amount": 0.385380114,
#             "avg_nutrition_fiber_amount": 2.58598826,
#             "avg_similarRecipes_metaData_totalCount": 14.5,
#             "avg_nutrition_saturatedFat_amount": 10.7349728,
#             "avg_submitter_ratingsCount": 10.0,
#             "avg_submitter_followersCount": 3.0,
#             "avg_reviewCount": 50.6666666667,
#             "avg_cookMinutes": 28.5,
#             "avg_submitter_reviewsCount": 9.6666666667,
#             "avg_nutrition_caloriesFromFat_amount": 219.514829,
#             "avg_nutrition_cholesterol_amount": 82.972396,
#             "avg_nutrition_carbohydrates_amount": 33.1075542,
#             "avg_submitter_reciepesCount": 1.0,
#             "avg_nutrition_calcium_amount": 148.4840393,
#             "avg_nutrition_potassium_amount": 483.65946,
#             "avg_submitter_madeRecipesCount": 10.25,
#             "avg_nutrition_folate_amount": 53.802855,
#             "avg_prepMinutes": 13.0833333333,
#             "avg_nutrition_protein_amount": 23.5617041,
#             "avg_similarRecipes_metaData_pagesize": 14.5,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 12,
#             "avg_nutrition_sodium_amount": 1137.50395,
#             "avg_nutrition_vitaminC_amount": 13.775039369,
#             "avg_ratingCount": 68.8333333333,
#             "avg_submitter_favoritesCount": 88.9166666667,
#             "avg_nutrition_calories_amount": 446.1634,
#             "avg_nutrition_thiamin_amount": 0.35442256,
#             "avg_ratingAverage": 4.3271377575,
#             "avg_nutrition_sugars_amount": 13.9112817,
#             "avg_nutrition_iron_amount": 2.63113087,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 44.5
#         },
#         "georgia": {
#             "avg_nutrition_niacin_amount": 4.391119622,
#             "avg_servings": 15.7183098592,
#             "avg_submitter_personalRecipeSharedCount": 9.7042253521,
#             "avg_nutrition_fat_amount": 20.2815547511,
#             "avg_nutrition_magnesium_amount": 36.8129842571,
#             "avg_nutrition_vitaminA_amount": 1829.5289358571,
#             "avg_nutrition_vitaminB6_amount": 0.2146132011,
#             "avg_nutrition_fiber_amount": 2.5095388411,
#             "avg_similarRecipes_metaData_totalCount": 14.8591549296,
#             "avg_nutrition_saturatedFat_amount": 7.3237251565,
#             "avg_submitter_ratingsCount": 17.3802816901,
#             "avg_submitter_followersCount": 5.6901408451,
#             "avg_reviewCount": 106.5211267606,
#             "avg_cookMinutes": 49.1126760563,
#             "avg_submitter_reviewsCount": 15.9154929577,
#             "avg_nutrition_caloriesFromFat_amount": 182.5339954329,
#             "avg_nutrition_cholesterol_amount": 58.2635068286,
#             "avg_nutrition_carbohydrates_amount": 34.2082966414,
#             "avg_submitter_reciepesCount": 6.5915492958,
#             "avg_nutrition_calcium_amount": 99.2761648714,
#             "avg_nutrition_potassium_amount": 343.1151770429,
#             "avg_submitter_madeRecipesCount": 17.661971831,
#             "avg_nutrition_folate_amount": 52.4274617571,
#             "avg_prepMinutes": 15.5915492958,
#             "avg_nutrition_protein_amount": 11.0973724957,
#             "avg_similarRecipes_metaData_pagesize": 14.8591549296,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 71,
#             "avg_nutrition_sodium_amount": 595.0686917429,
#             "avg_nutrition_vitaminC_amount": 12.11751674,
#             "avg_ratingCount": 135.338028169,
#             "avg_submitter_favoritesCount": 139.5633802817,
#             "avg_nutrition_calories_amount": 358.6492397143,
#             "avg_nutrition_thiamin_amount": 0.1861195221,
#             "avg_ratingAverage": 4.158777641,
#             "avg_nutrition_sugars_amount": 18.6805322896,
#             "avg_nutrition_iron_amount": 1.8700171199,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 95.7887323944
#         },
#         "indianapolis": {
#             "avg_nutrition_niacin_amount": 7.5555770779,
#             "avg_servings": 7.9333333333,
#             "avg_submitter_personalRecipeSharedCount": 6.2666666667,
#             "avg_nutrition_fat_amount": 20.78013555,
#             "avg_nutrition_magnesium_amount": 32.4746160714,
#             "avg_nutrition_vitaminA_amount": 877.3949448714,
#             "avg_nutrition_vitaminB6_amount": 0.3967395311,
#             "avg_nutrition_fiber_amount": 1.8113013571,
#             "avg_similarRecipes_metaData_totalCount": 15.2,
#             "avg_nutrition_saturatedFat_amount": 7.5749152914,
#             "avg_submitter_ratingsCount": 34.0,
#             "avg_submitter_followersCount": 13.4666666667,
#             "avg_reviewCount": 67.6666666667,
#             "avg_cookMinutes": 51.0,
#             "avg_submitter_reviewsCount": 30.8666666667,
#             "avg_nutrition_caloriesFromFat_amount": 187.0212205714,
#             "avg_nutrition_cholesterol_amount": 77.7785842857,
#             "avg_nutrition_carbohydrates_amount": 35.2995767143,
#             "avg_submitter_reciepesCount": 22.2,
#             "avg_nutrition_calcium_amount": 106.6231562143,
#             "avg_nutrition_potassium_amount": 432.0371707143,
#             "avg_submitter_madeRecipesCount": 34.4,
#             "avg_nutrition_folate_amount": 38.1160503714,
#             "avg_prepMinutes": 10.8666666667,
#             "avg_nutrition_protein_amount": 20.4746948193,
#             "avg_similarRecipes_metaData_pagesize": 15.2,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 15,
#             "avg_nutrition_sodium_amount": 641.9893585714,
#             "avg_nutrition_vitaminC_amount": 7.7831920016,
#             "avg_ratingCount": 87.0666666667,
#             "avg_submitter_favoritesCount": 95.2666666667,
#             "avg_nutrition_calories_amount": 425.4122357143,
#             "avg_nutrition_thiamin_amount": 0.4542568831,
#             "avg_ratingAverage": 3.8851282473,
#             "avg_nutrition_sugars_amount": 15.7910325714,
#             "avg_nutrition_iron_amount": 2.8803651857,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 66.8666666667
#         },
#         "san-francisco": {
#             "avg_nutrition_niacin_amount": 6.4557232849,
#             "avg_servings": 12.6829268293,
#             "avg_submitter_personalRecipeSharedCount": 6.2926829268,
#             "avg_nutrition_fat_amount": 12.0556219332,
#             "avg_nutrition_magnesium_amount": 58.4659303537,
#             "avg_nutrition_vitaminA_amount": 1177.7962191463,
#             "avg_nutrition_vitaminB6_amount": 0.2709673187,
#             "avg_nutrition_fiber_amount": 2.9773086473,
#             "avg_similarRecipes_metaData_totalCount": 15.8536585366,
#             "avg_nutrition_saturatedFat_amount": 4.4407462082,
#             "avg_submitter_ratingsCount": 108.7073170732,
#             "avg_submitter_followersCount": 11199.1219512195,
#             "avg_reviewCount": 68.8780487805,
#             "avg_cookMinutes": 39.8780487805,
#             "avg_submitter_reviewsCount": 18.0487804878,
#             "avg_nutrition_caloriesFromFat_amount": 108.500598678,
#             "avg_nutrition_cholesterol_amount": 66.2578526171,
#             "avg_nutrition_carbohydrates_amount": 25.6473037854,
#             "avg_submitter_reciepesCount": 269.3170731707,
#             "avg_nutrition_calcium_amount": 85.1226340244,
#             "avg_nutrition_potassium_amount": 498.6124517317,
#             "avg_submitter_madeRecipesCount": 111.9756097561,
#             "avg_nutrition_folate_amount": 58.5151527912,
#             "avg_prepMinutes": 18.4146341463,
#             "avg_nutrition_protein_amount": 17.9521666288,
#             "avg_similarRecipes_metaData_pagesize": 15.8536585366,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 41,
#             "avg_nutrition_sodium_amount": 575.5371249512,
#             "avg_nutrition_vitaminC_amount": 19.2749906017,
#             "avg_ratingCount": 88.1463414634,
#             "avg_submitter_favoritesCount": 164.0731707317,
#             "avg_nutrition_calories_amount": 291.9175343171,
#             "avg_nutrition_thiamin_amount": 0.1696685185,
#             "avg_ratingAverage": 3.8753884834,
#             "avg_nutrition_sugars_amount": 8.0171513306,
#             "avg_nutrition_iron_amount": 3.743290641,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 98.9756097561
#         },
#         "baltimore": {
#             "avg_nutrition_niacin_amount": 6.0732088472,
#             "avg_servings": 14.9,
#             "avg_submitter_personalRecipeSharedCount": 5.525,
#             "avg_nutrition_fat_amount": 14.7702118631,
#             "avg_nutrition_magnesium_amount": 47.9311626872,
#             "avg_nutrition_vitaminA_amount": 717.1477726923,
#             "avg_nutrition_vitaminB6_amount": 0.2259791803,
#             "avg_nutrition_fiber_amount": 1.4585683298,
#             "avg_similarRecipes_metaData_totalCount": 16.35,
#             "avg_nutrition_saturatedFat_amount": 5.40006226,
#             "avg_submitter_ratingsCount": 8.8,
#             "avg_submitter_followersCount": 4.8,
#             "avg_reviewCount": 80.375,
#             "avg_cookMinutes": 27.375,
#             "avg_submitter_reviewsCount": 7.4,
#             "avg_nutrition_caloriesFromFat_amount": 132.9319115974,
#             "avg_nutrition_cholesterol_amount": 77.6547251282,
#             "avg_nutrition_carbohydrates_amount": 21.2793264667,
#             "avg_submitter_reciepesCount": 2.3,
#             "avg_nutrition_calcium_amount": 97.5182042744,
#             "avg_nutrition_potassium_amount": 366.0909587436,
#             "avg_submitter_madeRecipesCount": 8.85,
#             "avg_nutrition_folate_amount": 64.73690206,
#             "avg_prepMinutes": 14.175,
#             "avg_nutrition_protein_amount": 15.2652843533,
#             "avg_similarRecipes_metaData_pagesize": 16.35,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 40,
#             "avg_nutrition_sodium_amount": 922.6234240769,
#             "avg_nutrition_vitaminC_amount": 6.1599226656,
#             "avg_ratingCount": 98.975,
#             "avg_submitter_favoritesCount": 79.25,
#             "avg_nutrition_calories_amount": 282.5841822308,
#             "avg_nutrition_thiamin_amount": 0.1763905158,
#             "avg_ratingAverage": 4.119503283,
#             "avg_nutrition_sugars_amount": 8.5506484808,
#             "avg_nutrition_iron_amount": 2.0725230292,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 340.175
#         },
#         "california": {
#             "avg_nutrition_niacin_amount": 6.4451584148,
#             "avg_servings": 9.484,
#             "avg_submitter_personalRecipeSharedCount": 16.852,
#             "avg_nutrition_fat_amount": 18.5514870699,
#             "avg_nutrition_magnesium_amount": 51.7179932675,
#             "avg_nutrition_vitaminA_amount": 1500.1951878537,
#             "avg_nutrition_vitaminB6_amount": 0.3467345465,
#             "avg_nutrition_fiber_amount": 3.7913148069,
#             "avg_similarRecipes_metaData_totalCount": 14.5,
#             "avg_nutrition_saturatedFat_amount": 5.9080431716,
#             "avg_submitter_ratingsCount": 36.336,
#             "avg_submitter_followersCount": 69033.26,
#             "avg_reviewCount": 67.324,
#             "avg_cookMinutes": 31.172,
#             "avg_submitter_reviewsCount": 17.132,
#             "avg_nutrition_caloriesFromFat_amount": 166.9633836325,
#             "avg_nutrition_cholesterol_amount": 58.8283987134,
#             "avg_nutrition_carbohydrates_amount": 31.139750222,
#             "avg_submitter_reciepesCount": 65.068,
#             "avg_nutrition_calcium_amount": 124.1717093821,
#             "avg_nutrition_potassium_amount": 509.1961640285,
#             "avg_submitter_madeRecipesCount": 39.412,
#             "avg_nutrition_folate_amount": 65.8570558583,
#             "avg_prepMinutes": 19.7,
#             "avg_nutrition_protein_amount": 17.1335965784,
#             "avg_similarRecipes_metaData_pagesize": 14.5,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 250,
#             "avg_nutrition_sodium_amount": 648.544411902,
#             "avg_nutrition_vitaminC_amount": 24.7245447284,
#             "avg_ratingCount": 88.84,
#             "avg_submitter_favoritesCount": 191.792,
#             "avg_nutrition_calories_amount": 361.590713878,
#             "avg_nutrition_thiamin_amount": 0.2142060071,
#             "avg_ratingAverage": 4.0030013945,
#             "avg_nutrition_sugars_amount": 9.3683412646,
#             "avg_nutrition_iron_amount": 2.78399907,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 132.472
#         },
#         "dallas": {
#             "avg_nutrition_niacin_amount": 3.7490150276,
#             "avg_servings": 14.724137931,
#             "avg_submitter_personalRecipeSharedCount": 4.7931034483,
#             "avg_nutrition_fat_amount": 14.259867369,
#             "avg_nutrition_magnesium_amount": 31.8671556552,
#             "avg_nutrition_vitaminA_amount": 2142.7329715172,
#             "avg_nutrition_vitaminB6_amount": 0.2289084511,
#             "avg_nutrition_fiber_amount": 3.3479804724,
#             "avg_similarRecipes_metaData_totalCount": 17.2413793103,
#             "avg_nutrition_saturatedFat_amount": 4.5802688862,
#             "avg_submitter_ratingsCount": 10.3103448276,
#             "avg_submitter_followersCount": 1.1034482759,
#             "avg_reviewCount": 85.7586206897,
#             "avg_cookMinutes": 16.5172413793,
#             "avg_submitter_reviewsCount": 6.2068965517,
#             "avg_nutrition_caloriesFromFat_amount": 128.338812069,
#             "avg_nutrition_cholesterol_amount": 48.2601582759,
#             "avg_nutrition_carbohydrates_amount": 29.1065187586,
#             "avg_submitter_reciepesCount": 2.1724137931,
#             "avg_nutrition_calcium_amount": 84.7029391034,
#             "avg_nutrition_potassium_amount": 347.4378434483,
#             "avg_submitter_madeRecipesCount": 10.7931034483,
#             "avg_nutrition_folate_amount": 48.1794948276,
#             "avg_prepMinutes": 17.8275862069,
#             "avg_nutrition_protein_amount": 9.7854165345,
#             "avg_similarRecipes_metaData_pagesize": 17.2413793103,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 29,
#             "avg_nutrition_sodium_amount": 555.5156519655,
#             "avg_nutrition_vitaminC_amount": 21.5955942847,
#             "avg_ratingCount": 107.7586206897,
#             "avg_submitter_favoritesCount": 95.724137931,
#             "avg_nutrition_calories_amount": 281.9190327586,
#             "avg_nutrition_thiamin_amount": 0.1641491599,
#             "avg_ratingAverage": 4.5723076031,
#             "avg_nutrition_sugars_amount": 12.2154127862,
#             "avg_nutrition_iron_amount": 1.9520466376,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 113.9310344828
#         },
#         "st-louis": {
#             "avg_nutrition_niacin_amount": 8.2253497778,
#             "avg_servings": 10.6296296296,
#             "avg_submitter_personalRecipeSharedCount": 3.5925925926,
#             "avg_nutrition_fat_amount": 28.6261497778,
#             "avg_nutrition_magnesium_amount": 41.3972659259,
#             "avg_nutrition_vitaminA_amount": 1428.0750611111,
#             "avg_nutrition_vitaminB6_amount": 0.4252018348,
#             "avg_nutrition_fiber_amount": 2.7868702321,
#             "avg_similarRecipes_metaData_totalCount": 15.8888888889,
#             "avg_nutrition_saturatedFat_amount": 10.6463396704,
#             "avg_submitter_ratingsCount": 105.8148148148,
#             "avg_submitter_followersCount": 24.5555555556,
#             "avg_reviewCount": 72.1481481481,
#             "avg_cookMinutes": 84.0,
#             "avg_submitter_reviewsCount": 104.7777777778,
#             "avg_nutrition_caloriesFromFat_amount": 257.6353418519,
#             "avg_nutrition_cholesterol_amount": 87.1776358148,
#             "avg_nutrition_carbohydrates_amount": 39.3335362222,
#             "avg_submitter_reciepesCount": 1.2962962963,
#             "avg_nutrition_calcium_amount": 108.1172686296,
#             "avg_nutrition_potassium_amount": 473.9753051852,
#             "avg_submitter_madeRecipesCount": 106.2222222222,
#             "avg_nutrition_folate_amount": 58.530613,
#             "avg_prepMinutes": 16.2592592593,
#             "avg_nutrition_protein_amount": 17.6499616778,
#             "avg_similarRecipes_metaData_pagesize": 15.8888888889,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 27,
#             "avg_nutrition_sodium_amount": 1665.9185703704,
#             "avg_nutrition_vitaminC_amount": 11.8623023581,
#             "avg_ratingCount": 92.0740740741,
#             "avg_submitter_favoritesCount": 297.5185185185,
#             "avg_nutrition_calories_amount": 485.8434666667,
#             "avg_nutrition_thiamin_amount": 0.5404099809,
# ...
#             "avg_nutrition_vitaminC_amount": 27.5254044833,
#             "avg_ratingCount": 14.4166666667,
#             "avg_submitter_favoritesCount": 60.8333333333,
#             "avg_nutrition_calories_amount": 359.15997,
#             "avg_nutrition_thiamin_amount": 0.2621183393,
#             "avg_ratingAverage": 3.7937663297,
#             "avg_nutrition_sugars_amount": 10.4180295694,
#             "avg_nutrition_iron_amount": 2.8378849391,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 386.8611111111
#         },
#         "south-african": {
#             "avg_nutrition_niacin_amount": 5.6247821808,
#             "avg_servings": 9.6296296296,
#             "avg_submitter_personalRecipeSharedCount": 2.7777777778,
#             "avg_nutrition_fat_amount": 15.5505202692,
#             "avg_nutrition_magnesium_amount": 39.7794348846,
#             "avg_nutrition_vitaminA_amount": 2123.258389359,
#             "avg_nutrition_vitaminB6_amount": 0.2520871015,
#             "avg_nutrition_fiber_amount": 2.8702573808,
#             "avg_similarRecipes_metaData_totalCount": 12.1851851852,
#             "avg_nutrition_saturatedFat_amount": 6.3876365654,
#             "avg_submitter_ratingsCount": 5.8518518519,
#             "avg_submitter_followersCount": 29.1481481481,
#             "avg_reviewCount": 19.2962962963,
#             "avg_cookMinutes": 52.6296296296,
#             "avg_submitter_reviewsCount": 4.4814814815,
#             "avg_nutrition_caloriesFromFat_amount": 139.9546942308,
#             "avg_nutrition_cholesterol_amount": 69.3561810769,
#             "avg_nutrition_carbohydrates_amount": 35.5916219231,
#             "avg_submitter_reciepesCount": 10.4074074074,
#             "avg_nutrition_calcium_amount": 88.8947012308,
#             "avg_nutrition_potassium_amount": 440.0337234615,
#             "avg_submitter_madeRecipesCount": 6.5185185185,
#             "avg_nutrition_folate_amount": 60.2134428077,
#             "avg_prepMinutes": 20.0,
#             "avg_nutrition_protein_amount": 14.2279443846,
#             "avg_similarRecipes_metaData_pagesize": 12.1851851852,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 27,
#             "avg_nutrition_sodium_amount": 452.9926777308,
#             "avg_nutrition_vitaminC_amount": 14.0924048192,
#             "avg_ratingCount": 23.4444444444,
#             "avg_submitter_favoritesCount": 56.9259259259,
#             "avg_nutrition_calories_amount": 336.5758846154,
#             "avg_nutrition_thiamin_amount": 0.1889819328,
#             "avg_ratingAverage": 3.7438709163,
#             "avg_nutrition_sugars_amount": 17.1953003077,
#             "avg_nutrition_iron_amount": 2.4279322038,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 185.5925925926
#         },
#         "vietnamese": {
#             "avg_nutrition_niacin_amount": 9.5424661703,
#             "avg_servings": 5.5692307692,
#             "avg_submitter_personalRecipeSharedCount": 9.0,
#             "avg_nutrition_fat_amount": 15.9128948321,
#             "avg_nutrition_magnesium_amount": 54.0933887969,
#             "avg_nutrition_vitaminA_amount": 1359.1273391562,
#             "avg_nutrition_vitaminB6_amount": 0.4280754553,
#             "avg_nutrition_fiber_amount": 2.5177691486,
#             "avg_similarRecipes_metaData_totalCount": 14.5230769231,
#             "avg_nutrition_saturatedFat_amount": 4.2574057961,
#             "avg_submitter_ratingsCount": 23.0461538462,
#             "avg_submitter_followersCount": 95837.5230769231,
#             "avg_reviewCount": 27.0615384615,
#             "avg_cookMinutes": 39.2461538462,
#             "avg_submitter_reviewsCount": 17.1846153846,
#             "avg_nutrition_caloriesFromFat_amount": 143.2160583298,
#             "avg_nutrition_cholesterol_amount": 71.117478125,
#             "avg_nutrition_carbohydrates_amount": 34.7233996875,
#             "avg_submitter_reciepesCount": 22.8,
#             "avg_nutrition_calcium_amount": 84.8626964844,
#             "avg_nutrition_potassium_amount": 485.5584982813,
#             "avg_submitter_madeRecipesCount": 27.7692307692,
#             "avg_nutrition_folate_amount": 54.5734211875,
#             "avg_prepMinutes": 19.8461538462,
#             "avg_nutrition_protein_amount": 22.2820613437,
#             "avg_similarRecipes_metaData_pagesize": 14.5230769231,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 65,
#             "avg_nutrition_sodium_amount": 906.7655025625,
#             "avg_nutrition_vitaminC_amount": 19.5559579855,
#             "avg_ratingCount": 36.6461538462,
#             "avg_submitter_favoritesCount": 140.6615384615,
#             "avg_nutrition_calories_amount": 371.1999254688,
#             "avg_nutrition_thiamin_amount": 0.2619469117,
#             "avg_ratingAverage": 3.8451726934,
#             "avg_nutrition_sugars_amount": 7.8938403891,
#             "avg_nutrition_iron_amount": 2.945049273,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 94.2461538462
#         },
#         "portuguese": {
#             "avg_nutrition_niacin_amount": 7.0927860193,
#             "avg_servings": 13.4788732394,
#             "avg_submitter_personalRecipeSharedCount": 4.1830985915,
#             "avg_nutrition_fat_amount": 19.43980218,
#             "avg_nutrition_magnesium_amount": 44.8865636305,
#             "avg_nutrition_vitaminA_amount": 1742.2827494528,
#             "avg_nutrition_vitaminB6_amount": 0.4377583749,
#             "avg_nutrition_fiber_amount": 3.3694097739,
#             "avg_similarRecipes_metaData_totalCount": 13.0281690141,
#             "avg_nutrition_saturatedFat_amount": 6.5825532429,
#             "avg_submitter_ratingsCount": 10.1126760563,
#             "avg_submitter_followersCount": 8.5211267606,
#             "avg_reviewCount": 23.1267605634,
#             "avg_cookMinutes": 65.014084507,
#             "avg_submitter_reviewsCount": 9.8309859155,
#             "avg_nutrition_caloriesFromFat_amount": 174.9582195634,
#             "avg_nutrition_cholesterol_amount": 68.7992434085,
#             "avg_nutrition_carbohydrates_amount": 32.773879662,
#             "avg_submitter_reciepesCount": 12.7042253521,
#             "avg_nutrition_calcium_amount": 74.2769091062,
#             "avg_nutrition_potassium_amount": 565.4404396746,
#             "avg_submitter_madeRecipesCount": 10.0704225352,
#             "avg_nutrition_folate_amount": 55.8780599761,
#             "avg_prepMinutes": 41.6901408451,
#             "avg_nutrition_protein_amount": 17.4819113634,
#             "avg_similarRecipes_metaData_pagesize": 13.0281690141,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 71,
#             "avg_nutrition_sodium_amount": 907.2470149601,
#             "avg_nutrition_vitaminC_amount": 22.3907729875,
#             "avg_ratingCount": 28.1408450704,
#             "avg_submitter_favoritesCount": 96.6338028169,
#             "avg_nutrition_calories_amount": 382.1134757746,
#             "avg_nutrition_thiamin_amount": 0.311931966,
#             "avg_ratingAverage": 3.9028916518,
#             "avg_nutrition_sugars_amount": 10.1883778042,
#             "avg_nutrition_iron_amount": 2.8175728485,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 282.7605633803
#         },
#         "chilean": {
#             "avg_nutrition_niacin_amount": 6.233372896,
#             "avg_servings": 8.3125,
#             "avg_submitter_personalRecipeSharedCount": 3.65625,
#             "avg_nutrition_fat_amount": 18.79237432,
#             "avg_nutrition_magnesium_amount": 41.3496612,
#             "avg_nutrition_vitaminA_amount": 1638.9038292,
#             "avg_nutrition_vitaminB6_amount": 0.3145408764,
#             "avg_nutrition_fiber_amount": 2.65840414,
#             "avg_similarRecipes_metaData_totalCount": 12.90625,
#             "avg_nutrition_saturatedFat_amount": 6.312188332,
#             "avg_submitter_ratingsCount": 10.15625,
#             "avg_submitter_followersCount": 16.59375,
#             "avg_reviewCount": 79.59375,
#             "avg_cookMinutes": 31.25,
#             "avg_submitter_reviewsCount": 9.75,
#             "avg_nutrition_caloriesFromFat_amount": 169.1313728,
#             "avg_nutrition_cholesterol_amount": 88.41144906,
#             "avg_nutrition_carbohydrates_amount": 32.167141428,
#             "avg_submitter_reciepesCount": 7.125,
#             "avg_nutrition_calcium_amount": 90.3537068,
#             "avg_nutrition_potassium_amount": 462.295466,
#             "avg_submitter_madeRecipesCount": 10.1875,
#             "avg_nutrition_folate_amount": 65.30928508,
#             "avg_prepMinutes": 21.625,
#             "avg_nutrition_protein_amount": 17.05239008,
#             "avg_similarRecipes_metaData_pagesize": 12.90625,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 32,
#             "avg_nutrition_sodium_amount": 440.4457032,
#             "avg_nutrition_vitaminC_amount": 17.01180092,
#             "avg_ratingCount": 103.0625,
#             "avg_submitter_favoritesCount": 51.9375,
#             "avg_nutrition_calories_amount": 373.2202384,
#             "avg_nutrition_thiamin_amount": 0.2494102376,
#             "avg_ratingAverage": 4.1819787528,
#             "avg_nutrition_sugars_amount": 9.214339576,
#             "avg_nutrition_iron_amount": 2.920028952,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 64.125
#         },
#         "moroccan": {
#             "avg_nutrition_niacin_amount": 8.6571840087,
#             "avg_servings": 6.4042553191,
#             "avg_submitter_personalRecipeSharedCount": 4.7446808511,
#             "avg_nutrition_fat_amount": 14.4877564851,
#             "avg_nutrition_magnesium_amount": 65.8795594468,
#             "avg_nutrition_vitaminA_amount": 6068.1345169149,
#             "avg_nutrition_vitaminB6_amount": 0.5626349987,
#             "avg_nutrition_fiber_amount": 6.6612501447,
#             "avg_similarRecipes_metaData_totalCount": 14.5106382979,
#             "avg_nutrition_saturatedFat_amount": 3.9460735877,
#             "avg_submitter_ratingsCount": 13.170212766,
#             "avg_submitter_followersCount": 18.6170212766,
#             "avg_reviewCount": 64.8085106383,
#             "avg_cookMinutes": 68.3829787234,
#             "avg_submitter_reviewsCount": 11.5319148936,
#             "avg_nutrition_caloriesFromFat_amount": 130.3898079787,
#             "avg_nutrition_cholesterol_amount": 52.2797916596,
#             "avg_nutrition_carbohydrates_amount": 39.3773053681,
#             "avg_submitter_reciepesCount": 4.3829787234,
#             "avg_nutrition_calcium_amount": 91.3638361277,
#             "avg_nutrition_potassium_amount": 725.0038125532,
#             "avg_submitter_madeRecipesCount": 13.5957446809,
#             "avg_nutrition_folate_amount": 91.843288883,
#             "avg_prepMinutes": 21.8085106383,
#             "avg_nutrition_protein_amount": 21.4345285553,
#             "avg_similarRecipes_metaData_pagesize": 14.5106382979,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 47,
#             "avg_nutrition_sodium_amount": 739.8005429787,
#             "avg_nutrition_vitaminC_amount": 26.8271868979,
#             "avg_ratingCount": 87.8085106383,
#             "avg_submitter_favoritesCount": 136.3617021277,
#             "avg_nutrition_calories_amount": 369.7492845532,
#             "avg_nutrition_thiamin_amount": 0.2308172929,
#             "avg_ratingAverage": 4.3498336957,
#             "avg_nutrition_sugars_amount": 10.8025218049,
#             "avg_nutrition_iron_amount": 3.7160831021,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 140.085106383
#         },
#         "danish": {
#             "avg_nutrition_niacin_amount": 2.8490052444,
#             "avg_servings": 32.8518518519,
#             "avg_submitter_personalRecipeSharedCount": 4.2962962963,
#             "avg_nutrition_fat_amount": 9.2348194185,
#             "avg_nutrition_magnesium_amount": 23.4690742222,
#             "avg_nutrition_vitaminA_amount": 372.0350590122,
#             "avg_nutrition_vitaminB6_amount": 0.1331037541,
#             "avg_nutrition_fiber_amount": 1.757884603,
#             "avg_similarRecipes_metaData_totalCount": 13.7037037037,
#             "avg_nutrition_saturatedFat_amount": 4.5994675467,
#             "avg_submitter_ratingsCount": 6.5555555556,
#             "avg_submitter_followersCount": 7.962962963,
#             "avg_reviewCount": 30.6666666667,
#             "avg_cookMinutes": 30.2962962963,
#             "avg_submitter_reviewsCount": 6.4814814815,
#             "avg_nutrition_caloriesFromFat_amount": 83.1133719259,
#             "avg_nutrition_cholesterol_amount": 52.7704283333,
#             "avg_nutrition_carbohydrates_amount": 24.4583575185,
#             "avg_submitter_reciepesCount": 1.7777777778,
#             "avg_nutrition_calcium_amount": 66.6358888519,
#             "avg_nutrition_potassium_amount": 207.0488810741,
#             "avg_submitter_madeRecipesCount": 6.6296296296,
#             "avg_nutrition_folate_amount": 41.6060976667,
#             "avg_prepMinutes": 21.8518518519,
#             "avg_nutrition_protein_amount": 6.7468044778,
#             "avg_similarRecipes_metaData_pagesize": 13.7037037037,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 27,
#             "avg_nutrition_sodium_amount": 404.6898390593,
#             "avg_nutrition_vitaminC_amount": 11.2848108924,
#             "avg_ratingCount": 37.4074074074,
#             "avg_submitter_favoritesCount": 111.8888888889,
#             "avg_nutrition_calories_amount": 206.7531092593,
#             "avg_nutrition_thiamin_amount": 0.1645444356,
#             "avg_ratingAverage": 4.1277816148,
#             "avg_nutrition_sugars_amount": 7.6813844444,
#             "avg_nutrition_iron_amount": 2.5893464574,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 208.0740740741
#         },
#         "indonesian": {
#             "avg_nutrition_niacin_amount": 8.8258426452,
#             "avg_servings": 8.25,
#             "avg_submitter_personalRecipeSharedCount": 2.9375,
#             "avg_nutrition_fat_amount": 20.5867613011,
#             "avg_nutrition_magnesium_amount": 55.6459974194,
#             "avg_nutrition_vitaminA_amount": 1512.5257970968,
#             "avg_nutrition_vitaminB6_amount": 0.5156000458,
#             "avg_nutrition_fiber_amount": 2.7652177635,
#             "avg_similarRecipes_metaData_totalCount": 12.96875,
#             "avg_nutrition_saturatedFat_amount": 7.0203488532,
#             "avg_submitter_ratingsCount": 13.375,
#             "avg_submitter_followersCount": 1195.6875,
#             "avg_reviewCount": 34.6875,
#             "avg_cookMinutes": 42.96875,
#             "avg_submitter_reviewsCount": 3.46875,
#             "avg_nutrition_caloriesFromFat_amount": 185.2808525481,
#             "avg_nutrition_cholesterol_amount": 94.5029175806,
#             "avg_nutrition_carbohydrates_amount": 29.4623248387,
#             "avg_submitter_reciepesCount": 29.65625,
#             "avg_nutrition_calcium_amount": 62.2890743871,
#             "avg_nutrition_potassium_amount": 531.993096871,
#             "avg_submitter_madeRecipesCount": 13.9375,
#             "avg_nutrition_folate_amount": 70.0859001065,
#             "avg_prepMinutes": 18.75,
#             "avg_nutrition_protein_amount": 22.1782591484,
#             "avg_similarRecipes_metaData_pagesize": 12.96875,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "nbRecipes": 32,
#             "avg_nutrition_sodium_amount": 749.2729496129,
#             "avg_nutrition_vitaminC_amount": 35.0774190677,
#             "avg_ratingCount": 46.5,
#             "avg_submitter_favoritesCount": 108.8125,
#             "avg_nutrition_calories_amount": 387.1879393548,
#             "avg_nutrition_thiamin_amount": 0.2380116495,
#             "avg_ratingAverage": 3.532881485,
#             "avg_nutrition_sugars_amount": 9.6395901452,
#             "avg_nutrition_iron_amount": 3.6132297603,
#             "avg_submitter_followingCount": 0.0,
#             "avg_readyInMinutes": 108.59375
#         }
#     }
# }

# %% [markdown]
# # A Safety Check for the Data

# %% [markdown]
# Check that the number of calories (for instance) is roughly constant per serving, i.e. the values (e.g. calories) do not need to be divided by the number of servings.

# %%
res = group_and_get_aggregate_of_field(
        collection, 
        group_by_field_address='$servings', 
        aggregate_field_address = '$nutrition.calories.amount', 
        group_by_field_output_name = 'servings', 
        aggregate_field_output_name = 'calories', 
        aggregationFunction = '$addToSet' 
)
res = pd.DataFrame.from_dict(res)
res['averageCalories'] = res['calories'].map(lambda x: np.mean(x))

res.head(3)
# Out:
# /home/maximilian/anaconda3/lib/python3.5/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
#      calories  nbRecipes  servings  averageCalories
# 0  [130.5006]          1        39        130.50060
# 1  [182.1069]          1        26        182.10690
# 2  [60.56655]          1        44         60.56655

# %%
# See how many servings are less than 20.
res[res['servings'] < 20]
# Out:
#                                              calories  nbRecipes  servings  \
# 27  [30.7259, 117.7393, 409.1838, 1076.825, 165.77...         66        14
# 28  [7.663048, 114.8627, 152.9864, 96.72525, 73.0,...        752        10
# 33  [378.8421, 666.5646, 610.725, 439.9805, 472.83...        599         2
# 35  [87.89926, 58.68952, 574.4297, 10.7974, 11.35,...        501        16
# 36  [845.1532, 321.1483, 805.8989, 47.271, 381.285...        306         1
# 38  [424.8909, 397.6094, 199.6972, 217.3545, 466.8...         99         7
# 40  [120.9205, 92.85124, 152.5559, 376.8631, 280.1...        170        18
# 42  [314.1674, 290.44, 19.44138, 33.27737, 524.404...       2919         8
# 43  [469.1374, 317.9422, 582.0063, 67.08359, 414.7...       3128         6
# 45  [253.275, 24.12324, 131.3087, 227.8033, 308.63...       1526        12
# 47  [716.6111, 484.9653, 526.5847, 82.27547, 198.8...       3646         4
# 49  [481.9153, 277.8476, 202.239, 722.0485, 337.65...        169        15
# 51  [426.7951, 352.1058, 448.8103, 278.8677, 30.08...        164         3
# 55  [346.9427, 797.5046, 490.7751, 297.3842, 599.2...        335         5
# 56  [285.3711, 195.6704, 204.3525, 547.737, 226.94...        102         9
# 59  [315.4269, 217.5262, 66.03377, 317.5177, 177.0...          5        13
# 67  [385.3093, 465.1614, 483.5129, 192.3791, 849.2...         21        11
# 72                               [372.5897, 493.2743]          2        17
#
#     averageCalories
# 27       287.960521
# 28       327.745643
# 33       494.605193
# 35       238.532929
# 36       392.117609
# 38       386.462684
# 40       256.450726
# 42       356.316380
# 43       388.387100
# 45       298.971966
# 47       419.950414
# 49       265.296943
# 51       411.312202
# 55       432.738707
# 56       384.274449
# 59       218.702194
# 67       364.763819
# 72       432.932000

# %% [markdown]
# We observe there exist recipes for 240 servings !

# %%
anotherRecipe = collection.find_one({'servings':240})
anotherRecipe
# Out:
# {'_id': ObjectId('5825c738b779830612cba06d'),
#  'adUnit': {'adKeys': [2,
#    59,
#    64,
#    106,
#    109,
#    125,
#    135,
#    139,
#    148,
#    173,
#    184,
#    201,
#    203,
#    221,
#    228,
#    241,
#    244,
#    264,
#    265,
#    268,
#    586,
#    639,
#    680],
#   'adZone': 'recipe',
#   'networkCode': '3865',
#   'site': 'ar.ios.apps.allrecipes.recipes'},
#  'ada-city': [],
#  'ada-continent': [],
#  'ada-country': ['us-recipes', 'australian-and-new-zealander'],
#  'ada-region': ['hawaii'],
#  'ada-subcontinent': ['north-american'],
#  'ada-tags': ['us-recipes',
#   'us-recipes-by-state',
#   'hawaii',
#   'world-cuisine',
#   'australian-and-new-zealander'],
#  'cookMinutes': 90,
#  'description': 'A Hawaiian chutney, excellent with pork or lamb. Also a treat with peanut butter on bread. Note: Common mangos are small and sweet even when half-ripe, not juicy.',
#  'directions': [{'displayValue': 'In a large saucepan combine vinegar, white sugar, brown sugar, cinnamon, ground ginger, allspice, cloves, nutmeg, chile peppers and salt. Bring to a boil; boil for 1/2 hour.',
#    'ordinal': 1,
#    'videoTimestamp': 0},
#   {'displayValue': 'Stir in onions, garlic, golden raisins, raisins and ginger and boil for another 1/2 hour.',
#    'ordinal': 2,
#    'videoTimestamp': 0},
#   {'displayValue': 'Stir in mangos (and almonds if using), reduce heat to low and simmer for 1/2 hour. Pour mixture into sterilized jars, to 1/2 inch below lid level, and seal.',
#    'ordinal': 3,
#    'videoTimestamp': 0}],
#  'footnotes': [],
#  'ingredients': [{'displayType': 'Normal',
#    'displayValue': '3 cups distilled white vinegar',
#    'grams': 720.0,
#    'ingredientID': 7842},
#   {'displayType': 'Normal',
#    'displayValue': '6 cups white sugar',
#    'grams': 1200.0,
#    'ingredientID': 1526},
#   {'displayType': 'Normal',
#    'displayValue': '6 cups brown sugar',
#    'grams': 870.0,
#    'ingredientID': 1525},
#   {'displayType': 'Normal',
#    'displayValue': '1 teaspoon ground cinnamon',
#    'grams': 2.3,
#    'ingredientID': 16386},
#   {'displayType': 'Normal',
#    'displayValue': '2 teaspoons ground ginger',
#    'grams': 3.6,
#    'ingredientID': 16397},
#   {'displayType': 'Normal',
#    'displayValue': '4 teaspoons ground allspice',
#    'grams': 7.6,
#    'ingredientID': 16377},
#   {'displayType': 'Normal',
#    'displayValue': '1 teaspoon ground cloves',
#    'grams': 2.1,
#    'ingredientID': 16387},
#   {'displayType': 'Normal',
#    'displayValue': '2 teaspoons ground nutmeg',
#    'grams': 6.0,
#    'ingredientID': 16401},
#   {'displayType': 'Normal',
#    'displayValue': '5 small red hot chile peppers, seeded and chopped',
#    'grams': 225.0,
#    'ingredientID': 4784},
#   {'displayType': 'Normal',
#    'displayValue': '1 teaspoon kosher salt',
#    'grams': 4.8,
#    'ingredientID': 18866},
#   {'displayType': 'Normal',
#    'displayValue': '2 large onions, chopped',
#    'grams': 300.0,
#    'ingredientID': 4397},
#   {'displayType': 'Normal',
#    'displayValue': '3 cloves garlic, chopped',
#    'grams': 9.0,
#    'ingredientID': 4342},
#   {'displayType': 'Normal',
#    'displayValue': '1 cup golden raisins',
#    'grams': 165.0,
#    'ingredientID': 5218},
#   {'displayType': 'Normal',
#    'displayValue': '1 cup raisins',
#    'grams': 165.0,
#    'ingredientID': 5219},
#   {'displayType': 'Normal',
#    'displayValue': '1/2 cup fresh ginger root, chopped',
#    'grams': 44.79984,
#    'ingredientID': 4343},
#   {'displayType': 'Normal',
#    'displayValue': '16 cups sliced, semi-ripe mangos',
#    'grams': 2640.0,
#    'ingredientID': 5121},
#   {'displayType': 'OptionalIngredient',
#    'displayValue': '1/2 cup sliced almonds (optional)',
#    'grams': 47.5,
#    'ingredientID': 3767}],
#  'isSponsored': False,
#  'links': {'recipeUrl': {'href': 'http://allrecipes.com/recipe/19842/mango-chutney/'},
#   'self': {'href': 'https://apps.allrecipes.com/v1/recipes/19842'}},
#  'nutrition': {'calcium': {'amount': 5.899712,
#    'displayValue': '6',
#    'hasCompleteData': False,
#    'name': 'Calcium',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'calories': {'amount': 45.91531,
#    'displayValue': '46',
#    'hasCompleteData': True,
#    'name': 'Calories',
#    'percentDailyValue': '2',
#    'unit': 'kcal'},
#   'caloriesFromFat': {'amount': 1.399966,
#    'displayValue': '1',
#    'hasCompleteData': True,
#    'name': 'Calories from Fat',
#    'percentDailyValue': '-',
#    'unit': 'kcal'},
#   'carbohydrates': {'amount': 11.55886,
#    'displayValue': '11.6',
#    'hasCompleteData': True,
#    'name': 'Carbohydrates',
#    'percentDailyValue': '4',
#    'unit': 'g'},
#   'cholesterol': {'amount': 0.0,
#    'displayValue': '0',
#    'hasCompleteData': True,
#    'name': 'Cholesterol',
#    'percentDailyValue': '0',
#    'unit': 'mg'},
#   'fat': {'amount': 0.1555518,
#    'displayValue': '0.2',
#    'hasCompleteData': True,
#    'name': 'Fat',
#    'percentDailyValue': '< 1',
#    'unit': 'g'},
#   'fiber': {'amount': 0.3050362,
#    'displayValue': '0.3',
#    'hasCompleteData': True,
#    'name': 'Dietary Fiber',
#    'percentDailyValue': '1',
#    'unit': 'g'},
#   'folate': {'amount': 2.113952,
#    'displayValue': '2',
#    'hasCompleteData': False,
#    'name': 'Folate',
#    'percentDailyValue': '1',
#    'unit': 'mcg'},
#   'iron': {'amount': 0.08332716,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Iron',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'magnesium': {'amount': 2.669516,
#    'displayValue': '3',
#    'hasCompleteData': False,
#    'name': 'Magnesium',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'niacin': {'amount': 0.1260433,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Niacin Equivalents',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'potassium': {'amount': 34.63036,
#    'displayValue': '35',
#    'hasCompleteData': False,
#    'name': 'Potassium',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'protein': {'amount': 0.169114,
#    'displayValue': '0.2',
#    'hasCompleteData': True,
#    'name': 'Protein',
#    'percentDailyValue': '< 1',
#    'unit': 'g'},
#   'saturatedFat': {'amount': 0.02518959,
#    'displayValue': '0',
#    'hasCompleteData': True,
#    'name': 'Saturated Fat',
#    'percentDailyValue': '< 1',
#    'unit': 'g'},
#   'sodium': {'amount': 12.50464,
#    'displayValue': '13',
#    'hasCompleteData': True,
#    'name': 'Sodium',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'sugars': {'amount': 10.27038,
#    'displayValue': '10.3',
#    'hasCompleteData': False,
#    'name': 'Sugars',
#    'percentDailyValue': '0',
#    'unit': 'g'},
#   'thiamin': {'amount': 0.008776487,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Thiamin',
#    'percentDailyValue': '< 1',
#    'unit': 'mg'},
#   'vitaminA': {'amount': 93.43557,
#    'displayValue': '93',
#    'hasCompleteData': False,
#    'name': 'Vitamin A - IU',
#    'percentDailyValue': '2',
#    'unit': 'IU'},
#   'vitaminB6': {'amount': 0.02533283,
#    'displayValue': '< 1',
#    'hasCompleteData': False,
#    'name': 'Vitamin B6',
#    'percentDailyValue': '2',
#    'unit': 'mg'},
#   'vitaminC': {'amount': 4.51665,
#    'displayValue': '5',
#    'hasCompleteData': False,
#    'name': 'Vitamin C',
#    'percentDailyValue': '8',
#    'unit': 'mg'}},
#  'photo': {'description': '',
#   'itemType': 'Photo',
#   'photoDetailUrl': 'http://m.allrecipes.com/photos/12507',
#   'photoID': 12507,
#   'rawItemType': 10,
#   'recipeTitle': None,
#   'title': '',
#   'urls': [{'height': 50,
#     'url': 'http://images.media-allrecipes.com/userphotos/50x50/12507.jpg',
#     'width': 50},
#    {'height': 110,
#     'url': 'http://images.media-allrecipes.com/userphotos/110x110/12507.jpg',
#     'width': 110},
#    {'height': 140,
#     'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/01/25/12507.jpg',
#     'width': 140},
#    {'height': 250,
#     'url': 'http://images.media-allrecipes.com/userphotos/250x250/12507.jpg',
#     'width': 250}]},
#  'prepMinutes': 10,
#  'ratingAverage': 4.364865,
#  'ratingCount': 74,
#  'readyInMinutes': 100,
#  'recipeID': 19842,
#  'reviewCount': 62,
#  'servings': 240,
#  'similarRecipes': {'links': {'self': {'href': 'https://apps.allrecipes.com/v1/recipes/19842'}},
#   'metaData': {'page': 1, 'pagesize': 20, 'totalCount': 20},
#   'recipes': [{'description': 'This chutney recipe comes direct from the Pakistani friend of an American living in an international community in Saudi Arabia. The zesty condiment combines green mangoes, garlic, ginger, cumin, cardamom, cinnamon, cloves, sugar and vinegar in a magical blend of spices to accompany meats, vegetables, and curries.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/150337'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/kokubs-mango-chutney-from-pakistan/'}},
#     'madeCount': 36,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/50104',
#      'photoID': 50104,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/50104.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/50104.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/05/01/50104.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/50104.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.74,
#     'ratingCount': 35,
#     'rawItemType': 1,
#     'recipeID': 150337,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 29,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 1204,
#      'followersCount': 127,
#      'followingCount': 58,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 49,
#      'name': 'PREGOCOOK',
#      'personalRecipeSharedCount': 44,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/2615883',
#       'photoID': 2615883,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/2615883.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/2615883.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/02/61/58/2615883.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/2615883.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/1155018/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 49,
#      'rawItemType': 11,
#      'reciepesCount': 8,
#      'region': None,
#      'reviewsCount': 49,
#      'userID': 1155018},
#     'title': "Kokub's Mango Chutney from Pakistan",
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'My mom makes this chutney during the summer to serve as a garnish for fish or steak. It is great as a gift too. Scrumptious!',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/165396'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/magues-green-mango-chutney/'}},
#     'madeCount': 2,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 2.0,
#     'ratingCount': 1,
#     'rawItemType': 1,
#     'recipeID': 165396,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 1,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 206,
#      'followersCount': 0,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 4,
#      'name': 'zuallemfahig',
#      'personalRecipeSharedCount': 1,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/2901379/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 4,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 4,
#      'userID': 2901379},
#     'title': "Mague's Green Mango Chutney",
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This refreshing mango chutney is quick and easy and perfect to top schnitzel.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/222329'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/refreshing-mango-chutney/'}},
#     'madeCount': 0,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 0.0,
#     'ratingCount': 0,
#     'rawItemType': 1,
#     'recipeID': 222329,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 0,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 40,
#      'followersCount': 0,
#      'followingCount': 3,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 4,
#      'name': 'Elliot Porter',
#      'personalRecipeSharedCount': 3,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/3849946',
#       'photoID': 3849946,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/3849946.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/3849946.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/03/84/99/3849946.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/3849946.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/1368661/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 4,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 4,
#      'userID': 1368661},
#     'title': 'Refreshing Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Make your own Indian-style mango chutney with dates and raisins. This recipe makes enough for freezing or canning.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/237069'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/real-indian-mango-chutney/'}},
#     'madeCount': 1,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 5.0,
#     'ratingCount': 1,
#     'rawItemType': 1,
#     'recipeID': 237069,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 0,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 166,
#      'followersCount': 6,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 60,
#      'name': 'Michelle Mackey',
#      'personalRecipeSharedCount': 2,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/1759291',
#       'photoID': 1759291,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/1759291.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/1759291.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/75/92/1759291.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/1759291.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/1950405/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 59,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 58,
#      'userID': 1950405},
#     'title': 'Real Indian Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This chutney with pears, mangos, dried cherries and lots of spice is a perfect addition to your holiday table.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/56219'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/roasted-pear-mango-chutney/'}},
#     'madeCount': 7,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 4.25,
#     'ratingCount': 4,
#     'rawItemType': 1,
#     'recipeID': 56219,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 4,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 1570,
#      'followersCount': 1,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 23,
#      'name': 'BASTET',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/87249',
#       'photoID': 87249,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/87249.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/87249.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/08/72/87249.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/87249.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/61705/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 23,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 14,
#      'userID': 61705},
#     'title': 'Roasted Pear Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This quick and easy mango chutney is ready in minutes after blending mango, habanero pepper, garlic, and lime juice together for a tasty accompaniment to many meals.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/222326'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/island-mango-chutney/'}},
#     'madeCount': 0,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 0.0,
#     'ratingCount': 0,
#     'rawItemType': 1,
#     'recipeID': 222326,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 0,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 1,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 5,
#      'name': 'KathyFL',
#      'personalRecipeSharedCount': 1,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/3731988/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 5,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 3,
#      'userID': 3731988},
#     'title': 'Island Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This sweet and spicy chutney combines pineapple, mango, cucumber, and jalapeno for a colorful topping for scallops or chicken.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/222324'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/pineapple-mango-chutney/'}},
#     'madeCount': 12,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/1128127',
#      'photoID': 1128127,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/1128127.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/1128127.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/12/81/1128127.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/1128127.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.5,
#     'ratingCount': 6,
#     'rawItemType': 1,
#     'recipeID': 222324,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 6,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 518,
#      'followersCount': 1,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 12,
#      'name': 'Yorkville_Mom',
#      'personalRecipeSharedCount': 3,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/643570',
#       'photoID': 643570,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/643570.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/643570.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/64/35/643570.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/643570.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/3739943/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 9,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 9,
#      'userID': 3739943},
#     'title': 'Pineapple Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Traditional naan dough is formed into bread twists and served with mango chutney made with lots of traditional spices and seasonings.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/239423'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/salted-naan-sticks-with-mango-chutney/'}},
#     'madeCount': 0,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/1474027',
#      'photoID': 1474027,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/1474027.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/1474027.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/47/40/1474027.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/1474027.jpg',
#        'width': 250}]},
#     'ratingAverage': 0.0,
#     'ratingCount': 0,
#     'rawItemType': 1,
#     'recipeID': 239423,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 0,
#     'sourceID': 482,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 30,
#      'followersCount': 1,
#      'followingCount': 0,
#      'handle': 'diamondcrystalsalt',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Diamond Crystal Salt',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/1381229',
#       'photoID': 1381229,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/1381229.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/1381229.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/38/12/1381229.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/1381229.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/diamondcrystalsalt/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 30,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 20505315},
#     'title': 'Salted Naan Sticks with Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Chicken salad with an Indian-inspired twist of mango chutney and curry powder is quick and easy to prepare. Dried cranberries, raisins, or pineapple chunks can also be added.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/222328'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/chicken-salad-with-mango-chutney/'}},
#     'madeCount': 5,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/963770',
#      'photoID': 963770,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/963770.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/963770.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/96/37/963770.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/963770.jpg',
#        'width': 250}]},
#     'ratingAverage': 5.0,
#     'ratingCount': 5,
#     'rawItemType': 1,
#     'recipeID': 222328,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 4,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 10,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'simone stevin',
#      'personalRecipeSharedCount': 10,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/1835422/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 4,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 1835422},
#     'title': 'Chicken Salad with Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Mango chutney tops off this magnificent cheese ball with bacon, onion and golden raisins. Simple, simple recipe and the dish is emptied EVERY time!!',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/84389'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/mango-chutney-cheese-ball/'}},
#     'madeCount': 58,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/240116',
#      'photoID': 240116,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/240116.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/240116.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/24/01/240116.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/240116.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.58,
#     'ratingCount': 64,
#     'rawItemType': 1,
#     'recipeID': 84389,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 54,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 1,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 2,
#      'name': 'PHROGGI19',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/1385861/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 2,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 2,
#      'userID': 1385861},
#     'title': 'Mango Chutney Cheese Ball',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'The sweetness of mango, pineapple and red pepper is given a zing from fresh ginger and a kick from hot chile pepper. Serve this chutney with grilled chicken or seafood for an exciting burst of flavor!',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/166016'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/mango-pineapple-chutney/'}},
#     'madeCount': 31,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/230419',
#      'photoID': 230419,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/230419.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/230419.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/23/04/230419.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/230419.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.68,
#     'ratingCount': 31,
#     'rawItemType': 1,
#     'recipeID': 166016,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 23,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 243,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 38,
#      'name': 'MATHTUTORRITA',
#      'personalRecipeSharedCount': 2,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/1444417/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 38,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 17,
#      'userID': 1444417},
#     'title': 'Mango-Pineapple Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This chutney recipe comes direct from the Pakistani friend of an American living in an international community in Saudi Arabia. The zesty condiment combines green mangoes, garlic, ginger, cumin, cardamom, cinnamon, cloves, sugar and vinegar in a magical blend of spices to accompany meats, vegetables, and curries.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/150337'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/kokubs-mango-chutney-from-pakistan/'}},
#     'madeCount': 36,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/50104',
#      'photoID': 50104,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/50104.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/50104.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/05/01/50104.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/50104.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.74,
#     'ratingCount': 35,
#     'rawItemType': 1,
#     'recipeID': 150337,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 29,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 1204,
#      'followersCount': 127,
#      'followingCount': 58,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 49,
#      'name': 'PREGOCOOK',
#      'personalRecipeSharedCount': 44,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/2615883',
#       'photoID': 2615883,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/2615883.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/2615883.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/02/61/58/2615883.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/2615883.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/1155018/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 49,
#      'rawItemType': 11,
#      'reciepesCount': 8,
#      'region': None,
#      'reviewsCount': 49,
#      'userID': 1155018},
#     'title': "Kokub's Mango Chutney from Pakistan",
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This sweet and spicy chutney combines pineapple, mango, cucumber, and jalapeno for a colorful topping for scallops or chicken.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/222324'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/pineapple-mango-chutney/'}},
#     'madeCount': 12,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/1128127',
#      'photoID': 1128127,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/1128127.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/1128127.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/12/81/1128127.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/1128127.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.5,
#     'ratingCount': 6,
#     'rawItemType': 1,
#     'recipeID': 222324,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 6,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 518,
#      'followersCount': 1,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 12,
#      'name': 'Yorkville_Mom',
#      'personalRecipeSharedCount': 3,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/643570',
#       'photoID': 643570,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/643570.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/643570.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/64/35/643570.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/643570.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/3739943/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 9,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 9,
#      'userID': 3739943},
#     'title': 'Pineapple Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'Make your own Indian-style mango chutney with dates and raisins. This recipe makes enough for freezing or canning.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/237069'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/real-indian-mango-chutney/'}},
#     'madeCount': 1,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/recipes/nophoto/nopicture-250x250.png',
#        'width': 250}]},
#     'ratingAverage': 5.0,
#     'ratingCount': 1,
#     'rawItemType': 1,
#     'recipeID': 237069,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 0,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 166,
#      'followersCount': 6,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 60,
#      'name': 'Michelle Mackey',
#      'personalRecipeSharedCount': 2,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/1759291',
#       'photoID': 1759291,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/1759291.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/1759291.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/75/92/1759291.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/1759291.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/1950405/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 59,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 58,
#      'userID': 1950405},
#     'title': 'Real Indian Mango Chutney',
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This easy chutney is a great companion for so many dishes from turkey sandwiches to pork chops.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/70037'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/apple-chutney/'}},
#     'madeCount': 47,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/318537',
#      'photoID': 318537,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/318537.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/318537.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/31/85/318537.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/318537.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.49,
#     'ratingCount': 45,
#     'rawItemType': 1,
#     'recipeID': 70037,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 38,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 3,
#      'followersCount': 3,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 3,
#      'name': 'CATSEO',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
# ...
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/161436'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/omas-rhubarb-cake/'}},
#     'madeCount': 483,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/1017615',
#      'photoID': 1017615,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/1017615.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/1017615.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/01/76/1017615.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/1017615.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.77,
#     'ratingCount': 320,
#     'rawItemType': 1,
#     'recipeID': 161436,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 259,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 229,
#      'followersCount': 10,
#      'followingCount': 1,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 17,
#      'name': 'Alea',
#      'personalRecipeSharedCount': 7,
#      'photo': {'description': '',
#       'itemType': 'Photo',
#       'photoDetailUrl': 'http://m.allrecipes.com/photos/861466',
#       'photoID': 861466,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': '',
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/userphotos/50x50/861466.jpg',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/userphotos/110x110/861466.jpg',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/86/14/861466.jpg',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/userphotos/250x250/861466.jpg',
#         'width': 250}]},
#      'profileUrl': '/cook/2808356/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 17,
#      'rawItemType': 11,
#      'reciepesCount': 2,
#      'region': None,
#      'reviewsCount': 15,
#      'userID': 2808356},
#     'title': "Oma's Rhubarb Cake",
#     'type': 'recipes',
#     'videoID': 0},
#    {'description': 'This is a moist fudgy type cake. Sweet but not extremely sweet and makes good use of zucchini! You can frost it with chocolate frosting or cream cheese icing.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/17643'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/chocolate-zucchini-cake-iii/'}},
#     'madeCount': 954,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/969089',
#      'photoID': 969089,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/969089.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/969089.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/96/90/969089.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/969089.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.71,
#     'ratingCount': 683,
#     'rawItemType': 1,
#     'recipeID': 17643,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 569,
#     'sourceID': 461,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 0,
#      'followingCount': 0,
#      'handle': None,
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'Sandy',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 0,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 0},
#     'title': 'Chocolate Zucchini Cake III',
#     'type': 'recipes',
#     'videoID': 2981},
#    {'description': 'These crispy shrimp are rolled in a coconut beer batter before frying. For dipping sauce, I use orange marmalade, mustard and horseradish mixed to taste.',
#     'isSponsored': False,
#     'itemType': 'Recipe',
#     'links': {'parent': {'href': 'https://apps.allrecipes.com/v1/recipes/17753'},
#      'recipeUrl': {'href': 'http://allrecipes.com/recipe/coconut-shrimp-i/'}},
#     'madeCount': 1592,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/693130',
#      'photoID': 693130,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/693130.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/693130.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/00/69/31/693130.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/693130.jpg',
#        'width': 250}]},
#     'ratingAverage': 4.79,
#     'ratingCount': 1819,
#     'rawItemType': 1,
#     'recipeID': 17753,
#     'recipeTrackingPixelUrl': None,
#     'reviewCount': 1354,
#     'sourceID': 0,
#     'submitter': {'brandedSourceID': 0,
#      'city': None,
#      'country': None,
#      'favoritesCount': 0,
#      'followersCount': 4,
#      'followingCount': 0,
#      'handle': '',
#      'isPro': False,
#      'itemType': 'Cook',
#      'madeRecipesCount': 0,
#      'name': 'LINDAV10',
#      'personalRecipeSharedCount': 0,
#      'photo': {'description': None,
#       'itemType': 'Photo',
#       'photoDetailUrl': None,
#       'rawItemType': 10,
#       'recipeTitle': None,
#       'title': None,
#       'urls': [{'height': 50,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#         'width': 50},
#        {'height': 110,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#         'width': 110},
#        {'height': 140,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#         'width': 140},
#        {'height': 250,
#         'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#         'width': 250}]},
#      'profileUrl': '/cook/338308/',
#      'promotedBrandPixelTrackingUrl': None,
#      'ratingsCount': 0,
#      'rawItemType': 11,
#      'reciepesCount': 1,
#      'region': None,
#      'reviewsCount': 0,
#      'userID': 338308},
#     'title': 'Coconut Shrimp I',
#     'type': 'recipes',
#     'videoID': 1126}]},
#  'sourceID': 0,
#  'submitter': {'brandedSourceID': 0,
#   'city': None,
#   'country': None,
#   'favoritesCount': 0,
#   'followersCount': 0,
#   'followingCount': 0,
#   'handle': None,
#   'isPro': False,
#   'itemType': 'Cook',
#   'madeRecipesCount': 0,
#   'name': 'Shirley Crowley',
#   'personalRecipeSharedCount': 0,
#   'photo': {'description': None,
#    'itemType': 'Photo',
#    'photoDetailUrl': None,
#    'rawItemType': 10,
#    'recipeTitle': None,
#    'title': None,
#    'urls': [{'height': 50,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#      'width': 50},
#     {'height': 110,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#      'width': 110},
#     {'height': 140,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#      'width': 140},
#     {'height': 250,
#      'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#      'width': 250}]},
#   'profileUrl': '',
#   'promotedBrandPixelTrackingUrl': None,
#   'ratingsCount': 0,
#   'rawItemType': 11,
#   'reciepesCount': 0,
#   'region': None,
#   'reviewsCount': 0,
#   'userID': 0},
#  'title': 'Mango Chutney',
#  'topReviews': [{'dateLastModified': '2007-02-02T20:32:25.88',
#    'helpfulCount': 138,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/19842/reviews/907416/increment-helpful-count'}},
#    'rating': 4,
#    'rawItemType': 9,
#    'reviewID': 907416,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 2,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': False,
#     'itemType': 'Cook',
#     'madeRecipesCount': 1,
#     'name': 'KIRCHY7',
#     'personalRecipeSharedCount': 0,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#        'width': 250}]},
#     'profileUrl': '/cook/2189581/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 1,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 1,
#     'userID': 2189581},
#    'text': 'If you prefer a thicker, more fruit preserve-like consistency for your chutney, you can modify the cooking method on this excellent recipe and its blend of flavors as I did: Using the 30 serving size recipe, use all ingredients as measured, except: Adjust sugar to 1/2 cup each white and brown, add 1 TBSP butter to your ingredient list, and try 2 TBSPs each white vinegar and lemon juice (vs. 1/4 cup vinegar).  For the cooking method: Set saucepan on medium heat (I used a 2.5 quart Le Creuset saucepan, which heats more evenly than any pan I have used, so medium high will be too high). Melt butter, and add dry spices, stirring with a silicone spatula or spoon, 2 mins. til fragrant.  Add all other ingredients (except nuts; you will add them at the end).  Stir gently until combined. It will take appr. 10 mins. for the mixture to come to a simmer.  Once the simmer has begun, set timer for 60 minutes, and cook, maintaining a gentle but consistent simmer (in my saucepan there were 10 pockets of nickel - size bubble groups across the top).  Stir gently with spatula every 5 mins. or so.  After 60 mins., turn off the heat and let cool in the saucepan.  The chutney will be reduced in volume, and will be the consistency of a fruit preserve.  Stir in 1/4 cup chopped slivered almonds or macadamia nuts.  Store in air tight container, refrigerate, and enjoy!  Great on Wasa crackers with cream cheese, or mixed with diced chicken for a salad!'},
#   {'dateLastModified': '2003-11-14T02:29:45.42',
#    'helpfulCount': 75,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/19842/reviews/194757/increment-helpful-count'}},
#    'rating': 3,
#    'rawItemType': 9,
#    'reviewID': 194757,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 145,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': False,
#     'itemType': 'Cook',
#     'madeRecipesCount': 13,
#     'name': 'CAROL POGIE',
#     'personalRecipeSharedCount': 2,
#     'photo': {'description': None,
#      'itemType': 'Photo',
#      'photoDetailUrl': None,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': None,
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-50x50.png',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-110x110.png',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-140x140.png',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/global/profile/nophoto/noprofile-250x250.png',
#        'width': 250}]},
#     'profileUrl': '/cook/449153/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 13,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 13,
#     'userID': 449153},
#    'text': 'I downsized this recipe to serve 30, you must also downsized cooking times as you can easily overcook. I love chutney with a pork roast, this one is good but not a favorite, I would cut out the allspice or just a pinch as it is a predominate taste in this chutney.'},
#   {'dateLastModified': '2003-11-14T02:29:34.61',
#    'helpfulCount': 42,
#    'itemType': 'Review',
#    'links': {'incrementHelpfulCount': {'href': 'https://apps.allrecipes.com/v1/recipes/19842/reviews/293315/increment-helpful-count'}},
#    'rating': 5,
#    'rawItemType': 9,
#    'reviewID': 293315,
#    'submitter': {'brandedSourceID': 0,
#     'city': None,
#     'country': None,
#     'favoritesCount': 141,
#     'followersCount': 0,
#     'followingCount': 0,
#     'handle': '',
#     'isPro': True,
#     'itemType': 'Cook',
#     'madeRecipesCount': 10,
#     'name': 'PATTRICIA',
#     'personalRecipeSharedCount': 0,
#     'photo': {'description': '',
#      'itemType': 'Photo',
#      'photoDetailUrl': 'http://m.allrecipes.com/photos/1113564',
#      'photoID': 1113564,
#      'rawItemType': 10,
#      'recipeTitle': None,
#      'title': '',
#      'urls': [{'height': 50,
#        'url': 'http://images.media-allrecipes.com/userphotos/50x50/1113564.jpg',
#        'width': 50},
#       {'height': 110,
#        'url': 'http://images.media-allrecipes.com/userphotos/110x110/1113564.jpg',
#        'width': 110},
#       {'height': 140,
#        'url': 'http://images.media-allrecipes.com/userphotos/140x140/01/11/35/1113564.jpg',
#        'width': 140},
#       {'height': 250,
#        'url': 'http://images.media-allrecipes.com/userphotos/250x250/1113564.jpg',
#        'width': 250}]},
#     'profileUrl': '/cook/551727/',
#     'promotedBrandPixelTrackingUrl': None,
#     'ratingsCount': 11,
#     'rawItemType': 11,
#     'reciepesCount': 0,
#     'region': None,
#     'reviewsCount': 11,
#     'userID': 551727},
#    'text': 'I am a chutney lover, and this is the best of all.  It is a wonderful chicken marinade.  \r\n\r\nMy favorite way of serving, is on top of cream cheese with triskets.\r\n\r\nI made this last summer, and gave away as Christmas gifts.  Everyone LOVED it!\r\n\r\nIt came out more juicy than I thought.  I thought it would thicken as it cooled.  Next time I would add more mango.'}],
#  'type': 'recipes',
#  'video': None}

# %% [markdown]
# ## Check that unit is the same for all same nutrients

# %% [markdown]
# There is a 'unit' field associated to each nutrient information, like 'mg', 'g', 'kg'. To avoid multiplying in mongodb, we check that they are the same across the whole database for each nutrient.

# %%
# Find all keys that have a unit information

all_keys_with_description = get_all_field_addresses_with_description(oneRecipe, shortenLongStrings=False)

key_addresses_with_unit = []
for key in all_keys_with_description:
    if key.endswith('.unit'):
        key_addresses_with_unit.append(key)

# %%
df_units = []
for keyName in key_addresses_with_unit:

    results = group_and_get_aggregate_of_field(
        collection, 
        group_by_field_address='get_global_aggregation', 
        aggregate_field_address=keyName,
        group_by_field_output_name='DummyName', 
        aggregate_field_output_name='units', 
        aggregationFunction = '$addToSet' 
    )
    
    #df_units = df_units.append(pd.DataFrame({'nutrition': make_column_name(keyName), 'observed units': results[0]['units']}))
    df_units.append({'nutrition': make_column_name(keyName), 'observed units': results[0]['units']})
    
df_units = pd.DataFrame(df_units, columns = ['nutrition' , 'observed units'])
    
df_units = df_units.reset_index()
df_units['nutrition'] = df_units['nutrition'].map(lambda elem: "avg_" + elem[:-5]) # to have the same keys as in the JSON
df_units = df_units.drop(axis=1, labels=['index'])
df_units
# Out:
#                         nutrition observed units
# 0          avg_nutrition_vitaminC           [mg]
# 1           avg_nutrition_calcium           [mg]
# 2            avg_nutrition_folate          [mcg]
# 3       avg_nutrition_cholesterol           [mg]
# 4          avg_nutrition_calories         [kcal]
# 5     avg_nutrition_carbohydrates            [g]
# 6            avg_nutrition_sodium           [mg]
# 7              avg_nutrition_iron           [mg]
# 8           avg_nutrition_thiamin           [mg]
# 9         avg_nutrition_vitaminB6           [mg]
# 10          avg_nutrition_protein            [g]
# 11            avg_nutrition_fiber            [g]
# 12        avg_nutrition_magnesium           [mg]
# 13           avg_nutrition_sugars            [g]
# 14              avg_nutrition_fat            [g]
# 15     avg_nutrition_saturatedFat            [g]
# 16           avg_nutrition_niacin           [mg]
# 17  avg_nutrition_caloriesFromFat         [kcal]
# 18        avg_nutrition_potassium           [mg]
# 19         avg_nutrition_vitaminA           [IU]

# %% [markdown]
# Hence we see that each ingredient is only given in a single unit in all recipes.

# %%
json_output_filename = '../website/data/nutritionAmountUnits.json'

os.makedirs(os.path.dirname(json_output_filename), exist_ok=True)
write_dataframes_to_json(json_output_filename, df_units)

# !cat '../website/data/nutritionAmountUnits.json'
# Out:
# {
#     "5": {
#         "nutrition": "avg_nutrition_carbohydrates",
#         "observed units": [
#             "g"
#         ]
#     },
#     "0": {
#         "nutrition": "avg_nutrition_vitaminC",
#         "observed units": [
#             "mg"
#         ]
#     },
#     "2": {
#         "nutrition": "avg_nutrition_folate",
#         "observed units": [
#             "mcg"
#         ]
#     },
#     "13": {
#         "nutrition": "avg_nutrition_sugars",
#         "observed units": [
#             "g"
#         ]
#     },
#     "19": {
#         "nutrition": "avg_nutrition_vitaminA",
#         "observed units": [
#             "IU"
#         ]
#     },
#     "6": {
#         "nutrition": "avg_nutrition_sodium",
#         "observed units": [
#             "mg"
#         ]
#     },
#     "11": {
#         "nutrition": "avg_nutrition_fiber",
#         "observed units": [
#             "g"
#         ]
#     },
#     "16": {
#         "nutrition": "avg_nutrition_niacin",
#         "observed units": [
#             "mg"
#         ]
#     },
#     "12": {
#         "nutrition": "avg_nutrition_magnesium",
#         "observed units": [
#             "mg"
#         ]
#     },
#     "3": {
#         "nutrition": "avg_nutrition_cholesterol",
#         "observed units": [
#             "mg"
#         ]
#     },
#     "9": {
#         "nutrition": "avg_nutrition_vitaminB6",
#         "observed units": [
#             "mg"
#         ]
#     },
#     "10": {
#         "nutrition": "avg_nutrition_protein",
#         "observed units": [
#             "g"
#         ]
#     },
#     "7": {
#         "nutrition": "avg_nutrition_iron",
#         "observed units": [
#             "mg"
#         ]
#     },
#     "8": {
#         "nutrition": "avg_nutrition_thiamin",
#         "observed units": [
#             "mg"
#         ]
#     },
#     "14": {
#         "nutrition": "avg_nutrition_fat",
#         "observed units": [
#             "g"
#         ]
#     },
#     "17": {
#         "nutrition": "avg_nutrition_caloriesFromFat",
#         "observed units": [
#             "kcal"
#         ]
#     },
#     "4": {
#         "nutrition": "avg_nutrition_calories",
#         "observed units": [
#             "kcal"
#         ]
#     },
#     "1": {
#         "nutrition": "avg_nutrition_calcium",
#         "observed units": [
#             "mg"
#         ]
#     },
#     "15": {
#         "nutrition": "avg_nutrition_saturatedFat",
#         "observed units": [
#             "g"
#         ]
#     },
#     "18": {
#         "nutrition": "avg_nutrition_potassium",
#         "observed units": [
#             "mg"
#         ]
#     }
# }

# %% [markdown]
# # Stubs

# %% [markdown]
# To be removed in the very end

# %%
# old: not currently used
def prettifyCities(cities):
    # cities is an array of arrays of cities
    # flattens this array
    return [city for citiesList in cities for city in citiesList]

# %%
def getAverageOfFieldPerRegion(fieldName, fieldAddress):
    # groups by continent, subcontinent, ... and computes the average
    # fieldName used in output, fieldAddress: path to access field in the collection

    results = collection.aggregate( [ 
            { '$group': 
                {
                    '_id': { 'continent': "$ada-continent", 'subcontinent': "$ada-subcontinent", 
                            'country': "$ada-country", 'region': '$ada-region', 'city': '$ada-city'},
                    # e.g. 'avgCalories': { '$avg': '$nutrition.calories.amount' },
                    fieldName: {'$avg': ('$' + fieldAddress)}, 
                    'nbRecipes': { "$sum": 1},
                }
            },
            { '$project': 
                {
                    '_id': 0,
                    # e.g. 'avgCalories': "$avgCalories",
                    fieldName: ("$" + fieldName),
                    'nbRecipes': "$nbRecipes",
                    'continent': "$_id.continent",
                    'subcontinent': "$_id.subcontinent",
                    'country': "$_id.country",
                    'region': "$_id.region",
                    'city': "$_id.city",
                }    
            }
        ]
    )
    
    return results

results = getAverageOfFieldPerRegion(fieldName='avgCalories', fieldAddress='nutrition.calories.amount')

# %%
#~ # group bys
#~ groupBysToQuery = [
    #~ {
        #~ # get global average
        #~ 'group_by_field_address': 'get_global_aggregation',
        #~ 'group_by_field_output_name': 'DummyColumn' # ignored,
    #~ },
    #~ {
        #~ 'group_by_field_address': '$ada-city',
        #~ 'group_by_field_output_name': 'city', # as it appears in dataframe
    #~ },
#~ ]

#~ # keep in sync with above groupBys
#~ dataframeNames = ['global', 'per_city']

#~ # what to aggregate for
#~ fieldArgumentsToQuery = [
    #~ {
        #~ 'aggregate_field_address': '$nutrition.calories.amount', 
        #~ 'aggregate_field_output_name': 'avg_calories', 
        #~ 'aggregationFunction': '$avg' 
    #~ },
    #~ {
        #~ 'aggregate_field_address': '$nutrition.vitaminA.amount', 
        #~ 'aggregate_field_output_name': 'total_vitaminA_Intake', 
        #~ 'aggregationFunction': '$sum' 
    #~ },
#~ ]



#~ for keyName, value in allKeysWithDescription.items():
    #~ if keyName == '_id':
        #~ continue
    
    #~ res = group_and_get_aggregate_of_field(collection, group_by_field_address='get_global_aggregation',
                                    #~ aggregate_field_address=keyName, 
                                    #~ group_by_field_output_name='outputField', 
                                    #~ aggregate_field_output_name=keyName, 
                                    #~ aggregationFunction = '$type' )
    
    #~ print(res)
    #~ break
    
    #~ #get_dataframe_per_groupby(collection, groupBysToQuery, fieldArgumentsToQuery, dataframeNames)

# %% [markdown]
# # What is below is not yet done

# %% [markdown]
# Need to add one entry per row when there are multiple countries.

# %%
import itertools


for i, document in enumerate(results):
    fieldnames = ['continent', 'subcontinent', 'country', 'region', 'city']
    fieldVals = []
    for field in fieldnames:
        fieldVals.append(document[field] or ['NA'])
    combinations = list(itertools.product(*fieldVals))
    localDf = pd.DataFrame.from_records(combinations, columns=fieldnames)
    pd.DataFrame.add(localDf, axis=document.keys())
    
    remainingFields = list(set(document.keys()) - set(fieldnames))
    
    localDf.fillna(value={key: document[key] for key in remainingFields})
    
    if i >= 0:
        break
        
list(combinations)
localDf

# %%
# if there occurs an error "NoCursorFound", rerun the above query or set the property 'noCursorTimeout'
#df = pd.DataFrame(columns={'continent', 'country', 'avgCalories', 'nbRecipes'})


allData = []
for i, document in enumerate(results):
    #print(document)
    #df = df.append(document, ignore_index=True)
    allData.append(document)
    #if i >= 3:
    #    break

#allData
df = pd.DataFrame.from_dict(allData)

applyDataTransf = False

if applyDataTransf:
    joinList = lambda myList: ", ".join(myList)
    df['country'] = df['country'].apply(joinList)
    df['continent'] = df['continent'].apply(joinList)
    df['subcontinent'] = df['subcontinent'].apply(joinList)
    df['region'] = df['region'].apply(joinList)
    df['city'] = df['city'].apply(joinList)
    
    
df.head(3)

# %%
for i, do

# %%
df['continent'].apply(len).value_counts()

df[df['continent'].apply(len) == 2]

# %%
df = df.set_index(['continent', 'subcontinent', 'country'])
df.head(3)

# %%
df.groupby(level=[0,1])[['nbRecipes']].sum()

# %%
# Find an element by ID
oneRecipe = collection.find_one({'recipeID':47564})
oneRecipe

# %%
#started from http://stackoverflow.com/a/23282291

from bson.code import Code

# only emit the key of the field, no values
mapper = Code("""
    function() {
    
        function isObject(val) {
            if (val === null) { return false;}
            return ( (typeof val === 'function') || (typeof val === 'object') );
        }
        function getSubkeys(obj) {
            var subKeys = [];
            for (subKey in obj) {
                if (isObject(obj[subKey])) {
                    subKeys.push(subKey);
                }
                
            }
            return subKeys;
        }
        for (var key in this) { 
            subkeys = getSubkeys(this[key])
            emit(key, subkeys); 
        }
    }
""")

# keep the key, do nothing
reducer = Code("""
    function(key, values) {
        //return values.toString() + "END";
        /*
        function onlyUnique(value, index, self) { 
            return self.indexOf(value) === index;
        }
        return values.filter( onlyUnique ).toString();
        */
        return Array.from(new Set(values)).toString();
        //return new Set(values);
        
        
    }
    
    
""")

distinctThingFields = collection.map_reduce(mapper, reducer, 
    out = {'inline' : 1}, query = {'recipeID': { '$in': [47564, 98310]} }, full_response = True) #
distinctThingFields

# %%
collection.aggregate( [ 
        { 
            '$project': {
                '_id': 0
            }
        }
    ]
)

# %%
oneRecipe['nutrition']['sugars']

# %%
distinctThingFields

# %%
distinctThingFields.ok == 1.0

# %% [markdown]
# Resources:
# * [PyMongo Tutorial](https://api.mongodb.com/python/current/tutorial.html)
# * [Mongo Documentation](https://docs.mongodb.com/ecosystem/drivers/python/)
