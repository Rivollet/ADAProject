# %%
# %load_ext autoreload
# %autoreload 2

from pymongo import MongoClient
import datetime
import numpy as np
import pandas as pd
import getpass
from utility_functions import *

# %%
mapping_from_database_names_to_geojson_ids_filename = '../website/data/database_names_to_geojson_ids.json'
name_to_geojson_content = load_JSON(mapping_from_database_names_to_geojson_ids_filename)

database_aggregated_values_filename = '../website/data/aggregatedData.json'
database_aggregated_content = load_JSON(database_aggregated_values_filename)

# %%
name_to_geojson_content
# Out:
# {'city': {'atlanta': {'display_name': 'Atlanta', 'geo_identifier': 'Atlanta'},
#   'baltimore': {'display_name': 'Baltimore', 'geo_identifier': 'Baltimore'},
#   'boston': {'display_name': 'Boston', 'geo_identifier': 'Boston'},
#   'buffalo': {'display_name': 'Buffalo', 'geo_identifier': 'Buffalo'},
#   'california': {'display_name': 'California (Riverside)',
#    'geo_identifier': 'Riverside'},
#   'chicago': {'display_name': 'Chicago', 'geo_identifier': 'Chicago'},
#   'cincinnati': {'display_name': 'Cincinnati', 'geo_identifier': 'Cincinnati'},
#   'cleveland': {'display_name': 'Cleveland', 'geo_identifier': 'Cleveland'},
#   'dallas': {'display_name': 'Dallas', 'geo_identifier': 'Dallas'},
#   'detroit': {'display_name': 'Detroit', 'geo_identifier': 'Detroit'},
#   'georgia': {'display_name': 'Atlanta', 'geo_identifier': 'Atlanta'},
#   'green-bay': {'display_name': 'Green Bay', 'geo_identifier': 'Milwaukee'},
#   'houston': {'display_name': 'Houston', 'geo_identifier': 'Houston'},
#   'indianapolis': {'display_name': 'Indianapolis',
#    'geo_identifier': 'Indianapolis'},
#   'kansas-city': {'display_name': 'Kansas City',
#    'geo_identifier': 'Kansas City'},
#   'los-angeles': {'display_name': 'Los Angeles',
#    'geo_identifier': 'Los Angeles'},
#   'miami': {'display_name': 'Miami', 'geo_identifier': 'Miami'},
#   'milwaukee': {'display_name': 'Milwaukee', 'geo_identifier': 'Milwaukee'},
#   'minneapolis': {'display_name': 'Minneapolis',
#    'geo_identifier': 'Minneapolis'},
#   'new-orleans': {'display_name': 'New Orleans',
#    'geo_identifier': 'New Orleans'},
#   'new-york': {'display_name': 'New York City',
#    'geo_identifier': 'New York City'},
#   'new-york-city': {'display_name': 'New York City',
#    'geo_identifier': 'New York City'},
#   'oakland': {'display_name': 'Oakland', 'geo_identifier': 'San Francisco'},
#   'philadelphia': {'display_name': 'Philadelphia',
#    'geo_identifier': 'Philadelphia'},
#   'pittsburgh': {'display_name': 'Pittsburgh', 'geo_identifier': 'Pittsburgh'},
#   'san-diego': {'display_name': 'San Diego', 'geo_identifier': 'San Diego'},
#   'san-francisco': {'display_name': 'San Francisco',
#    'geo_identifier': 'San Francisco'},
#   'seattle': {'display_name': 'Seattle', 'geo_identifier': 'Seattle'},
#   'st-louis': {'display_name': 'St. Louis', 'geo_identifier': 'St. Louis'},
#   'tampa-bay': {'display_name': 'Tampa Bay', 'geo_identifier': 'Tampa'},
#   'toronto': {'display_name': 'Toronto', 'geo_identifier': 'Toronto'},
#   'vancouver': {'display_name': 'Vancouver', 'geo_identifier': 'Vancouver'},
#   'washington-dc': {'display_name': 'Washington',
#    'geo_identifier': 'Washington'}},
#  'country': {'argentinian': {'display_name': 'Argentina',
#    'geo_identifier': 'ARG'},
#   'australian-and-new-zealander': {'display_name': 'New Zealand',
#    'geo_identifier': 'NZL'},
#   'austrian': {'display_name': 'Austria', 'geo_identifier': 'AUT'},
#   'bangladeshi': {'display_name': 'Bangladesh', 'geo_identifier': 'BGD'},
#   'belgian': {'display_name': 'Belgium', 'geo_identifier': 'BEL'},
#   'brazilian': {'display_name': 'Brazil', 'geo_identifier': 'BRA'},
#   'canadian': {'display_name': 'Canada', 'geo_identifier': 'CAN'},
#   'chilean': {'display_name': 'Chile', 'geo_identifier': 'CHL'},
#   'chili': {'display_name': 'Chile', 'geo_identifier': 'CHL'},
#   'chinese': {'display_name': 'China', 'geo_identifier': 'CHN'},
#   'colombian': {'display_name': 'Colombia', 'geo_identifier': 'COL'},
#   'cuban': {'display_name': 'Cuba', 'geo_identifier': 'CUB'},
#   'czech': {'display_name': 'Czech Republic', 'geo_identifier': 'CZE'},
#   'danish': {'display_name': 'Denmark', 'geo_identifier': 'GRL'},
#   'dutch': {'display_name': 'Netherlands', 'geo_identifier': 'NLD'},
#   'egyptian': {'display_name': 'Egypt', 'geo_identifier': 'EGY'},
#   'english': {'display_name': 'United Kingdom', 'geo_identifier': 'GBR'},
#   'filipino': {'display_name': 'Philippines', 'geo_identifier': 'PHL'},
#   'finnish': {'display_name': 'Finland', 'geo_identifier': 'FIN'},
#   'french': {'display_name': 'France', 'geo_identifier': 'FRA'},
#   'german': {'display_name': 'Germany', 'geo_identifier': 'DEU'},
#   'greek': {'display_name': 'Greece', 'geo_identifier': 'GRC'},
#   'hungarian': {'display_name': 'Hungary', 'geo_identifier': 'HUN'},
#   'indian': {'display_name': 'India', 'geo_identifier': 'IND'},
#   'indonesian': {'display_name': 'Indonesia', 'geo_identifier': 'IDN'},
#   'irish': {'display_name': 'Ireland', 'geo_identifier': 'IRL'},
#   'israeli': {'display_name': 'Israel', 'geo_identifier': 'ISR'},
#   'italian': {'display_name': 'Italy', 'geo_identifier': 'ITA'},
#   'jamaican': {'display_name': 'Jamaica', 'geo_identifier': 'JAM'},
#   'japanese': {'display_name': 'Japan', 'geo_identifier': 'JPN'},
#   'korean': {'display_name': 'South Korea', 'geo_identifier': 'KOR'},
#   'lebanese': {'display_name': 'Lebanon', 'geo_identifier': 'LBN'},
#   'malaysian': {'display_name': 'Malaysia', 'geo_identifier': 'MYS'},
#   'mexican': {'display_name': 'Mexico', 'geo_identifier': 'MEX'},
#   'moroccan': {'display_name': 'Morocco', 'geo_identifier': 'MAR'},
#   'norwegian': {'display_name': 'Norway', 'geo_identifier': 'NOR'},
#   'pakistani': {'display_name': 'Pakistan', 'geo_identifier': 'PAK'},
#   'peruvian': {'display_name': 'Peru', 'geo_identifier': 'PER'},
#   'polish': {'display_name': 'Poland', 'geo_identifier': 'POL'},
#   'portuguese': {'display_name': 'Portugal', 'geo_identifier': 'PRT'},
#   'puerto-rican': {'display_name': 'Puerto Rico', 'geo_identifier': 'DOM'},
#   'russian': {'display_name': 'Russia', 'geo_identifier': 'RUS'},
#   'scottish': {'display_name': 'Scotland', 'geo_identifier': 'GBR'},
#   'south-african': {'display_name': 'South Africa', 'geo_identifier': 'ZAF'},
#   'spanish': {'display_name': 'Spain', 'geo_identifier': 'ESP'},
#   'swedish': {'display_name': 'Sweden', 'geo_identifier': 'SWE'},
#   'swiss': {'display_name': 'Switzerland', 'geo_identifier': 'CHE'},
#   'thai': {'display_name': 'Thailand', 'geo_identifier': 'THA'},
#   'turkey': {'display_name': 'Turkey', 'geo_identifier': 'TUR'},
#   'turkish': {'display_name': 'Turkey', 'geo_identifier': 'TUR'},
#   'us-recipes': {'display_name': 'United States of America',
#    'geo_identifier': 'USA'},
#   'vietnamese': {'display_name': 'Vietnam', 'geo_identifier': 'VNM'},
#   'welsh': {'display_name': 'Wales', 'geo_identifier': 'GBR'}},
#  'region': {'alabama': {'display_name': 'Alabama', 'geo_identifier': '01'},
#   'alaska': {'display_name': 'Alaska', 'geo_identifier': '02'},
#   'arizona': {'display_name': 'Arizona', 'geo_identifier': '04'},
#   'arkansas': {'display_name': 'Arkansas', 'geo_identifier': '05'},
#   'colorado': {'display_name': 'Colorado', 'geo_identifier': '08'},
#   'connecticut': {'display_name': 'Connecticut', 'geo_identifier': '09'},
#   'delaware': {'display_name': 'Delaware', 'geo_identifier': '10'},
#   'florida': {'display_name': 'Florida', 'geo_identifier': '12'},
#   'hawaii': {'display_name': 'Hawaii', 'geo_identifier': '15'},
#   'idaho': {'display_name': 'Idaho', 'geo_identifier': '16'},
#   'illinois': {'display_name': 'Illinois', 'geo_identifier': '17'},
#   'indiana': {'display_name': 'Indiana', 'geo_identifier': '18'},
#   'iowa': {'display_name': 'Iowa', 'geo_identifier': '19'},
#   'kansas': {'display_name': 'Kansas', 'geo_identifier': '20'},
#   'kentucky': {'display_name': 'Kentucky', 'geo_identifier': '21'},
#   'louisiana': {'display_name': 'Louisiana', 'geo_identifier': '22'},
#   'maine': {'display_name': 'Maine', 'geo_identifier': '23'},
#   'maryland': {'display_name': 'Maryland', 'geo_identifier': '24'},
#   'massachusetts': {'display_name': 'Massachusetts', 'geo_identifier': '25'},
#   'michigan': {'display_name': 'Michigan', 'geo_identifier': '26'},
#   'minnesota': {'display_name': 'Minnesota', 'geo_identifier': '27'},
#   'mississippi': {'display_name': 'Mississippi', 'geo_identifier': '28'},
#   'missouri': {'display_name': 'Missouri', 'geo_identifier': '29'},
#   'montana': {'display_name': 'Montana', 'geo_identifier': '30'},
#   'nebraska': {'display_name': 'Nebraska', 'geo_identifier': '31'},
#   'nevada': {'display_name': 'Nevada', 'geo_identifier': '32'},
#   'new-hampshire': {'display_name': 'New Hampshire', 'geo_identifier': '33'},
#   'new-jersey': {'display_name': 'New Jersey', 'geo_identifier': '34'},
#   'new-mexico': {'display_name': 'New Mexico', 'geo_identifier': '35'},
#   'new-york': {'display_name': 'New York', 'geo_identifier': '36'},
#   'north-carolina': {'display_name': 'North Carolina', 'geo_identifier': '37'},
#   'north-dakota': {'display_name': 'North Dakota', 'geo_identifier': '38'},
#   'ohio': {'display_name': 'Ohio', 'geo_identifier': '39'},
#   'oklahoma': {'display_name': 'Oklahoma', 'geo_identifier': '40'},
#   'oregon': {'display_name': 'Oregon', 'geo_identifier': '41'},
#   'pennsylvania': {'display_name': 'Pennsylvania', 'geo_identifier': '42'},
#   'quebec': {'display_name': 'quebec', 'geo_identifier': 'invalid'},
#   'rhode-island': {'display_name': 'Rhode Island', 'geo_identifier': '44'},
#   'south-carolina': {'display_name': 'South Carolina', 'geo_identifier': '45'},
#   'south-dakota': {'display_name': 'South Dakota', 'geo_identifier': '46'},
#   'tennessee': {'display_name': 'Tennessee', 'geo_identifier': '47'},
#   'texas': {'display_name': 'Texas', 'geo_identifier': '48'},
#   'utah': {'display_name': 'Utah', 'geo_identifier': '49'},
#   'vermont': {'display_name': 'Vermont', 'geo_identifier': '50'},
#   'virginia': {'display_name': 'Virginia', 'geo_identifier': '51'},
#   'washington': {'display_name': 'Washington', 'geo_identifier': '53'},
#   'west-virginia': {'display_name': 'West Virginia', 'geo_identifier': '54'},
#   'wisconsin': {'display_name': 'Wisconsin', 'geo_identifier': '55'},
#   'wyoming': {'display_name': 'Wyoming', 'geo_identifier': '56'}}}

# %%
database_aggregated_content
# Out:
# {'global': {'Global aggregation': {'avg_cookMinutes': 41.1077453516,
#    'avg_nutrition_calcium_amount': 114.9318745406,
#    'avg_nutrition_caloriesFromFat_amount': 160.0322171934,
#    'avg_nutrition_calories_amount': 350.2467986302,
#    'avg_nutrition_carbohydrates_amount': 31.5380632211,
#    'avg_nutrition_cholesterol_amount': 66.2203374766,
#    'avg_nutrition_fat_amount': 17.7817337376,
#    'avg_nutrition_fiber_amount': 3.1178096283,
#    'avg_nutrition_folate_amount': 60.2745651289,
#    'avg_nutrition_iron_amount': 2.6678069684,
#    'avg_nutrition_magnesium_amount': 42.7467841021,
#    'avg_nutrition_niacin_amount': 6.5819486949,
#    'avg_nutrition_potassium_amount': 434.1991336157,
#    'avg_nutrition_protein_amount': 16.2278095183,
#    'avg_nutrition_saturatedFat_amount': 6.5396016803,
#    'avg_nutrition_sodium_amount': 661.4516873115,
#    'avg_nutrition_sugars_amount': 9.8466210198,
#    'avg_nutrition_thiamin_amount': 0.2271286606,
#    'avg_nutrition_vitaminA_amount': 1418.1540015684,
#    'avg_nutrition_vitaminB6_amount': 0.3188769283,
#    'avg_nutrition_vitaminC_amount': 18.3412098224,
#    'avg_prepMinutes': 20.2409186061,
#    'avg_ratingAverage': 4.0803297995,
#    'avg_ratingCount': 102.3711981283,
#    'avg_readyInMinutes': 157.1372367935,
#    'avg_reviewCount': 77.7717029922,
#    'avg_servings': 10.2102573575,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.7297130895,
#    'avg_similarRecipes_metaData_totalCount': 14.7297130895,
#    'avg_submitter_favoritesCount': 151.0502401182,
#    'avg_submitter_followersCount': 7870.611685753,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 30.7689939663,
#    'avg_submitter_personalRecipeSharedCount': 8.0709272257,
#    'avg_submitter_ratingsCount': 29.7984238394,
#    'avg_submitter_reciepesCount': 22.6657431351,
#    'avg_submitter_reviewsCount': 23.1030045561,
#    'nbRecipes': 16242}},
#  'per_city': {'atlanta': {'avg_cookMinutes': 72.6785714286,
#    'avg_nutrition_calcium_amount': 102.0047476071,
#    'avg_nutrition_caloriesFromFat_amount': 214.0845010821,
#    'avg_nutrition_calories_amount': 424.3144992857,
#    'avg_nutrition_carbohydrates_amount': 39.3647434143,
#    'avg_nutrition_cholesterol_amount': 78.3939721071,
#    'avg_nutrition_fat_amount': 23.7871666814,
#    'avg_nutrition_fiber_amount': 3.0967039829,
#    'avg_nutrition_folate_amount': 48.5445705714,
#    'avg_nutrition_iron_amount': 2.1804457757,
#    'avg_nutrition_magnesium_amount': 44.0108625,
#    'avg_nutrition_niacin_amount': 6.04422843,
#    'avg_nutrition_potassium_amount': 440.0926471429,
#    'avg_nutrition_protein_amount': 14.9179720036,
#    'avg_nutrition_saturatedFat_amount': 7.8238756717,
#    'avg_nutrition_sodium_amount': 512.9678246429,
#    'avg_nutrition_sugars_amount': 20.341919475,
#    'avg_nutrition_thiamin_amount': 0.2052050258,
#    'avg_nutrition_vitaminA_amount': 3036.5497525,
#    'avg_nutrition_vitaminB6_amount': 0.2941749989,
#    'avg_nutrition_vitaminC_amount': 11.3826714225,
#    'avg_prepMinutes': 19.8214285714,
#    'avg_ratingAverage': 4.4145081739,
#    'avg_ratingCount': 167.6428571429,
#    'avg_readyInMinutes': 115.3571428571,
#    'avg_reviewCount': 132.3571428571,
#    'avg_servings': 19.6785714286,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.1785714286,
#    'avg_similarRecipes_metaData_totalCount': 15.1785714286,
#    'avg_submitter_favoritesCount': 114.1071428571,
#    'avg_submitter_followersCount': 2.4642857143,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 21.6785714286,
#    'avg_submitter_personalRecipeSharedCount': 4.0357142857,
#    'avg_submitter_ratingsCount': 21.6785714286,
#    'avg_submitter_reciepesCount': 1.5714285714,
#    'avg_submitter_reviewsCount': 20.8571428571,
#    'nbRecipes': 28},
#   'baltimore': {'avg_cookMinutes': 27.375,
#    'avg_nutrition_calcium_amount': 97.5182042744,
#    'avg_nutrition_caloriesFromFat_amount': 132.9319115974,
#    'avg_nutrition_calories_amount': 282.5841822308,
#    'avg_nutrition_carbohydrates_amount': 21.2793264667,
#    'avg_nutrition_cholesterol_amount': 77.6547251282,
#    'avg_nutrition_fat_amount': 14.7702118631,
#    'avg_nutrition_fiber_amount': 1.4585683298,
#    'avg_nutrition_folate_amount': 64.73690206,
#    'avg_nutrition_iron_amount': 2.0725230292,
#    'avg_nutrition_magnesium_amount': 47.9311626872,
#    'avg_nutrition_niacin_amount': 6.0732088472,
#    'avg_nutrition_potassium_amount': 366.0909587436,
#    'avg_nutrition_protein_amount': 15.2652843533,
#    'avg_nutrition_saturatedFat_amount': 5.40006226,
#    'avg_nutrition_sodium_amount': 922.6234240769,
#    'avg_nutrition_sugars_amount': 8.5506484808,
#    'avg_nutrition_thiamin_amount': 0.1763905158,
#    'avg_nutrition_vitaminA_amount': 717.1477726923,
#    'avg_nutrition_vitaminB6_amount': 0.2259791803,
#    'avg_nutrition_vitaminC_amount': 6.1599226656,
#    'avg_prepMinutes': 14.175,
#    'avg_ratingAverage': 4.119503283,
#    'avg_ratingCount': 98.975,
#    'avg_readyInMinutes': 340.175,
#    'avg_reviewCount': 80.375,
#    'avg_servings': 14.9,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 16.35,
#    'avg_similarRecipes_metaData_totalCount': 16.35,
#    'avg_submitter_favoritesCount': 79.25,
#    'avg_submitter_followersCount': 4.8,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 8.85,
#    'avg_submitter_personalRecipeSharedCount': 5.525,
#    'avg_submitter_ratingsCount': 8.8,
#    'avg_submitter_reciepesCount': 2.3,
#    'avg_submitter_reviewsCount': 7.4,
#    'nbRecipes': 40},
#   'boston': {'avg_cookMinutes': 126.25,
#    'avg_nutrition_calcium_amount': 96.3790575,
#    'avg_nutrition_caloriesFromFat_amount': 130.3512266667,
#    'avg_nutrition_calories_amount': 411.6663833333,
#    'avg_nutrition_carbohydrates_amount': 61.6097666667,
#    'avg_nutrition_cholesterol_amount': 60.9165060833,
#    'avg_nutrition_fat_amount': 14.48347025,
#    'avg_nutrition_fiber_amount': 3.7532331133,
#    'avg_nutrition_folate_amount': 69.1808425,
#    'avg_nutrition_iron_amount': 2.4268407383,
#    'avg_nutrition_magnesium_amount': 56.7193199167,
#    'avg_nutrition_niacin_amount': 4.3486284642,
#    'avg_nutrition_potassium_amount': 457.4909183333,
#    'avg_nutrition_protein_amount': 10.7414880592,
#    'avg_nutrition_saturatedFat_amount': 5.1985809667,
#    'avg_nutrition_sodium_amount': 493.0753570833,
#    'avg_nutrition_sugars_amount': 34.4743725,
#    'avg_nutrition_thiamin_amount': 0.240348669,
#    'avg_nutrition_vitaminA_amount': 230.68042075,
#    'avg_nutrition_vitaminB6_amount': 0.2608668275,
#    'avg_nutrition_vitaminC_amount': 4.8695579583,
#    'avg_prepMinutes': 26.25,
#    'avg_ratingAverage': 4.1276258017,
#    'avg_ratingCount': 153.3333333333,
#    'avg_readyInMinutes': 249.1666666667,
#    'avg_reviewCount': 123.25,
#    'avg_servings': 9.8333333333,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 16.5833333333,
#    'avg_similarRecipes_metaData_totalCount': 16.5833333333,
#    'avg_submitter_favoritesCount': 67.25,
#    'avg_submitter_followersCount': 3200.9166666667,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 36.0,
#    'avg_submitter_personalRecipeSharedCount': 3.1666666667,
#    'avg_submitter_ratingsCount': 35.75,
#    'avg_submitter_reciepesCount': 110.5833333333,
#    'avg_submitter_reviewsCount': 9.75,
#    'nbRecipes': 12},
#   'buffalo': {'avg_cookMinutes': 27.243902439,
#    'avg_nutrition_calcium_amount': 65.7200556195,
#    'avg_nutrition_caloriesFromFat_amount': 155.7728659024,
#    'avg_nutrition_calories_amount': 274.4892507317,
#    'avg_nutrition_carbohydrates_amount': 18.7452494951,
#    'avg_nutrition_cholesterol_amount': 63.7754877317,
#    'avg_nutrition_fat_amount': 17.3080967829,
#    'avg_nutrition_fiber_amount': 1.4754392502,
#    'avg_nutrition_folate_amount': 33.2850871244,
#    'avg_nutrition_iron_amount': 1.9006710515,
#    'avg_nutrition_magnesium_amount': 26.2155527951,
#    'avg_nutrition_niacin_amount': 4.2063185402,
#    'avg_nutrition_potassium_amount': 249.2301235854,
#    'avg_nutrition_protein_amount': 11.4925765829,
#    'avg_nutrition_saturatedFat_amount': 6.653792509,
#    'avg_nutrition_sodium_amount': 751.4575639024,
#    'avg_nutrition_sugars_amount': 6.7007981976,
#    'avg_nutrition_thiamin_amount': 0.1099706034,
#    'avg_nutrition_vitaminA_amount': 586.9734563902,
#    'avg_nutrition_vitaminB6_amount': 0.1978445112,
#    'avg_nutrition_vitaminC_amount': 18.0834784651,
#    'avg_prepMinutes': 12.5609756098,
#    'avg_ratingAverage': 3.9525303493,
#    'avg_ratingCount': 46.2682926829,
#    'avg_readyInMinutes': 58.9512195122,
#    'avg_reviewCount': 36.2682926829,
#    'avg_servings': 11.5365853659,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.6585365854,
#    'avg_similarRecipes_metaData_totalCount': 15.6585365854,
#    'avg_submitter_favoritesCount': 110.8292682927,
#    'avg_submitter_followersCount': 1913.7804878049,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 25.0731707317,
#    'avg_submitter_personalRecipeSharedCount': 9.8536585366,
#    'avg_submitter_ratingsCount': 23.7073170732,
#    'avg_submitter_reciepesCount': 46.6097560976,
#    'avg_submitter_reviewsCount': 7.8048780488,
#    'nbRecipes': 41},
#   'california': {'avg_cookMinutes': 31.172,
#    'avg_nutrition_calcium_amount': 124.1717093821,
#    'avg_nutrition_caloriesFromFat_amount': 166.9633836325,
#    'avg_nutrition_calories_amount': 361.590713878,
#    'avg_nutrition_carbohydrates_amount': 31.139750222,
#    'avg_nutrition_cholesterol_amount': 58.8283987134,
#    'avg_nutrition_fat_amount': 18.5514870699,
#    'avg_nutrition_fiber_amount': 3.7913148069,
#    'avg_nutrition_folate_amount': 65.8570558583,
#    'avg_nutrition_iron_amount': 2.78399907,
#    'avg_nutrition_magnesium_amount': 51.7179932675,
#    'avg_nutrition_niacin_amount': 6.4451584148,
#    'avg_nutrition_potassium_amount': 509.1961640285,
#    'avg_nutrition_protein_amount': 17.1335965784,
#    'avg_nutrition_saturatedFat_amount': 5.9080431716,
#    'avg_nutrition_sodium_amount': 648.544411902,
#    'avg_nutrition_sugars_amount': 9.3683412646,
#    'avg_nutrition_thiamin_amount': 0.2142060071,
#    'avg_nutrition_vitaminA_amount': 1500.1951878537,
#    'avg_nutrition_vitaminB6_amount': 0.3467345465,
#    'avg_nutrition_vitaminC_amount': 24.7245447284,
#    'avg_prepMinutes': 19.7,
#    'avg_ratingAverage': 4.0030013945,
#    'avg_ratingCount': 88.84,
#    'avg_readyInMinutes': 132.472,
#    'avg_reviewCount': 67.324,
#    'avg_servings': 9.484,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.5,
#    'avg_similarRecipes_metaData_totalCount': 14.5,
#    'avg_submitter_favoritesCount': 191.792,
#    'avg_submitter_followersCount': 69033.26,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 39.412,
#    'avg_submitter_personalRecipeSharedCount': 16.852,
#    'avg_submitter_ratingsCount': 36.336,
#    'avg_submitter_reciepesCount': 65.068,
#    'avg_submitter_reviewsCount': 17.132,
#    'nbRecipes': 250},
#   'chicago': {'avg_cookMinutes': 45.9090909091,
#    'avg_nutrition_calcium_amount': 145.0406539091,
#    'avg_nutrition_caloriesFromFat_amount': 177.9834209091,
#    'avg_nutrition_calories_amount': 403.8004090909,
#    'avg_nutrition_carbohydrates_amount': 32.4189234545,
#    'avg_nutrition_cholesterol_amount': 57.7919054545,
#    'avg_nutrition_fat_amount': 19.7759342727,
#    'avg_nutrition_fiber_amount': 3.3221818182,
#    'avg_nutrition_folate_amount': 78.5223227273,
#    'avg_nutrition_iron_amount': 4.0340229091,
#    'avg_nutrition_magnesium_amount': 35.6325027273,
#    'avg_nutrition_niacin_amount': 8.4149930909,
#    'avg_nutrition_potassium_amount': 406.8057072727,
#    'avg_nutrition_protein_amount': 22.7507469091,
#    'avg_nutrition_saturatedFat_amount': 6.2244856364,
#    'avg_nutrition_sodium_amount': 1152.7164454545,
#    'avg_nutrition_sugars_amount': 5.8000551273,
#    'avg_nutrition_thiamin_amount': 0.3377867473,
#    'avg_nutrition_vitaminA_amount': 1159.4425090909,
#    'avg_nutrition_vitaminB6_amount': 0.3570065909,
#    'avg_nutrition_vitaminC_amount': 9.1900536364,
#    'avg_prepMinutes': 21.3636363636,
#    'avg_ratingAverage': 4.2650518455,
#    'avg_ratingCount': 126.1818181818,
#    'avg_readyInMinutes': 130.0,
#    'avg_reviewCount': 93.5454545455,
#    'avg_servings': 5.8181818182,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 17.0,
#    'avg_similarRecipes_metaData_totalCount': 17.0,
#    'avg_submitter_favoritesCount': 115.1818181818,
#    'avg_submitter_followersCount': 3476.1818181818,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 31.1818181818,
#    'avg_submitter_personalRecipeSharedCount': 10.9090909091,
#    'avg_submitter_ratingsCount': 30.4545454545,
#    'avg_submitter_reciepesCount': 84.5454545455,
#    'avg_submitter_reviewsCount': 2.0909090909,
#    'nbRecipes': 11},
#   'cincinnati': {'avg_cookMinutes': 53.3333333333,
#    'avg_nutrition_calcium_amount': 120.0086608333,
#    'avg_nutrition_caloriesFromFat_amount': 177.4081733333,
#    'avg_nutrition_calories_amount': 424.625025,
#    'avg_nutrition_carbohydrates_amount': 35.1568405,
#    'avg_nutrition_cholesterol_amount': 65.80625,
#    'avg_nutrition_fat_amount': 19.712018,
#    'avg_nutrition_fiber_amount': 5.79568,
#    'avg_nutrition_folate_amount': 85.2405008333,
#    'avg_nutrition_iron_amount': 4.81320185,
#    'avg_nutrition_magnesium_amount': 54.6861808333,
#    'avg_nutrition_niacin_amount': 10.1573376667,
#    'avg_nutrition_potassium_amount': 563.3410333333,
#    'avg_nutrition_protein_amount': 28.6368300833,
#    'avg_nutrition_saturatedFat_amount': 7.5697554833,
#    'avg_nutrition_sodium_amount': 755.1521833333,
#    'avg_nutrition_sugars_amount': 8.8096128083,
#    'avg_nutrition_thiamin_amount': 0.3062611983,
#    'avg_nutrition_vitaminA_amount': 3300.7328333333,
#    'avg_nutrition_vitaminB6_amount': 0.409118955,
#    'avg_nutrition_vitaminC_amount': 16.8670281667,
#    'avg_prepMinutes': 35.0,
#    'avg_ratingAverage': 4.21401596,
#    'avg_ratingCount': 78.5833333333,
#    'avg_readyInMinutes': 140.0,
#    'avg_reviewCount': 62.9166666667,
#    'avg_servings': 9.3333333333,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.75,
#    'avg_similarRecipes_metaData_totalCount': 14.75,
#    'avg_submitter_favoritesCount': 65.6666666667,
#    'avg_submitter_followersCount': 3097.8333333333,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 3.0,
#    'avg_submitter_personalRecipeSharedCount': 5.75,
#    'avg_submitter_ratingsCount': 2.9166666667,
#    'avg_submitter_reciepesCount': 30.25,
#    'avg_submitter_reviewsCount': 2.25,
#    'nbRecipes': 12},
#   'cleveland': {'avg_cookMinutes': 36.1515151515,
#    'avg_nutrition_calcium_amount': 100.1309782121,
#    'avg_nutrition_caloriesFromFat_amount': 207.9462324242,
#    'avg_nutrition_calories_amount': 429.2601442424,
#    'avg_nutrition_carbohydrates_amount': 39.4166334545,
#    'avg_nutrition_cholesterol_amount': 99.5148733636,
#    'avg_nutrition_fat_amount': 23.1051369091,
#    'avg_nutrition_fiber_amount': 3.0080272485,
#    'avg_nutrition_folate_amount': 70.7054735152,
#    'avg_nutrition_iron_amount': 2.7811271091,
#    'avg_nutrition_magnesium_amount': 33.3385739697,
#    'avg_nutrition_niacin_amount': 7.0798285636,
#    'avg_nutrition_potassium_amount': 344.2120930303,
#    'avg_nutrition_protein_amount': 16.4890986364,
#    'avg_nutrition_saturatedFat_amount': 9.2561569848,
#    'avg_nutrition_sodium_amount': 523.6588359697,
#    'avg_nutrition_sugars_amount': 14.4876601697,
#    'avg_nutrition_thiamin_amount': 0.3449261991,
#    'avg_nutrition_vitaminA_amount': 1103.2204585961,
#    'avg_nutrition_vitaminB6_amount': 0.2845104261,
#    'avg_nutrition_vitaminC_amount': 11.7181878182,
#    'avg_prepMinutes': 12.9393939394,
#    'avg_ratingAverage': 4.2665948664,
#    'avg_ratingCount': 76.3636363636,
#    'avg_readyInMinutes': 91.7575757576,
#    'avg_reviewCount': 63.0909090909,
#    'avg_servings': 11.3636363636,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.9696969697,
#    'avg_similarRecipes_metaData_totalCount': 14.9696969697,
#    'avg_submitter_favoritesCount': 27.6666666667,
#    'avg_submitter_followersCount': 2.696969697,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 8.4242424242,
#    'avg_submitter_personalRecipeSharedCount': 2.4242424242,
#    'avg_submitter_ratingsCount': 8.3333333333,
#    'avg_submitter_reciepesCount': 1.6060606061,
#    'avg_submitter_reviewsCount': 8.2424242424,
#    'nbRecipes': 33},
#   'dallas': {'avg_cookMinutes': 16.5172413793,
#    'avg_nutrition_calcium_amount': 84.7029391034,
#    'avg_nutrition_caloriesFromFat_amount': 128.338812069,
#    'avg_nutrition_calories_amount': 281.9190327586,
#    'avg_nutrition_carbohydrates_amount': 29.1065187586,
#    'avg_nutrition_cholesterol_amount': 48.2601582759,
#    'avg_nutrition_fat_amount': 14.259867369,
#    'avg_nutrition_fiber_amount': 3.3479804724,
#    'avg_nutrition_folate_amount': 48.1794948276,
#    'avg_nutrition_iron_amount': 1.9520466376,
#    'avg_nutrition_magnesium_amount': 31.8671556552,
#    'avg_nutrition_niacin_amount': 3.7490150276,
#    'avg_nutrition_potassium_amount': 347.4378434483,
#    'avg_nutrition_protein_amount': 9.7854165345,
#    'avg_nutrition_saturatedFat_amount': 4.5802688862,
#    'avg_nutrition_sodium_amount': 555.5156519655,
#    'avg_nutrition_sugars_amount': 12.2154127862,
#    'avg_nutrition_thiamin_amount': 0.1641491599,
#    'avg_nutrition_vitaminA_amount': 2142.7329715172,
#    'avg_nutrition_vitaminB6_amount': 0.2289084511,
#    'avg_nutrition_vitaminC_amount': 21.5955942847,
#    'avg_prepMinutes': 17.8275862069,
#    'avg_ratingAverage': 4.5723076031,
#    'avg_ratingCount': 107.7586206897,
#    'avg_readyInMinutes': 113.9310344828,
#    'avg_reviewCount': 85.7586206897,
#    'avg_servings': 14.724137931,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 17.2413793103,
#    'avg_similarRecipes_metaData_totalCount': 17.2413793103,
#    'avg_submitter_favoritesCount': 95.724137931,
#    'avg_submitter_followersCount': 1.1034482759,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 10.7931034483,
#    'avg_submitter_personalRecipeSharedCount': 4.7931034483,
#    'avg_submitter_ratingsCount': 10.3103448276,
#    'avg_submitter_reciepesCount': 2.1724137931,
#    'avg_submitter_reviewsCount': 6.2068965517,
#    'nbRecipes': 29},
#   'detroit': {'avg_cookMinutes': 33.5833333333,
#    'avg_nutrition_calcium_amount': 110.7019808333,
#    'avg_nutrition_caloriesFromFat_amount': 173.7162475,
#    'avg_nutrition_calories_amount': 311.01333,
#    'avg_nutrition_carbohydrates_amount': 21.7459650833,
#    'avg_nutrition_cholesterol_amount': 66.9126066667,
#    'avg_nutrition_fat_amount': 19.3018065,
#    'avg_nutrition_fiber_amount': 1.8416292833,
#    'avg_nutrition_folate_amount': 28.8361064167,
#    'avg_nutrition_iron_amount': 1.668542725,
#    'avg_nutrition_magnesium_amount': 23.7152309167,
#    'avg_nutrition_niacin_amount': 4.3379916667,
#    'avg_nutrition_potassium_amount': 246.0533683333,
#    'avg_nutrition_protein_amount': 13.32736325,
#    'avg_nutrition_saturatedFat_amount': 8.9966050833,
#    'avg_nutrition_sodium_amount': 654.6641141667,
#    'avg_nutrition_sugars_amount': 12.1358863333,
#    'avg_nutrition_thiamin_amount': 0.1416485077,
#    'avg_nutrition_vitaminA_amount': 914.0964908333,
#    'avg_nutrition_vitaminB6_amount': 0.1985869233,
#    'avg_nutrition_vitaminC_amount': 9.3191774417,
#    'avg_prepMinutes': 13.75,
#    'avg_ratingAverage': 4.5795446975,
#    'avg_ratingCount': 92.75,
#    'avg_readyInMinutes': 55.0833333333,
#    'avg_reviewCount': 76.0,
#    'avg_servings': 8.5,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.5,
#    'avg_similarRecipes_metaData_totalCount': 15.5,
#    'avg_submitter_favoritesCount': 172.1666666667,
#    'avg_submitter_followersCount': 3202.6666666667,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 82.0,
#    'avg_submitter_personalRecipeSharedCount': 4.75,
#    'avg_submitter_ratingsCount': 82.0,
#    'avg_submitter_reciepesCount': 78.0833333333,
#    'avg_submitter_reviewsCount': 55.0833333333,
#    'nbRecipes': 12},
#   'georgia': {'avg_cookMinutes': 49.1126760563,
#    'avg_nutrition_calcium_amount': 99.2761648714,
#    'avg_nutrition_caloriesFromFat_amount': 182.5339954329,
#    'avg_nutrition_calories_amount': 358.6492397143,
#    'avg_nutrition_carbohydrates_amount': 34.2082966414,
#    'avg_nutrition_cholesterol_amount': 58.2635068286,
#    'avg_nutrition_fat_amount': 20.2815547511,
#    'avg_nutrition_fiber_amount': 2.5095388411,
#    'avg_nutrition_folate_amount': 52.4274617571,
#    'avg_nutrition_iron_amount': 1.8700171199,
#    'avg_nutrition_magnesium_amount': 36.8129842571,
#    'avg_nutrition_niacin_amount': 4.391119622,
#    'avg_nutrition_potassium_amount': 343.1151770429,
#    'avg_nutrition_protein_amount': 11.0973724957,
#    'avg_nutrition_saturatedFat_amount': 7.3237251565,
#    'avg_nutrition_sodium_amount': 595.0686917429,
#    'avg_nutrition_sugars_amount': 18.6805322896,
#    'avg_nutrition_thiamin_amount': 0.1861195221,
#    'avg_nutrition_vitaminA_amount': 1829.5289358571,
#    'avg_nutrition_vitaminB6_amount': 0.2146132011,
#    'avg_nutrition_vitaminC_amount': 12.11751674,
#    'avg_prepMinutes': 15.5915492958,
#    'avg_ratingAverage': 4.158777641,
#    'avg_ratingCount': 135.338028169,
#    'avg_readyInMinutes': 95.7887323944,
#    'avg_reviewCount': 106.5211267606,
#    'avg_servings': 15.7183098592,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.8591549296,
#    'avg_similarRecipes_metaData_totalCount': 14.8591549296,
#    'avg_submitter_favoritesCount': 139.5633802817,
#    'avg_submitter_followersCount': 5.6901408451,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 17.661971831,
#    'avg_submitter_personalRecipeSharedCount': 9.7042253521,
#    'avg_submitter_ratingsCount': 17.3802816901,
#    'avg_submitter_reciepesCount': 6.5915492958,
#    'avg_submitter_reviewsCount': 15.9154929577,
#    'nbRecipes': 71},
#   'green-bay': {'avg_cookMinutes': 40.625,
#    'avg_nutrition_calcium_amount': 107.8039268462,
#    'avg_nutrition_caloriesFromFat_amount': 184.6795501923,
#    'avg_nutrition_calories_amount': 407.6131015385,
#    'avg_nutrition_carbohydrates_amount': 26.8232490538,
#    'avg_nutrition_cholesterol_amount': 90.0401742308,
#    'avg_nutrition_fat_amount': 20.5199484154,
#    'avg_nutrition_fiber_amount': 1.7425228762,
#    'avg_nutrition_folate_amount': 56.2237626923,
#    'avg_nutrition_iron_amount': 3.7296937538,
#    'avg_nutrition_magnesium_amount': 44.7756590769,
#    'avg_nutrition_niacin_amount': 9.271571,
#    'avg_nutrition_potassium_amount': 496.9851723077,
#    'avg_nutrition_protein_amount': 25.2286861538,
#    'avg_nutrition_saturatedFat_amount': 6.8581744877,
#    'avg_nutrition_sodium_amount': 764.01584,
#    'avg_nutrition_sugars_amount': 3.2473853846,
#    'avg_nutrition_thiamin_amount': 0.2769959485,
#    'avg_nutrition_vitaminA_amount': 1214.13568,
#    'avg_nutrition_vitaminB6_amount': 0.4712018831,
#    'avg_nutrition_vitaminC_amount': 6.9153687846,
#    'avg_prepMinutes': 34.375,
#    'avg_ratingAverage': 4.2604424237,
#    'avg_ratingCount': 64.5625,
#    'avg_readyInMinutes': 6382.5,
#    'avg_reviewCount': 49.6875,
#    'avg_servings': 14.6875,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.25,
#    'avg_similarRecipes_metaData_totalCount': 14.25,
#    'avg_submitter_favoritesCount': 21.4375,
#    'avg_submitter_followersCount': 1.3125,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 1.6875,
#    'avg_submitter_personalRecipeSharedCount': 2.375,
#    'avg_submitter_ratingsCount': 1.5625,
#    'avg_submitter_reciepesCount': 1.0625,
#    'avg_submitter_reviewsCount': 1.5,
#    'nbRecipes': 16},
#   'houston': {'avg_cookMinutes': 60.7222222222,
#    'avg_nutrition_calcium_amount': 107.5836688889,
#    'avg_nutrition_caloriesFromFat_amount': 191.2437795556,
#    'avg_nutrition_calories_amount': 366.3758511111,
#    'avg_nutrition_carbohydrates_amount': 18.0047835556,
#    'avg_nutrition_cholesterol_amount': 111.187795,
#    'avg_nutrition_fat_amount': 21.2493087111,
#    'avg_nutrition_fiber_amount': 2.6954533056,
#    'avg_nutrition_folate_amount': 42.5995917778,
#    'avg_nutrition_iron_amount': 2.9635454278,
#    'avg_nutrition_magnesium_amount': 51.5887053889,
#    'avg_nutrition_niacin_amount': 8.2419543556,
#    'avg_nutrition_potassium_amount': 542.9018705556,
#    'avg_nutrition_protein_amount': 25.2114449222,
#    'avg_nutrition_saturatedFat_amount': 6.6243364278,
#    'avg_nutrition_sodium_amount': 705.3128685,
#    'avg_nutrition_sugars_amount': 4.3589591333,
#    'avg_nutrition_thiamin_amount': 0.4833365948,
#    'avg_nutrition_vitaminA_amount': 1325.1604157222,
#    'avg_nutrition_vitaminB6_amount': 0.4164473133,
#    'avg_nutrition_vitaminC_amount': 21.3800209278,
#    'avg_prepMinutes': 27.5,
#    'avg_ratingAverage': 3.9081002267,
#    'avg_ratingCount': 71.8333333333,
#    'avg_readyInMinutes': 130.2777777778,
#    'avg_reviewCount': 58.5555555556,
#    'avg_servings': 10.5555555556,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.2222222222,
#    'avg_similarRecipes_metaData_totalCount': 14.2222222222,
#    'avg_submitter_favoritesCount': 91.0555555556,
#    'avg_submitter_followersCount': 8.0,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 14.0555555556,
#    'avg_submitter_personalRecipeSharedCount': 4.7222222222,
#    'avg_submitter_ratingsCount': 13.9444444444,
#    'avg_submitter_reciepesCount': 19.3333333333,
#    'avg_submitter_reviewsCount': 13.2777777778,
#    'nbRecipes': 18},
#   'indianapolis': {'avg_cookMinutes': 51.0,
#    'avg_nutrition_calcium_amount': 106.6231562143,
#    'avg_nutrition_caloriesFromFat_amount': 187.0212205714,
#    'avg_nutrition_calories_amount': 425.4122357143,
#    'avg_nutrition_carbohydrates_amount': 35.2995767143,
#    'avg_nutrition_cholesterol_amount': 77.7785842857,
#    'avg_nutrition_fat_amount': 20.78013555,
#    'avg_nutrition_fiber_amount': 1.8113013571,
#    'avg_nutrition_folate_amount': 38.1160503714,
#    'avg_nutrition_iron_amount': 2.8803651857,
#    'avg_nutrition_magnesium_amount': 32.4746160714,
#    'avg_nutrition_niacin_amount': 7.5555770779,
#    'avg_nutrition_potassium_amount': 432.0371707143,
#    'avg_nutrition_protein_amount': 20.4746948193,
#    'avg_nutrition_saturatedFat_amount': 7.5749152914,
#    'avg_nutrition_sodium_amount': 641.9893585714,
#    'avg_nutrition_sugars_amount': 15.7910325714,
#    'avg_nutrition_thiamin_amount': 0.4542568831,
#    'avg_nutrition_vitaminA_amount': 877.3949448714,
#    'avg_nutrition_vitaminB6_amount': 0.3967395311,
#    'avg_nutrition_vitaminC_amount': 7.7831920016,
#    'avg_prepMinutes': 10.8666666667,
#    'avg_ratingAverage': 3.8851282473,
#    'avg_ratingCount': 87.0666666667,
#    'avg_readyInMinutes': 66.8666666667,
#    'avg_reviewCount': 67.6666666667,
#    'avg_servings': 7.9333333333,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.2,
#    'avg_similarRecipes_metaData_totalCount': 15.2,
#    'avg_submitter_favoritesCount': 95.2666666667,
#    'avg_submitter_followersCount': 13.4666666667,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 34.4,
#    'avg_submitter_personalRecipeSharedCount': 6.2666666667,
#    'avg_submitter_ratingsCount': 34.0,
#    'avg_submitter_reciepesCount': 22.2,
#    'avg_submitter_reviewsCount': 30.8666666667,
#    'nbRecipes': 15},
#   'kansas-city': {'avg_cookMinutes': 25.125,
#    'avg_nutrition_calcium_amount': 88.0432716818,
#    'avg_nutrition_caloriesFromFat_amount': 135.3280215909,
#    'avg_nutrition_calories_amount': 300.2158104545,
#    'avg_nutrition_carbohydrates_amount': 33.1955072273,
#    'avg_nutrition_cholesterol_amount': 42.0874889091,
#    'avg_nutrition_fat_amount': 15.0364464455,
#    'avg_nutrition_fiber_amount': 2.1658508545,
#    'avg_nutrition_folate_amount': 47.5829189091,
#    'avg_nutrition_iron_amount': 1.7319653,
#    'avg_nutrition_magnesium_amount': 32.0467021364,
#    'avg_nutrition_niacin_amount': 3.974544735,
#    'avg_nutrition_potassium_amount': 243.5239927273,
#    'avg_nutrition_protein_amount': 9.5829484818,
#    'avg_nutrition_saturatedFat_amount': 6.1034923091,
#    'avg_nutrition_sodium_amount': 421.2166277273,
#    'avg_nutrition_sugars_amount': 11.7726006045,
#    'avg_nutrition_thiamin_amount': 0.1217278914,
#    'avg_nutrition_vitaminA_amount': 1676.5504568182,
#    'avg_nutrition_vitaminB6_amount': 0.1577434245,
#    'avg_nutrition_vitaminC_amount': 7.8234801123,
#    'avg_prepMinutes': 10.9166666667,
#    'avg_ratingAverage': 4.2158064117,
#    'avg_ratingCount': 76.25,
#    'avg_readyInMinutes': 42.7083333333,
#    'avg_reviewCount': 60.625,
#    'avg_servings': 13.6666666667,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 12.5416666667,
#    'avg_similarRecipes_metaData_totalCount': 12.5416666667,
#    'avg_submitter_favoritesCount': 98.4166666667,
#    'avg_submitter_followersCount': 2.0416666667,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 19.625,
#    'avg_submitter_personalRecipeSharedCount': 3.0416666667,
#    'avg_submitter_ratingsCount': 19.125,
#    'avg_submitter_reciepesCount': 1.4583333333,
#    'avg_submitter_reviewsCount': 18.125,
#    'nbRecipes': 24},
#   'los-angeles': {'avg_cookMinutes': 53.9666666667,
#    'avg_nutrition_calcium_amount': 144.626957,
#    'avg_nutrition_caloriesFromFat_amount': 175.34119787,
#    'avg_nutrition_calories_amount': 374.2129283333,
#    'avg_nutrition_carbohydrates_amount': 27.0084856667,
#    'avg_nutrition_cholesterol_amount': 70.7815406667,
#    'avg_nutrition_fat_amount': 19.4823559003,
#    'avg_nutrition_fiber_amount': 4.5759873967,
#    'avg_nutrition_folate_amount': 67.6437203333,
#    'avg_nutrition_iron_amount': 2.9128851667,
#    'avg_nutrition_magnesium_amount': 55.4423327333,
#    'avg_nutrition_niacin_amount': 7.9396035703,
#    'avg_nutrition_potassium_amount': 614.5194593333,
#    'avg_nutrition_protein_amount': 19.6331104167,
#    'avg_nutrition_saturatedFat_amount': 6.9379219367,
#    'avg_nutrition_sodium_amount': 671.3785358,
#    'avg_nutrition_sugars_amount': 5.8711526333,
#    'avg_nutrition_thiamin_amount': 0.2499014367,
#    'avg_nutrition_vitaminA_amount': 1701.4872813333,
#    'avg_nutrition_vitaminB6_amount': 0.5078947378,
#    'avg_nutrition_vitaminC_amount': 51.5466371667,
#    'avg_prepMinutes': 21.0,
#    'avg_ratingAverage': 3.8786580587,
#    'avg_ratingCount': 48.8333333333,
#    'avg_readyInMinutes': 117.8,
#    'avg_reviewCount': 36.3666666667,
#    'avg_servings': 6.7333333333,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 12.9666666667,
#    'avg_similarRecipes_metaData_totalCount': 12.9666666667,
#    'avg_submitter_favoritesCount': 262.6,
#    'avg_submitter_followersCount': 206368.8333333333,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 12.0,
#    'avg_submitter_personalRecipeSharedCount': 9.4333333333,
#    'avg_submitter_ratingsCount': 5.5333333333,
#    'avg_submitter_reciepesCount': 17.1333333333,
#    'avg_submitter_reviewsCount': 5.1333333333,
#    'nbRecipes': 30},
#   'miami': {'avg_cookMinutes': 28.5,
#    'avg_nutrition_calcium_amount': 148.4840393,
#    'avg_nutrition_caloriesFromFat_amount': 219.514829,
#    'avg_nutrition_calories_amount': 446.1634,
#    'avg_nutrition_carbohydrates_amount': 33.1075542,
#    'avg_nutrition_cholesterol_amount': 82.972396,
#    'avg_nutrition_fat_amount': 24.3905374,
#    'avg_nutrition_fiber_amount': 2.58598826,
#    'avg_nutrition_folate_amount': 53.802855,
#    'avg_nutrition_iron_amount': 2.63113087,
#    'avg_nutrition_magnesium_amount': 51.583778,
#    'avg_nutrition_niacin_amount': 7.92152196,
#    'avg_nutrition_potassium_amount': 483.65946,
#    'avg_nutrition_protein_amount': 23.5617041,
#    'avg_nutrition_saturatedFat_amount': 10.7349728,
#    'avg_nutrition_sodium_amount': 1137.50395,
#    'avg_nutrition_sugars_amount': 13.9112817,
#    'avg_nutrition_thiamin_amount': 0.35442256,
#    'avg_nutrition_vitaminA_amount': 534.437133,
#    'avg_nutrition_vitaminB6_amount': 0.385380114,
#    'avg_nutrition_vitaminC_amount': 13.775039369,
#    'avg_prepMinutes': 13.0833333333,
#    'avg_ratingAverage': 4.3271377575,
#    'avg_ratingCount': 68.8333333333,
#    'avg_readyInMinutes': 44.5,
#    'avg_reviewCount': 50.6666666667,
#    'avg_servings': 6.6666666667,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.5,
#    'avg_similarRecipes_metaData_totalCount': 14.5,
#    'avg_submitter_favoritesCount': 88.9166666667,
#    'avg_submitter_followersCount': 3.0,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 10.25,
#    'avg_submitter_personalRecipeSharedCount': 1.8333333333,
#    'avg_submitter_ratingsCount': 10.0,
#    'avg_submitter_reciepesCount': 1.0,
#    'avg_submitter_reviewsCount': 9.6666666667,
#    'nbRecipes': 12},
#   'milwaukee': {'avg_cookMinutes': 43.5185185185,
#    'avg_nutrition_calcium_amount': 122.7239127619,
#    'avg_nutrition_caloriesFromFat_amount': 149.7707734524,
#    'avg_nutrition_calories_amount': 344.2545928571,
#    'avg_nutrition_carbohydrates_amount': 31.8670666333,
#    'avg_nutrition_cholesterol_amount': 71.0539208571,
#    'avg_nutrition_fat_amount': 16.6411957538,
#    'avg_nutrition_fiber_amount': 2.3278076571,
#    'avg_nutrition_folate_amount': 41.4845067857,
#    'avg_nutrition_iron_amount': 2.3519146581,
#    'avg_nutrition_magnesium_amount': 30.9155015095,
#    'avg_nutrition_niacin_amount': 6.3474277967,
#    'avg_nutrition_potassium_amount': 303.862565381,
#    'avg_nutrition_protein_amount': 16.8256470076,
#    'avg_nutrition_saturatedFat_amount': 7.4278637206,
#    'avg_nutrition_sodium_amount': 473.4390500905,
#    'avg_nutrition_sugars_amount': 17.4172225381,
#    'avg_nutrition_thiamin_amount': 0.1554577799,
#    'avg_nutrition_vitaminA_amount': 1254.0578828571,
#    'avg_nutrition_vitaminB6_amount': 0.2583515574,
#    'avg_nutrition_vitaminC_amount': 4.0750595929,
#    'avg_prepMinutes': 18.7037037037,
#    'avg_ratingAverage': 4.3539763722,
#    'avg_ratingCount': 72.7777777778,
#    'avg_readyInMinutes': 158.8888888889,
#    'avg_reviewCount': 56.9259259259,
#    'avg_servings': 19.7407407407,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 12.9259259259,
#    'avg_similarRecipes_metaData_totalCount': 12.9259259259,
#    'avg_submitter_favoritesCount': 201.4814814815,
#    'avg_submitter_followersCount': 294.6296296296,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 211.6296296296,
#    'avg_submitter_personalRecipeSharedCount': 1.8888888889,
#    'avg_submitter_ratingsCount': 217.5555555556,
#    'avg_submitter_reciepesCount': 2.2592592593,
#    'avg_submitter_reviewsCount': 214.3703703704,
#    'nbRecipes': 27},
#   'minneapolis': {'avg_cookMinutes': 49.8965517241,
#    'avg_nutrition_calcium_amount': 95.8436251724,
#    'avg_nutrition_caloriesFromFat_amount': 224.125457931,
#    'avg_nutrition_calories_amount': 426.5461631034,
#    'avg_nutrition_carbohydrates_amount': 34.0948805172,
#    'avg_nutrition_cholesterol_amount': 61.7396821379,
#    'avg_nutrition_fat_amount': 24.9028292069,
#    'avg_nutrition_fiber_amount': 3.2539545241,
#    'avg_nutrition_folate_amount': 51.7617023448,
#    'avg_nutrition_iron_amount': 2.6665336345,
#    'avg_nutrition_magnesium_amount': 51.2976915517,
#    'avg_nutrition_niacin_amount': 8.1992381276,
#    'avg_nutrition_potassium_amount': 575.8242837931,
#    'avg_nutrition_protein_amount': 18.7169525828,
#    'avg_nutrition_saturatedFat_amount': 9.010628,
#    'avg_nutrition_sodium_amount': 842.8650586207,
#    'avg_nutrition_sugars_amount': 7.7990003241,
#    'avg_nutrition_thiamin_amount': 0.2159119795,
#    'avg_nutrition_vitaminA_amount': 1893.9085395517,
#    'avg_nutrition_vitaminB6_amount': 0.3978801269,
#    'avg_nutrition_vitaminC_amount': 13.4663282014,
#    'avg_prepMinutes': 18.4482758621,
#    'avg_ratingAverage': 4.2164214128,
#    'avg_ratingCount': 58.7931034483,
#    'avg_readyInMinutes': 71.2068965517,
#    'avg_reviewCount': 46.5517241379,
#    'avg_servings': 13.6896551724,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.0344827586,
#    'avg_similarRecipes_metaData_totalCount': 15.0344827586,
#    'avg_submitter_favoritesCount': 108.0344827586,
#    'avg_submitter_followersCount': 14.1379310345,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 12.4482758621,
#    'avg_submitter_personalRecipeSharedCount': 9.6896551724,
#    'avg_submitter_ratingsCount': 12.275862069,
#    'avg_submitter_reciepesCount': 34.0689655172,
#    'avg_submitter_reviewsCount': 10.724137931,
#    'nbRecipes': 29},
#   'new-orleans': {'avg_cookMinutes': 28.5434782609,
#    'avg_nutrition_calcium_amount': 128.9259451163,
#    'avg_nutrition_caloriesFromFat_amount': 200.4084444419,
#    'avg_nutrition_calories_amount': 445.9402834884,
#    'avg_nutrition_carbohydrates_amount': 37.0686305279,
#    'avg_nutrition_cholesterol_amount': 112.8882237209,
#    'avg_nutrition_fat_amount': 22.267603107,
#    'avg_nutrition_fiber_amount': 2.5569047091,
#    'avg_nutrition_folate_amount': 78.3735415814,
#    'avg_nutrition_iron_amount': 3.7052496693,
#    'avg_nutrition_magnesium_amount': 46.5328142558,
#    'avg_nutrition_niacin_amount': 6.4543105844,
#    'avg_nutrition_potassium_amount': 395.3045097674,
#    'avg_nutrition_protein_amount': 17.4942017521,
#    'avg_nutrition_saturatedFat_amount': 9.5023519814,
#    'avg_nutrition_sodium_amount': 845.9362781395,
#    'avg_nutrition_sugars_amount': 10.9223112407,
#    'avg_nutrition_thiamin_amount': 0.3470168237,
#    'avg_nutrition_vitaminA_amount': 992.4081416279,
#    'avg_nutrition_vitaminB6_amount': 0.2601072309,
#    'avg_nutrition_vitaminC_amount': 18.2565974605,
#    'avg_prepMinutes': 21.4565217391,
#    'avg_ratingAverage': 4.3605372796,
#    'avg_ratingCount': 40.6086956522,
#    'avg_readyInMinutes': 1050.3260869565,
#    'avg_reviewCount': 32.3913043478,
#    'avg_servings': 10.347826087,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.152173913,
#    'avg_similarRecipes_metaData_totalCount': 14.152173913,
#    'avg_submitter_favoritesCount': 258.3043478261,
#    'avg_submitter_followersCount': 137098.2173913044,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 56.4347826087,
#    'avg_submitter_personalRecipeSharedCount': 6.8260869565,
#    'avg_submitter_ratingsCount': 52.4565217391,
#    'avg_submitter_reciepesCount': 75.3695652174,
#    'avg_submitter_reviewsCount': 7.5217391304,
#    'nbRecipes': 46},
#   'new-york-city': {'avg_cookMinutes': 35.288,
#    'avg_nutrition_calcium_amount': 95.5071747438,
#    'avg_nutrition_caloriesFromFat_amount': 197.6827069587,
#    'avg_nutrition_calories_amount': 411.8799015702,
#    'avg_nutrition_carbohydrates_amount': 33.5271574231,
#    'avg_nutrition_cholesterol_amount': 85.2771413719,
#    'avg_nutrition_fat_amount': 21.9647443719,
#    'avg_nutrition_fiber_amount': 2.2644520866,
#    'avg_nutrition_folate_amount': 50.1536934959,
#    'avg_nutrition_iron_amount': 2.4951306835,
#    'avg_nutrition_magnesium_amount': 36.3795383471,
#    'avg_nutrition_niacin_amount': 7.206435757,
#    'avg_nutrition_potassium_amount': 418.2511784711,
#    'avg_nutrition_protein_amount': 17.8896237174,
#    'avg_nutrition_saturatedFat_amount': 8.9740257264,
#    'avg_nutrition_sodium_amount': 700.8915924711,
#    'avg_nutrition_sugars_amount': 13.1172453805,
#    'avg_nutrition_thiamin_amount': 0.1932303072,
#    'avg_nutrition_vitaminA_amount': 1417.0557266223,
#    'avg_nutrition_vitaminB6_amount': 0.3385195889,
#    'avg_nutrition_vitaminC_amount': 16.3531299945,
#    'avg_prepMinutes': 16.76,
#    'avg_ratingAverage': 4.1732518509,
#    'avg_ratingCount': 111.336,
#    'avg_readyInMinutes': 160.368,
#    'avg_reviewCount': 88.52,
#    'avg_servings': 9.48,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.072,
#    'avg_similarRecipes_metaData_totalCount': 15.072,
#    'avg_submitter_favoritesCount': 199.608,
#    'avg_submitter_followersCount': 70765.312,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 57.272,
#    'avg_submitter_personalRecipeSharedCount': 6.608,
#    'avg_submitter_ratingsCount': 55.24,
#    'avg_submitter_reciepesCount': 104.256,
#    'avg_submitter_reviewsCount': 24.2,
#    'nbRecipes': 125},
#   'oakland': {'avg_cookMinutes': 37.6923076923,
#    'avg_nutrition_calcium_amount': 145.6520065385,
#    'avg_nutrition_caloriesFromFat_amount': 218.9042311538,
#    'avg_nutrition_calories_amount': 448.8614230769,
#    'avg_nutrition_carbohydrates_amount': 35.2154799923,
#    'avg_nutrition_cholesterol_amount': 79.1141545462,
#    'avg_nutrition_fat_amount': 24.3226906923,
#    'avg_nutrition_fiber_amount': 2.8158160346,
#    'avg_nutrition_folate_amount': 65.1093506538,
#    'avg_nutrition_iron_amount': 3.6042783192,
#    'avg_nutrition_magnesium_amount': 60.1629373077,
#    'avg_nutrition_niacin_amount': 8.3302825088,
#    'avg_nutrition_potassium_amount': 579.9714888462,
#    'avg_nutrition_protein_amount': 22.2931578462,
#    'avg_nutrition_saturatedFat_amount': 7.0818176654,
#    'avg_nutrition_sodium_amount': 706.4344396154,
#    'avg_nutrition_sugars_amount': 14.7109440923,
#    'avg_nutrition_thiamin_amount': 0.2790700631,
#    'avg_nutrition_vitaminA_amount': 1532.4941,
#    'avg_nutrition_vitaminB6_amount': 0.3636194046,
#    'avg_nutrition_vitaminC_amount': 17.7529579577,
#    'avg_prepMinutes': 16.9230769231,
#    'avg_ratingAverage': 4.0684482792,
#    'avg_ratingCount': 22.1538461538,
#    'avg_readyInMinutes': 65.3846153846,
#    'avg_reviewCount': 18.3076923077,
#    'avg_servings': 8.4230769231,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 12.0769230769,
#    'avg_similarRecipes_metaData_totalCount': 12.0769230769,
#    'avg_submitter_favoritesCount': 127.2692307692,
#    'avg_submitter_followersCount': 3.5,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 11.4615384615,
#    'avg_submitter_personalRecipeSharedCount': 4.7692307692,
#    'avg_submitter_ratingsCount': 11.1538461538,
#    'avg_submitter_reciepesCount': 1.3846153846,
#    'avg_submitter_reviewsCount': 10.5384615385,
#    'nbRecipes': 26},
#   'philadelphia': {'avg_cookMinutes': 25.9,
#    'avg_nutrition_calcium_amount': 256.67036744,
#    'avg_nutrition_caloriesFromFat_amount': 241.1907634,
#    'avg_nutrition_calories_amount': 510.41504,
#    'avg_nutrition_carbohydrates_amount': 41.94946146,
#    'avg_nutrition_cholesterol_amount': 91.16037164,
#    'avg_nutrition_fat_amount': 26.79897344,
#    'avg_nutrition_fiber_amount': 2.629553508,
#    'avg_nutrition_folate_amount': 66.51275544,
#    'avg_nutrition_iron_amount': 3.120636906,
#    'avg_nutrition_magnesium_amount': 42.76173593,
#    'avg_nutrition_niacin_amount': 7.709990388,
#    'avg_nutrition_potassium_amount': 400.41947886,
#    'avg_nutrition_protein_amount': 24.51036292,
#    'avg_nutrition_saturatedFat_amount': 11.22191714,
#    'avg_nutrition_sodium_amount': 969.3789018,
#    'avg_nutrition_sugars_amount': 10.181250826,
#    'avg_nutrition_thiamin_amount': 0.2211141053,
#    'avg_nutrition_vitaminA_amount': 922.4537942,
#    'avg_nutrition_vitaminB6_amount': 0.3141011734,
#    'avg_nutrition_vitaminC_amount': 18.4969734301,
#    'avg_prepMinutes': 15.6,
#    'avg_ratingAverage': 4.2303322426,
#    'avg_ratingCount': 47.72,
#    'avg_readyInMinutes': 75.32,
#    'avg_reviewCount': 36.82,
#    'avg_servings': 7.82,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.5,
#    'avg_similarRecipes_metaData_totalCount': 14.5,
#    'avg_submitter_favoritesCount': 221.14,
#    'avg_submitter_followersCount': 43661.24,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 61.18,
#    'avg_submitter_personalRecipeSharedCount': 9.26,
#    'avg_submitter_ratingsCount': 59.68,
#    'avg_submitter_reciepesCount': 68.12,
#    'avg_submitter_reviewsCount': 40.48,
#    'nbRecipes': 50},
#   'pittsburgh': {'avg_cookMinutes': 63.0357142857,
#    'avg_nutrition_calcium_amount': 176.3509592857,
#    'avg_nutrition_caloriesFromFat_amount': 215.4658885714,
#    'avg_nutrition_calories_amount': 483.6879928571,
#    'avg_nutrition_carbohydrates_amount': 44.8913861786,
#    'avg_nutrition_cholesterol_amount': 76.4513171429,
#    'avg_nutrition_fat_amount': 23.9406550357,
#    'avg_nutrition_fiber_amount': 3.7168764329,
#    'avg_nutrition_folate_amount': 87.593270625,
#    'avg_nutrition_iron_amount': 3.181308925,
#    'avg_nutrition_magnesium_amount': 46.9784233571,
#    'avg_nutrition_niacin_amount': 8.0869232025,
#    'avg_nutrition_potassium_amount': 553.1527578571,
#    'avg_nutrition_protein_amount': 22.6650185714,
#    'avg_nutrition_saturatedFat_amount': 9.1614294643,
#    'avg_nutrition_sodium_amount': 1177.559305,
#    'avg_nutrition_sugars_amount': 10.2933764357,
#    'avg_nutrition_thiamin_amount': 0.3739265813,
#    'avg_nutrition_vitaminA_amount': 750.5714234643,
#    'avg_nutrition_vitaminB6_amount': 0.3713053325,
#    'avg_nutrition_vitaminC_amount': 24.3195612929,
#    'avg_prepMinutes': 16.7857142857,
#    'avg_ratingAverage': 4.3639157029,
#    'avg_ratingCount': 193.6428571429,
#    'avg_readyInMinutes': 130.1785714286,
#    'avg_reviewCount': 148.4285714286,
#    'avg_servings': 8.0357142857,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.1785714286,
#    'avg_similarRecipes_metaData_totalCount': 15.1785714286,
#    'avg_submitter_favoritesCount': 63.0714285714,
#    'avg_submitter_followersCount': 3.3571428571,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 9.9285714286,
#    'avg_submitter_personalRecipeSharedCount': 1.9642857143,
#    'avg_submitter_ratingsCount': 9.8571428571,
#    'avg_submitter_reciepesCount': 15.0,
#    'avg_submitter_reviewsCount': 8.9285714286,
#    'nbRecipes': 28},
#   'san-diego': {'avg_cookMinutes': 19.3870967742,
#    'avg_nutrition_calcium_amount': 123.9850940333,
#    'avg_nutrition_caloriesFromFat_amount': 152.2295126667,
#    'avg_nutrition_calories_amount': 401.5872333333,
#    'avg_nutrition_carbohydrates_amount': 41.5719148133,
#    'avg_nutrition_cholesterol_amount': 55.5185,
#    'avg_nutrition_fat_amount': 16.9143911333,
#    'avg_nutrition_fiber_amount': 5.1018845483,
#    'avg_nutrition_folate_amount': 73.1248744333,
#    'avg_nutrition_iron_amount': 2.6139855823,
#    'avg_nutrition_magnesium_amount': 71.6664576667,
#    'avg_nutrition_niacin_amount': 7.2018205693,
#    'avg_nutrition_potassium_amount': 711.033659,
#    'avg_nutrition_protein_amount': 22.6181271967,
#    'avg_nutrition_saturatedFat_amount': 3.8838472067,
#    'avg_nutrition_sodium_amount': 743.090265,
#    'avg_nutrition_sugars_amount': 8.9109309767,
#    'avg_nutrition_thiamin_amount': 0.2542885452,
#    'avg_nutrition_vitaminA_amount': 2641.551526,
#    'avg_nutrition_vitaminB6_amount': 0.4836998991,
#    'avg_nutrition_vitaminC_amount': 35.2134353,
#    'avg_prepMinutes': 22.4193548387,
#    'avg_ratingAverage': 3.8715675723,
#    'avg_ratingCount': 176.4516129032,
#    'avg_readyInMinutes': 69.5483870968,
#    'avg_reviewCount': 131.2258064516,
#    'avg_servings': 7.7419354839,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 17.5483870968,
#    'avg_similarRecipes_metaData_totalCount': 17.5483870968,
#    'avg_submitter_favoritesCount': 99.4838709677,
#    'avg_submitter_followersCount': 2748.935483871,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 14.3225806452,
#    'avg_submitter_personalRecipeSharedCount': 5.7741935484,
#    'avg_submitter_ratingsCount': 12.8709677419,
#    'avg_submitter_reciepesCount': 16.0322580645,
#    'avg_submitter_reviewsCount': 12.0322580645,
#    'nbRecipes': 31},
#   'san-francisco': {'avg_cookMinutes': 39.8780487805,
#    'avg_nutrition_calcium_amount': 85.1226340244,
#    'avg_nutrition_caloriesFromFat_amount': 108.500598678,
#    'avg_nutrition_calories_amount': 291.9175343171,
#    'avg_nutrition_carbohydrates_amount': 25.6473037854,
#    'avg_nutrition_cholesterol_amount': 66.2578526171,
#    'avg_nutrition_fat_amount': 12.0556219332,
#    'avg_nutrition_fiber_amount': 2.9773086473,
#    'avg_nutrition_folate_amount': 58.5151527912,
#    'avg_nutrition_iron_amount': 3.743290641,
#    'avg_nutrition_magnesium_amount': 58.4659303537,
# ...
#    'avg_nutrition_protein_amount': 9.5694446647,
#    'avg_nutrition_saturatedFat_amount': 5.7859270382,
#    'avg_nutrition_sodium_amount': 718.5944308824,
#    'avg_nutrition_sugars_amount': 19.7792949853,
#    'avg_nutrition_thiamin_amount': 0.2007594049,
#    'avg_nutrition_vitaminA_amount': 3017.7629244118,
#    'avg_nutrition_vitaminB6_amount': 0.2097889344,
#    'avg_nutrition_vitaminC_amount': 11.2401632903,
#    'avg_prepMinutes': 13.9705882353,
#    'avg_ratingAverage': 4.1578684685,
#    'avg_ratingCount': 46.8823529412,
#    'avg_readyInMinutes': 253.2941176471,
#    'avg_reviewCount': 37.9117647059,
#    'avg_servings': 11.4117647059,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.5882352941,
#    'avg_similarRecipes_metaData_totalCount': 14.5882352941,
#    'avg_submitter_favoritesCount': 132.7352941176,
#    'avg_submitter_followersCount': 10.8235294118,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 16.5294117647,
#    'avg_submitter_personalRecipeSharedCount': 3.0882352941,
#    'avg_submitter_ratingsCount': 15.2352941176,
#    'avg_submitter_reciepesCount': 3.9411764706,
#    'avg_submitter_reviewsCount': 14.3529411765,
#    'nbRecipes': 34},
#   'texas': {'avg_cookMinutes': 65.0107526882,
#    'avg_nutrition_calcium_amount': 103.1124223889,
#    'avg_nutrition_caloriesFromFat_amount': 172.2608236033,
#    'avg_nutrition_calories_amount': 353.2934563333,
#    'avg_nutrition_carbohydrates_amount': 28.5617996785,
#    'avg_nutrition_cholesterol_amount': 66.0425069248,
#    'avg_nutrition_fat_amount': 19.140091538,
#    'avg_nutrition_fiber_amount': 3.5157293997,
#    'avg_nutrition_folate_amount': 49.702710203,
#    'avg_nutrition_iron_amount': 2.6009334371,
#    'avg_nutrition_magnesium_amount': 40.4642331789,
#    'avg_nutrition_niacin_amount': 6.3303489187,
#    'avg_nutrition_potassium_amount': 434.2123460074,
#    'avg_nutrition_protein_amount': 17.0558498598,
#    'avg_nutrition_saturatedFat_amount': 6.769412804,
#    'avg_nutrition_sodium_amount': 707.8997133193,
#    'avg_nutrition_sugars_amount': 10.7140498651,
#    'avg_nutrition_thiamin_amount': 0.1952091371,
#    'avg_nutrition_vitaminA_amount': 1151.8433258074,
#    'avg_nutrition_vitaminB6_amount': 0.3380390608,
#    'avg_nutrition_vitaminC_amount': 16.6231302028,
#    'avg_prepMinutes': 17.7491039427,
#    'avg_ratingAverage': 4.0835861544,
#    'avg_ratingCount': 79.5519713262,
#    'avg_readyInMinutes': 172.7777777778,
#    'avg_reviewCount': 62.7240143369,
#    'avg_servings': 12.7455197133,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.0286738351,
#    'avg_similarRecipes_metaData_totalCount': 15.0286738351,
#    'avg_submitter_favoritesCount': 93.5734767025,
#    'avg_submitter_followersCount': 337.1218637993,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 24.6308243728,
#    'avg_submitter_personalRecipeSharedCount': 4.7885304659,
#    'avg_submitter_ratingsCount': 24.4551971326,
#    'avg_submitter_reciepesCount': 7.3584229391,
#    'avg_submitter_reviewsCount': 21.7204301075,
#    'nbRecipes': 279},
#   'utah': {'avg_cookMinutes': 20.1785714286,
#    'avg_nutrition_calcium_amount': 65.7313578929,
#    'avg_nutrition_caloriesFromFat_amount': 148.8449864286,
#    'avg_nutrition_calories_amount': 283.6460714286,
#    'avg_nutrition_carbohydrates_amount': 26.5193084643,
#    'avg_nutrition_cholesterol_amount': 45.2401505357,
#    'avg_nutrition_fat_amount': 16.5383311429,
#    'avg_nutrition_fiber_amount': 2.3103185039,
#    'avg_nutrition_folate_amount': 38.7931163893,
#    'avg_nutrition_iron_amount': 1.8744500225,
#    'avg_nutrition_magnesium_amount': 35.9538693429,
#    'avg_nutrition_niacin_amount': 3.5134253914,
#    'avg_nutrition_potassium_amount': 410.2506785714,
#    'avg_nutrition_protein_amount': 8.9398425571,
#    'avg_nutrition_saturatedFat_amount': 5.8624726607,
#    'avg_nutrition_sodium_amount': 557.9333182143,
#    'avg_nutrition_sugars_amount': 13.5558351071,
#    'avg_nutrition_thiamin_amount': 0.1804741569,
#    'avg_nutrition_vitaminA_amount': 1393.2343864286,
#    'avg_nutrition_vitaminB6_amount': 0.2755061989,
#    'avg_nutrition_vitaminC_amount': 14.2999565286,
#    'avg_prepMinutes': 20.5357142857,
#    'avg_ratingAverage': 4.3986764771,
#    'avg_ratingCount': 122.3928571429,
#    'avg_readyInMinutes': 87.3214285714,
#    'avg_reviewCount': 93.1428571429,
#    'avg_servings': 13.4642857143,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 16.6785714286,
#    'avg_similarRecipes_metaData_totalCount': 16.6785714286,
#    'avg_submitter_favoritesCount': 163.0357142857,
#    'avg_submitter_followersCount': 6.7857142857,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 37.6071428571,
#    'avg_submitter_personalRecipeSharedCount': 4.6785714286,
#    'avg_submitter_ratingsCount': 37.6428571429,
#    'avg_submitter_reciepesCount': 1.8571428571,
#    'avg_submitter_reviewsCount': 36.8214285714,
#    'nbRecipes': 28},
#   'vermont': {'avg_cookMinutes': 60.8529411765,
#    'avg_nutrition_calcium_amount': 101.8220117719,
#    'avg_nutrition_caloriesFromFat_amount': 159.081366875,
#    'avg_nutrition_calories_amount': 369.18786875,
#    'avg_nutrition_carbohydrates_amount': 40.6927433125,
#    'avg_nutrition_cholesterol_amount': 58.2422657188,
#    'avg_nutrition_fat_amount': 17.67570725,
#    'avg_nutrition_fiber_amount': 2.9878586375,
#    'avg_nutrition_folate_amount': 50.6960613438,
#    'avg_nutrition_iron_amount': 2.4230976458,
#    'avg_nutrition_magnesium_amount': 37.0015854063,
#    'avg_nutrition_niacin_amount': 5.1624441594,
#    'avg_nutrition_potassium_amount': 383.8787097813,
#    'avg_nutrition_protein_amount': 12.874424875,
#    'avg_nutrition_saturatedFat_amount': 6.1784134531,
#    'avg_nutrition_sodium_amount': 418.88206875,
#    'avg_nutrition_sugars_amount': 19.409331,
#    'avg_nutrition_thiamin_amount': 0.1837670159,
#    'avg_nutrition_vitaminA_amount': 1401.8521313531,
#    'avg_nutrition_vitaminB6_amount': 0.2702705116,
#    'avg_nutrition_vitaminC_amount': 11.1494171359,
#    'avg_prepMinutes': 13.3235294118,
#    'avg_ratingAverage': 4.2885155565,
#    'avg_ratingCount': 42.2941176471,
#    'avg_readyInMinutes': 346.6176470588,
#    'avg_reviewCount': 34.0588235294,
#    'avg_servings': 9.5882352941,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.1470588235,
#    'avg_similarRecipes_metaData_totalCount': 14.1470588235,
#    'avg_submitter_favoritesCount': 28.0588235294,
#    'avg_submitter_followersCount': 323.8235294118,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 9.1176470588,
#    'avg_submitter_personalRecipeSharedCount': 1.4411764706,
#    'avg_submitter_ratingsCount': 7.4411764706,
#    'avg_submitter_reciepesCount': 1.7941176471,
#    'avg_submitter_reviewsCount': 6.6176470588,
#    'nbRecipes': 34},
#   'virginia': {'avg_cookMinutes': 56.4375,
#    'avg_nutrition_calcium_amount': 75.1409375625,
#    'avg_nutrition_caloriesFromFat_amount': 179.2666849375,
#    'avg_nutrition_calories_amount': 358.06851625,
#    'avg_nutrition_carbohydrates_amount': 31.57439225,
#    'avg_nutrition_cholesterol_amount': 69.6040119781,
#    'avg_nutrition_fat_amount': 19.918520625,
#    'avg_nutrition_fiber_amount': 1.6366456156,
#    'avg_nutrition_folate_amount': 36.7026315781,
#    'avg_nutrition_iron_amount': 1.6818465044,
#    'avg_nutrition_magnesium_amount': 29.6905674156,
#    'avg_nutrition_niacin_amount': 5.4624150888,
#    'avg_nutrition_potassium_amount': 302.8984799375,
#    'avg_nutrition_protein_amount': 11.7819286813,
#    'avg_nutrition_saturatedFat_amount': 8.1838373403,
#    'avg_nutrition_sodium_amount': 1168.321465375,
#    'avg_nutrition_sugars_amount': 18.4577318984,
#    'avg_nutrition_thiamin_amount': 0.3514948358,
#    'avg_nutrition_vitaminA_amount': 444.0085157188,
#    'avg_nutrition_vitaminB6_amount': 0.2589568883,
#    'avg_nutrition_vitaminC_amount': 5.7695234738,
#    'avg_prepMinutes': 18.59375,
#    'avg_ratingAverage': 3.7143175916,
#    'avg_ratingCount': 35.84375,
#    'avg_readyInMinutes': 120.90625,
#    'avg_reviewCount': 29.71875,
#    'avg_servings': 17.3125,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 13.1875,
#    'avg_similarRecipes_metaData_totalCount': 13.1875,
#    'avg_submitter_favoritesCount': 96.0625,
#    'avg_submitter_followersCount': 9.875,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 42.15625,
#    'avg_submitter_personalRecipeSharedCount': 5.4375,
#    'avg_submitter_ratingsCount': 42.0,
#    'avg_submitter_reciepesCount': 1.875,
#    'avg_submitter_reviewsCount': 39.09375,
#    'nbRecipes': 32},
#   'washington': {'avg_cookMinutes': 28.203125,
#    'avg_nutrition_calcium_amount': 102.3996342195,
#    'avg_nutrition_caloriesFromFat_amount': 186.6611215146,
#    'avg_nutrition_calories_amount': 369.054199187,
#    'avg_nutrition_carbohydrates_amount': 30.0589518317,
#    'avg_nutrition_cholesterol_amount': 65.0236844626,
#    'avg_nutrition_fat_amount': 20.740124183,
#    'avg_nutrition_fiber_amount': 2.8771862628,
#    'avg_nutrition_folate_amount': 60.2775973203,
#    'avg_nutrition_iron_amount': 3.2799927298,
#    'avg_nutrition_magnesium_amount': 41.9545481057,
#    'avg_nutrition_niacin_amount': 6.4335387025,
#    'avg_nutrition_potassium_amount': 429.7750607724,
#    'avg_nutrition_protein_amount': 15.6889246654,
#    'avg_nutrition_saturatedFat_amount': 6.5756268588,
#    'avg_nutrition_sodium_amount': 641.6101956902,
#    'avg_nutrition_sugars_amount': 9.8834069502,
#    'avg_nutrition_thiamin_amount': 0.2385029415,
#    'avg_nutrition_vitaminA_amount': 1487.928066748,
#    'avg_nutrition_vitaminB6_amount': 0.3329521574,
#    'avg_nutrition_vitaminC_amount': 16.457595231,
#    'avg_prepMinutes': 16.1640625,
#    'avg_ratingAverage': 4.3770598588,
#    'avg_ratingCount': 220.984375,
#    'avg_readyInMinutes': 219.9609375,
#    'avg_reviewCount': 159.2265625,
#    'avg_servings': 9.53125,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.359375,
#    'avg_similarRecipes_metaData_totalCount': 15.359375,
#    'avg_submitter_favoritesCount': 223.140625,
#    'avg_submitter_followersCount': 80647.2890625,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 43.90625,
#    'avg_submitter_personalRecipeSharedCount': 8.0234375,
#    'avg_submitter_ratingsCount': 38.9921875,
#    'avg_submitter_reciepesCount': 12.90625,
#    'avg_submitter_reviewsCount': 22.265625,
#    'nbRecipes': 128},
#   'west-virginia': {'avg_cookMinutes': 57.4,
#    'avg_nutrition_calcium_amount': 93.0973164857,
#    'avg_nutrition_caloriesFromFat_amount': 140.6566015086,
#    'avg_nutrition_calories_amount': 340.0653042857,
#    'avg_nutrition_carbohydrates_amount': 35.1998450857,
#    'avg_nutrition_cholesterol_amount': 64.1967813343,
#    'avg_nutrition_fat_amount': 15.628510824,
#    'avg_nutrition_fiber_amount': 2.4154619246,
#    'avg_nutrition_folate_amount': 47.1710609943,
#    'avg_nutrition_iron_amount': 1.8882234069,
#    'avg_nutrition_magnesium_amount': 38.2060530543,
#    'avg_nutrition_niacin_amount': 6.4868511477,
#    'avg_nutrition_potassium_amount': 362.3476511429,
#    'avg_nutrition_protein_amount': 15.4839191714,
#    'avg_nutrition_saturatedFat_amount': 5.8709633074,
#    'avg_nutrition_sodium_amount': 701.9055300571,
#    'avg_nutrition_sugars_amount': 19.3069959543,
#    'avg_nutrition_thiamin_amount': 0.2737735974,
#    'avg_nutrition_vitaminA_amount': 822.9065045143,
#    'avg_nutrition_vitaminB6_amount': 0.24966926,
#    'avg_nutrition_vitaminC_amount': 11.6682706314,
#    'avg_prepMinutes': 16.0,
#    'avg_ratingAverage': 4.2774152991,
#    'avg_ratingCount': 140.6857142857,
#    'avg_readyInMinutes': 369.9714285714,
#    'avg_reviewCount': 111.8,
#    'avg_servings': 11.0857142857,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 16.1714285714,
#    'avg_similarRecipes_metaData_totalCount': 16.1714285714,
#    'avg_submitter_favoritesCount': 92.2857142857,
#    'avg_submitter_followersCount': 3.2,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 6.6285714286,
#    'avg_submitter_personalRecipeSharedCount': 1.6285714286,
#    'avg_submitter_ratingsCount': 6.1142857143,
#    'avg_submitter_reciepesCount': 12.3714285714,
#    'avg_submitter_reviewsCount': 5.8285714286,
#    'nbRecipes': 35},
#   'wisconsin': {'avg_cookMinutes': 48.0412371134,
#    'avg_nutrition_calcium_amount': 136.7494770465,
#    'avg_nutrition_caloriesFromFat_amount': 190.6321047326,
#    'avg_nutrition_calories_amount': 387.4638053488,
#    'avg_nutrition_carbohydrates_amount': 29.9529028837,
#    'avg_nutrition_cholesterol_amount': 74.766736314,
#    'avg_nutrition_fat_amount': 21.1813445597,
#    'avg_nutrition_fiber_amount': 2.3831685255,
#    'avg_nutrition_folate_amount': 50.5704682384,
#    'avg_nutrition_iron_amount': 2.5465027584,
#    'avg_nutrition_magnesium_amount': 36.6354029965,
#    'avg_nutrition_niacin_amount': 7.1358703783,
#    'avg_nutrition_potassium_amount': 409.4383365465,
#    'avg_nutrition_protein_amount': 18.3398494809,
#    'avg_nutrition_saturatedFat_amount': 8.5978058425,
#    'avg_nutrition_sodium_amount': 729.9496557198,
#    'avg_nutrition_sugars_amount': 10.3062866186,
#    'avg_nutrition_thiamin_amount': 0.2727710251,
#    'avg_nutrition_vitaminA_amount': 1060.9827887209,
#    'avg_nutrition_vitaminB6_amount': 0.3201808688,
#    'avg_nutrition_vitaminC_amount': 10.6140723956,
#    'avg_prepMinutes': 21.6494845361,
#    'avg_ratingAverage': 4.2839092754,
#    'avg_ratingCount': 78.0515463918,
#    'avg_readyInMinutes': 1176.793814433,
#    'avg_reviewCount': 60.8969072165,
#    'avg_servings': 14.6288659794,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.6391752577,
#    'avg_similarRecipes_metaData_totalCount': 14.6391752577,
#    'avg_submitter_favoritesCount': 157.2268041237,
#    'avg_submitter_followersCount': 487.8041237113,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 73.2680412371,
#    'avg_submitter_personalRecipeSharedCount': 3.7216494845,
#    'avg_submitter_ratingsCount': 74.8041237113,
#    'avg_submitter_reciepesCount': 18.5463917526,
#    'avg_submitter_reviewsCount': 70.3505154639,
#    'nbRecipes': 97},
#   'wyoming': {'avg_cookMinutes': 122.7777777778,
#    'avg_nutrition_calcium_amount': 92.8955021143,
#    'avg_nutrition_caloriesFromFat_amount': 243.1427481886,
#    'avg_nutrition_calories_amount': 494.4578434286,
#    'avg_nutrition_carbohydrates_amount': 32.7849573914,
#    'avg_nutrition_cholesterol_amount': 107.5585763714,
#    'avg_nutrition_fat_amount': 27.0158628446,
#    'avg_nutrition_fiber_amount': 2.79049226,
#    'avg_nutrition_folate_amount': 38.9438028571,
#    'avg_nutrition_iron_amount': 3.5895553571,
#    'avg_nutrition_magnesium_amount': 52.0479670571,
#    'avg_nutrition_niacin_amount': 11.6154668186,
#    'avg_nutrition_potassium_amount': 764.009124,
#    'avg_nutrition_protein_amount': 28.893057534,
#    'avg_nutrition_saturatedFat_amount': 10.0238252904,
#    'avg_nutrition_sodium_amount': 1041.95756366,
#    'avg_nutrition_sugars_amount': 17.9053921457,
#    'avg_nutrition_thiamin_amount': 0.3712201702,
#    'avg_nutrition_vitaminA_amount': 1433.0784588571,
#    'avg_nutrition_vitaminB6_amount': 0.5556831291,
#    'avg_nutrition_vitaminC_amount': 15.3263220157,
#    'avg_prepMinutes': 31.1666666667,
#    'avg_ratingAverage': 4.2858910089,
#    'avg_ratingCount': 103.4722222222,
#    'avg_readyInMinutes': 355.75,
#    'avg_reviewCount': 77.7777777778,
#    'avg_servings': 9.1111111111,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.9722222222,
#    'avg_similarRecipes_metaData_totalCount': 14.9722222222,
#    'avg_submitter_favoritesCount': 33.2222222222,
#    'avg_submitter_followersCount': 1.5277777778,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 7.7222222222,
#    'avg_submitter_personalRecipeSharedCount': 4.8055555556,
#    'avg_submitter_ratingsCount': 7.6944444444,
#    'avg_submitter_reciepesCount': 2.3055555556,
#    'avg_submitter_reviewsCount': 5.25,
#    'nbRecipes': 36}}}

# %%
# map from one file to the other
aggregation_field_mappings = {
    'per_continent': 'continent',
    'per_subcontinent': 'subcontinent',
    'per_country': 'country',
    'per_region': 'region',
    'per_city': 'city',
}

# %% [markdown]
# We now add the geodata to the database.

# %%
for (aggregation_key, fields) in database_aggregated_content.items():
    if aggregation_key not in aggregation_field_mappings:
        # ignore
        continue
    # otherwise is an aggregation e.g. "per_country"
    # e.g. display name and geoid for each country
    equivalent_key = aggregation_field_mappings[aggregation_key]
    if equivalent_key not in name_to_geojson_content:
        continue
        
    properties = name_to_geojson_content[equivalent_key]
    for location_name in fields:
        if location_name not in properties:
            continue
        fields[location_name]['geo_identifier'] = properties[location_name]['geo_identifier']
        fields[location_name]['geo_name'] = properties[location_name]['display_name']
        fields[location_name]['database_name'] = location_name
        
        
# now make a list out of the dict
for (aggregation_key, fields) in database_aggregated_content.items():
    if aggregation_key not in aggregation_field_mappings:
        # ignore
        continue
    database_aggregated_content[aggregation_key] = list(fields.values())

# %%
database_aggregated_content
# Out:
# {'global': {'Global aggregation': {'avg_cookMinutes': 41.1077453516,
#    'avg_nutrition_calcium_amount': 114.9318745406,
#    'avg_nutrition_caloriesFromFat_amount': 160.0322171934,
#    'avg_nutrition_calories_amount': 350.2467986302,
#    'avg_nutrition_carbohydrates_amount': 31.5380632211,
#    'avg_nutrition_cholesterol_amount': 66.2203374766,
#    'avg_nutrition_fat_amount': 17.7817337376,
#    'avg_nutrition_fiber_amount': 3.1178096283,
#    'avg_nutrition_folate_amount': 60.2745651289,
#    'avg_nutrition_iron_amount': 2.6678069684,
#    'avg_nutrition_magnesium_amount': 42.7467841021,
#    'avg_nutrition_niacin_amount': 6.5819486949,
#    'avg_nutrition_potassium_amount': 434.1991336157,
#    'avg_nutrition_protein_amount': 16.2278095183,
#    'avg_nutrition_saturatedFat_amount': 6.5396016803,
#    'avg_nutrition_sodium_amount': 661.4516873115,
#    'avg_nutrition_sugars_amount': 9.8466210198,
#    'avg_nutrition_thiamin_amount': 0.2271286606,
#    'avg_nutrition_vitaminA_amount': 1418.1540015684,
#    'avg_nutrition_vitaminB6_amount': 0.3188769283,
#    'avg_nutrition_vitaminC_amount': 18.3412098224,
#    'avg_prepMinutes': 20.2409186061,
#    'avg_ratingAverage': 4.0803297995,
#    'avg_ratingCount': 102.3711981283,
#    'avg_readyInMinutes': 157.1372367935,
#    'avg_reviewCount': 77.7717029922,
#    'avg_servings': 10.2102573575,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.7297130895,
#    'avg_similarRecipes_metaData_totalCount': 14.7297130895,
#    'avg_submitter_favoritesCount': 151.0502401182,
#    'avg_submitter_followersCount': 7870.611685753,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 30.7689939663,
#    'avg_submitter_personalRecipeSharedCount': 8.0709272257,
#    'avg_submitter_ratingsCount': 29.7984238394,
#    'avg_submitter_reciepesCount': 22.6657431351,
#    'avg_submitter_reviewsCount': 23.1030045561,
#    'nbRecipes': 16242}},
#  'per_city': [{'avg_cookMinutes': 49.1126760563,
#    'avg_nutrition_calcium_amount': 99.2761648714,
#    'avg_nutrition_caloriesFromFat_amount': 182.5339954329,
#    'avg_nutrition_calories_amount': 358.6492397143,
#    'avg_nutrition_carbohydrates_amount': 34.2082966414,
#    'avg_nutrition_cholesterol_amount': 58.2635068286,
#    'avg_nutrition_fat_amount': 20.2815547511,
#    'avg_nutrition_fiber_amount': 2.5095388411,
#    'avg_nutrition_folate_amount': 52.4274617571,
#    'avg_nutrition_iron_amount': 1.8700171199,
#    'avg_nutrition_magnesium_amount': 36.8129842571,
#    'avg_nutrition_niacin_amount': 4.391119622,
#    'avg_nutrition_potassium_amount': 343.1151770429,
#    'avg_nutrition_protein_amount': 11.0973724957,
#    'avg_nutrition_saturatedFat_amount': 7.3237251565,
#    'avg_nutrition_sodium_amount': 595.0686917429,
#    'avg_nutrition_sugars_amount': 18.6805322896,
#    'avg_nutrition_thiamin_amount': 0.1861195221,
#    'avg_nutrition_vitaminA_amount': 1829.5289358571,
#    'avg_nutrition_vitaminB6_amount': 0.2146132011,
#    'avg_nutrition_vitaminC_amount': 12.11751674,
#    'avg_prepMinutes': 15.5915492958,
#    'avg_ratingAverage': 4.158777641,
#    'avg_ratingCount': 135.338028169,
#    'avg_readyInMinutes': 95.7887323944,
#    'avg_reviewCount': 106.5211267606,
#    'avg_servings': 15.7183098592,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.8591549296,
#    'avg_similarRecipes_metaData_totalCount': 14.8591549296,
#    'avg_submitter_favoritesCount': 139.5633802817,
#    'avg_submitter_followersCount': 5.6901408451,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 17.661971831,
#    'avg_submitter_personalRecipeSharedCount': 9.7042253521,
#    'avg_submitter_ratingsCount': 17.3802816901,
#    'avg_submitter_reciepesCount': 6.5915492958,
#    'avg_submitter_reviewsCount': 15.9154929577,
#    'database_name': 'georgia',
#    'geo_identifier': 'Atlanta',
#    'geo_name': 'Atlanta',
#    'nbRecipes': 71},
#   {'avg_cookMinutes': 35.9842519685,
#    'avg_nutrition_calcium_amount': 82.7725916587,
#    'avg_nutrition_caloriesFromFat_amount': 146.2542457849,
#    'avg_nutrition_calories_amount': 342.3823438095,
#    'avg_nutrition_carbohydrates_amount': 34.4544898103,
#    'avg_nutrition_cholesterol_amount': 62.7981470476,
#    'avg_nutrition_fat_amount': 16.2504720899,
#    'avg_nutrition_fiber_amount': 2.4105628283,
#    'avg_nutrition_folate_amount': 44.3598037056,
#    'avg_nutrition_iron_amount': 2.5025073252,
#    'avg_nutrition_magnesium_amount': 38.5106154627,
#    'avg_nutrition_niacin_amount': 5.92065496,
#    'avg_nutrition_potassium_amount': 389.5275147302,
#    'avg_nutrition_protein_amount': 15.136433368,
#    'avg_nutrition_saturatedFat_amount': 6.8086557517,
#    'avg_nutrition_sodium_amount': 546.5264371206,
#    'avg_nutrition_sugars_amount': 15.3392824762,
#    'avg_nutrition_thiamin_amount': 0.1973573406,
#    'avg_nutrition_vitaminA_amount': 810.4165892246,
#    'avg_nutrition_vitaminB6_amount': 0.2804936542,
#    'avg_nutrition_vitaminC_amount': 12.7607153502,
#    'avg_prepMinutes': 21.4803149606,
#    'avg_ratingAverage': 4.1240063483,
#    'avg_ratingCount': 44.8661417323,
#    'avg_readyInMinutes': 301.3622047244,
#    'avg_reviewCount': 35.1496062992,
#    'avg_servings': 11.6535433071,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.031496063,
#    'avg_similarRecipes_metaData_totalCount': 14.031496063,
#    'avg_submitter_favoritesCount': 172.2598425197,
#    'avg_submitter_followersCount': 9.5511811024,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 21.5118110236,
#    'avg_submitter_personalRecipeSharedCount': 13.0157480315,
#    'avg_submitter_ratingsCount': 19.6850393701,
#    'avg_submitter_reciepesCount': 4.0393700787,
#    'avg_submitter_reviewsCount': 17.3543307087,
#    'database_name': 'vancouver',
#    'geo_identifier': 'Vancouver',
#    'geo_name': 'Vancouver',
#    'nbRecipes': 127},
#   {'avg_cookMinutes': 53.3333333333,
#    'avg_nutrition_calcium_amount': 120.0086608333,
#    'avg_nutrition_caloriesFromFat_amount': 177.4081733333,
#    'avg_nutrition_calories_amount': 424.625025,
#    'avg_nutrition_carbohydrates_amount': 35.1568405,
#    'avg_nutrition_cholesterol_amount': 65.80625,
#    'avg_nutrition_fat_amount': 19.712018,
#    'avg_nutrition_fiber_amount': 5.79568,
#    'avg_nutrition_folate_amount': 85.2405008333,
#    'avg_nutrition_iron_amount': 4.81320185,
#    'avg_nutrition_magnesium_amount': 54.6861808333,
#    'avg_nutrition_niacin_amount': 10.1573376667,
#    'avg_nutrition_potassium_amount': 563.3410333333,
#    'avg_nutrition_protein_amount': 28.6368300833,
#    'avg_nutrition_saturatedFat_amount': 7.5697554833,
#    'avg_nutrition_sodium_amount': 755.1521833333,
#    'avg_nutrition_sugars_amount': 8.8096128083,
#    'avg_nutrition_thiamin_amount': 0.3062611983,
#    'avg_nutrition_vitaminA_amount': 3300.7328333333,
#    'avg_nutrition_vitaminB6_amount': 0.409118955,
#    'avg_nutrition_vitaminC_amount': 16.8670281667,
#    'avg_prepMinutes': 35.0,
#    'avg_ratingAverage': 4.21401596,
#    'avg_ratingCount': 78.5833333333,
#    'avg_readyInMinutes': 140.0,
#    'avg_reviewCount': 62.9166666667,
#    'avg_servings': 9.3333333333,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.75,
#    'avg_similarRecipes_metaData_totalCount': 14.75,
#    'avg_submitter_favoritesCount': 65.6666666667,
#    'avg_submitter_followersCount': 3097.8333333333,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 3.0,
#    'avg_submitter_personalRecipeSharedCount': 5.75,
#    'avg_submitter_ratingsCount': 2.9166666667,
#    'avg_submitter_reciepesCount': 30.25,
#    'avg_submitter_reviewsCount': 2.25,
#    'database_name': 'cincinnati',
#    'geo_identifier': 'Cincinnati',
#    'geo_name': 'Cincinnati',
#    'nbRecipes': 12},
#   {'avg_cookMinutes': 60.7222222222,
#    'avg_nutrition_calcium_amount': 107.5836688889,
#    'avg_nutrition_caloriesFromFat_amount': 191.2437795556,
#    'avg_nutrition_calories_amount': 366.3758511111,
#    'avg_nutrition_carbohydrates_amount': 18.0047835556,
#    'avg_nutrition_cholesterol_amount': 111.187795,
#    'avg_nutrition_fat_amount': 21.2493087111,
#    'avg_nutrition_fiber_amount': 2.6954533056,
#    'avg_nutrition_folate_amount': 42.5995917778,
#    'avg_nutrition_iron_amount': 2.9635454278,
#    'avg_nutrition_magnesium_amount': 51.5887053889,
#    'avg_nutrition_niacin_amount': 8.2419543556,
#    'avg_nutrition_potassium_amount': 542.9018705556,
#    'avg_nutrition_protein_amount': 25.2114449222,
#    'avg_nutrition_saturatedFat_amount': 6.6243364278,
#    'avg_nutrition_sodium_amount': 705.3128685,
#    'avg_nutrition_sugars_amount': 4.3589591333,
#    'avg_nutrition_thiamin_amount': 0.4833365948,
#    'avg_nutrition_vitaminA_amount': 1325.1604157222,
#    'avg_nutrition_vitaminB6_amount': 0.4164473133,
#    'avg_nutrition_vitaminC_amount': 21.3800209278,
#    'avg_prepMinutes': 27.5,
#    'avg_ratingAverage': 3.9081002267,
#    'avg_ratingCount': 71.8333333333,
#    'avg_readyInMinutes': 130.2777777778,
#    'avg_reviewCount': 58.5555555556,
#    'avg_servings': 10.5555555556,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.2222222222,
#    'avg_similarRecipes_metaData_totalCount': 14.2222222222,
#    'avg_submitter_favoritesCount': 91.0555555556,
#    'avg_submitter_followersCount': 8.0,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 14.0555555556,
#    'avg_submitter_personalRecipeSharedCount': 4.7222222222,
#    'avg_submitter_ratingsCount': 13.9444444444,
#    'avg_submitter_reciepesCount': 19.3333333333,
#    'avg_submitter_reviewsCount': 13.2777777778,
#    'database_name': 'houston',
#    'geo_identifier': 'Houston',
#    'geo_name': 'Houston',
#    'nbRecipes': 18},
#   {'avg_cookMinutes': 22.7164179104,
#    'avg_nutrition_calcium_amount': 104.2027518906,
#    'avg_nutrition_caloriesFromFat_amount': 215.4816058281,
#    'avg_nutrition_calories_amount': 415.338245,
#    'avg_nutrition_carbohydrates_amount': 28.9806050203,
#    'avg_nutrition_cholesterol_amount': 81.3847190141,
#    'avg_nutrition_fat_amount': 23.9424004797,
#    'avg_nutrition_fiber_amount': 3.0802562672,
#    'avg_nutrition_folate_amount': 62.2402307969,
#    'avg_nutrition_iron_amount': 4.2691250437,
#    'avg_nutrition_magnesium_amount': 52.0927064688,
#    'avg_nutrition_niacin_amount': 8.757527289,
#    'avg_nutrition_potassium_amount': 517.2492336719,
#    'avg_nutrition_protein_amount': 20.5943655992,
#    'avg_nutrition_saturatedFat_amount': 7.2110913953,
#    'avg_nutrition_sodium_amount': 809.3939725312,
#    'avg_nutrition_sugars_amount': 8.5214698198,
#    'avg_nutrition_thiamin_amount': 0.2829692072,
#    'avg_nutrition_vitaminA_amount': 2170.3961329688,
#    'avg_nutrition_vitaminB6_amount': 0.4587975699,
#    'avg_nutrition_vitaminC_amount': 21.9334769783,
#    'avg_prepMinutes': 15.8805970149,
#    'avg_ratingAverage': 4.323805857,
#    'avg_ratingCount': 307.8507462687,
#    'avg_readyInMinutes': 223.2835820896,
#    'avg_reviewCount': 219.6865671642,
#    'avg_servings': 8.3432835821,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.4776119403,
#    'avg_similarRecipes_metaData_totalCount': 15.4776119403,
#    'avg_submitter_favoritesCount': 362.6119402985,
#    'avg_submitter_followersCount': 154042.9402985075,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 71.9402985075,
#    'avg_submitter_personalRecipeSharedCount': 12.6417910448,
#    'avg_submitter_ratingsCount': 62.7014925373,
#    'avg_submitter_reciepesCount': 19.3432835821,
#    'avg_submitter_reviewsCount': 31.8805970149,
#    'database_name': 'seattle',
#    'geo_identifier': 'Seattle',
#    'geo_name': 'Seattle',
#    'nbRecipes': 67},
#   {'avg_cookMinutes': 40.625,
#    'avg_nutrition_calcium_amount': 107.8039268462,
#    'avg_nutrition_caloriesFromFat_amount': 184.6795501923,
#    'avg_nutrition_calories_amount': 407.6131015385,
#    'avg_nutrition_carbohydrates_amount': 26.8232490538,
#    'avg_nutrition_cholesterol_amount': 90.0401742308,
#    'avg_nutrition_fat_amount': 20.5199484154,
#    'avg_nutrition_fiber_amount': 1.7425228762,
#    'avg_nutrition_folate_amount': 56.2237626923,
#    'avg_nutrition_iron_amount': 3.7296937538,
#    'avg_nutrition_magnesium_amount': 44.7756590769,
#    'avg_nutrition_niacin_amount': 9.271571,
#    'avg_nutrition_potassium_amount': 496.9851723077,
#    'avg_nutrition_protein_amount': 25.2286861538,
#    'avg_nutrition_saturatedFat_amount': 6.8581744877,
#    'avg_nutrition_sodium_amount': 764.01584,
#    'avg_nutrition_sugars_amount': 3.2473853846,
#    'avg_nutrition_thiamin_amount': 0.2769959485,
#    'avg_nutrition_vitaminA_amount': 1214.13568,
#    'avg_nutrition_vitaminB6_amount': 0.4712018831,
#    'avg_nutrition_vitaminC_amount': 6.9153687846,
#    'avg_prepMinutes': 34.375,
#    'avg_ratingAverage': 4.2604424237,
#    'avg_ratingCount': 64.5625,
#    'avg_readyInMinutes': 6382.5,
#    'avg_reviewCount': 49.6875,
#    'avg_servings': 14.6875,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.25,
#    'avg_similarRecipes_metaData_totalCount': 14.25,
#    'avg_submitter_favoritesCount': 21.4375,
#    'avg_submitter_followersCount': 1.3125,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 1.6875,
#    'avg_submitter_personalRecipeSharedCount': 2.375,
#    'avg_submitter_ratingsCount': 1.5625,
#    'avg_submitter_reciepesCount': 1.0625,
#    'avg_submitter_reviewsCount': 1.5,
#    'database_name': 'green-bay',
#    'geo_identifier': 'Milwaukee',
#    'geo_name': 'Green Bay',
#    'nbRecipes': 16},
#   {'avg_cookMinutes': 63.0357142857,
#    'avg_nutrition_calcium_amount': 176.3509592857,
#    'avg_nutrition_caloriesFromFat_amount': 215.4658885714,
#    'avg_nutrition_calories_amount': 483.6879928571,
#    'avg_nutrition_carbohydrates_amount': 44.8913861786,
#    'avg_nutrition_cholesterol_amount': 76.4513171429,
#    'avg_nutrition_fat_amount': 23.9406550357,
#    'avg_nutrition_fiber_amount': 3.7168764329,
#    'avg_nutrition_folate_amount': 87.593270625,
#    'avg_nutrition_iron_amount': 3.181308925,
#    'avg_nutrition_magnesium_amount': 46.9784233571,
#    'avg_nutrition_niacin_amount': 8.0869232025,
#    'avg_nutrition_potassium_amount': 553.1527578571,
#    'avg_nutrition_protein_amount': 22.6650185714,
#    'avg_nutrition_saturatedFat_amount': 9.1614294643,
#    'avg_nutrition_sodium_amount': 1177.559305,
#    'avg_nutrition_sugars_amount': 10.2933764357,
#    'avg_nutrition_thiamin_amount': 0.3739265813,
#    'avg_nutrition_vitaminA_amount': 750.5714234643,
#    'avg_nutrition_vitaminB6_amount': 0.3713053325,
#    'avg_nutrition_vitaminC_amount': 24.3195612929,
#    'avg_prepMinutes': 16.7857142857,
#    'avg_ratingAverage': 4.3639157029,
#    'avg_ratingCount': 193.6428571429,
#    'avg_readyInMinutes': 130.1785714286,
#    'avg_reviewCount': 148.4285714286,
#    'avg_servings': 8.0357142857,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.1785714286,
#    'avg_similarRecipes_metaData_totalCount': 15.1785714286,
#    'avg_submitter_favoritesCount': 63.0714285714,
#    'avg_submitter_followersCount': 3.3571428571,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 9.9285714286,
#    'avg_submitter_personalRecipeSharedCount': 1.9642857143,
#    'avg_submitter_ratingsCount': 9.8571428571,
#    'avg_submitter_reciepesCount': 15.0,
#    'avg_submitter_reviewsCount': 8.9285714286,
#    'database_name': 'pittsburgh',
#    'geo_identifier': 'Pittsburgh',
#    'geo_name': 'Pittsburgh',
#    'nbRecipes': 28},
#   {'avg_cookMinutes': 27.243902439,
#    'avg_nutrition_calcium_amount': 65.7200556195,
#    'avg_nutrition_caloriesFromFat_amount': 155.7728659024,
#    'avg_nutrition_calories_amount': 274.4892507317,
#    'avg_nutrition_carbohydrates_amount': 18.7452494951,
#    'avg_nutrition_cholesterol_amount': 63.7754877317,
#    'avg_nutrition_fat_amount': 17.3080967829,
#    'avg_nutrition_fiber_amount': 1.4754392502,
#    'avg_nutrition_folate_amount': 33.2850871244,
#    'avg_nutrition_iron_amount': 1.9006710515,
#    'avg_nutrition_magnesium_amount': 26.2155527951,
#    'avg_nutrition_niacin_amount': 4.2063185402,
#    'avg_nutrition_potassium_amount': 249.2301235854,
#    'avg_nutrition_protein_amount': 11.4925765829,
#    'avg_nutrition_saturatedFat_amount': 6.653792509,
#    'avg_nutrition_sodium_amount': 751.4575639024,
#    'avg_nutrition_sugars_amount': 6.7007981976,
#    'avg_nutrition_thiamin_amount': 0.1099706034,
#    'avg_nutrition_vitaminA_amount': 586.9734563902,
#    'avg_nutrition_vitaminB6_amount': 0.1978445112,
#    'avg_nutrition_vitaminC_amount': 18.0834784651,
#    'avg_prepMinutes': 12.5609756098,
#    'avg_ratingAverage': 3.9525303493,
#    'avg_ratingCount': 46.2682926829,
#    'avg_readyInMinutes': 58.9512195122,
#    'avg_reviewCount': 36.2682926829,
#    'avg_servings': 11.5365853659,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.6585365854,
#    'avg_similarRecipes_metaData_totalCount': 15.6585365854,
#    'avg_submitter_favoritesCount': 110.8292682927,
#    'avg_submitter_followersCount': 1913.7804878049,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 25.0731707317,
#    'avg_submitter_personalRecipeSharedCount': 9.8536585366,
#    'avg_submitter_ratingsCount': 23.7073170732,
#    'avg_submitter_reciepesCount': 46.6097560976,
#    'avg_submitter_reviewsCount': 7.8048780488,
#    'database_name': 'buffalo',
#    'geo_identifier': 'Buffalo',
#    'geo_name': 'Buffalo',
#    'nbRecipes': 41},
#   {'avg_cookMinutes': 25.9,
#    'avg_nutrition_calcium_amount': 256.67036744,
#    'avg_nutrition_caloriesFromFat_amount': 241.1907634,
#    'avg_nutrition_calories_amount': 510.41504,
#    'avg_nutrition_carbohydrates_amount': 41.94946146,
#    'avg_nutrition_cholesterol_amount': 91.16037164,
#    'avg_nutrition_fat_amount': 26.79897344,
#    'avg_nutrition_fiber_amount': 2.629553508,
#    'avg_nutrition_folate_amount': 66.51275544,
#    'avg_nutrition_iron_amount': 3.120636906,
#    'avg_nutrition_magnesium_amount': 42.76173593,
#    'avg_nutrition_niacin_amount': 7.709990388,
#    'avg_nutrition_potassium_amount': 400.41947886,
#    'avg_nutrition_protein_amount': 24.51036292,
#    'avg_nutrition_saturatedFat_amount': 11.22191714,
#    'avg_nutrition_sodium_amount': 969.3789018,
#    'avg_nutrition_sugars_amount': 10.181250826,
#    'avg_nutrition_thiamin_amount': 0.2211141053,
#    'avg_nutrition_vitaminA_amount': 922.4537942,
#    'avg_nutrition_vitaminB6_amount': 0.3141011734,
#    'avg_nutrition_vitaminC_amount': 18.4969734301,
#    'avg_prepMinutes': 15.6,
#    'avg_ratingAverage': 4.2303322426,
#    'avg_ratingCount': 47.72,
#    'avg_readyInMinutes': 75.32,
#    'avg_reviewCount': 36.82,
#    'avg_servings': 7.82,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.5,
#    'avg_similarRecipes_metaData_totalCount': 14.5,
#    'avg_submitter_favoritesCount': 221.14,
#    'avg_submitter_followersCount': 43661.24,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 61.18,
#    'avg_submitter_personalRecipeSharedCount': 9.26,
#    'avg_submitter_ratingsCount': 59.68,
#    'avg_submitter_reciepesCount': 68.12,
#    'avg_submitter_reviewsCount': 40.48,
#    'database_name': 'philadelphia',
#    'geo_identifier': 'Philadelphia',
#    'geo_name': 'Philadelphia',
#    'nbRecipes': 50},
#   {'avg_cookMinutes': 37.6923076923,
#    'avg_nutrition_calcium_amount': 145.6520065385,
#    'avg_nutrition_caloriesFromFat_amount': 218.9042311538,
#    'avg_nutrition_calories_amount': 448.8614230769,
#    'avg_nutrition_carbohydrates_amount': 35.2154799923,
#    'avg_nutrition_cholesterol_amount': 79.1141545462,
#    'avg_nutrition_fat_amount': 24.3226906923,
#    'avg_nutrition_fiber_amount': 2.8158160346,
#    'avg_nutrition_folate_amount': 65.1093506538,
#    'avg_nutrition_iron_amount': 3.6042783192,
#    'avg_nutrition_magnesium_amount': 60.1629373077,
#    'avg_nutrition_niacin_amount': 8.3302825088,
#    'avg_nutrition_potassium_amount': 579.9714888462,
#    'avg_nutrition_protein_amount': 22.2931578462,
#    'avg_nutrition_saturatedFat_amount': 7.0818176654,
#    'avg_nutrition_sodium_amount': 706.4344396154,
#    'avg_nutrition_sugars_amount': 14.7109440923,
#    'avg_nutrition_thiamin_amount': 0.2790700631,
#    'avg_nutrition_vitaminA_amount': 1532.4941,
#    'avg_nutrition_vitaminB6_amount': 0.3636194046,
#    'avg_nutrition_vitaminC_amount': 17.7529579577,
#    'avg_prepMinutes': 16.9230769231,
#    'avg_ratingAverage': 4.0684482792,
#    'avg_ratingCount': 22.1538461538,
#    'avg_readyInMinutes': 65.3846153846,
#    'avg_reviewCount': 18.3076923077,
#    'avg_servings': 8.4230769231,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 12.0769230769,
#    'avg_similarRecipes_metaData_totalCount': 12.0769230769,
#    'avg_submitter_favoritesCount': 127.2692307692,
#    'avg_submitter_followersCount': 3.5,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 11.4615384615,
#    'avg_submitter_personalRecipeSharedCount': 4.7692307692,
#    'avg_submitter_ratingsCount': 11.1538461538,
#    'avg_submitter_reciepesCount': 1.3846153846,
#    'avg_submitter_reviewsCount': 10.5384615385,
#    'database_name': 'oakland',
#    'geo_identifier': 'San Francisco',
#    'geo_name': 'Oakland',
#    'nbRecipes': 26},
#   {'avg_cookMinutes': 53.9666666667,
#    'avg_nutrition_calcium_amount': 144.626957,
#    'avg_nutrition_caloriesFromFat_amount': 175.34119787,
#    'avg_nutrition_calories_amount': 374.2129283333,
#    'avg_nutrition_carbohydrates_amount': 27.0084856667,
#    'avg_nutrition_cholesterol_amount': 70.7815406667,
#    'avg_nutrition_fat_amount': 19.4823559003,
#    'avg_nutrition_fiber_amount': 4.5759873967,
#    'avg_nutrition_folate_amount': 67.6437203333,
#    'avg_nutrition_iron_amount': 2.9128851667,
#    'avg_nutrition_magnesium_amount': 55.4423327333,
#    'avg_nutrition_niacin_amount': 7.9396035703,
#    'avg_nutrition_potassium_amount': 614.5194593333,
#    'avg_nutrition_protein_amount': 19.6331104167,
#    'avg_nutrition_saturatedFat_amount': 6.9379219367,
#    'avg_nutrition_sodium_amount': 671.3785358,
#    'avg_nutrition_sugars_amount': 5.8711526333,
#    'avg_nutrition_thiamin_amount': 0.2499014367,
#    'avg_nutrition_vitaminA_amount': 1701.4872813333,
#    'avg_nutrition_vitaminB6_amount': 0.5078947378,
#    'avg_nutrition_vitaminC_amount': 51.5466371667,
#    'avg_prepMinutes': 21.0,
#    'avg_ratingAverage': 3.8786580587,
#    'avg_ratingCount': 48.8333333333,
#    'avg_readyInMinutes': 117.8,
#    'avg_reviewCount': 36.3666666667,
#    'avg_servings': 6.7333333333,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 12.9666666667,
#    'avg_similarRecipes_metaData_totalCount': 12.9666666667,
#    'avg_submitter_favoritesCount': 262.6,
#    'avg_submitter_followersCount': 206368.8333333333,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 12.0,
#    'avg_submitter_personalRecipeSharedCount': 9.4333333333,
#    'avg_submitter_ratingsCount': 5.5333333333,
#    'avg_submitter_reciepesCount': 17.1333333333,
#    'avg_submitter_reviewsCount': 5.1333333333,
#    'database_name': 'los-angeles',
#    'geo_identifier': 'Los Angeles',
#    'geo_name': 'Los Angeles',
#    'nbRecipes': 30},
#   {'avg_cookMinutes': 25.125,
#    'avg_nutrition_calcium_amount': 88.0432716818,
#    'avg_nutrition_caloriesFromFat_amount': 135.3280215909,
#    'avg_nutrition_calories_amount': 300.2158104545,
#    'avg_nutrition_carbohydrates_amount': 33.1955072273,
#    'avg_nutrition_cholesterol_amount': 42.0874889091,
#    'avg_nutrition_fat_amount': 15.0364464455,
#    'avg_nutrition_fiber_amount': 2.1658508545,
#    'avg_nutrition_folate_amount': 47.5829189091,
#    'avg_nutrition_iron_amount': 1.7319653,
#    'avg_nutrition_magnesium_amount': 32.0467021364,
#    'avg_nutrition_niacin_amount': 3.974544735,
#    'avg_nutrition_potassium_amount': 243.5239927273,
#    'avg_nutrition_protein_amount': 9.5829484818,
#    'avg_nutrition_saturatedFat_amount': 6.1034923091,
#    'avg_nutrition_sodium_amount': 421.2166277273,
#    'avg_nutrition_sugars_amount': 11.7726006045,
#    'avg_nutrition_thiamin_amount': 0.1217278914,
#    'avg_nutrition_vitaminA_amount': 1676.5504568182,
#    'avg_nutrition_vitaminB6_amount': 0.1577434245,
#    'avg_nutrition_vitaminC_amount': 7.8234801123,
#    'avg_prepMinutes': 10.9166666667,
#    'avg_ratingAverage': 4.2158064117,
#    'avg_ratingCount': 76.25,
#    'avg_readyInMinutes': 42.7083333333,
#    'avg_reviewCount': 60.625,
#    'avg_servings': 13.6666666667,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 12.5416666667,
#    'avg_similarRecipes_metaData_totalCount': 12.5416666667,
#    'avg_submitter_favoritesCount': 98.4166666667,
#    'avg_submitter_followersCount': 2.0416666667,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 19.625,
#    'avg_submitter_personalRecipeSharedCount': 3.0416666667,
#    'avg_submitter_ratingsCount': 19.125,
#    'avg_submitter_reciepesCount': 1.4583333333,
#    'avg_submitter_reviewsCount': 18.125,
#    'database_name': 'kansas-city',
#    'geo_identifier': 'Kansas City',
#    'geo_name': 'Kansas City',
#    'nbRecipes': 24},
#   {'avg_cookMinutes': 84.0,
#    'avg_nutrition_calcium_amount': 108.1172686296,
#    'avg_nutrition_caloriesFromFat_amount': 257.6353418519,
#    'avg_nutrition_calories_amount': 485.8434666667,
#    'avg_nutrition_carbohydrates_amount': 39.3335362222,
#    'avg_nutrition_cholesterol_amount': 87.1776358148,
#    'avg_nutrition_fat_amount': 28.6261497778,
#    'avg_nutrition_fiber_amount': 2.7868702321,
#    'avg_nutrition_folate_amount': 58.530613,
#    'avg_nutrition_iron_amount': 3.1187290704,
#    'avg_nutrition_magnesium_amount': 41.3972659259,
#    'avg_nutrition_niacin_amount': 8.2253497778,
#    'avg_nutrition_potassium_amount': 473.9753051852,
#    'avg_nutrition_protein_amount': 17.6499616778,
#    'avg_nutrition_saturatedFat_amount': 10.6463396704,
#    'avg_nutrition_sodium_amount': 1665.9185703704,
#    'avg_nutrition_sugars_amount': 20.0582743259,
#    'avg_nutrition_thiamin_amount': 0.5404099809,
#    'avg_nutrition_vitaminA_amount': 1428.0750611111,
#    'avg_nutrition_vitaminB6_amount': 0.4252018348,
#    'avg_nutrition_vitaminC_amount': 11.8623023581,
#    'avg_prepMinutes': 16.2592592593,
#    'avg_ratingAverage': 4.3339577211,
#    'avg_ratingCount': 92.0740740741,
#    'avg_readyInMinutes': 113.4074074074,
#    'avg_reviewCount': 72.1481481481,
#    'avg_servings': 10.6296296296,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.8888888889,
#    'avg_similarRecipes_metaData_totalCount': 15.8888888889,
#    'avg_submitter_favoritesCount': 297.5185185185,
#    'avg_submitter_followersCount': 24.5555555556,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 106.2222222222,
#    'avg_submitter_personalRecipeSharedCount': 3.5925925926,
#    'avg_submitter_ratingsCount': 105.8148148148,
#    'avg_submitter_reciepesCount': 1.2962962963,
#    'avg_submitter_reviewsCount': 104.7777777778,
#    'database_name': 'st-louis',
#    'geo_identifier': 'St. Louis',
#    'geo_name': 'St. Louis',
#    'nbRecipes': 27},
#   {'avg_cookMinutes': 35.288,
#    'avg_nutrition_calcium_amount': 95.5071747438,
#    'avg_nutrition_caloriesFromFat_amount': 197.6827069587,
#    'avg_nutrition_calories_amount': 411.8799015702,
#    'avg_nutrition_carbohydrates_amount': 33.5271574231,
#    'avg_nutrition_cholesterol_amount': 85.2771413719,
#    'avg_nutrition_fat_amount': 21.9647443719,
#    'avg_nutrition_fiber_amount': 2.2644520866,
#    'avg_nutrition_folate_amount': 50.1536934959,
#    'avg_nutrition_iron_amount': 2.4951306835,
#    'avg_nutrition_magnesium_amount': 36.3795383471,
#    'avg_nutrition_niacin_amount': 7.206435757,
#    'avg_nutrition_potassium_amount': 418.2511784711,
#    'avg_nutrition_protein_amount': 17.8896237174,
#    'avg_nutrition_saturatedFat_amount': 8.9740257264,
#    'avg_nutrition_sodium_amount': 700.8915924711,
#    'avg_nutrition_sugars_amount': 13.1172453805,
#    'avg_nutrition_thiamin_amount': 0.1932303072,
#    'avg_nutrition_vitaminA_amount': 1417.0557266223,
#    'avg_nutrition_vitaminB6_amount': 0.3385195889,
#    'avg_nutrition_vitaminC_amount': 16.3531299945,
#    'avg_prepMinutes': 16.76,
#    'avg_ratingAverage': 4.1732518509,
#    'avg_ratingCount': 111.336,
#    'avg_readyInMinutes': 160.368,
#    'avg_reviewCount': 88.52,
#    'avg_servings': 9.48,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.072,
#    'avg_similarRecipes_metaData_totalCount': 15.072,
#    'avg_submitter_favoritesCount': 199.608,
#    'avg_submitter_followersCount': 70765.312,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 57.272,
#    'avg_submitter_personalRecipeSharedCount': 6.608,
#    'avg_submitter_ratingsCount': 55.24,
#    'avg_submitter_reciepesCount': 104.256,
#    'avg_submitter_reviewsCount': 24.2,
#    'database_name': 'new-york-city',
#    'geo_identifier': 'New York City',
#    'geo_name': 'New York City',
#    'nbRecipes': 125},
#   {'avg_cookMinutes': 19.3870967742,
#    'avg_nutrition_calcium_amount': 123.9850940333,
#    'avg_nutrition_caloriesFromFat_amount': 152.2295126667,
#    'avg_nutrition_calories_amount': 401.5872333333,
#    'avg_nutrition_carbohydrates_amount': 41.5719148133,
#    'avg_nutrition_cholesterol_amount': 55.5185,
#    'avg_nutrition_fat_amount': 16.9143911333,
#    'avg_nutrition_fiber_amount': 5.1018845483,
#    'avg_nutrition_folate_amount': 73.1248744333,
#    'avg_nutrition_iron_amount': 2.6139855823,
#    'avg_nutrition_magnesium_amount': 71.6664576667,
#    'avg_nutrition_niacin_amount': 7.2018205693,
#    'avg_nutrition_potassium_amount': 711.033659,
#    'avg_nutrition_protein_amount': 22.6181271967,
#    'avg_nutrition_saturatedFat_amount': 3.8838472067,
#    'avg_nutrition_sodium_amount': 743.090265,
#    'avg_nutrition_sugars_amount': 8.9109309767,
#    'avg_nutrition_thiamin_amount': 0.2542885452,
#    'avg_nutrition_vitaminA_amount': 2641.551526,
#    'avg_nutrition_vitaminB6_amount': 0.4836998991,
#    'avg_nutrition_vitaminC_amount': 35.2134353,
#    'avg_prepMinutes': 22.4193548387,
#    'avg_ratingAverage': 3.8715675723,
#    'avg_ratingCount': 176.4516129032,
#    'avg_readyInMinutes': 69.5483870968,
#    'avg_reviewCount': 131.2258064516,
#    'avg_servings': 7.7419354839,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 17.5483870968,
#    'avg_similarRecipes_metaData_totalCount': 17.5483870968,
#    'avg_submitter_favoritesCount': 99.4838709677,
#    'avg_submitter_followersCount': 2748.935483871,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 14.3225806452,
#    'avg_submitter_personalRecipeSharedCount': 5.7741935484,
#    'avg_submitter_ratingsCount': 12.8709677419,
#    'avg_submitter_reciepesCount': 16.0322580645,
#    'avg_submitter_reviewsCount': 12.0322580645,
#    'database_name': 'san-diego',
#    'geo_identifier': 'San Diego',
#    'geo_name': 'San Diego',
#    'nbRecipes': 31},
#   {'avg_cookMinutes': 51.0,
#    'avg_nutrition_calcium_amount': 106.6231562143,
#    'avg_nutrition_caloriesFromFat_amount': 187.0212205714,
#    'avg_nutrition_calories_amount': 425.4122357143,
#    'avg_nutrition_carbohydrates_amount': 35.2995767143,
#    'avg_nutrition_cholesterol_amount': 77.7785842857,
#    'avg_nutrition_fat_amount': 20.78013555,
#    'avg_nutrition_fiber_amount': 1.8113013571,
#    'avg_nutrition_folate_amount': 38.1160503714,
#    'avg_nutrition_iron_amount': 2.8803651857,
#    'avg_nutrition_magnesium_amount': 32.4746160714,
#    'avg_nutrition_niacin_amount': 7.5555770779,
#    'avg_nutrition_potassium_amount': 432.0371707143,
#    'avg_nutrition_protein_amount': 20.4746948193,
#    'avg_nutrition_saturatedFat_amount': 7.5749152914,
#    'avg_nutrition_sodium_amount': 641.9893585714,
#    'avg_nutrition_sugars_amount': 15.7910325714,
#    'avg_nutrition_thiamin_amount': 0.4542568831,
#    'avg_nutrition_vitaminA_amount': 877.3949448714,
#    'avg_nutrition_vitaminB6_amount': 0.3967395311,
#    'avg_nutrition_vitaminC_amount': 7.7831920016,
#    'avg_prepMinutes': 10.8666666667,
#    'avg_ratingAverage': 3.8851282473,
#    'avg_ratingCount': 87.0666666667,
#    'avg_readyInMinutes': 66.8666666667,
#    'avg_reviewCount': 67.6666666667,
#    'avg_servings': 7.9333333333,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.2,
#    'avg_similarRecipes_metaData_totalCount': 15.2,
#    'avg_submitter_favoritesCount': 95.2666666667,
#    'avg_submitter_followersCount': 13.4666666667,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 34.4,
#    'avg_submitter_personalRecipeSharedCount': 6.2666666667,
#    'avg_submitter_ratingsCount': 34.0,
#    'avg_submitter_reciepesCount': 22.2,
#    'avg_submitter_reviewsCount': 30.8666666667,
#    'database_name': 'indianapolis',
#    'geo_identifier': 'Indianapolis',
#    'geo_name': 'Indianapolis',
#    'nbRecipes': 15},
#   {'avg_cookMinutes': 36.1515151515,
#    'avg_nutrition_calcium_amount': 100.1309782121,
#    'avg_nutrition_caloriesFromFat_amount': 207.9462324242,
#    'avg_nutrition_calories_amount': 429.2601442424,
#    'avg_nutrition_carbohydrates_amount': 39.4166334545,
#    'avg_nutrition_cholesterol_amount': 99.5148733636,
#    'avg_nutrition_fat_amount': 23.1051369091,
#    'avg_nutrition_fiber_amount': 3.0080272485,
#    'avg_nutrition_folate_amount': 70.7054735152,
#    'avg_nutrition_iron_amount': 2.7811271091,
#    'avg_nutrition_magnesium_amount': 33.3385739697,
#    'avg_nutrition_niacin_amount': 7.0798285636,
#    'avg_nutrition_potassium_amount': 344.2120930303,
#    'avg_nutrition_protein_amount': 16.4890986364,
#    'avg_nutrition_saturatedFat_amount': 9.2561569848,
#    'avg_nutrition_sodium_amount': 523.6588359697,
#    'avg_nutrition_sugars_amount': 14.4876601697,
#    'avg_nutrition_thiamin_amount': 0.3449261991,
#    'avg_nutrition_vitaminA_amount': 1103.2204585961,
#    'avg_nutrition_vitaminB6_amount': 0.2845104261,
#    'avg_nutrition_vitaminC_amount': 11.7181878182,
#    'avg_prepMinutes': 12.9393939394,
#    'avg_ratingAverage': 4.2665948664,
#    'avg_ratingCount': 76.3636363636,
#    'avg_readyInMinutes': 91.7575757576,
#    'avg_reviewCount': 63.0909090909,
#    'avg_servings': 11.3636363636,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.9696969697,
#    'avg_similarRecipes_metaData_totalCount': 14.9696969697,
#    'avg_submitter_favoritesCount': 27.6666666667,
#    'avg_submitter_followersCount': 2.696969697,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 8.4242424242,
#    'avg_submitter_personalRecipeSharedCount': 2.4242424242,
#    'avg_submitter_ratingsCount': 8.3333333333,
#    'avg_submitter_reciepesCount': 1.6060606061,
#    'avg_submitter_reviewsCount': 8.2424242424,
#    'database_name': 'cleveland',
#    'geo_identifier': 'Cleveland',
#    'geo_name': 'Cleveland',
#    'nbRecipes': 33},
#   {'avg_cookMinutes': 28.5434782609,
#    'avg_nutrition_calcium_amount': 128.9259451163,
#    'avg_nutrition_caloriesFromFat_amount': 200.4084444419,
#    'avg_nutrition_calories_amount': 445.9402834884,
#    'avg_nutrition_carbohydrates_amount': 37.0686305279,
#    'avg_nutrition_cholesterol_amount': 112.8882237209,
#    'avg_nutrition_fat_amount': 22.267603107,
#    'avg_nutrition_fiber_amount': 2.5569047091,
#    'avg_nutrition_folate_amount': 78.3735415814,
#    'avg_nutrition_iron_amount': 3.7052496693,
#    'avg_nutrition_magnesium_amount': 46.5328142558,
#    'avg_nutrition_niacin_amount': 6.4543105844,
#    'avg_nutrition_potassium_amount': 395.3045097674,
#    'avg_nutrition_protein_amount': 17.4942017521,
#    'avg_nutrition_saturatedFat_amount': 9.5023519814,
#    'avg_nutrition_sodium_amount': 845.9362781395,
#    'avg_nutrition_sugars_amount': 10.9223112407,
#    'avg_nutrition_thiamin_amount': 0.3470168237,
#    'avg_nutrition_vitaminA_amount': 992.4081416279,
#    'avg_nutrition_vitaminB6_amount': 0.2601072309,
#    'avg_nutrition_vitaminC_amount': 18.2565974605,
#    'avg_prepMinutes': 21.4565217391,
#    'avg_ratingAverage': 4.3605372796,
#    'avg_ratingCount': 40.6086956522,
#    'avg_readyInMinutes': 1050.3260869565,
#    'avg_reviewCount': 32.3913043478,
#    'avg_servings': 10.347826087,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.152173913,
#    'avg_similarRecipes_metaData_totalCount': 14.152173913,
#    'avg_submitter_favoritesCount': 258.3043478261,
#    'avg_submitter_followersCount': 137098.2173913044,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 56.4347826087,
#    'avg_submitter_personalRecipeSharedCount': 6.8260869565,
#    'avg_submitter_ratingsCount': 52.4565217391,
#    'avg_submitter_reciepesCount': 75.3695652174,
#    'avg_submitter_reviewsCount': 7.5217391304,
#    'database_name': 'new-orleans',
#    'geo_identifier': 'New Orleans',
#    'geo_name': 'New Orleans',
#    'nbRecipes': 46},
#   {'avg_cookMinutes': 39.8780487805,
#    'avg_nutrition_calcium_amount': 85.1226340244,
#    'avg_nutrition_caloriesFromFat_amount': 108.500598678,
#    'avg_nutrition_calories_amount': 291.9175343171,
#    'avg_nutrition_carbohydrates_amount': 25.6473037854,
#    'avg_nutrition_cholesterol_amount': 66.2578526171,
#    'avg_nutrition_fat_amount': 12.0556219332,
#    'avg_nutrition_fiber_amount': 2.9773086473,
#    'avg_nutrition_folate_amount': 58.5151527912,
#    'avg_nutrition_iron_amount': 3.743290641,
#    'avg_nutrition_magnesium_amount': 58.4659303537,
#    'avg_nutrition_niacin_amount': 6.4557232849,
#    'avg_nutrition_potassium_amount': 498.6124517317,
#    'avg_nutrition_protein_amount': 17.9521666288,
#    'avg_nutrition_saturatedFat_amount': 4.4407462082,
#    'avg_nutrition_sodium_amount': 575.5371249512,
#    'avg_nutrition_sugars_amount': 8.0171513306,
#    'avg_nutrition_thiamin_amount': 0.1696685185,
#    'avg_nutrition_vitaminA_amount': 1177.7962191463,
#    'avg_nutrition_vitaminB6_amount': 0.2709673187,
#    'avg_nutrition_vitaminC_amount': 19.2749906017,
#    'avg_prepMinutes': 18.4146341463,
#    'avg_ratingAverage': 3.8753884834,
#    'avg_ratingCount': 88.1463414634,
#    'avg_readyInMinutes': 98.9756097561,
#    'avg_reviewCount': 68.8780487805,
#    'avg_servings': 12.6829268293,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.8536585366,
#    'avg_similarRecipes_metaData_totalCount': 15.8536585366,
#    'avg_submitter_favoritesCount': 164.0731707317,
#    'avg_submitter_followersCount': 11199.1219512195,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 111.9756097561,
#    'avg_submitter_personalRecipeSharedCount': 6.2926829268,
#    'avg_submitter_ratingsCount': 108.7073170732,
#    'avg_submitter_reciepesCount': 269.3170731707,
#    'avg_submitter_reviewsCount': 18.0487804878,
#    'database_name': 'san-francisco',
#    'geo_identifier': 'San Francisco',
#    'geo_name': 'San Francisco',
#    'nbRecipes': 41},
#   {'avg_cookMinutes': 72.6785714286,
#    'avg_nutrition_calcium_amount': 102.0047476071,
#    'avg_nutrition_caloriesFromFat_amount': 214.0845010821,
#    'avg_nutrition_calories_amount': 424.3144992857,
#    'avg_nutrition_carbohydrates_amount': 39.3647434143,
#    'avg_nutrition_cholesterol_amount': 78.3939721071,
#    'avg_nutrition_fat_amount': 23.7871666814,
#    'avg_nutrition_fiber_amount': 3.0967039829,
#    'avg_nutrition_folate_amount': 48.5445705714,
#    'avg_nutrition_iron_amount': 2.1804457757,
#    'avg_nutrition_magnesium_amount': 44.0108625,
#    'avg_nutrition_niacin_amount': 6.04422843,
#    'avg_nutrition_potassium_amount': 440.0926471429,
#    'avg_nutrition_protein_amount': 14.9179720036,
#    'avg_nutrition_saturatedFat_amount': 7.8238756717,
#    'avg_nutrition_sodium_amount': 512.9678246429,
#    'avg_nutrition_sugars_amount': 20.341919475,
#    'avg_nutrition_thiamin_amount': 0.2052050258,
#    'avg_nutrition_vitaminA_amount': 3036.5497525,
#    'avg_nutrition_vitaminB6_amount': 0.2941749989,
#    'avg_nutrition_vitaminC_amount': 11.3826714225,
#    'avg_prepMinutes': 19.8214285714,
#    'avg_ratingAverage': 4.4145081739,
#    'avg_ratingCount': 167.6428571429,
#    'avg_readyInMinutes': 115.3571428571,
#    'avg_reviewCount': 132.3571428571,
#    'avg_servings': 19.6785714286,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.1785714286,
#    'avg_similarRecipes_metaData_totalCount': 15.1785714286,
#    'avg_submitter_favoritesCount': 114.1071428571,
#    'avg_submitter_followersCount': 2.4642857143,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 21.6785714286,
#    'avg_submitter_personalRecipeSharedCount': 4.0357142857,
#    'avg_submitter_ratingsCount': 21.6785714286,
#    'avg_submitter_reciepesCount': 1.5714285714,
#    'avg_submitter_reviewsCount': 20.8571428571,
#    'database_name': 'atlanta',
#    'geo_identifier': 'Atlanta',
#    'geo_name': 'Atlanta',
#    'nbRecipes': 28},
#   {'avg_cookMinutes': 45.9090909091,
#    'avg_nutrition_calcium_amount': 145.0406539091,
#    'avg_nutrition_caloriesFromFat_amount': 177.9834209091,
#    'avg_nutrition_calories_amount': 403.8004090909,
#    'avg_nutrition_carbohydrates_amount': 32.4189234545,
#    'avg_nutrition_cholesterol_amount': 57.7919054545,
#    'avg_nutrition_fat_amount': 19.7759342727,
#    'avg_nutrition_fiber_amount': 3.3221818182,
#    'avg_nutrition_folate_amount': 78.5223227273,
#    'avg_nutrition_iron_amount': 4.0340229091,
#    'avg_nutrition_magnesium_amount': 35.6325027273,
#    'avg_nutrition_niacin_amount': 8.4149930909,
#    'avg_nutrition_potassium_amount': 406.8057072727,
#    'avg_nutrition_protein_amount': 22.7507469091,
#    'avg_nutrition_saturatedFat_amount': 6.2244856364,
#    'avg_nutrition_sodium_amount': 1152.7164454545,
#    'avg_nutrition_sugars_amount': 5.8000551273,
#    'avg_nutrition_thiamin_amount': 0.3377867473,
#    'avg_nutrition_vitaminA_amount': 1159.4425090909,
#    'avg_nutrition_vitaminB6_amount': 0.3570065909,
#    'avg_nutrition_vitaminC_amount': 9.1900536364,
#    'avg_prepMinutes': 21.3636363636,
#    'avg_ratingAverage': 4.2650518455,
#    'avg_ratingCount': 126.1818181818,
#    'avg_readyInMinutes': 130.0,
#    'avg_reviewCount': 93.5454545455,
#    'avg_servings': 5.8181818182,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 17.0,
#    'avg_similarRecipes_metaData_totalCount': 17.0,
#    'avg_submitter_favoritesCount': 115.1818181818,
#    'avg_submitter_followersCount': 3476.1818181818,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 31.1818181818,
#    'avg_submitter_personalRecipeSharedCount': 10.9090909091,
#    'avg_submitter_ratingsCount': 30.4545454545,
#    'avg_submitter_reciepesCount': 84.5454545455,
#    'avg_submitter_reviewsCount': 2.0909090909,
#    'database_name': 'chicago',
#    'geo_identifier': 'Chicago',
#    'geo_name': 'Chicago',
#    'nbRecipes': 11},
#   {'avg_cookMinutes': 16.5172413793,
#    'avg_nutrition_calcium_amount': 84.7029391034,
#    'avg_nutrition_caloriesFromFat_amount': 128.338812069,
#    'avg_nutrition_calories_amount': 281.9190327586,
#    'avg_nutrition_carbohydrates_amount': 29.1065187586,
#    'avg_nutrition_cholesterol_amount': 48.2601582759,
#    'avg_nutrition_fat_amount': 14.259867369,
#    'avg_nutrition_fiber_amount': 3.3479804724,
#    'avg_nutrition_folate_amount': 48.1794948276,
#    'avg_nutrition_iron_amount': 1.9520466376,
#    'avg_nutrition_magnesium_amount': 31.8671556552,
#    'avg_nutrition_niacin_amount': 3.7490150276,
#    'avg_nutrition_potassium_amount': 347.4378434483,
#    'avg_nutrition_protein_amount': 9.7854165345,
#    'avg_nutrition_saturatedFat_amount': 4.5802688862,
#    'avg_nutrition_sodium_amount': 555.5156519655,
#    'avg_nutrition_sugars_amount': 12.2154127862,
#    'avg_nutrition_thiamin_amount': 0.1641491599,
#    'avg_nutrition_vitaminA_amount': 2142.7329715172,
#    'avg_nutrition_vitaminB6_amount': 0.2289084511,
#    'avg_nutrition_vitaminC_amount': 21.5955942847,
#    'avg_prepMinutes': 17.8275862069,
#    'avg_ratingAverage': 4.5723076031,
#    'avg_ratingCount': 107.7586206897,
#    'avg_readyInMinutes': 113.9310344828,
#    'avg_reviewCount': 85.7586206897,
#    'avg_servings': 14.724137931,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 17.2413793103,
#    'avg_similarRecipes_metaData_totalCount': 17.2413793103,
#    'avg_submitter_favoritesCount': 95.724137931,
#    'avg_submitter_followersCount': 1.1034482759,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 10.7931034483,
#    'avg_submitter_personalRecipeSharedCount': 4.7931034483,
#    'avg_submitter_ratingsCount': 10.3103448276,
#    'avg_submitter_reciepesCount': 2.1724137931,
#    'avg_submitter_reviewsCount': 6.2068965517,
#    'database_name': 'dallas',
#    'geo_identifier': 'Dallas',
#    'geo_name': 'Dallas',
#    'nbRecipes': 29},
#   {'avg_cookMinutes': 28.5,
#    'avg_nutrition_calcium_amount': 148.4840393,
#    'avg_nutrition_caloriesFromFat_amount': 219.514829,
#    'avg_nutrition_calories_amount': 446.1634,
#    'avg_nutrition_carbohydrates_amount': 33.1075542,
#    'avg_nutrition_cholesterol_amount': 82.972396,
#    'avg_nutrition_fat_amount': 24.3905374,
#    'avg_nutrition_fiber_amount': 2.58598826,
#    'avg_nutrition_folate_amount': 53.802855,
#    'avg_nutrition_iron_amount': 2.63113087,
#    'avg_nutrition_magnesium_amount': 51.583778,
#    'avg_nutrition_niacin_amount': 7.92152196,
#    'avg_nutrition_potassium_amount': 483.65946,
#    'avg_nutrition_protein_amount': 23.5617041,
#    'avg_nutrition_saturatedFat_amount': 10.7349728,
#    'avg_nutrition_sodium_amount': 1137.50395,
#    'avg_nutrition_sugars_amount': 13.9112817,
#    'avg_nutrition_thiamin_amount': 0.35442256,
#    'avg_nutrition_vitaminA_amount': 534.437133,
#    'avg_nutrition_vitaminB6_amount': 0.385380114,
#    'avg_nutrition_vitaminC_amount': 13.775039369,
#    'avg_prepMinutes': 13.0833333333,
#    'avg_ratingAverage': 4.3271377575,
#    'avg_ratingCount': 68.8333333333,
#    'avg_readyInMinutes': 44.5,
#    'avg_reviewCount': 50.6666666667,
#    'avg_servings': 6.6666666667,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.5,
#    'avg_similarRecipes_metaData_totalCount': 14.5,
#    'avg_submitter_favoritesCount': 88.9166666667,
#    'avg_submitter_followersCount': 3.0,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 10.25,
#    'avg_submitter_personalRecipeSharedCount': 1.8333333333,
#    'avg_submitter_ratingsCount': 10.0,
#    'avg_submitter_reciepesCount': 1.0,
#    'avg_submitter_reviewsCount': 9.6666666667,
#    'database_name': 'miami',
#    'geo_identifier': 'Miami',
#    'geo_name': 'Miami',
#    'nbRecipes': 12},
#   {'avg_cookMinutes': 49.8965517241,
#    'avg_nutrition_calcium_amount': 95.8436251724,
#    'avg_nutrition_caloriesFromFat_amount': 224.125457931,
#    'avg_nutrition_calories_amount': 426.5461631034,
#    'avg_nutrition_carbohydrates_amount': 34.0948805172,
#    'avg_nutrition_cholesterol_amount': 61.7396821379,
#    'avg_nutrition_fat_amount': 24.9028292069,
#    'avg_nutrition_fiber_amount': 3.2539545241,
#    'avg_nutrition_folate_amount': 51.7617023448,
#    'avg_nutrition_iron_amount': 2.6665336345,
#    'avg_nutrition_magnesium_amount': 51.2976915517,
#    'avg_nutrition_niacin_amount': 8.1992381276,
#    'avg_nutrition_potassium_amount': 575.8242837931,
#    'avg_nutrition_protein_amount': 18.7169525828,
#    'avg_nutrition_saturatedFat_amount': 9.010628,
#    'avg_nutrition_sodium_amount': 842.8650586207,
#    'avg_nutrition_sugars_amount': 7.7990003241,
#    'avg_nutrition_thiamin_amount': 0.2159119795,
#    'avg_nutrition_vitaminA_amount': 1893.9085395517,
#    'avg_nutrition_vitaminB6_amount': 0.3978801269,
#    'avg_nutrition_vitaminC_amount': 13.4663282014,
#    'avg_prepMinutes': 18.4482758621,
#    'avg_ratingAverage': 4.2164214128,
#    'avg_ratingCount': 58.7931034483,
#    'avg_readyInMinutes': 71.2068965517,
#    'avg_reviewCount': 46.5517241379,
#    'avg_servings': 13.6896551724,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.0344827586,
#    'avg_similarRecipes_metaData_totalCount': 15.0344827586,
#    'avg_submitter_favoritesCount': 108.0344827586,
#    'avg_submitter_followersCount': 14.1379310345,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 12.4482758621,
#    'avg_submitter_personalRecipeSharedCount': 9.6896551724,
#    'avg_submitter_ratingsCount': 12.275862069,
#    'avg_submitter_reciepesCount': 34.0689655172,
#    'avg_submitter_reviewsCount': 10.724137931,
#    'database_name': 'minneapolis',
#    'geo_identifier': 'Minneapolis',
#    'geo_name': 'Minneapolis',
#    'nbRecipes': 29},
#   {'avg_cookMinutes': 27.7142857143,
# ...
#    'avg_submitter_favoritesCount': 65.3333333333,
#    'avg_submitter_followersCount': 6.2142857143,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 16.1904761905,
#    'avg_submitter_personalRecipeSharedCount': 3.4047619048,
#    'avg_submitter_ratingsCount': 15.8095238095,
#    'avg_submitter_reciepesCount': 2.3095238095,
#    'avg_submitter_reviewsCount': 12.3095238095,
#    'database_name': 'iowa',
#    'geo_identifier': '19',
#    'geo_name': 'Iowa',
#    'nbRecipes': 42},
#   {'avg_cookMinutes': 46.2173913043,
#    'avg_nutrition_calcium_amount': 111.3506937391,
#    'avg_nutrition_caloriesFromFat_amount': 162.6995288261,
#    'avg_nutrition_calories_amount': 337.4189930435,
#    'avg_nutrition_carbohydrates_amount': 30.334356,
#    'avg_nutrition_cholesterol_amount': 60.4299924826,
#    'avg_nutrition_fat_amount': 18.0777249174,
#    'avg_nutrition_fiber_amount': 2.3309225087,
#    'avg_nutrition_folate_amount': 41.1430323044,
#    'avg_nutrition_iron_amount': 2.5439336,
#    'avg_nutrition_magnesium_amount': 37.1001647826,
#    'avg_nutrition_niacin_amount': 6.1728515634,
#    'avg_nutrition_potassium_amount': 413.9601165217,
#    'avg_nutrition_protein_amount': 14.5209468391,
#    'avg_nutrition_saturatedFat_amount': 6.6066718687,
#    'avg_nutrition_sodium_amount': 442.278816087,
#    'avg_nutrition_sugars_amount': 16.5823012565,
#    'avg_nutrition_thiamin_amount': 0.2104034278,
#    'avg_nutrition_vitaminA_amount': 2906.4968978261,
#    'avg_nutrition_vitaminB6_amount': 0.2880107378,
#    'avg_nutrition_vitaminC_amount': 19.6070429539,
#    'avg_prepMinutes': 14.5652173913,
#    'avg_ratingAverage': 4.0911872183,
#    'avg_ratingCount': 232.7826086957,
#    'avg_readyInMinutes': 108.6086956522,
#    'avg_reviewCount': 183.4347826087,
#    'avg_servings': 16.0869565217,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.7826086957,
#    'avg_similarRecipes_metaData_totalCount': 14.7826086957,
#    'avg_submitter_favoritesCount': 302.4347826087,
#    'avg_submitter_followersCount': 86.2608695652,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 97.5217391304,
#    'avg_submitter_personalRecipeSharedCount': 9.7391304348,
#    'avg_submitter_ratingsCount': 85.8260869565,
#    'avg_submitter_reciepesCount': 4.4782608696,
#    'avg_submitter_reviewsCount': 82.2608695652,
#    'database_name': 'new-jersey',
#    'geo_identifier': '34',
#    'geo_name': 'New Jersey',
#    'nbRecipes': 23},
#   {'avg_cookMinutes': 83.8235294118,
#    'avg_nutrition_calcium_amount': 125.5274713235,
#    'avg_nutrition_caloriesFromFat_amount': 180.7351151765,
#    'avg_nutrition_calories_amount': 363.4112755882,
#    'avg_nutrition_carbohydrates_amount': 21.8647600588,
#    'avg_nutrition_cholesterol_amount': 126.2709718235,
#    'avg_nutrition_fat_amount': 20.0816792706,
#    'avg_nutrition_fiber_amount': 1.8208775324,
#    'avg_nutrition_folate_amount': 36.6054144706,
#    'avg_nutrition_iron_amount': 2.5207901618,
#    'avg_nutrition_magnesium_amount': 49.6666091765,
#    'avg_nutrition_niacin_amount': 8.5104273118,
#    'avg_nutrition_potassium_amount': 500.2721791176,
#    'avg_nutrition_protein_amount': 23.5094691765,
#    'avg_nutrition_saturatedFat_amount': 7.8715732429,
#    'avg_nutrition_sodium_amount': 898.7769585294,
#    'avg_nutrition_sugars_amount': 7.4194910735,
#    'avg_nutrition_thiamin_amount': 0.3129009801,
#    'avg_nutrition_vitaminA_amount': 799.3434448529,
#    'avg_nutrition_vitaminB6_amount': 0.3318352868,
#    'avg_nutrition_vitaminC_amount': 13.8162377588,
#    'avg_prepMinutes': 24.5882352941,
#    'avg_ratingAverage': 4.3269966056,
#    'avg_ratingCount': 83.7058823529,
#    'avg_readyInMinutes': 162.0882352941,
#    'avg_reviewCount': 66.3529411765,
#    'avg_servings': 10.1470588235,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.1764705882,
#    'avg_similarRecipes_metaData_totalCount': 15.1764705882,
#    'avg_submitter_favoritesCount': 102.2058823529,
#    'avg_submitter_followersCount': 4.1176470588,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 6.6470588235,
#    'avg_submitter_personalRecipeSharedCount': 5.2352941176,
#    'avg_submitter_ratingsCount': 6.2647058824,
#    'avg_submitter_reciepesCount': 10.3823529412,
#    'avg_submitter_reviewsCount': 5.0588235294,
#    'database_name': 'south-carolina',
#    'geo_identifier': '45',
#    'geo_name': 'South Carolina',
#    'nbRecipes': 34},
#   {'avg_cookMinutes': 60.8644067797,
#    'avg_nutrition_calcium_amount': 140.5805511864,
#    'avg_nutrition_caloriesFromFat_amount': 178.8624615254,
#    'avg_nutrition_calories_amount': 398.2849947458,
#    'avg_nutrition_carbohydrates_amount': 37.0817358814,
#    'avg_nutrition_cholesterol_amount': 83.8922972881,
#    'avg_nutrition_fat_amount': 19.8736068305,
#    'avg_nutrition_fiber_amount': 3.053037139,
#    'avg_nutrition_folate_amount': 61.0128959661,
#    'avg_nutrition_iron_amount': 4.7412773119,
#    'avg_nutrition_magnesium_amount': 47.1958289153,
#    'avg_nutrition_niacin_amount': 6.4735809102,
#    'avg_nutrition_potassium_amount': 578.972800339,
#    'avg_nutrition_protein_amount': 18.2617344695,
#    'avg_nutrition_saturatedFat_amount': 8.2655407407,
#    'avg_nutrition_sodium_amount': 599.7759057627,
#    'avg_nutrition_sugars_amount': 11.1616536678,
#    'avg_nutrition_thiamin_amount': 0.2447240559,
#    'avg_nutrition_vitaminA_amount': 1166.2450000559,
#    'avg_nutrition_vitaminB6_amount': 0.3390079641,
#    'avg_nutrition_vitaminC_amount': 18.1958595105,
#    'avg_prepMinutes': 17.6271186441,
#    'avg_ratingAverage': 4.1015236115,
#    'avg_ratingCount': 213.8813559322,
#    'avg_readyInMinutes': 177.2711864407,
#    'avg_reviewCount': 164.2881355932,
#    'avg_servings': 11.186440678,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.8644067797,
#    'avg_similarRecipes_metaData_totalCount': 15.8644067797,
#    'avg_submitter_favoritesCount': 138.813559322,
#    'avg_submitter_followersCount': 21.2033898305,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 11.6271186441,
#    'avg_submitter_personalRecipeSharedCount': 5.3389830508,
#    'avg_submitter_ratingsCount': 10.9830508475,
#    'avg_submitter_reciepesCount': 3.9322033898,
#    'avg_submitter_reviewsCount': 10.6101694915,
#    'database_name': 'maine',
#    'geo_identifier': '23',
#    'geo_name': 'Maine',
#    'nbRecipes': 59},
#   {'avg_cookMinutes': 19.0961538462,
#    'avg_nutrition_calcium_amount': 93.1902522157,
#    'avg_nutrition_caloriesFromFat_amount': 154.1174768431,
#    'avg_nutrition_calories_amount': 313.6181192157,
#    'avg_nutrition_carbohydrates_amount': 27.8004294549,
#    'avg_nutrition_cholesterol_amount': 54.1407658235,
#    'avg_nutrition_fat_amount': 17.1241639098,
#    'avg_nutrition_fiber_amount': 2.422326092,
#    'avg_nutrition_folate_amount': 46.8348743137,
#    'avg_nutrition_iron_amount': 1.679650332,
#    'avg_nutrition_magnesium_amount': 35.5439486392,
#    'avg_nutrition_niacin_amount': 4.4413471771,
#    'avg_nutrition_potassium_amount': 306.2544708824,
#    'avg_nutrition_protein_amount': 11.8300800196,
#    'avg_nutrition_saturatedFat_amount': 6.4686361235,
#    'avg_nutrition_sodium_amount': 360.1029626863,
#    'avg_nutrition_sugars_amount': 13.632301382,
#    'avg_nutrition_thiamin_amount': 0.1613280974,
#    'avg_nutrition_vitaminA_amount': 680.4262564706,
#    'avg_nutrition_vitaminB6_amount': 0.1824981687,
#    'avg_nutrition_vitaminC_amount': 15.4689219898,
#    'avg_prepMinutes': 15.1153846154,
#    'avg_ratingAverage': 4.1549933046,
#    'avg_ratingCount': 204.4615384615,
#    'avg_readyInMinutes': 56.6538461538,
#    'avg_reviewCount': 148.2692307692,
#    'avg_servings': 12.7115384615,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.6346153846,
#    'avg_similarRecipes_metaData_totalCount': 14.6346153846,
#    'avg_submitter_favoritesCount': 100.8653846154,
#    'avg_submitter_followersCount': 7.3076923077,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 13.0,
#    'avg_submitter_personalRecipeSharedCount': 5.2884615385,
#    'avg_submitter_ratingsCount': 12.5961538462,
#    'avg_submitter_reciepesCount': 2.5192307692,
#    'avg_submitter_reviewsCount': 11.25,
#    'database_name': 'oregon',
#    'geo_identifier': '41',
#    'geo_name': 'Oregon',
#    'nbRecipes': 52},
#   {'avg_cookMinutes': 44.6470588235,
#    'avg_nutrition_calcium_amount': 70.3181940588,
#    'avg_nutrition_caloriesFromFat_amount': 161.1705175588,
#    'avg_nutrition_calories_amount': 349.3525404412,
#    'avg_nutrition_carbohydrates_amount': 35.0727387338,
#    'avg_nutrition_cholesterol_amount': 68.0991680294,
#    'avg_nutrition_fat_amount': 17.9078349074,
#    'avg_nutrition_fiber_amount': 1.8288597378,
#    'avg_nutrition_folate_amount': 44.3332465147,
#    'avg_nutrition_iron_amount': 1.8574309618,
#    'avg_nutrition_magnesium_amount': 29.6787246471,
#    'avg_nutrition_niacin_amount': 4.6042626999,
#    'avg_nutrition_potassium_amount': 263.9175884706,
#    'avg_nutrition_protein_amount': 11.3250072047,
#    'avg_nutrition_saturatedFat_amount': 6.9678136168,
#    'avg_nutrition_sodium_amount': 611.9731071912,
#    'avg_nutrition_sugars_amount': 19.3360348401,
#    'avg_nutrition_thiamin_amount': 0.1864508676,
#    'avg_nutrition_vitaminA_amount': 1068.6486310294,
#    'avg_nutrition_vitaminB6_amount': 0.1977227142,
#    'avg_nutrition_vitaminC_amount': 8.1342030818,
#    'avg_prepMinutes': 15.9852941176,
#    'avg_ratingAverage': 4.3242521837,
#    'avg_ratingCount': 71.1911764706,
#    'avg_readyInMinutes': 243.5735294118,
#    'avg_reviewCount': 57.6764705882,
#    'avg_servings': 14.6323529412,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.1764705882,
#    'avg_similarRecipes_metaData_totalCount': 15.1764705882,
#    'avg_submitter_favoritesCount': 65.2647058824,
#    'avg_submitter_followersCount': 12.2941176471,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 6.5,
#    'avg_submitter_personalRecipeSharedCount': 4.4705882353,
#    'avg_submitter_ratingsCount': 6.6323529412,
#    'avg_submitter_reciepesCount': 12.1764705882,
#    'avg_submitter_reviewsCount': 6.1617647059,
#    'database_name': 'mississippi',
#    'geo_identifier': '28',
#    'geo_name': 'Mississippi',
#    'nbRecipes': 68},
#   {'avg_cookMinutes': 68.9444444444,
#    'avg_nutrition_calcium_amount': 110.7658201389,
#    'avg_nutrition_caloriesFromFat_amount': 187.3793991667,
#    'avg_nutrition_calories_amount': 380.5956652778,
#    'avg_nutrition_carbohydrates_amount': 25.6781879722,
#    'avg_nutrition_cholesterol_amount': 96.5384327778,
#    'avg_nutrition_fat_amount': 20.8199330833,
#    'avg_nutrition_fiber_amount': 1.7256179297,
#    'avg_nutrition_folate_amount': 37.2045090472,
#    'avg_nutrition_iron_amount': 2.1124744003,
#    'avg_nutrition_magnesium_amount': 35.9174353417,
#    'avg_nutrition_niacin_amount': 7.4428182825,
#    'avg_nutrition_potassium_amount': 485.7328086667,
#    'avg_nutrition_protein_amount': 22.2195323972,
#    'avg_nutrition_saturatedFat_amount': 6.6355355778,
#    'avg_nutrition_sodium_amount': 517.4037447222,
#    'avg_nutrition_sugars_amount': 12.5067168083,
#    'avg_nutrition_thiamin_amount': 0.2069363738,
#    'avg_nutrition_vitaminA_amount': 1082.5959986111,
#    'avg_nutrition_vitaminB6_amount': 0.3818206276,
#    'avg_nutrition_vitaminC_amount': 16.2750596833,
#    'avg_prepMinutes': 15.9722222222,
#    'avg_ratingAverage': 3.9128514572,
#    'avg_ratingCount': 141.6944444444,
#    'avg_readyInMinutes': 263.8055555556,
#    'avg_reviewCount': 103.4722222222,
#    'avg_servings': 10.9444444444,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.0,
#    'avg_similarRecipes_metaData_totalCount': 14.0,
#    'avg_submitter_favoritesCount': 156.25,
#    'avg_submitter_followersCount': 17.5277777778,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 36.2222222222,
#    'avg_submitter_personalRecipeSharedCount': 7.7222222222,
#    'avg_submitter_ratingsCount': 35.8333333333,
#    'avg_submitter_reciepesCount': 3.2777777778,
#    'avg_submitter_reviewsCount': 32.3611111111,
#    'database_name': 'alaska',
#    'geo_identifier': '02',
#    'geo_name': 'Alaska',
#    'nbRecipes': 36},
#   {'avg_cookMinutes': 29.6666666667,
#    'avg_nutrition_calcium_amount': 89.3378013333,
#    'avg_nutrition_caloriesFromFat_amount': 125.7254903333,
#    'avg_nutrition_calories_amount': 297.9107403333,
#    'avg_nutrition_carbohydrates_amount': 33.9620595667,
#    'avg_nutrition_cholesterol_amount': 45.1346885,
#    'avg_nutrition_fat_amount': 13.9694989667,
#    'avg_nutrition_fiber_amount': 3.3793476767,
#    'avg_nutrition_folate_amount': 50.2434609067,
#    'avg_nutrition_iron_amount': 2.0058182112,
#    'avg_nutrition_magnesium_amount': 37.1905779667,
#    'avg_nutrition_niacin_amount': 4.8571287447,
#    'avg_nutrition_potassium_amount': 461.2649783333,
#    'avg_nutrition_protein_amount': 10.12427179,
#    'avg_nutrition_saturatedFat_amount': 5.59332547,
#    'avg_nutrition_sodium_amount': 324.3166963333,
#    'avg_nutrition_sugars_amount': 15.64299254,
#    'avg_nutrition_thiamin_amount': 0.1933300801,
#    'avg_nutrition_vitaminA_amount': 5948.6307425667,
#    'avg_nutrition_vitaminB6_amount': 0.2927254558,
#    'avg_nutrition_vitaminC_amount': 18.543776336,
#    'avg_prepMinutes': 21.5333333333,
#    'avg_ratingAverage': 4.360933108,
#    'avg_ratingCount': 130.9333333333,
#    'avg_readyInMinutes': 57.5333333333,
#    'avg_reviewCount': 100.4333333333,
#    'avg_servings': 12.9666666667,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.4666666667,
#    'avg_similarRecipes_metaData_totalCount': 14.4666666667,
#    'avg_submitter_favoritesCount': 60.9,
#    'avg_submitter_followersCount': 5.9666666667,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 5.2333333333,
#    'avg_submitter_personalRecipeSharedCount': 1.5666666667,
#    'avg_submitter_ratingsCount': 5.1,
#    'avg_submitter_reciepesCount': 2.0,
#    'avg_submitter_reviewsCount': 4.5666666667,
#    'database_name': 'south-dakota',
#    'geo_identifier': '46',
#    'geo_name': 'South Dakota',
#    'nbRecipes': 30},
#   {'avg_cookMinutes': 106.8918918919,
#    'avg_nutrition_calcium_amount': 65.1385527027,
#    'avg_nutrition_caloriesFromFat_amount': 101.3771043378,
#    'avg_nutrition_calories_amount': 211.9236606216,
#    'avg_nutrition_carbohydrates_amount': 15.0260340486,
#    'avg_nutrition_cholesterol_amount': 46.3623013784,
#    'avg_nutrition_fat_amount': 11.2641222824,
#    'avg_nutrition_fiber_amount': 1.2318723822,
#    'avg_nutrition_folate_amount': 20.0968515405,
#    'avg_nutrition_iron_amount': 2.1542095516,
#    'avg_nutrition_magnesium_amount': 24.1267823486,
#    'avg_nutrition_niacin_amount': 5.0176823224,
#    'avg_nutrition_potassium_amount': 341.8459818919,
#    'avg_nutrition_protein_amount': 12.3336353649,
#    'avg_nutrition_saturatedFat_amount': 4.5299736999,
#    'avg_nutrition_sodium_amount': 595.9440113514,
#    'avg_nutrition_sugars_amount': 8.093933703,
#    'avg_nutrition_thiamin_amount': 0.219732994,
#    'avg_nutrition_vitaminA_amount': 952.2068537838,
#    'avg_nutrition_vitaminB6_amount': 0.220669927,
#    'avg_nutrition_vitaminC_amount': 7.1761824243,
#    'avg_prepMinutes': 23.1081081081,
#    'avg_ratingAverage': 4.1113635073,
#    'avg_ratingCount': 47.7027027027,
#    'avg_readyInMinutes': 358.9189189189,
#    'avg_reviewCount': 37.9189189189,
#    'avg_servings': 17.1351351351,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.0540540541,
#    'avg_similarRecipes_metaData_totalCount': 15.0540540541,
#    'avg_submitter_favoritesCount': 146.7837837838,
#    'avg_submitter_followersCount': 2069.1621621622,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 31.2702702703,
#    'avg_submitter_personalRecipeSharedCount': 1.8918918919,
#    'avg_submitter_ratingsCount': 30.7837837838,
#    'avg_submitter_reciepesCount': 50.3513513514,
#    'avg_submitter_reviewsCount': 13.1621621622,
#    'database_name': 'north-carolina',
#    'geo_identifier': '37',
#    'geo_name': 'North Carolina',
#    'nbRecipes': 37}]}

# %% [markdown]
# # Getting the nutrition intake values

# %%
# install: pip install html5lib, pip install lxml, pip install bs4
# see http://stackoverflow.com/questions/38447738/beautifulsoup-html5lib-module-object-has-no-attribute-base
# if this doesn't run straightforwardly

reference_intakes_website = 'https://en.wikipedia.org/wiki/Dietary_Reference_Intake' # Wikipedia
intake_tables = pd.read_html(reference_intakes_website, header=0, na_values=['NE', 'ND']) # na values requires version 0.19.1
intake_df = pd.DataFrame(intake_tables[0])
intake_df = intake_df.rename(columns={'EAR': 'Estimated', 'RDA/AI': 'Recommended', 'UL[6]': 'Tolerable', 'unit': 'Unit'})
intake_df.head(10)
#intake_df
# Out:
#                    Nutrient  Estimated  Recommended Tolerable Unit  \
# 0                 Vitamin A      625.0        900.0      3000   µg
# 1                 Vitamin C       75.0         90.0      2000   mg
# 2              Vitamin D[9]       10.0         15.0       100   µg
# 3                 Vitamin K        NaN        120.0       NaN   µg
# 4                Vitamin B6        1.1          1.3       100   mg
# 5  α-tocopherol (Vitamin E)       12.0         15.0      1000   mg
# 6               Biotin (B7)        NaN         30.0       NaN   µg
# 7                Calcium[9]      800.0       1000.0      2500   mg
# 8                  Chloride        NaN       2300.0      3600   mg
# 9                  Chromium        NaN         35.0       NaN   µg
#
#              Top sources in common measures, USDA[7]
# 0  turkey and chicken giblets, liver, red capsicu...
# 1  guavas, oranges, grapefruits, frozen peaches,[...
# 2  fortified cereals, mushrooms, yeast, sockeye s...
# 3  kale, collards, spinach, broccoli, brussel spr...
# 4       fortified cereals, chickpeas, sockeye salmon
# 5   fortified cereals, tomato paste, sunflower seeds
# 6  whole grains, almonds, peanuts, beef liver, eg...
# 7  fortified cereals, collards, almonds, condense...
# 8                                         table salt
# 9  broccoli, turkey ham, dried apricots, tuna, pi...

# %%
import re
myStr = 'Vitamin D[9]'
myStr = re.sub(r'\[.*\]', '', myStr)
myStr = myStr.replace(' ', '')
myStr
# Out:
# 'VitaminD'

# %%
def simplify_name(myStr):
    myStr = re.sub(r'\[.*\]', '', myStr)
    myStr = myStr.replace(' ', '')
    myStr = myStr.lower()
    return myStr

# %%
additional_daily_intake_dict = {
    'Fat': 65, #g
    'SaturatedFat': 20, #g
    'Cholesterol': 300, #mg
    'protein': 56, #g
    'calories': 2000, #kcal
    'caloriesFromFat': 400, #kcal
    'carbohydrates': 130, #g
    'sugars': 30, #g
    'fiber': 38, #g
}
units = ['g', 'g', 'mg', 'g', 'kcal', 'kcal', 'g', 'g', 'g'];
additional_df = pd.DataFrame.from_dict([(key, value) for (key, value) in additional_daily_intake_dict.items()])
additional_df.columns=['Nutrient', 'Recommended']
additional_df['Unit'] = units
#additional_df

intake_df = pd.concat([intake_df, additional_df], axis=0)
intake_df = intake_df.reset_index()

intake_df['simpleName'] = intake_df['Nutrient'].map(simplify_name)
intake_df.head(3)
# Out:
#    index  Estimated      Nutrient  Recommended Tolerable  \
# 0      0      625.0     Vitamin A        900.0      3000
# 1      1       75.0     Vitamin C         90.0      2000
# 2      2       10.0  Vitamin D[9]         15.0       100
#
#              Top sources in common measures, USDA[7] Unit simpleName
# 0  turkey and chicken giblets, liver, red capsicu...   µg   vitamina
# 1  guavas, oranges, grapefruits, frozen peaches,[...   mg   vitaminc
# 2  fortified cereals, mushrooms, yeast, sockeye s...   µg   vitamind

# %%
# We can take this column
assert( not intake_df[['Recommended', 'Unit']].isnull().values.any() )

# %%
# from nutrition fields in database to information about this nutrition
intake_map = dict()

for field_key in database_aggregated_content['global']['Global aggregation']:
    if "nutrition" in field_key:
        searchObj = re.search( r'nutrition_(.*)_amount', field_key, re.M|re.I) # first occurrence only
        if not searchObj:
            print("Error processing {}".format(field_key))
            continue
        nutrition_name = searchObj.group(1)
        
        # 'Estimated', 'Recommended', 'Tolerable'
        nutrition_data = intake_df[intake_df['simpleName'].str.contains(nutrition_name.lower())][['Recommended', 'Unit']]
        nutrition_data = nutrition_data.iloc[0] # only first entry
        if len(nutrition_data) == 0:
            additional_daily_intake_map
        if len(nutrition_data) == 0:
            print("Could not map nutrition {}".format(field_key))
            continue
        intake_map[field_key] = nutrition_data.values

# %%
intake_map
# Out:
# {'avg_nutrition_calcium_amount': array([1000.0, 'mg'], dtype=object),
#  'avg_nutrition_caloriesFromFat_amount': array([400.0, 'kcal'], dtype=object),
#  'avg_nutrition_calories_amount': array([400.0, 'kcal'], dtype=object),
#  'avg_nutrition_carbohydrates_amount': array([130.0, 'g'], dtype=object),
#  'avg_nutrition_cholesterol_amount': array([300.0, 'kcal'], dtype=object),
#  'avg_nutrition_fat_amount': array([20.0, 'g'], dtype=object),
#  'avg_nutrition_fiber_amount': array([38.0, 'g'], dtype=object),
#  'avg_nutrition_folate_amount': array([400.0, 'µg'], dtype=object),
#  'avg_nutrition_iron_amount': array([8.0, 'mg'], dtype=object),
#  'avg_nutrition_magnesium_amount': array([420.0, 'mg'], dtype=object),
#  'avg_nutrition_niacin_amount': array([16.0, 'mg'], dtype=object),
#  'avg_nutrition_potassium_amount': array([4700.0, 'mg'], dtype=object),
#  'avg_nutrition_protein_amount': array([56.0, 'g'], dtype=object),
#  'avg_nutrition_saturatedFat_amount': array([20.0, 'g'], dtype=object),
#  'avg_nutrition_sodium_amount': array([1500.0, 'mg'], dtype=object),
#  'avg_nutrition_sugars_amount': array([30.0, 'g'], dtype=object),
#  'avg_nutrition_thiamin_amount': array([1.2, 'mg'], dtype=object),
#  'avg_nutrition_vitaminA_amount': array([900.0, 'µg'], dtype=object),
#  'avg_nutrition_vitaminB6_amount': array([1.3, 'mg'], dtype=object),
#  'avg_nutrition_vitaminC_amount': array([90.0, 'mg'], dtype=object)}

# %% [markdown]
# We now add this data to the json aggregated data.

# %%
intake_field_name = 'daily_recommended_intake'
database_aggregated_content[intake_field_name] = dict()
for (nutrition_key, nutr_values) in intake_map.items():
    database_aggregated_content[intake_field_name][nutrition_key] = {'Recommended': nutr_values[0], 'unit': nutr_values[1]}

# %%
database_aggregated_content
# Out:
# {'daily_recommended_intake': {'avg_nutrition_calcium_amount': {'Recommended': 1000.0,
#    'unit': 'mg'},
#   'avg_nutrition_caloriesFromFat_amount': {'Recommended': 400.0,
#    'unit': 'kcal'},
#   'avg_nutrition_calories_amount': {'Recommended': 400.0, 'unit': 'kcal'},
#   'avg_nutrition_carbohydrates_amount': {'Recommended': 130.0, 'unit': 'g'},
#   'avg_nutrition_cholesterol_amount': {'Recommended': 300.0, 'unit': 'kcal'},
#   'avg_nutrition_fat_amount': {'Recommended': 20.0, 'unit': 'g'},
#   'avg_nutrition_fiber_amount': {'Recommended': 38.0, 'unit': 'g'},
#   'avg_nutrition_folate_amount': {'Recommended': 400.0, 'unit': 'µg'},
#   'avg_nutrition_iron_amount': {'Recommended': 8.0, 'unit': 'mg'},
#   'avg_nutrition_magnesium_amount': {'Recommended': 420.0, 'unit': 'mg'},
#   'avg_nutrition_niacin_amount': {'Recommended': 16.0, 'unit': 'mg'},
#   'avg_nutrition_potassium_amount': {'Recommended': 4700.0, 'unit': 'mg'},
#   'avg_nutrition_protein_amount': {'Recommended': 56.0, 'unit': 'g'},
#   'avg_nutrition_saturatedFat_amount': {'Recommended': 20.0, 'unit': 'g'},
#   'avg_nutrition_sodium_amount': {'Recommended': 1500.0, 'unit': 'mg'},
#   'avg_nutrition_sugars_amount': {'Recommended': 30.0, 'unit': 'g'},
#   'avg_nutrition_thiamin_amount': {'Recommended': 1.2, 'unit': 'mg'},
#   'avg_nutrition_vitaminA_amount': {'Recommended': 900.0, 'unit': 'µg'},
#   'avg_nutrition_vitaminB6_amount': {'Recommended': 1.3, 'unit': 'mg'},
#   'avg_nutrition_vitaminC_amount': {'Recommended': 90.0, 'unit': 'mg'}},
#  'global': {'Global aggregation': {'avg_cookMinutes': 41.1077453516,
#    'avg_nutrition_calcium_amount': 114.9318745406,
#    'avg_nutrition_caloriesFromFat_amount': 160.0322171934,
#    'avg_nutrition_calories_amount': 350.2467986302,
#    'avg_nutrition_carbohydrates_amount': 31.5380632211,
#    'avg_nutrition_cholesterol_amount': 66.2203374766,
#    'avg_nutrition_fat_amount': 17.7817337376,
#    'avg_nutrition_fiber_amount': 3.1178096283,
#    'avg_nutrition_folate_amount': 60.2745651289,
#    'avg_nutrition_iron_amount': 2.6678069684,
#    'avg_nutrition_magnesium_amount': 42.7467841021,
#    'avg_nutrition_niacin_amount': 6.5819486949,
#    'avg_nutrition_potassium_amount': 434.1991336157,
#    'avg_nutrition_protein_amount': 16.2278095183,
#    'avg_nutrition_saturatedFat_amount': 6.5396016803,
#    'avg_nutrition_sodium_amount': 661.4516873115,
#    'avg_nutrition_sugars_amount': 9.8466210198,
#    'avg_nutrition_thiamin_amount': 0.2271286606,
#    'avg_nutrition_vitaminA_amount': 1418.1540015684,
#    'avg_nutrition_vitaminB6_amount': 0.3188769283,
#    'avg_nutrition_vitaminC_amount': 18.3412098224,
#    'avg_prepMinutes': 20.2409186061,
#    'avg_ratingAverage': 4.0803297995,
#    'avg_ratingCount': 102.3711981283,
#    'avg_readyInMinutes': 157.1372367935,
#    'avg_reviewCount': 77.7717029922,
#    'avg_servings': 10.2102573575,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.7297130895,
#    'avg_similarRecipes_metaData_totalCount': 14.7297130895,
#    'avg_submitter_favoritesCount': 151.0502401182,
#    'avg_submitter_followersCount': 7870.611685753,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 30.7689939663,
#    'avg_submitter_personalRecipeSharedCount': 8.0709272257,
#    'avg_submitter_ratingsCount': 29.7984238394,
#    'avg_submitter_reciepesCount': 22.6657431351,
#    'avg_submitter_reviewsCount': 23.1030045561,
#    'nbRecipes': 16242}},
#  'per_city': [{'avg_cookMinutes': 49.1126760563,
#    'avg_nutrition_calcium_amount': 99.2761648714,
#    'avg_nutrition_caloriesFromFat_amount': 182.5339954329,
#    'avg_nutrition_calories_amount': 358.6492397143,
#    'avg_nutrition_carbohydrates_amount': 34.2082966414,
#    'avg_nutrition_cholesterol_amount': 58.2635068286,
#    'avg_nutrition_fat_amount': 20.2815547511,
#    'avg_nutrition_fiber_amount': 2.5095388411,
#    'avg_nutrition_folate_amount': 52.4274617571,
#    'avg_nutrition_iron_amount': 1.8700171199,
#    'avg_nutrition_magnesium_amount': 36.8129842571,
#    'avg_nutrition_niacin_amount': 4.391119622,
#    'avg_nutrition_potassium_amount': 343.1151770429,
#    'avg_nutrition_protein_amount': 11.0973724957,
#    'avg_nutrition_saturatedFat_amount': 7.3237251565,
#    'avg_nutrition_sodium_amount': 595.0686917429,
#    'avg_nutrition_sugars_amount': 18.6805322896,
#    'avg_nutrition_thiamin_amount': 0.1861195221,
#    'avg_nutrition_vitaminA_amount': 1829.5289358571,
#    'avg_nutrition_vitaminB6_amount': 0.2146132011,
#    'avg_nutrition_vitaminC_amount': 12.11751674,
#    'avg_prepMinutes': 15.5915492958,
#    'avg_ratingAverage': 4.158777641,
#    'avg_ratingCount': 135.338028169,
#    'avg_readyInMinutes': 95.7887323944,
#    'avg_reviewCount': 106.5211267606,
#    'avg_servings': 15.7183098592,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.8591549296,
#    'avg_similarRecipes_metaData_totalCount': 14.8591549296,
#    'avg_submitter_favoritesCount': 139.5633802817,
#    'avg_submitter_followersCount': 5.6901408451,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 17.661971831,
#    'avg_submitter_personalRecipeSharedCount': 9.7042253521,
#    'avg_submitter_ratingsCount': 17.3802816901,
#    'avg_submitter_reciepesCount': 6.5915492958,
#    'avg_submitter_reviewsCount': 15.9154929577,
#    'database_name': 'georgia',
#    'geo_identifier': 'Atlanta',
#    'geo_name': 'Atlanta',
#    'nbRecipes': 71},
#   {'avg_cookMinutes': 35.9842519685,
#    'avg_nutrition_calcium_amount': 82.7725916587,
#    'avg_nutrition_caloriesFromFat_amount': 146.2542457849,
#    'avg_nutrition_calories_amount': 342.3823438095,
#    'avg_nutrition_carbohydrates_amount': 34.4544898103,
#    'avg_nutrition_cholesterol_amount': 62.7981470476,
#    'avg_nutrition_fat_amount': 16.2504720899,
#    'avg_nutrition_fiber_amount': 2.4105628283,
#    'avg_nutrition_folate_amount': 44.3598037056,
#    'avg_nutrition_iron_amount': 2.5025073252,
#    'avg_nutrition_magnesium_amount': 38.5106154627,
#    'avg_nutrition_niacin_amount': 5.92065496,
#    'avg_nutrition_potassium_amount': 389.5275147302,
#    'avg_nutrition_protein_amount': 15.136433368,
#    'avg_nutrition_saturatedFat_amount': 6.8086557517,
#    'avg_nutrition_sodium_amount': 546.5264371206,
#    'avg_nutrition_sugars_amount': 15.3392824762,
#    'avg_nutrition_thiamin_amount': 0.1973573406,
#    'avg_nutrition_vitaminA_amount': 810.4165892246,
#    'avg_nutrition_vitaminB6_amount': 0.2804936542,
#    'avg_nutrition_vitaminC_amount': 12.7607153502,
#    'avg_prepMinutes': 21.4803149606,
#    'avg_ratingAverage': 4.1240063483,
#    'avg_ratingCount': 44.8661417323,
#    'avg_readyInMinutes': 301.3622047244,
#    'avg_reviewCount': 35.1496062992,
#    'avg_servings': 11.6535433071,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.031496063,
#    'avg_similarRecipes_metaData_totalCount': 14.031496063,
#    'avg_submitter_favoritesCount': 172.2598425197,
#    'avg_submitter_followersCount': 9.5511811024,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 21.5118110236,
#    'avg_submitter_personalRecipeSharedCount': 13.0157480315,
#    'avg_submitter_ratingsCount': 19.6850393701,
#    'avg_submitter_reciepesCount': 4.0393700787,
#    'avg_submitter_reviewsCount': 17.3543307087,
#    'database_name': 'vancouver',
#    'geo_identifier': 'Vancouver',
#    'geo_name': 'Vancouver',
#    'nbRecipes': 127},
#   {'avg_cookMinutes': 53.3333333333,
#    'avg_nutrition_calcium_amount': 120.0086608333,
#    'avg_nutrition_caloriesFromFat_amount': 177.4081733333,
#    'avg_nutrition_calories_amount': 424.625025,
#    'avg_nutrition_carbohydrates_amount': 35.1568405,
#    'avg_nutrition_cholesterol_amount': 65.80625,
#    'avg_nutrition_fat_amount': 19.712018,
#    'avg_nutrition_fiber_amount': 5.79568,
#    'avg_nutrition_folate_amount': 85.2405008333,
#    'avg_nutrition_iron_amount': 4.81320185,
#    'avg_nutrition_magnesium_amount': 54.6861808333,
#    'avg_nutrition_niacin_amount': 10.1573376667,
#    'avg_nutrition_potassium_amount': 563.3410333333,
#    'avg_nutrition_protein_amount': 28.6368300833,
#    'avg_nutrition_saturatedFat_amount': 7.5697554833,
#    'avg_nutrition_sodium_amount': 755.1521833333,
#    'avg_nutrition_sugars_amount': 8.8096128083,
#    'avg_nutrition_thiamin_amount': 0.3062611983,
#    'avg_nutrition_vitaminA_amount': 3300.7328333333,
#    'avg_nutrition_vitaminB6_amount': 0.409118955,
#    'avg_nutrition_vitaminC_amount': 16.8670281667,
#    'avg_prepMinutes': 35.0,
#    'avg_ratingAverage': 4.21401596,
#    'avg_ratingCount': 78.5833333333,
#    'avg_readyInMinutes': 140.0,
#    'avg_reviewCount': 62.9166666667,
#    'avg_servings': 9.3333333333,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.75,
#    'avg_similarRecipes_metaData_totalCount': 14.75,
#    'avg_submitter_favoritesCount': 65.6666666667,
#    'avg_submitter_followersCount': 3097.8333333333,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 3.0,
#    'avg_submitter_personalRecipeSharedCount': 5.75,
#    'avg_submitter_ratingsCount': 2.9166666667,
#    'avg_submitter_reciepesCount': 30.25,
#    'avg_submitter_reviewsCount': 2.25,
#    'database_name': 'cincinnati',
#    'geo_identifier': 'Cincinnati',
#    'geo_name': 'Cincinnati',
#    'nbRecipes': 12},
#   {'avg_cookMinutes': 60.7222222222,
#    'avg_nutrition_calcium_amount': 107.5836688889,
#    'avg_nutrition_caloriesFromFat_amount': 191.2437795556,
#    'avg_nutrition_calories_amount': 366.3758511111,
#    'avg_nutrition_carbohydrates_amount': 18.0047835556,
#    'avg_nutrition_cholesterol_amount': 111.187795,
#    'avg_nutrition_fat_amount': 21.2493087111,
#    'avg_nutrition_fiber_amount': 2.6954533056,
#    'avg_nutrition_folate_amount': 42.5995917778,
#    'avg_nutrition_iron_amount': 2.9635454278,
#    'avg_nutrition_magnesium_amount': 51.5887053889,
#    'avg_nutrition_niacin_amount': 8.2419543556,
#    'avg_nutrition_potassium_amount': 542.9018705556,
#    'avg_nutrition_protein_amount': 25.2114449222,
#    'avg_nutrition_saturatedFat_amount': 6.6243364278,
#    'avg_nutrition_sodium_amount': 705.3128685,
#    'avg_nutrition_sugars_amount': 4.3589591333,
#    'avg_nutrition_thiamin_amount': 0.4833365948,
#    'avg_nutrition_vitaminA_amount': 1325.1604157222,
#    'avg_nutrition_vitaminB6_amount': 0.4164473133,
#    'avg_nutrition_vitaminC_amount': 21.3800209278,
#    'avg_prepMinutes': 27.5,
#    'avg_ratingAverage': 3.9081002267,
#    'avg_ratingCount': 71.8333333333,
#    'avg_readyInMinutes': 130.2777777778,
#    'avg_reviewCount': 58.5555555556,
#    'avg_servings': 10.5555555556,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.2222222222,
#    'avg_similarRecipes_metaData_totalCount': 14.2222222222,
#    'avg_submitter_favoritesCount': 91.0555555556,
#    'avg_submitter_followersCount': 8.0,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 14.0555555556,
#    'avg_submitter_personalRecipeSharedCount': 4.7222222222,
#    'avg_submitter_ratingsCount': 13.9444444444,
#    'avg_submitter_reciepesCount': 19.3333333333,
#    'avg_submitter_reviewsCount': 13.2777777778,
#    'database_name': 'houston',
#    'geo_identifier': 'Houston',
#    'geo_name': 'Houston',
#    'nbRecipes': 18},
#   {'avg_cookMinutes': 22.7164179104,
#    'avg_nutrition_calcium_amount': 104.2027518906,
#    'avg_nutrition_caloriesFromFat_amount': 215.4816058281,
#    'avg_nutrition_calories_amount': 415.338245,
#    'avg_nutrition_carbohydrates_amount': 28.9806050203,
#    'avg_nutrition_cholesterol_amount': 81.3847190141,
#    'avg_nutrition_fat_amount': 23.9424004797,
#    'avg_nutrition_fiber_amount': 3.0802562672,
#    'avg_nutrition_folate_amount': 62.2402307969,
#    'avg_nutrition_iron_amount': 4.2691250437,
#    'avg_nutrition_magnesium_amount': 52.0927064688,
#    'avg_nutrition_niacin_amount': 8.757527289,
#    'avg_nutrition_potassium_amount': 517.2492336719,
#    'avg_nutrition_protein_amount': 20.5943655992,
#    'avg_nutrition_saturatedFat_amount': 7.2110913953,
#    'avg_nutrition_sodium_amount': 809.3939725312,
#    'avg_nutrition_sugars_amount': 8.5214698198,
#    'avg_nutrition_thiamin_amount': 0.2829692072,
#    'avg_nutrition_vitaminA_amount': 2170.3961329688,
#    'avg_nutrition_vitaminB6_amount': 0.4587975699,
#    'avg_nutrition_vitaminC_amount': 21.9334769783,
#    'avg_prepMinutes': 15.8805970149,
#    'avg_ratingAverage': 4.323805857,
#    'avg_ratingCount': 307.8507462687,
#    'avg_readyInMinutes': 223.2835820896,
#    'avg_reviewCount': 219.6865671642,
#    'avg_servings': 8.3432835821,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.4776119403,
#    'avg_similarRecipes_metaData_totalCount': 15.4776119403,
#    'avg_submitter_favoritesCount': 362.6119402985,
#    'avg_submitter_followersCount': 154042.9402985075,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 71.9402985075,
#    'avg_submitter_personalRecipeSharedCount': 12.6417910448,
#    'avg_submitter_ratingsCount': 62.7014925373,
#    'avg_submitter_reciepesCount': 19.3432835821,
#    'avg_submitter_reviewsCount': 31.8805970149,
#    'database_name': 'seattle',
#    'geo_identifier': 'Seattle',
#    'geo_name': 'Seattle',
#    'nbRecipes': 67},
#   {'avg_cookMinutes': 40.625,
#    'avg_nutrition_calcium_amount': 107.8039268462,
#    'avg_nutrition_caloriesFromFat_amount': 184.6795501923,
#    'avg_nutrition_calories_amount': 407.6131015385,
#    'avg_nutrition_carbohydrates_amount': 26.8232490538,
#    'avg_nutrition_cholesterol_amount': 90.0401742308,
#    'avg_nutrition_fat_amount': 20.5199484154,
#    'avg_nutrition_fiber_amount': 1.7425228762,
#    'avg_nutrition_folate_amount': 56.2237626923,
#    'avg_nutrition_iron_amount': 3.7296937538,
#    'avg_nutrition_magnesium_amount': 44.7756590769,
#    'avg_nutrition_niacin_amount': 9.271571,
#    'avg_nutrition_potassium_amount': 496.9851723077,
#    'avg_nutrition_protein_amount': 25.2286861538,
#    'avg_nutrition_saturatedFat_amount': 6.8581744877,
#    'avg_nutrition_sodium_amount': 764.01584,
#    'avg_nutrition_sugars_amount': 3.2473853846,
#    'avg_nutrition_thiamin_amount': 0.2769959485,
#    'avg_nutrition_vitaminA_amount': 1214.13568,
#    'avg_nutrition_vitaminB6_amount': 0.4712018831,
#    'avg_nutrition_vitaminC_amount': 6.9153687846,
#    'avg_prepMinutes': 34.375,
#    'avg_ratingAverage': 4.2604424237,
#    'avg_ratingCount': 64.5625,
#    'avg_readyInMinutes': 6382.5,
#    'avg_reviewCount': 49.6875,
#    'avg_servings': 14.6875,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.25,
#    'avg_similarRecipes_metaData_totalCount': 14.25,
#    'avg_submitter_favoritesCount': 21.4375,
#    'avg_submitter_followersCount': 1.3125,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 1.6875,
#    'avg_submitter_personalRecipeSharedCount': 2.375,
#    'avg_submitter_ratingsCount': 1.5625,
#    'avg_submitter_reciepesCount': 1.0625,
#    'avg_submitter_reviewsCount': 1.5,
#    'database_name': 'green-bay',
#    'geo_identifier': 'Milwaukee',
#    'geo_name': 'Green Bay',
#    'nbRecipes': 16},
#   {'avg_cookMinutes': 63.0357142857,
#    'avg_nutrition_calcium_amount': 176.3509592857,
#    'avg_nutrition_caloriesFromFat_amount': 215.4658885714,
#    'avg_nutrition_calories_amount': 483.6879928571,
#    'avg_nutrition_carbohydrates_amount': 44.8913861786,
#    'avg_nutrition_cholesterol_amount': 76.4513171429,
#    'avg_nutrition_fat_amount': 23.9406550357,
#    'avg_nutrition_fiber_amount': 3.7168764329,
#    'avg_nutrition_folate_amount': 87.593270625,
#    'avg_nutrition_iron_amount': 3.181308925,
#    'avg_nutrition_magnesium_amount': 46.9784233571,
#    'avg_nutrition_niacin_amount': 8.0869232025,
#    'avg_nutrition_potassium_amount': 553.1527578571,
#    'avg_nutrition_protein_amount': 22.6650185714,
#    'avg_nutrition_saturatedFat_amount': 9.1614294643,
#    'avg_nutrition_sodium_amount': 1177.559305,
#    'avg_nutrition_sugars_amount': 10.2933764357,
#    'avg_nutrition_thiamin_amount': 0.3739265813,
#    'avg_nutrition_vitaminA_amount': 750.5714234643,
#    'avg_nutrition_vitaminB6_amount': 0.3713053325,
#    'avg_nutrition_vitaminC_amount': 24.3195612929,
#    'avg_prepMinutes': 16.7857142857,
#    'avg_ratingAverage': 4.3639157029,
#    'avg_ratingCount': 193.6428571429,
#    'avg_readyInMinutes': 130.1785714286,
#    'avg_reviewCount': 148.4285714286,
#    'avg_servings': 8.0357142857,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.1785714286,
#    'avg_similarRecipes_metaData_totalCount': 15.1785714286,
#    'avg_submitter_favoritesCount': 63.0714285714,
#    'avg_submitter_followersCount': 3.3571428571,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 9.9285714286,
#    'avg_submitter_personalRecipeSharedCount': 1.9642857143,
#    'avg_submitter_ratingsCount': 9.8571428571,
#    'avg_submitter_reciepesCount': 15.0,
#    'avg_submitter_reviewsCount': 8.9285714286,
#    'database_name': 'pittsburgh',
#    'geo_identifier': 'Pittsburgh',
#    'geo_name': 'Pittsburgh',
#    'nbRecipes': 28},
#   {'avg_cookMinutes': 27.243902439,
#    'avg_nutrition_calcium_amount': 65.7200556195,
#    'avg_nutrition_caloriesFromFat_amount': 155.7728659024,
#    'avg_nutrition_calories_amount': 274.4892507317,
#    'avg_nutrition_carbohydrates_amount': 18.7452494951,
#    'avg_nutrition_cholesterol_amount': 63.7754877317,
#    'avg_nutrition_fat_amount': 17.3080967829,
#    'avg_nutrition_fiber_amount': 1.4754392502,
#    'avg_nutrition_folate_amount': 33.2850871244,
#    'avg_nutrition_iron_amount': 1.9006710515,
#    'avg_nutrition_magnesium_amount': 26.2155527951,
#    'avg_nutrition_niacin_amount': 4.2063185402,
#    'avg_nutrition_potassium_amount': 249.2301235854,
#    'avg_nutrition_protein_amount': 11.4925765829,
#    'avg_nutrition_saturatedFat_amount': 6.653792509,
#    'avg_nutrition_sodium_amount': 751.4575639024,
#    'avg_nutrition_sugars_amount': 6.7007981976,
#    'avg_nutrition_thiamin_amount': 0.1099706034,
#    'avg_nutrition_vitaminA_amount': 586.9734563902,
#    'avg_nutrition_vitaminB6_amount': 0.1978445112,
#    'avg_nutrition_vitaminC_amount': 18.0834784651,
#    'avg_prepMinutes': 12.5609756098,
#    'avg_ratingAverage': 3.9525303493,
#    'avg_ratingCount': 46.2682926829,
#    'avg_readyInMinutes': 58.9512195122,
#    'avg_reviewCount': 36.2682926829,
#    'avg_servings': 11.5365853659,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.6585365854,
#    'avg_similarRecipes_metaData_totalCount': 15.6585365854,
#    'avg_submitter_favoritesCount': 110.8292682927,
#    'avg_submitter_followersCount': 1913.7804878049,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 25.0731707317,
#    'avg_submitter_personalRecipeSharedCount': 9.8536585366,
#    'avg_submitter_ratingsCount': 23.7073170732,
#    'avg_submitter_reciepesCount': 46.6097560976,
#    'avg_submitter_reviewsCount': 7.8048780488,
#    'database_name': 'buffalo',
#    'geo_identifier': 'Buffalo',
#    'geo_name': 'Buffalo',
#    'nbRecipes': 41},
#   {'avg_cookMinutes': 25.9,
#    'avg_nutrition_calcium_amount': 256.67036744,
#    'avg_nutrition_caloriesFromFat_amount': 241.1907634,
#    'avg_nutrition_calories_amount': 510.41504,
#    'avg_nutrition_carbohydrates_amount': 41.94946146,
#    'avg_nutrition_cholesterol_amount': 91.16037164,
#    'avg_nutrition_fat_amount': 26.79897344,
#    'avg_nutrition_fiber_amount': 2.629553508,
#    'avg_nutrition_folate_amount': 66.51275544,
#    'avg_nutrition_iron_amount': 3.120636906,
#    'avg_nutrition_magnesium_amount': 42.76173593,
#    'avg_nutrition_niacin_amount': 7.709990388,
#    'avg_nutrition_potassium_amount': 400.41947886,
#    'avg_nutrition_protein_amount': 24.51036292,
#    'avg_nutrition_saturatedFat_amount': 11.22191714,
#    'avg_nutrition_sodium_amount': 969.3789018,
#    'avg_nutrition_sugars_amount': 10.181250826,
#    'avg_nutrition_thiamin_amount': 0.2211141053,
#    'avg_nutrition_vitaminA_amount': 922.4537942,
#    'avg_nutrition_vitaminB6_amount': 0.3141011734,
#    'avg_nutrition_vitaminC_amount': 18.4969734301,
#    'avg_prepMinutes': 15.6,
#    'avg_ratingAverage': 4.2303322426,
#    'avg_ratingCount': 47.72,
#    'avg_readyInMinutes': 75.32,
#    'avg_reviewCount': 36.82,
#    'avg_servings': 7.82,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.5,
#    'avg_similarRecipes_metaData_totalCount': 14.5,
#    'avg_submitter_favoritesCount': 221.14,
#    'avg_submitter_followersCount': 43661.24,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 61.18,
#    'avg_submitter_personalRecipeSharedCount': 9.26,
#    'avg_submitter_ratingsCount': 59.68,
#    'avg_submitter_reciepesCount': 68.12,
#    'avg_submitter_reviewsCount': 40.48,
#    'database_name': 'philadelphia',
#    'geo_identifier': 'Philadelphia',
#    'geo_name': 'Philadelphia',
#    'nbRecipes': 50},
#   {'avg_cookMinutes': 37.6923076923,
#    'avg_nutrition_calcium_amount': 145.6520065385,
#    'avg_nutrition_caloriesFromFat_amount': 218.9042311538,
#    'avg_nutrition_calories_amount': 448.8614230769,
#    'avg_nutrition_carbohydrates_amount': 35.2154799923,
#    'avg_nutrition_cholesterol_amount': 79.1141545462,
#    'avg_nutrition_fat_amount': 24.3226906923,
#    'avg_nutrition_fiber_amount': 2.8158160346,
#    'avg_nutrition_folate_amount': 65.1093506538,
#    'avg_nutrition_iron_amount': 3.6042783192,
#    'avg_nutrition_magnesium_amount': 60.1629373077,
#    'avg_nutrition_niacin_amount': 8.3302825088,
#    'avg_nutrition_potassium_amount': 579.9714888462,
#    'avg_nutrition_protein_amount': 22.2931578462,
#    'avg_nutrition_saturatedFat_amount': 7.0818176654,
#    'avg_nutrition_sodium_amount': 706.4344396154,
#    'avg_nutrition_sugars_amount': 14.7109440923,
#    'avg_nutrition_thiamin_amount': 0.2790700631,
#    'avg_nutrition_vitaminA_amount': 1532.4941,
#    'avg_nutrition_vitaminB6_amount': 0.3636194046,
#    'avg_nutrition_vitaminC_amount': 17.7529579577,
#    'avg_prepMinutes': 16.9230769231,
#    'avg_ratingAverage': 4.0684482792,
#    'avg_ratingCount': 22.1538461538,
#    'avg_readyInMinutes': 65.3846153846,
#    'avg_reviewCount': 18.3076923077,
#    'avg_servings': 8.4230769231,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 12.0769230769,
#    'avg_similarRecipes_metaData_totalCount': 12.0769230769,
#    'avg_submitter_favoritesCount': 127.2692307692,
#    'avg_submitter_followersCount': 3.5,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 11.4615384615,
#    'avg_submitter_personalRecipeSharedCount': 4.7692307692,
#    'avg_submitter_ratingsCount': 11.1538461538,
#    'avg_submitter_reciepesCount': 1.3846153846,
#    'avg_submitter_reviewsCount': 10.5384615385,
#    'database_name': 'oakland',
#    'geo_identifier': 'San Francisco',
#    'geo_name': 'Oakland',
#    'nbRecipes': 26},
#   {'avg_cookMinutes': 53.9666666667,
#    'avg_nutrition_calcium_amount': 144.626957,
#    'avg_nutrition_caloriesFromFat_amount': 175.34119787,
#    'avg_nutrition_calories_amount': 374.2129283333,
#    'avg_nutrition_carbohydrates_amount': 27.0084856667,
#    'avg_nutrition_cholesterol_amount': 70.7815406667,
#    'avg_nutrition_fat_amount': 19.4823559003,
#    'avg_nutrition_fiber_amount': 4.5759873967,
#    'avg_nutrition_folate_amount': 67.6437203333,
#    'avg_nutrition_iron_amount': 2.9128851667,
#    'avg_nutrition_magnesium_amount': 55.4423327333,
#    'avg_nutrition_niacin_amount': 7.9396035703,
#    'avg_nutrition_potassium_amount': 614.5194593333,
#    'avg_nutrition_protein_amount': 19.6331104167,
#    'avg_nutrition_saturatedFat_amount': 6.9379219367,
#    'avg_nutrition_sodium_amount': 671.3785358,
#    'avg_nutrition_sugars_amount': 5.8711526333,
#    'avg_nutrition_thiamin_amount': 0.2499014367,
#    'avg_nutrition_vitaminA_amount': 1701.4872813333,
#    'avg_nutrition_vitaminB6_amount': 0.5078947378,
#    'avg_nutrition_vitaminC_amount': 51.5466371667,
#    'avg_prepMinutes': 21.0,
#    'avg_ratingAverage': 3.8786580587,
#    'avg_ratingCount': 48.8333333333,
#    'avg_readyInMinutes': 117.8,
#    'avg_reviewCount': 36.3666666667,
#    'avg_servings': 6.7333333333,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 12.9666666667,
#    'avg_similarRecipes_metaData_totalCount': 12.9666666667,
#    'avg_submitter_favoritesCount': 262.6,
#    'avg_submitter_followersCount': 206368.8333333333,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 12.0,
#    'avg_submitter_personalRecipeSharedCount': 9.4333333333,
#    'avg_submitter_ratingsCount': 5.5333333333,
#    'avg_submitter_reciepesCount': 17.1333333333,
#    'avg_submitter_reviewsCount': 5.1333333333,
#    'database_name': 'los-angeles',
#    'geo_identifier': 'Los Angeles',
#    'geo_name': 'Los Angeles',
#    'nbRecipes': 30},
#   {'avg_cookMinutes': 25.125,
#    'avg_nutrition_calcium_amount': 88.0432716818,
#    'avg_nutrition_caloriesFromFat_amount': 135.3280215909,
#    'avg_nutrition_calories_amount': 300.2158104545,
#    'avg_nutrition_carbohydrates_amount': 33.1955072273,
#    'avg_nutrition_cholesterol_amount': 42.0874889091,
#    'avg_nutrition_fat_amount': 15.0364464455,
#    'avg_nutrition_fiber_amount': 2.1658508545,
#    'avg_nutrition_folate_amount': 47.5829189091,
#    'avg_nutrition_iron_amount': 1.7319653,
#    'avg_nutrition_magnesium_amount': 32.0467021364,
#    'avg_nutrition_niacin_amount': 3.974544735,
#    'avg_nutrition_potassium_amount': 243.5239927273,
#    'avg_nutrition_protein_amount': 9.5829484818,
#    'avg_nutrition_saturatedFat_amount': 6.1034923091,
#    'avg_nutrition_sodium_amount': 421.2166277273,
#    'avg_nutrition_sugars_amount': 11.7726006045,
#    'avg_nutrition_thiamin_amount': 0.1217278914,
#    'avg_nutrition_vitaminA_amount': 1676.5504568182,
#    'avg_nutrition_vitaminB6_amount': 0.1577434245,
#    'avg_nutrition_vitaminC_amount': 7.8234801123,
#    'avg_prepMinutes': 10.9166666667,
#    'avg_ratingAverage': 4.2158064117,
#    'avg_ratingCount': 76.25,
#    'avg_readyInMinutes': 42.7083333333,
#    'avg_reviewCount': 60.625,
#    'avg_servings': 13.6666666667,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 12.5416666667,
#    'avg_similarRecipes_metaData_totalCount': 12.5416666667,
#    'avg_submitter_favoritesCount': 98.4166666667,
#    'avg_submitter_followersCount': 2.0416666667,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 19.625,
#    'avg_submitter_personalRecipeSharedCount': 3.0416666667,
#    'avg_submitter_ratingsCount': 19.125,
#    'avg_submitter_reciepesCount': 1.4583333333,
#    'avg_submitter_reviewsCount': 18.125,
#    'database_name': 'kansas-city',
#    'geo_identifier': 'Kansas City',
#    'geo_name': 'Kansas City',
#    'nbRecipes': 24},
#   {'avg_cookMinutes': 84.0,
#    'avg_nutrition_calcium_amount': 108.1172686296,
#    'avg_nutrition_caloriesFromFat_amount': 257.6353418519,
#    'avg_nutrition_calories_amount': 485.8434666667,
#    'avg_nutrition_carbohydrates_amount': 39.3335362222,
#    'avg_nutrition_cholesterol_amount': 87.1776358148,
#    'avg_nutrition_fat_amount': 28.6261497778,
#    'avg_nutrition_fiber_amount': 2.7868702321,
#    'avg_nutrition_folate_amount': 58.530613,
#    'avg_nutrition_iron_amount': 3.1187290704,
#    'avg_nutrition_magnesium_amount': 41.3972659259,
#    'avg_nutrition_niacin_amount': 8.2253497778,
#    'avg_nutrition_potassium_amount': 473.9753051852,
#    'avg_nutrition_protein_amount': 17.6499616778,
#    'avg_nutrition_saturatedFat_amount': 10.6463396704,
#    'avg_nutrition_sodium_amount': 1665.9185703704,
#    'avg_nutrition_sugars_amount': 20.0582743259,
#    'avg_nutrition_thiamin_amount': 0.5404099809,
#    'avg_nutrition_vitaminA_amount': 1428.0750611111,
#    'avg_nutrition_vitaminB6_amount': 0.4252018348,
#    'avg_nutrition_vitaminC_amount': 11.8623023581,
#    'avg_prepMinutes': 16.2592592593,
#    'avg_ratingAverage': 4.3339577211,
#    'avg_ratingCount': 92.0740740741,
#    'avg_readyInMinutes': 113.4074074074,
#    'avg_reviewCount': 72.1481481481,
#    'avg_servings': 10.6296296296,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.8888888889,
#    'avg_similarRecipes_metaData_totalCount': 15.8888888889,
#    'avg_submitter_favoritesCount': 297.5185185185,
#    'avg_submitter_followersCount': 24.5555555556,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 106.2222222222,
#    'avg_submitter_personalRecipeSharedCount': 3.5925925926,
#    'avg_submitter_ratingsCount': 105.8148148148,
#    'avg_submitter_reciepesCount': 1.2962962963,
#    'avg_submitter_reviewsCount': 104.7777777778,
#    'database_name': 'st-louis',
#    'geo_identifier': 'St. Louis',
#    'geo_name': 'St. Louis',
#    'nbRecipes': 27},
#   {'avg_cookMinutes': 35.288,
#    'avg_nutrition_calcium_amount': 95.5071747438,
#    'avg_nutrition_caloriesFromFat_amount': 197.6827069587,
#    'avg_nutrition_calories_amount': 411.8799015702,
#    'avg_nutrition_carbohydrates_amount': 33.5271574231,
#    'avg_nutrition_cholesterol_amount': 85.2771413719,
#    'avg_nutrition_fat_amount': 21.9647443719,
#    'avg_nutrition_fiber_amount': 2.2644520866,
#    'avg_nutrition_folate_amount': 50.1536934959,
#    'avg_nutrition_iron_amount': 2.4951306835,
#    'avg_nutrition_magnesium_amount': 36.3795383471,
#    'avg_nutrition_niacin_amount': 7.206435757,
#    'avg_nutrition_potassium_amount': 418.2511784711,
#    'avg_nutrition_protein_amount': 17.8896237174,
#    'avg_nutrition_saturatedFat_amount': 8.9740257264,
#    'avg_nutrition_sodium_amount': 700.8915924711,
#    'avg_nutrition_sugars_amount': 13.1172453805,
#    'avg_nutrition_thiamin_amount': 0.1932303072,
#    'avg_nutrition_vitaminA_amount': 1417.0557266223,
#    'avg_nutrition_vitaminB6_amount': 0.3385195889,
#    'avg_nutrition_vitaminC_amount': 16.3531299945,
#    'avg_prepMinutes': 16.76,
#    'avg_ratingAverage': 4.1732518509,
#    'avg_ratingCount': 111.336,
#    'avg_readyInMinutes': 160.368,
#    'avg_reviewCount': 88.52,
#    'avg_servings': 9.48,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.072,
#    'avg_similarRecipes_metaData_totalCount': 15.072,
#    'avg_submitter_favoritesCount': 199.608,
#    'avg_submitter_followersCount': 70765.312,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 57.272,
#    'avg_submitter_personalRecipeSharedCount': 6.608,
#    'avg_submitter_ratingsCount': 55.24,
#    'avg_submitter_reciepesCount': 104.256,
#    'avg_submitter_reviewsCount': 24.2,
#    'database_name': 'new-york-city',
#    'geo_identifier': 'New York City',
#    'geo_name': 'New York City',
#    'nbRecipes': 125},
#   {'avg_cookMinutes': 19.3870967742,
#    'avg_nutrition_calcium_amount': 123.9850940333,
#    'avg_nutrition_caloriesFromFat_amount': 152.2295126667,
#    'avg_nutrition_calories_amount': 401.5872333333,
#    'avg_nutrition_carbohydrates_amount': 41.5719148133,
#    'avg_nutrition_cholesterol_amount': 55.5185,
#    'avg_nutrition_fat_amount': 16.9143911333,
#    'avg_nutrition_fiber_amount': 5.1018845483,
#    'avg_nutrition_folate_amount': 73.1248744333,
#    'avg_nutrition_iron_amount': 2.6139855823,
#    'avg_nutrition_magnesium_amount': 71.6664576667,
#    'avg_nutrition_niacin_amount': 7.2018205693,
#    'avg_nutrition_potassium_amount': 711.033659,
#    'avg_nutrition_protein_amount': 22.6181271967,
#    'avg_nutrition_saturatedFat_amount': 3.8838472067,
#    'avg_nutrition_sodium_amount': 743.090265,
#    'avg_nutrition_sugars_amount': 8.9109309767,
#    'avg_nutrition_thiamin_amount': 0.2542885452,
#    'avg_nutrition_vitaminA_amount': 2641.551526,
#    'avg_nutrition_vitaminB6_amount': 0.4836998991,
#    'avg_nutrition_vitaminC_amount': 35.2134353,
#    'avg_prepMinutes': 22.4193548387,
#    'avg_ratingAverage': 3.8715675723,
#    'avg_ratingCount': 176.4516129032,
#    'avg_readyInMinutes': 69.5483870968,
#    'avg_reviewCount': 131.2258064516,
#    'avg_servings': 7.7419354839,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 17.5483870968,
#    'avg_similarRecipes_metaData_totalCount': 17.5483870968,
#    'avg_submitter_favoritesCount': 99.4838709677,
#    'avg_submitter_followersCount': 2748.935483871,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 14.3225806452,
#    'avg_submitter_personalRecipeSharedCount': 5.7741935484,
#    'avg_submitter_ratingsCount': 12.8709677419,
#    'avg_submitter_reciepesCount': 16.0322580645,
#    'avg_submitter_reviewsCount': 12.0322580645,
#    'database_name': 'san-diego',
#    'geo_identifier': 'San Diego',
#    'geo_name': 'San Diego',
#    'nbRecipes': 31},
#   {'avg_cookMinutes': 51.0,
#    'avg_nutrition_calcium_amount': 106.6231562143,
#    'avg_nutrition_caloriesFromFat_amount': 187.0212205714,
#    'avg_nutrition_calories_amount': 425.4122357143,
#    'avg_nutrition_carbohydrates_amount': 35.2995767143,
#    'avg_nutrition_cholesterol_amount': 77.7785842857,
#    'avg_nutrition_fat_amount': 20.78013555,
#    'avg_nutrition_fiber_amount': 1.8113013571,
#    'avg_nutrition_folate_amount': 38.1160503714,
#    'avg_nutrition_iron_amount': 2.8803651857,
#    'avg_nutrition_magnesium_amount': 32.4746160714,
#    'avg_nutrition_niacin_amount': 7.5555770779,
#    'avg_nutrition_potassium_amount': 432.0371707143,
#    'avg_nutrition_protein_amount': 20.4746948193,
#    'avg_nutrition_saturatedFat_amount': 7.5749152914,
#    'avg_nutrition_sodium_amount': 641.9893585714,
#    'avg_nutrition_sugars_amount': 15.7910325714,
#    'avg_nutrition_thiamin_amount': 0.4542568831,
#    'avg_nutrition_vitaminA_amount': 877.3949448714,
#    'avg_nutrition_vitaminB6_amount': 0.3967395311,
#    'avg_nutrition_vitaminC_amount': 7.7831920016,
#    'avg_prepMinutes': 10.8666666667,
#    'avg_ratingAverage': 3.8851282473,
#    'avg_ratingCount': 87.0666666667,
#    'avg_readyInMinutes': 66.8666666667,
#    'avg_reviewCount': 67.6666666667,
#    'avg_servings': 7.9333333333,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.2,
#    'avg_similarRecipes_metaData_totalCount': 15.2,
#    'avg_submitter_favoritesCount': 95.2666666667,
#    'avg_submitter_followersCount': 13.4666666667,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 34.4,
#    'avg_submitter_personalRecipeSharedCount': 6.2666666667,
#    'avg_submitter_ratingsCount': 34.0,
#    'avg_submitter_reciepesCount': 22.2,
#    'avg_submitter_reviewsCount': 30.8666666667,
#    'database_name': 'indianapolis',
#    'geo_identifier': 'Indianapolis',
#    'geo_name': 'Indianapolis',
#    'nbRecipes': 15},
#   {'avg_cookMinutes': 36.1515151515,
#    'avg_nutrition_calcium_amount': 100.1309782121,
#    'avg_nutrition_caloriesFromFat_amount': 207.9462324242,
#    'avg_nutrition_calories_amount': 429.2601442424,
#    'avg_nutrition_carbohydrates_amount': 39.4166334545,
#    'avg_nutrition_cholesterol_amount': 99.5148733636,
#    'avg_nutrition_fat_amount': 23.1051369091,
#    'avg_nutrition_fiber_amount': 3.0080272485,
#    'avg_nutrition_folate_amount': 70.7054735152,
#    'avg_nutrition_iron_amount': 2.7811271091,
#    'avg_nutrition_magnesium_amount': 33.3385739697,
#    'avg_nutrition_niacin_amount': 7.0798285636,
#    'avg_nutrition_potassium_amount': 344.2120930303,
#    'avg_nutrition_protein_amount': 16.4890986364,
#    'avg_nutrition_saturatedFat_amount': 9.2561569848,
#    'avg_nutrition_sodium_amount': 523.6588359697,
#    'avg_nutrition_sugars_amount': 14.4876601697,
#    'avg_nutrition_thiamin_amount': 0.3449261991,
#    'avg_nutrition_vitaminA_amount': 1103.2204585961,
#    'avg_nutrition_vitaminB6_amount': 0.2845104261,
#    'avg_nutrition_vitaminC_amount': 11.7181878182,
#    'avg_prepMinutes': 12.9393939394,
#    'avg_ratingAverage': 4.2665948664,
#    'avg_ratingCount': 76.3636363636,
#    'avg_readyInMinutes': 91.7575757576,
#    'avg_reviewCount': 63.0909090909,
#    'avg_servings': 11.3636363636,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.9696969697,
#    'avg_similarRecipes_metaData_totalCount': 14.9696969697,
#    'avg_submitter_favoritesCount': 27.6666666667,
#    'avg_submitter_followersCount': 2.696969697,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 8.4242424242,
#    'avg_submitter_personalRecipeSharedCount': 2.4242424242,
#    'avg_submitter_ratingsCount': 8.3333333333,
#    'avg_submitter_reciepesCount': 1.6060606061,
#    'avg_submitter_reviewsCount': 8.2424242424,
#    'database_name': 'cleveland',
#    'geo_identifier': 'Cleveland',
#    'geo_name': 'Cleveland',
#    'nbRecipes': 33},
#   {'avg_cookMinutes': 28.5434782609,
#    'avg_nutrition_calcium_amount': 128.9259451163,
#    'avg_nutrition_caloriesFromFat_amount': 200.4084444419,
#    'avg_nutrition_calories_amount': 445.9402834884,
#    'avg_nutrition_carbohydrates_amount': 37.0686305279,
#    'avg_nutrition_cholesterol_amount': 112.8882237209,
#    'avg_nutrition_fat_amount': 22.267603107,
#    'avg_nutrition_fiber_amount': 2.5569047091,
#    'avg_nutrition_folate_amount': 78.3735415814,
#    'avg_nutrition_iron_amount': 3.7052496693,
#    'avg_nutrition_magnesium_amount': 46.5328142558,
#    'avg_nutrition_niacin_amount': 6.4543105844,
#    'avg_nutrition_potassium_amount': 395.3045097674,
#    'avg_nutrition_protein_amount': 17.4942017521,
#    'avg_nutrition_saturatedFat_amount': 9.5023519814,
#    'avg_nutrition_sodium_amount': 845.9362781395,
#    'avg_nutrition_sugars_amount': 10.9223112407,
#    'avg_nutrition_thiamin_amount': 0.3470168237,
#    'avg_nutrition_vitaminA_amount': 992.4081416279,
#    'avg_nutrition_vitaminB6_amount': 0.2601072309,
#    'avg_nutrition_vitaminC_amount': 18.2565974605,
#    'avg_prepMinutes': 21.4565217391,
#    'avg_ratingAverage': 4.3605372796,
#    'avg_ratingCount': 40.6086956522,
#    'avg_readyInMinutes': 1050.3260869565,
#    'avg_reviewCount': 32.3913043478,
#    'avg_servings': 10.347826087,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.152173913,
#    'avg_similarRecipes_metaData_totalCount': 14.152173913,
#    'avg_submitter_favoritesCount': 258.3043478261,
#    'avg_submitter_followersCount': 137098.2173913044,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 56.4347826087,
#    'avg_submitter_personalRecipeSharedCount': 6.8260869565,
#    'avg_submitter_ratingsCount': 52.4565217391,
#    'avg_submitter_reciepesCount': 75.3695652174,
#    'avg_submitter_reviewsCount': 7.5217391304,
#    'database_name': 'new-orleans',
#    'geo_identifier': 'New Orleans',
#    'geo_name': 'New Orleans',
#    'nbRecipes': 46},
#   {'avg_cookMinutes': 39.8780487805,
#    'avg_nutrition_calcium_amount': 85.1226340244,
#    'avg_nutrition_caloriesFromFat_amount': 108.500598678,
#    'avg_nutrition_calories_amount': 291.9175343171,
#    'avg_nutrition_carbohydrates_amount': 25.6473037854,
#    'avg_nutrition_cholesterol_amount': 66.2578526171,
#    'avg_nutrition_fat_amount': 12.0556219332,
#    'avg_nutrition_fiber_amount': 2.9773086473,
#    'avg_nutrition_folate_amount': 58.5151527912,
#    'avg_nutrition_iron_amount': 3.743290641,
#    'avg_nutrition_magnesium_amount': 58.4659303537,
#    'avg_nutrition_niacin_amount': 6.4557232849,
#    'avg_nutrition_potassium_amount': 498.6124517317,
#    'avg_nutrition_protein_amount': 17.9521666288,
#    'avg_nutrition_saturatedFat_amount': 4.4407462082,
#    'avg_nutrition_sodium_amount': 575.5371249512,
#    'avg_nutrition_sugars_amount': 8.0171513306,
#    'avg_nutrition_thiamin_amount': 0.1696685185,
#    'avg_nutrition_vitaminA_amount': 1177.7962191463,
#    'avg_nutrition_vitaminB6_amount': 0.2709673187,
#    'avg_nutrition_vitaminC_amount': 19.2749906017,
#    'avg_prepMinutes': 18.4146341463,
#    'avg_ratingAverage': 3.8753884834,
#    'avg_ratingCount': 88.1463414634,
#    'avg_readyInMinutes': 98.9756097561,
#    'avg_reviewCount': 68.8780487805,
#    'avg_servings': 12.6829268293,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.8536585366,
#    'avg_similarRecipes_metaData_totalCount': 15.8536585366,
#    'avg_submitter_favoritesCount': 164.0731707317,
#    'avg_submitter_followersCount': 11199.1219512195,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 111.9756097561,
#    'avg_submitter_personalRecipeSharedCount': 6.2926829268,
#    'avg_submitter_ratingsCount': 108.7073170732,
#    'avg_submitter_reciepesCount': 269.3170731707,
#    'avg_submitter_reviewsCount': 18.0487804878,
#    'database_name': 'san-francisco',
#    'geo_identifier': 'San Francisco',
#    'geo_name': 'San Francisco',
#    'nbRecipes': 41},
#   {'avg_cookMinutes': 72.6785714286,
#    'avg_nutrition_calcium_amount': 102.0047476071,
#    'avg_nutrition_caloriesFromFat_amount': 214.0845010821,
#    'avg_nutrition_calories_amount': 424.3144992857,
#    'avg_nutrition_carbohydrates_amount': 39.3647434143,
#    'avg_nutrition_cholesterol_amount': 78.3939721071,
#    'avg_nutrition_fat_amount': 23.7871666814,
#    'avg_nutrition_fiber_amount': 3.0967039829,
#    'avg_nutrition_folate_amount': 48.5445705714,
#    'avg_nutrition_iron_amount': 2.1804457757,
#    'avg_nutrition_magnesium_amount': 44.0108625,
#    'avg_nutrition_niacin_amount': 6.04422843,
#    'avg_nutrition_potassium_amount': 440.0926471429,
#    'avg_nutrition_protein_amount': 14.9179720036,
#    'avg_nutrition_saturatedFat_amount': 7.8238756717,
#    'avg_nutrition_sodium_amount': 512.9678246429,
#    'avg_nutrition_sugars_amount': 20.341919475,
#    'avg_nutrition_thiamin_amount': 0.2052050258,
#    'avg_nutrition_vitaminA_amount': 3036.5497525,
#    'avg_nutrition_vitaminB6_amount': 0.2941749989,
#    'avg_nutrition_vitaminC_amount': 11.3826714225,
#    'avg_prepMinutes': 19.8214285714,
#    'avg_ratingAverage': 4.4145081739,
#    'avg_ratingCount': 167.6428571429,
#    'avg_readyInMinutes': 115.3571428571,
#    'avg_reviewCount': 132.3571428571,
#    'avg_servings': 19.6785714286,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.1785714286,
#    'avg_similarRecipes_metaData_totalCount': 15.1785714286,
#    'avg_submitter_favoritesCount': 114.1071428571,
#    'avg_submitter_followersCount': 2.4642857143,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 21.6785714286,
#    'avg_submitter_personalRecipeSharedCount': 4.0357142857,
#    'avg_submitter_ratingsCount': 21.6785714286,
#    'avg_submitter_reciepesCount': 1.5714285714,
#    'avg_submitter_reviewsCount': 20.8571428571,
#    'database_name': 'atlanta',
#    'geo_identifier': 'Atlanta',
#    'geo_name': 'Atlanta',
#    'nbRecipes': 28},
#   {'avg_cookMinutes': 45.9090909091,
#    'avg_nutrition_calcium_amount': 145.0406539091,
#    'avg_nutrition_caloriesFromFat_amount': 177.9834209091,
#    'avg_nutrition_calories_amount': 403.8004090909,
#    'avg_nutrition_carbohydrates_amount': 32.4189234545,
#    'avg_nutrition_cholesterol_amount': 57.7919054545,
#    'avg_nutrition_fat_amount': 19.7759342727,
#    'avg_nutrition_fiber_amount': 3.3221818182,
#    'avg_nutrition_folate_amount': 78.5223227273,
#    'avg_nutrition_iron_amount': 4.0340229091,
#    'avg_nutrition_magnesium_amount': 35.6325027273,
#    'avg_nutrition_niacin_amount': 8.4149930909,
#    'avg_nutrition_potassium_amount': 406.8057072727,
#    'avg_nutrition_protein_amount': 22.7507469091,
#    'avg_nutrition_saturatedFat_amount': 6.2244856364,
#    'avg_nutrition_sodium_amount': 1152.7164454545,
#    'avg_nutrition_sugars_amount': 5.8000551273,
#    'avg_nutrition_thiamin_amount': 0.3377867473,
#    'avg_nutrition_vitaminA_amount': 1159.4425090909,
#    'avg_nutrition_vitaminB6_amount': 0.3570065909,
#    'avg_nutrition_vitaminC_amount': 9.1900536364,
#    'avg_prepMinutes': 21.3636363636,
#    'avg_ratingAverage': 4.2650518455,
#    'avg_ratingCount': 126.1818181818,
#    'avg_readyInMinutes': 130.0,
#    'avg_reviewCount': 93.5454545455,
#    'avg_servings': 5.8181818182,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 17.0,
#    'avg_similarRecipes_metaData_totalCount': 17.0,
#    'avg_submitter_favoritesCount': 115.1818181818,
#    'avg_submitter_followersCount': 3476.1818181818,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 31.1818181818,
#    'avg_submitter_personalRecipeSharedCount': 10.9090909091,
#    'avg_submitter_ratingsCount': 30.4545454545,
#    'avg_submitter_reciepesCount': 84.5454545455,
#    'avg_submitter_reviewsCount': 2.0909090909,
#    'database_name': 'chicago',
#    'geo_identifier': 'Chicago',
#    'geo_name': 'Chicago',
#    'nbRecipes': 11},
#   {'avg_cookMinutes': 16.5172413793,
#    'avg_nutrition_calcium_amount': 84.7029391034,
#    'avg_nutrition_caloriesFromFat_amount': 128.338812069,
#    'avg_nutrition_calories_amount': 281.9190327586,
#    'avg_nutrition_carbohydrates_amount': 29.1065187586,
#    'avg_nutrition_cholesterol_amount': 48.2601582759,
#    'avg_nutrition_fat_amount': 14.259867369,
#    'avg_nutrition_fiber_amount': 3.3479804724,
#    'avg_nutrition_folate_amount': 48.1794948276,
#    'avg_nutrition_iron_amount': 1.9520466376,
#    'avg_nutrition_magnesium_amount': 31.8671556552,
#    'avg_nutrition_niacin_amount': 3.7490150276,
#    'avg_nutrition_potassium_amount': 347.4378434483,
#    'avg_nutrition_protein_amount': 9.7854165345,
#    'avg_nutrition_saturatedFat_amount': 4.5802688862,
#    'avg_nutrition_sodium_amount': 555.5156519655,
#    'avg_nutrition_sugars_amount': 12.2154127862,
#    'avg_nutrition_thiamin_amount': 0.1641491599,
#    'avg_nutrition_vitaminA_amount': 2142.7329715172,
#    'avg_nutrition_vitaminB6_amount': 0.2289084511,
#    'avg_nutrition_vitaminC_amount': 21.5955942847,
#    'avg_prepMinutes': 17.8275862069,
#    'avg_ratingAverage': 4.5723076031,
#    'avg_ratingCount': 107.7586206897,
#    'avg_readyInMinutes': 113.9310344828,
#    'avg_reviewCount': 85.7586206897,
#    'avg_servings': 14.724137931,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 17.2413793103,
#    'avg_similarRecipes_metaData_totalCount': 17.2413793103,
#    'avg_submitter_favoritesCount': 95.724137931,
#    'avg_submitter_followersCount': 1.1034482759,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 10.7931034483,
#    'avg_submitter_personalRecipeSharedCount': 4.7931034483,
#    'avg_submitter_ratingsCount': 10.3103448276,
#    'avg_submitter_reciepesCount': 2.1724137931,
#    'avg_submitter_reviewsCount': 6.2068965517,
#    'database_name': 'dallas',
#    'geo_identifier': 'Dallas',
#    'geo_name': 'Dallas',
#    'nbRecipes': 29},
#   {'avg_cookMinutes': 28.5,
#    'avg_nutrition_calcium_amount': 148.4840393,
#    'avg_nutrition_caloriesFromFat_amount': 219.514829,
#    'avg_nutrition_calories_amount': 446.1634,
#    'avg_nutrition_carbohydrates_amount': 33.1075542,
#    'avg_nutrition_cholesterol_amount': 82.972396,
#    'avg_nutrition_fat_amount': 24.3905374,
#    'avg_nutrition_fiber_amount': 2.58598826,
#    'avg_nutrition_folate_amount': 53.802855,
#    'avg_nutrition_iron_amount': 2.63113087,
#    'avg_nutrition_magnesium_amount': 51.583778,
#    'avg_nutrition_niacin_amount': 7.92152196,
#    'avg_nutrition_potassium_amount': 483.65946,
#    'avg_nutrition_protein_amount': 23.5617041,
#    'avg_nutrition_saturatedFat_amount': 10.7349728,
#    'avg_nutrition_sodium_amount': 1137.50395,
#    'avg_nutrition_sugars_amount': 13.9112817,
#    'avg_nutrition_thiamin_amount': 0.35442256,
#    'avg_nutrition_vitaminA_amount': 534.437133,
#    'avg_nutrition_vitaminB6_amount': 0.385380114,
#    'avg_nutrition_vitaminC_amount': 13.775039369,
#    'avg_prepMinutes': 13.0833333333,
#    'avg_ratingAverage': 4.3271377575,
#    'avg_ratingCount': 68.8333333333,
#    'avg_readyInMinutes': 44.5,
#    'avg_reviewCount': 50.6666666667,
#    'avg_servings': 6.6666666667,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.5,
#    'avg_similarRecipes_metaData_totalCount': 14.5,
#    'avg_submitter_favoritesCount': 88.9166666667,
#    'avg_submitter_followersCount': 3.0,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 10.25,
#    'avg_submitter_personalRecipeSharedCount': 1.8333333333,
#    'avg_submitter_ratingsCount': 10.0,
#    'avg_submitter_reciepesCount': 1.0,
#    'avg_submitter_reviewsCount': 9.6666666667,
#    'database_name': 'miami',
#    'geo_identifier': 'Miami',
#    'geo_name': 'Miami',
#    'nbRecipes': 12},
#   {'avg_cookMinutes': 49.8965517241,
#    'avg_nutrition_calcium_amount': 95.8436251724,
#    'avg_nutrition_caloriesFromFat_amount': 224.125457931,
#    'avg_nutrition_calories_amount': 426.5461631034,
#    'avg_nutrition_carbohydrates_amount': 34.0948805172,
#    'avg_nutrition_cholesterol_amount': 61.7396821379,
#    'avg_nutrition_fat_amount': 24.9028292069,
#    'avg_nutrition_fiber_amount': 3.2539545241,
#    'avg_nutrition_folate_amount': 51.7617023448,
#    'avg_nutrition_iron_amount': 2.6665336345,
# ...
#    'avg_submitter_favoritesCount': 65.3333333333,
#    'avg_submitter_followersCount': 6.2142857143,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 16.1904761905,
#    'avg_submitter_personalRecipeSharedCount': 3.4047619048,
#    'avg_submitter_ratingsCount': 15.8095238095,
#    'avg_submitter_reciepesCount': 2.3095238095,
#    'avg_submitter_reviewsCount': 12.3095238095,
#    'database_name': 'iowa',
#    'geo_identifier': '19',
#    'geo_name': 'Iowa',
#    'nbRecipes': 42},
#   {'avg_cookMinutes': 46.2173913043,
#    'avg_nutrition_calcium_amount': 111.3506937391,
#    'avg_nutrition_caloriesFromFat_amount': 162.6995288261,
#    'avg_nutrition_calories_amount': 337.4189930435,
#    'avg_nutrition_carbohydrates_amount': 30.334356,
#    'avg_nutrition_cholesterol_amount': 60.4299924826,
#    'avg_nutrition_fat_amount': 18.0777249174,
#    'avg_nutrition_fiber_amount': 2.3309225087,
#    'avg_nutrition_folate_amount': 41.1430323044,
#    'avg_nutrition_iron_amount': 2.5439336,
#    'avg_nutrition_magnesium_amount': 37.1001647826,
#    'avg_nutrition_niacin_amount': 6.1728515634,
#    'avg_nutrition_potassium_amount': 413.9601165217,
#    'avg_nutrition_protein_amount': 14.5209468391,
#    'avg_nutrition_saturatedFat_amount': 6.6066718687,
#    'avg_nutrition_sodium_amount': 442.278816087,
#    'avg_nutrition_sugars_amount': 16.5823012565,
#    'avg_nutrition_thiamin_amount': 0.2104034278,
#    'avg_nutrition_vitaminA_amount': 2906.4968978261,
#    'avg_nutrition_vitaminB6_amount': 0.2880107378,
#    'avg_nutrition_vitaminC_amount': 19.6070429539,
#    'avg_prepMinutes': 14.5652173913,
#    'avg_ratingAverage': 4.0911872183,
#    'avg_ratingCount': 232.7826086957,
#    'avg_readyInMinutes': 108.6086956522,
#    'avg_reviewCount': 183.4347826087,
#    'avg_servings': 16.0869565217,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.7826086957,
#    'avg_similarRecipes_metaData_totalCount': 14.7826086957,
#    'avg_submitter_favoritesCount': 302.4347826087,
#    'avg_submitter_followersCount': 86.2608695652,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 97.5217391304,
#    'avg_submitter_personalRecipeSharedCount': 9.7391304348,
#    'avg_submitter_ratingsCount': 85.8260869565,
#    'avg_submitter_reciepesCount': 4.4782608696,
#    'avg_submitter_reviewsCount': 82.2608695652,
#    'database_name': 'new-jersey',
#    'geo_identifier': '34',
#    'geo_name': 'New Jersey',
#    'nbRecipes': 23},
#   {'avg_cookMinutes': 83.8235294118,
#    'avg_nutrition_calcium_amount': 125.5274713235,
#    'avg_nutrition_caloriesFromFat_amount': 180.7351151765,
#    'avg_nutrition_calories_amount': 363.4112755882,
#    'avg_nutrition_carbohydrates_amount': 21.8647600588,
#    'avg_nutrition_cholesterol_amount': 126.2709718235,
#    'avg_nutrition_fat_amount': 20.0816792706,
#    'avg_nutrition_fiber_amount': 1.8208775324,
#    'avg_nutrition_folate_amount': 36.6054144706,
#    'avg_nutrition_iron_amount': 2.5207901618,
#    'avg_nutrition_magnesium_amount': 49.6666091765,
#    'avg_nutrition_niacin_amount': 8.5104273118,
#    'avg_nutrition_potassium_amount': 500.2721791176,
#    'avg_nutrition_protein_amount': 23.5094691765,
#    'avg_nutrition_saturatedFat_amount': 7.8715732429,
#    'avg_nutrition_sodium_amount': 898.7769585294,
#    'avg_nutrition_sugars_amount': 7.4194910735,
#    'avg_nutrition_thiamin_amount': 0.3129009801,
#    'avg_nutrition_vitaminA_amount': 799.3434448529,
#    'avg_nutrition_vitaminB6_amount': 0.3318352868,
#    'avg_nutrition_vitaminC_amount': 13.8162377588,
#    'avg_prepMinutes': 24.5882352941,
#    'avg_ratingAverage': 4.3269966056,
#    'avg_ratingCount': 83.7058823529,
#    'avg_readyInMinutes': 162.0882352941,
#    'avg_reviewCount': 66.3529411765,
#    'avg_servings': 10.1470588235,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.1764705882,
#    'avg_similarRecipes_metaData_totalCount': 15.1764705882,
#    'avg_submitter_favoritesCount': 102.2058823529,
#    'avg_submitter_followersCount': 4.1176470588,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 6.6470588235,
#    'avg_submitter_personalRecipeSharedCount': 5.2352941176,
#    'avg_submitter_ratingsCount': 6.2647058824,
#    'avg_submitter_reciepesCount': 10.3823529412,
#    'avg_submitter_reviewsCount': 5.0588235294,
#    'database_name': 'south-carolina',
#    'geo_identifier': '45',
#    'geo_name': 'South Carolina',
#    'nbRecipes': 34},
#   {'avg_cookMinutes': 60.8644067797,
#    'avg_nutrition_calcium_amount': 140.5805511864,
#    'avg_nutrition_caloriesFromFat_amount': 178.8624615254,
#    'avg_nutrition_calories_amount': 398.2849947458,
#    'avg_nutrition_carbohydrates_amount': 37.0817358814,
#    'avg_nutrition_cholesterol_amount': 83.8922972881,
#    'avg_nutrition_fat_amount': 19.8736068305,
#    'avg_nutrition_fiber_amount': 3.053037139,
#    'avg_nutrition_folate_amount': 61.0128959661,
#    'avg_nutrition_iron_amount': 4.7412773119,
#    'avg_nutrition_magnesium_amount': 47.1958289153,
#    'avg_nutrition_niacin_amount': 6.4735809102,
#    'avg_nutrition_potassium_amount': 578.972800339,
#    'avg_nutrition_protein_amount': 18.2617344695,
#    'avg_nutrition_saturatedFat_amount': 8.2655407407,
#    'avg_nutrition_sodium_amount': 599.7759057627,
#    'avg_nutrition_sugars_amount': 11.1616536678,
#    'avg_nutrition_thiamin_amount': 0.2447240559,
#    'avg_nutrition_vitaminA_amount': 1166.2450000559,
#    'avg_nutrition_vitaminB6_amount': 0.3390079641,
#    'avg_nutrition_vitaminC_amount': 18.1958595105,
#    'avg_prepMinutes': 17.6271186441,
#    'avg_ratingAverage': 4.1015236115,
#    'avg_ratingCount': 213.8813559322,
#    'avg_readyInMinutes': 177.2711864407,
#    'avg_reviewCount': 164.2881355932,
#    'avg_servings': 11.186440678,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.8644067797,
#    'avg_similarRecipes_metaData_totalCount': 15.8644067797,
#    'avg_submitter_favoritesCount': 138.813559322,
#    'avg_submitter_followersCount': 21.2033898305,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 11.6271186441,
#    'avg_submitter_personalRecipeSharedCount': 5.3389830508,
#    'avg_submitter_ratingsCount': 10.9830508475,
#    'avg_submitter_reciepesCount': 3.9322033898,
#    'avg_submitter_reviewsCount': 10.6101694915,
#    'database_name': 'maine',
#    'geo_identifier': '23',
#    'geo_name': 'Maine',
#    'nbRecipes': 59},
#   {'avg_cookMinutes': 19.0961538462,
#    'avg_nutrition_calcium_amount': 93.1902522157,
#    'avg_nutrition_caloriesFromFat_amount': 154.1174768431,
#    'avg_nutrition_calories_amount': 313.6181192157,
#    'avg_nutrition_carbohydrates_amount': 27.8004294549,
#    'avg_nutrition_cholesterol_amount': 54.1407658235,
#    'avg_nutrition_fat_amount': 17.1241639098,
#    'avg_nutrition_fiber_amount': 2.422326092,
#    'avg_nutrition_folate_amount': 46.8348743137,
#    'avg_nutrition_iron_amount': 1.679650332,
#    'avg_nutrition_magnesium_amount': 35.5439486392,
#    'avg_nutrition_niacin_amount': 4.4413471771,
#    'avg_nutrition_potassium_amount': 306.2544708824,
#    'avg_nutrition_protein_amount': 11.8300800196,
#    'avg_nutrition_saturatedFat_amount': 6.4686361235,
#    'avg_nutrition_sodium_amount': 360.1029626863,
#    'avg_nutrition_sugars_amount': 13.632301382,
#    'avg_nutrition_thiamin_amount': 0.1613280974,
#    'avg_nutrition_vitaminA_amount': 680.4262564706,
#    'avg_nutrition_vitaminB6_amount': 0.1824981687,
#    'avg_nutrition_vitaminC_amount': 15.4689219898,
#    'avg_prepMinutes': 15.1153846154,
#    'avg_ratingAverage': 4.1549933046,
#    'avg_ratingCount': 204.4615384615,
#    'avg_readyInMinutes': 56.6538461538,
#    'avg_reviewCount': 148.2692307692,
#    'avg_servings': 12.7115384615,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.6346153846,
#    'avg_similarRecipes_metaData_totalCount': 14.6346153846,
#    'avg_submitter_favoritesCount': 100.8653846154,
#    'avg_submitter_followersCount': 7.3076923077,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 13.0,
#    'avg_submitter_personalRecipeSharedCount': 5.2884615385,
#    'avg_submitter_ratingsCount': 12.5961538462,
#    'avg_submitter_reciepesCount': 2.5192307692,
#    'avg_submitter_reviewsCount': 11.25,
#    'database_name': 'oregon',
#    'geo_identifier': '41',
#    'geo_name': 'Oregon',
#    'nbRecipes': 52},
#   {'avg_cookMinutes': 44.6470588235,
#    'avg_nutrition_calcium_amount': 70.3181940588,
#    'avg_nutrition_caloriesFromFat_amount': 161.1705175588,
#    'avg_nutrition_calories_amount': 349.3525404412,
#    'avg_nutrition_carbohydrates_amount': 35.0727387338,
#    'avg_nutrition_cholesterol_amount': 68.0991680294,
#    'avg_nutrition_fat_amount': 17.9078349074,
#    'avg_nutrition_fiber_amount': 1.8288597378,
#    'avg_nutrition_folate_amount': 44.3332465147,
#    'avg_nutrition_iron_amount': 1.8574309618,
#    'avg_nutrition_magnesium_amount': 29.6787246471,
#    'avg_nutrition_niacin_amount': 4.6042626999,
#    'avg_nutrition_potassium_amount': 263.9175884706,
#    'avg_nutrition_protein_amount': 11.3250072047,
#    'avg_nutrition_saturatedFat_amount': 6.9678136168,
#    'avg_nutrition_sodium_amount': 611.9731071912,
#    'avg_nutrition_sugars_amount': 19.3360348401,
#    'avg_nutrition_thiamin_amount': 0.1864508676,
#    'avg_nutrition_vitaminA_amount': 1068.6486310294,
#    'avg_nutrition_vitaminB6_amount': 0.1977227142,
#    'avg_nutrition_vitaminC_amount': 8.1342030818,
#    'avg_prepMinutes': 15.9852941176,
#    'avg_ratingAverage': 4.3242521837,
#    'avg_ratingCount': 71.1911764706,
#    'avg_readyInMinutes': 243.5735294118,
#    'avg_reviewCount': 57.6764705882,
#    'avg_servings': 14.6323529412,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.1764705882,
#    'avg_similarRecipes_metaData_totalCount': 15.1764705882,
#    'avg_submitter_favoritesCount': 65.2647058824,
#    'avg_submitter_followersCount': 12.2941176471,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 6.5,
#    'avg_submitter_personalRecipeSharedCount': 4.4705882353,
#    'avg_submitter_ratingsCount': 6.6323529412,
#    'avg_submitter_reciepesCount': 12.1764705882,
#    'avg_submitter_reviewsCount': 6.1617647059,
#    'database_name': 'mississippi',
#    'geo_identifier': '28',
#    'geo_name': 'Mississippi',
#    'nbRecipes': 68},
#   {'avg_cookMinutes': 68.9444444444,
#    'avg_nutrition_calcium_amount': 110.7658201389,
#    'avg_nutrition_caloriesFromFat_amount': 187.3793991667,
#    'avg_nutrition_calories_amount': 380.5956652778,
#    'avg_nutrition_carbohydrates_amount': 25.6781879722,
#    'avg_nutrition_cholesterol_amount': 96.5384327778,
#    'avg_nutrition_fat_amount': 20.8199330833,
#    'avg_nutrition_fiber_amount': 1.7256179297,
#    'avg_nutrition_folate_amount': 37.2045090472,
#    'avg_nutrition_iron_amount': 2.1124744003,
#    'avg_nutrition_magnesium_amount': 35.9174353417,
#    'avg_nutrition_niacin_amount': 7.4428182825,
#    'avg_nutrition_potassium_amount': 485.7328086667,
#    'avg_nutrition_protein_amount': 22.2195323972,
#    'avg_nutrition_saturatedFat_amount': 6.6355355778,
#    'avg_nutrition_sodium_amount': 517.4037447222,
#    'avg_nutrition_sugars_amount': 12.5067168083,
#    'avg_nutrition_thiamin_amount': 0.2069363738,
#    'avg_nutrition_vitaminA_amount': 1082.5959986111,
#    'avg_nutrition_vitaminB6_amount': 0.3818206276,
#    'avg_nutrition_vitaminC_amount': 16.2750596833,
#    'avg_prepMinutes': 15.9722222222,
#    'avg_ratingAverage': 3.9128514572,
#    'avg_ratingCount': 141.6944444444,
#    'avg_readyInMinutes': 263.8055555556,
#    'avg_reviewCount': 103.4722222222,
#    'avg_servings': 10.9444444444,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.0,
#    'avg_similarRecipes_metaData_totalCount': 14.0,
#    'avg_submitter_favoritesCount': 156.25,
#    'avg_submitter_followersCount': 17.5277777778,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 36.2222222222,
#    'avg_submitter_personalRecipeSharedCount': 7.7222222222,
#    'avg_submitter_ratingsCount': 35.8333333333,
#    'avg_submitter_reciepesCount': 3.2777777778,
#    'avg_submitter_reviewsCount': 32.3611111111,
#    'database_name': 'alaska',
#    'geo_identifier': '02',
#    'geo_name': 'Alaska',
#    'nbRecipes': 36},
#   {'avg_cookMinutes': 29.6666666667,
#    'avg_nutrition_calcium_amount': 89.3378013333,
#    'avg_nutrition_caloriesFromFat_amount': 125.7254903333,
#    'avg_nutrition_calories_amount': 297.9107403333,
#    'avg_nutrition_carbohydrates_amount': 33.9620595667,
#    'avg_nutrition_cholesterol_amount': 45.1346885,
#    'avg_nutrition_fat_amount': 13.9694989667,
#    'avg_nutrition_fiber_amount': 3.3793476767,
#    'avg_nutrition_folate_amount': 50.2434609067,
#    'avg_nutrition_iron_amount': 2.0058182112,
#    'avg_nutrition_magnesium_amount': 37.1905779667,
#    'avg_nutrition_niacin_amount': 4.8571287447,
#    'avg_nutrition_potassium_amount': 461.2649783333,
#    'avg_nutrition_protein_amount': 10.12427179,
#    'avg_nutrition_saturatedFat_amount': 5.59332547,
#    'avg_nutrition_sodium_amount': 324.3166963333,
#    'avg_nutrition_sugars_amount': 15.64299254,
#    'avg_nutrition_thiamin_amount': 0.1933300801,
#    'avg_nutrition_vitaminA_amount': 5948.6307425667,
#    'avg_nutrition_vitaminB6_amount': 0.2927254558,
#    'avg_nutrition_vitaminC_amount': 18.543776336,
#    'avg_prepMinutes': 21.5333333333,
#    'avg_ratingAverage': 4.360933108,
#    'avg_ratingCount': 130.9333333333,
#    'avg_readyInMinutes': 57.5333333333,
#    'avg_reviewCount': 100.4333333333,
#    'avg_servings': 12.9666666667,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 14.4666666667,
#    'avg_similarRecipes_metaData_totalCount': 14.4666666667,
#    'avg_submitter_favoritesCount': 60.9,
#    'avg_submitter_followersCount': 5.9666666667,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 5.2333333333,
#    'avg_submitter_personalRecipeSharedCount': 1.5666666667,
#    'avg_submitter_ratingsCount': 5.1,
#    'avg_submitter_reciepesCount': 2.0,
#    'avg_submitter_reviewsCount': 4.5666666667,
#    'database_name': 'south-dakota',
#    'geo_identifier': '46',
#    'geo_name': 'South Dakota',
#    'nbRecipes': 30},
#   {'avg_cookMinutes': 106.8918918919,
#    'avg_nutrition_calcium_amount': 65.1385527027,
#    'avg_nutrition_caloriesFromFat_amount': 101.3771043378,
#    'avg_nutrition_calories_amount': 211.9236606216,
#    'avg_nutrition_carbohydrates_amount': 15.0260340486,
#    'avg_nutrition_cholesterol_amount': 46.3623013784,
#    'avg_nutrition_fat_amount': 11.2641222824,
#    'avg_nutrition_fiber_amount': 1.2318723822,
#    'avg_nutrition_folate_amount': 20.0968515405,
#    'avg_nutrition_iron_amount': 2.1542095516,
#    'avg_nutrition_magnesium_amount': 24.1267823486,
#    'avg_nutrition_niacin_amount': 5.0176823224,
#    'avg_nutrition_potassium_amount': 341.8459818919,
#    'avg_nutrition_protein_amount': 12.3336353649,
#    'avg_nutrition_saturatedFat_amount': 4.5299736999,
#    'avg_nutrition_sodium_amount': 595.9440113514,
#    'avg_nutrition_sugars_amount': 8.093933703,
#    'avg_nutrition_thiamin_amount': 0.219732994,
#    'avg_nutrition_vitaminA_amount': 952.2068537838,
#    'avg_nutrition_vitaminB6_amount': 0.220669927,
#    'avg_nutrition_vitaminC_amount': 7.1761824243,
#    'avg_prepMinutes': 23.1081081081,
#    'avg_ratingAverage': 4.1113635073,
#    'avg_ratingCount': 47.7027027027,
#    'avg_readyInMinutes': 358.9189189189,
#    'avg_reviewCount': 37.9189189189,
#    'avg_servings': 17.1351351351,
#    'avg_similarRecipes_metaData_page': 1.0,
#    'avg_similarRecipes_metaData_pagesize': 15.0540540541,
#    'avg_similarRecipes_metaData_totalCount': 15.0540540541,
#    'avg_submitter_favoritesCount': 146.7837837838,
#    'avg_submitter_followersCount': 2069.1621621622,
#    'avg_submitter_followingCount': 0.0,
#    'avg_submitter_madeRecipesCount': 31.2702702703,
#    'avg_submitter_personalRecipeSharedCount': 1.8918918919,
#    'avg_submitter_ratingsCount': 30.7837837838,
#    'avg_submitter_reciepesCount': 50.3513513514,
#    'avg_submitter_reviewsCount': 13.1621621622,
#    'database_name': 'north-carolina',
#    'geo_identifier': '37',
#    'geo_name': 'North Carolina',
#    'nbRecipes': 37}]}

# %%
database_aggregated_values_full_filename = '../website/data/fullAggregatedData.json'

write_JSON(database_aggregated_values_full_filename, database_aggregated_content)
# !cat {database_aggregated_values_full_filename}
# Out:
# {
#     "per_city": [
#         {
#             "avg_nutrition_fat_amount": 20.2815547511,
#             "avg_readyInMinutes": 95.7887323944,
#             "avg_submitter_personalRecipeSharedCount": 9.7042253521,
#             "avg_nutrition_protein_amount": 11.0973724957,
#             "avg_submitter_reviewsCount": 15.9154929577,
#             "avg_submitter_followersCount": 5.6901408451,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 49.1126760563,
#             "avg_nutrition_vitaminA_amount": 1829.5289358571,
#             "avg_nutrition_niacin_amount": 4.391119622,
#             "avg_nutrition_potassium_amount": 343.1151770429,
#             "avg_nutrition_calories_amount": 358.6492397143,
#             "avg_prepMinutes": 15.5915492958,
#             "avg_submitter_reciepesCount": 6.5915492958,
#             "avg_nutrition_saturatedFat_amount": 7.3237251565,
#             "geo_name": "Atlanta",
#             "avg_nutrition_calcium_amount": 99.2761648714,
#             "avg_nutrition_thiamin_amount": 0.1861195221,
#             "avg_ratingCount": 135.338028169,
#             "avg_similarRecipes_metaData_pagesize": 14.8591549296,
#             "avg_nutrition_fiber_amount": 2.5095388411,
#             "avg_nutrition_sodium_amount": 595.0686917429,
#             "avg_nutrition_sugars_amount": 18.6805322896,
#             "avg_ratingAverage": 4.158777641,
#             "avg_nutrition_carbohydrates_amount": 34.2082966414,
#             "nbRecipes": 71,
#             "avg_nutrition_folate_amount": 52.4274617571,
#             "avg_servings": 15.7183098592,
#             "geo_identifier": "Atlanta",
#             "avg_nutrition_cholesterol_amount": 58.2635068286,
#             "avg_submitter_favoritesCount": 139.5633802817,
#             "avg_nutrition_vitaminC_amount": 12.11751674,
#             "avg_submitter_madeRecipesCount": 17.661971831,
#             "avg_similarRecipes_metaData_totalCount": 14.8591549296,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 36.8129842571,
#             "avg_nutrition_iron_amount": 1.8700171199,
#             "avg_submitter_ratingsCount": 17.3802816901,
#             "avg_reviewCount": 106.5211267606,
#             "avg_nutrition_vitaminB6_amount": 0.2146132011,
#             "database_name": "georgia",
#             "avg_nutrition_caloriesFromFat_amount": 182.5339954329
#         },
#         {
#             "avg_nutrition_fat_amount": 16.2504720899,
#             "avg_readyInMinutes": 301.3622047244,
#             "avg_submitter_personalRecipeSharedCount": 13.0157480315,
#             "avg_nutrition_protein_amount": 15.136433368,
#             "avg_submitter_reviewsCount": 17.3543307087,
#             "avg_submitter_followersCount": 9.5511811024,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 35.9842519685,
#             "avg_nutrition_vitaminA_amount": 810.4165892246,
#             "avg_nutrition_niacin_amount": 5.92065496,
#             "avg_nutrition_potassium_amount": 389.5275147302,
#             "avg_nutrition_calories_amount": 342.3823438095,
#             "avg_prepMinutes": 21.4803149606,
#             "avg_submitter_reciepesCount": 4.0393700787,
#             "avg_nutrition_saturatedFat_amount": 6.8086557517,
#             "geo_name": "Vancouver",
#             "avg_nutrition_calcium_amount": 82.7725916587,
#             "avg_nutrition_thiamin_amount": 0.1973573406,
#             "avg_ratingCount": 44.8661417323,
#             "avg_similarRecipes_metaData_pagesize": 14.031496063,
#             "avg_nutrition_fiber_amount": 2.4105628283,
#             "avg_nutrition_sodium_amount": 546.5264371206,
#             "avg_nutrition_sugars_amount": 15.3392824762,
#             "avg_ratingAverage": 4.1240063483,
#             "avg_nutrition_carbohydrates_amount": 34.4544898103,
#             "nbRecipes": 127,
#             "avg_nutrition_folate_amount": 44.3598037056,
#             "avg_servings": 11.6535433071,
#             "geo_identifier": "Vancouver",
#             "avg_nutrition_cholesterol_amount": 62.7981470476,
#             "avg_submitter_favoritesCount": 172.2598425197,
#             "avg_nutrition_vitaminC_amount": 12.7607153502,
#             "avg_submitter_madeRecipesCount": 21.5118110236,
#             "avg_similarRecipes_metaData_totalCount": 14.031496063,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 38.5106154627,
#             "avg_nutrition_iron_amount": 2.5025073252,
#             "avg_submitter_ratingsCount": 19.6850393701,
#             "avg_reviewCount": 35.1496062992,
#             "avg_nutrition_vitaminB6_amount": 0.2804936542,
#             "database_name": "vancouver",
#             "avg_nutrition_caloriesFromFat_amount": 146.2542457849
#         },
#         {
#             "avg_nutrition_fat_amount": 19.712018,
#             "avg_readyInMinutes": 140.0,
#             "avg_submitter_personalRecipeSharedCount": 5.75,
#             "avg_nutrition_protein_amount": 28.6368300833,
#             "avg_submitter_reviewsCount": 2.25,
#             "avg_submitter_followersCount": 3097.8333333333,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 53.3333333333,
#             "avg_nutrition_vitaminA_amount": 3300.7328333333,
#             "avg_nutrition_niacin_amount": 10.1573376667,
#             "avg_nutrition_potassium_amount": 563.3410333333,
#             "avg_nutrition_calories_amount": 424.625025,
#             "avg_prepMinutes": 35.0,
#             "avg_submitter_reciepesCount": 30.25,
#             "avg_nutrition_saturatedFat_amount": 7.5697554833,
#             "geo_name": "Cincinnati",
#             "avg_nutrition_calcium_amount": 120.0086608333,
#             "avg_nutrition_thiamin_amount": 0.3062611983,
#             "avg_ratingCount": 78.5833333333,
#             "avg_similarRecipes_metaData_pagesize": 14.75,
#             "avg_nutrition_fiber_amount": 5.79568,
#             "avg_nutrition_sodium_amount": 755.1521833333,
#             "avg_nutrition_sugars_amount": 8.8096128083,
#             "avg_ratingAverage": 4.21401596,
#             "avg_nutrition_carbohydrates_amount": 35.1568405,
#             "nbRecipes": 12,
#             "avg_nutrition_folate_amount": 85.2405008333,
#             "avg_servings": 9.3333333333,
#             "geo_identifier": "Cincinnati",
#             "avg_nutrition_cholesterol_amount": 65.80625,
#             "avg_submitter_favoritesCount": 65.6666666667,
#             "avg_nutrition_vitaminC_amount": 16.8670281667,
#             "avg_submitter_madeRecipesCount": 3.0,
#             "avg_similarRecipes_metaData_totalCount": 14.75,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 54.6861808333,
#             "avg_nutrition_iron_amount": 4.81320185,
#             "avg_submitter_ratingsCount": 2.9166666667,
#             "avg_reviewCount": 62.9166666667,
#             "avg_nutrition_vitaminB6_amount": 0.409118955,
#             "database_name": "cincinnati",
#             "avg_nutrition_caloriesFromFat_amount": 177.4081733333
#         },
#         {
#             "avg_nutrition_fat_amount": 21.2493087111,
#             "avg_readyInMinutes": 130.2777777778,
#             "avg_submitter_personalRecipeSharedCount": 4.7222222222,
#             "avg_nutrition_protein_amount": 25.2114449222,
#             "avg_submitter_reviewsCount": 13.2777777778,
#             "avg_submitter_followersCount": 8.0,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 60.7222222222,
#             "avg_nutrition_vitaminA_amount": 1325.1604157222,
#             "avg_nutrition_niacin_amount": 8.2419543556,
#             "avg_nutrition_potassium_amount": 542.9018705556,
#             "avg_nutrition_calories_amount": 366.3758511111,
#             "avg_prepMinutes": 27.5,
#             "avg_submitter_reciepesCount": 19.3333333333,
#             "avg_nutrition_saturatedFat_amount": 6.6243364278,
#             "geo_name": "Houston",
#             "avg_nutrition_calcium_amount": 107.5836688889,
#             "avg_nutrition_thiamin_amount": 0.4833365948,
#             "avg_ratingCount": 71.8333333333,
#             "avg_similarRecipes_metaData_pagesize": 14.2222222222,
#             "avg_nutrition_fiber_amount": 2.6954533056,
#             "avg_nutrition_sodium_amount": 705.3128685,
#             "avg_nutrition_sugars_amount": 4.3589591333,
#             "avg_ratingAverage": 3.9081002267,
#             "avg_nutrition_carbohydrates_amount": 18.0047835556,
#             "nbRecipes": 18,
#             "avg_nutrition_folate_amount": 42.5995917778,
#             "avg_servings": 10.5555555556,
#             "geo_identifier": "Houston",
#             "avg_nutrition_cholesterol_amount": 111.187795,
#             "avg_submitter_favoritesCount": 91.0555555556,
#             "avg_nutrition_vitaminC_amount": 21.3800209278,
#             "avg_submitter_madeRecipesCount": 14.0555555556,
#             "avg_similarRecipes_metaData_totalCount": 14.2222222222,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 51.5887053889,
#             "avg_nutrition_iron_amount": 2.9635454278,
#             "avg_submitter_ratingsCount": 13.9444444444,
#             "avg_reviewCount": 58.5555555556,
#             "avg_nutrition_vitaminB6_amount": 0.4164473133,
#             "database_name": "houston",
#             "avg_nutrition_caloriesFromFat_amount": 191.2437795556
#         },
#         {
#             "avg_nutrition_fat_amount": 23.9424004797,
#             "avg_readyInMinutes": 223.2835820896,
#             "avg_submitter_personalRecipeSharedCount": 12.6417910448,
#             "avg_nutrition_protein_amount": 20.5943655992,
#             "avg_submitter_reviewsCount": 31.8805970149,
#             "avg_submitter_followersCount": 154042.9402985075,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 22.7164179104,
#             "avg_nutrition_vitaminA_amount": 2170.3961329688,
#             "avg_nutrition_niacin_amount": 8.757527289,
#             "avg_nutrition_potassium_amount": 517.2492336719,
#             "avg_nutrition_calories_amount": 415.338245,
#             "avg_prepMinutes": 15.8805970149,
#             "avg_submitter_reciepesCount": 19.3432835821,
#             "avg_nutrition_saturatedFat_amount": 7.2110913953,
#             "geo_name": "Seattle",
#             "avg_nutrition_calcium_amount": 104.2027518906,
#             "avg_nutrition_thiamin_amount": 0.2829692072,
#             "avg_ratingCount": 307.8507462687,
#             "avg_similarRecipes_metaData_pagesize": 15.4776119403,
#             "avg_nutrition_fiber_amount": 3.0802562672,
#             "avg_nutrition_sodium_amount": 809.3939725312,
#             "avg_nutrition_sugars_amount": 8.5214698198,
#             "avg_ratingAverage": 4.323805857,
#             "avg_nutrition_carbohydrates_amount": 28.9806050203,
#             "nbRecipes": 67,
#             "avg_nutrition_folate_amount": 62.2402307969,
#             "avg_servings": 8.3432835821,
#             "geo_identifier": "Seattle",
#             "avg_nutrition_cholesterol_amount": 81.3847190141,
#             "avg_submitter_favoritesCount": 362.6119402985,
#             "avg_nutrition_vitaminC_amount": 21.9334769783,
#             "avg_submitter_madeRecipesCount": 71.9402985075,
#             "avg_similarRecipes_metaData_totalCount": 15.4776119403,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 52.0927064688,
#             "avg_nutrition_iron_amount": 4.2691250437,
#             "avg_submitter_ratingsCount": 62.7014925373,
#             "avg_reviewCount": 219.6865671642,
#             "avg_nutrition_vitaminB6_amount": 0.4587975699,
#             "database_name": "seattle",
#             "avg_nutrition_caloriesFromFat_amount": 215.4816058281
#         },
#         {
#             "avg_nutrition_fat_amount": 20.5199484154,
#             "avg_readyInMinutes": 6382.5,
#             "avg_submitter_personalRecipeSharedCount": 2.375,
#             "avg_nutrition_protein_amount": 25.2286861538,
#             "avg_submitter_reviewsCount": 1.5,
#             "avg_submitter_followersCount": 1.3125,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 40.625,
#             "avg_nutrition_vitaminA_amount": 1214.13568,
#             "avg_nutrition_niacin_amount": 9.271571,
#             "avg_nutrition_potassium_amount": 496.9851723077,
#             "avg_nutrition_calories_amount": 407.6131015385,
#             "avg_prepMinutes": 34.375,
#             "avg_submitter_reciepesCount": 1.0625,
#             "avg_nutrition_saturatedFat_amount": 6.8581744877,
#             "geo_name": "Green Bay",
#             "avg_nutrition_calcium_amount": 107.8039268462,
#             "avg_nutrition_thiamin_amount": 0.2769959485,
#             "avg_ratingCount": 64.5625,
#             "avg_similarRecipes_metaData_pagesize": 14.25,
#             "avg_nutrition_fiber_amount": 1.7425228762,
#             "avg_nutrition_sodium_amount": 764.01584,
#             "avg_nutrition_sugars_amount": 3.2473853846,
#             "avg_ratingAverage": 4.2604424237,
#             "avg_nutrition_carbohydrates_amount": 26.8232490538,
#             "nbRecipes": 16,
#             "avg_nutrition_folate_amount": 56.2237626923,
#             "avg_servings": 14.6875,
#             "geo_identifier": "Milwaukee",
#             "avg_nutrition_cholesterol_amount": 90.0401742308,
#             "avg_submitter_favoritesCount": 21.4375,
#             "avg_nutrition_vitaminC_amount": 6.9153687846,
#             "avg_submitter_madeRecipesCount": 1.6875,
#             "avg_similarRecipes_metaData_totalCount": 14.25,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 44.7756590769,
#             "avg_nutrition_iron_amount": 3.7296937538,
#             "avg_submitter_ratingsCount": 1.5625,
#             "avg_reviewCount": 49.6875,
#             "avg_nutrition_vitaminB6_amount": 0.4712018831,
#             "database_name": "green-bay",
#             "avg_nutrition_caloriesFromFat_amount": 184.6795501923
#         },
#         {
#             "avg_nutrition_fat_amount": 23.9406550357,
#             "avg_readyInMinutes": 130.1785714286,
#             "avg_submitter_personalRecipeSharedCount": 1.9642857143,
#             "avg_nutrition_protein_amount": 22.6650185714,
#             "avg_submitter_reviewsCount": 8.9285714286,
#             "avg_submitter_followersCount": 3.3571428571,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 63.0357142857,
#             "avg_nutrition_vitaminA_amount": 750.5714234643,
#             "avg_nutrition_niacin_amount": 8.0869232025,
#             "avg_nutrition_potassium_amount": 553.1527578571,
#             "avg_nutrition_calories_amount": 483.6879928571,
#             "avg_prepMinutes": 16.7857142857,
#             "avg_submitter_reciepesCount": 15.0,
#             "avg_nutrition_saturatedFat_amount": 9.1614294643,
#             "geo_name": "Pittsburgh",
#             "avg_nutrition_calcium_amount": 176.3509592857,
#             "avg_nutrition_thiamin_amount": 0.3739265813,
#             "avg_ratingCount": 193.6428571429,
#             "avg_similarRecipes_metaData_pagesize": 15.1785714286,
#             "avg_nutrition_fiber_amount": 3.7168764329,
#             "avg_nutrition_sodium_amount": 1177.559305,
#             "avg_nutrition_sugars_amount": 10.2933764357,
#             "avg_ratingAverage": 4.3639157029,
#             "avg_nutrition_carbohydrates_amount": 44.8913861786,
#             "nbRecipes": 28,
#             "avg_nutrition_folate_amount": 87.593270625,
#             "avg_servings": 8.0357142857,
#             "geo_identifier": "Pittsburgh",
#             "avg_nutrition_cholesterol_amount": 76.4513171429,
#             "avg_submitter_favoritesCount": 63.0714285714,
#             "avg_nutrition_vitaminC_amount": 24.3195612929,
#             "avg_submitter_madeRecipesCount": 9.9285714286,
#             "avg_similarRecipes_metaData_totalCount": 15.1785714286,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 46.9784233571,
#             "avg_nutrition_iron_amount": 3.181308925,
#             "avg_submitter_ratingsCount": 9.8571428571,
#             "avg_reviewCount": 148.4285714286,
#             "avg_nutrition_vitaminB6_amount": 0.3713053325,
#             "database_name": "pittsburgh",
#             "avg_nutrition_caloriesFromFat_amount": 215.4658885714
#         },
#         {
#             "avg_nutrition_fat_amount": 17.3080967829,
#             "avg_readyInMinutes": 58.9512195122,
#             "avg_submitter_personalRecipeSharedCount": 9.8536585366,
#             "avg_nutrition_protein_amount": 11.4925765829,
#             "avg_submitter_reviewsCount": 7.8048780488,
#             "avg_submitter_followersCount": 1913.7804878049,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 27.243902439,
#             "avg_nutrition_vitaminA_amount": 586.9734563902,
#             "avg_nutrition_niacin_amount": 4.2063185402,
#             "avg_nutrition_potassium_amount": 249.2301235854,
#             "avg_nutrition_calories_amount": 274.4892507317,
#             "avg_prepMinutes": 12.5609756098,
#             "avg_submitter_reciepesCount": 46.6097560976,
#             "avg_nutrition_saturatedFat_amount": 6.653792509,
#             "geo_name": "Buffalo",
#             "avg_nutrition_calcium_amount": 65.7200556195,
#             "avg_nutrition_thiamin_amount": 0.1099706034,
#             "avg_ratingCount": 46.2682926829,
#             "avg_similarRecipes_metaData_pagesize": 15.6585365854,
#             "avg_nutrition_fiber_amount": 1.4754392502,
#             "avg_nutrition_sodium_amount": 751.4575639024,
#             "avg_nutrition_sugars_amount": 6.7007981976,
#             "avg_ratingAverage": 3.9525303493,
#             "avg_nutrition_carbohydrates_amount": 18.7452494951,
#             "nbRecipes": 41,
#             "avg_nutrition_folate_amount": 33.2850871244,
#             "avg_servings": 11.5365853659,
#             "geo_identifier": "Buffalo",
#             "avg_nutrition_cholesterol_amount": 63.7754877317,
#             "avg_submitter_favoritesCount": 110.8292682927,
#             "avg_nutrition_vitaminC_amount": 18.0834784651,
#             "avg_submitter_madeRecipesCount": 25.0731707317,
#             "avg_similarRecipes_metaData_totalCount": 15.6585365854,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 26.2155527951,
#             "avg_nutrition_iron_amount": 1.9006710515,
#             "avg_submitter_ratingsCount": 23.7073170732,
#             "avg_reviewCount": 36.2682926829,
#             "avg_nutrition_vitaminB6_amount": 0.1978445112,
#             "database_name": "buffalo",
#             "avg_nutrition_caloriesFromFat_amount": 155.7728659024
#         },
#         {
#             "avg_nutrition_fat_amount": 26.79897344,
#             "avg_readyInMinutes": 75.32,
#             "avg_submitter_personalRecipeSharedCount": 9.26,
#             "avg_nutrition_protein_amount": 24.51036292,
#             "avg_submitter_reviewsCount": 40.48,
#             "avg_submitter_followersCount": 43661.24,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 25.9,
#             "avg_nutrition_vitaminA_amount": 922.4537942,
#             "avg_nutrition_niacin_amount": 7.709990388,
#             "avg_nutrition_potassium_amount": 400.41947886,
#             "avg_nutrition_calories_amount": 510.41504,
#             "avg_prepMinutes": 15.6,
#             "avg_submitter_reciepesCount": 68.12,
#             "avg_nutrition_saturatedFat_amount": 11.22191714,
#             "geo_name": "Philadelphia",
#             "avg_nutrition_calcium_amount": 256.67036744,
#             "avg_nutrition_thiamin_amount": 0.2211141053,
#             "avg_ratingCount": 47.72,
#             "avg_similarRecipes_metaData_pagesize": 14.5,
#             "avg_nutrition_fiber_amount": 2.629553508,
#             "avg_nutrition_sodium_amount": 969.3789018,
#             "avg_nutrition_sugars_amount": 10.181250826,
#             "avg_ratingAverage": 4.2303322426,
#             "avg_nutrition_carbohydrates_amount": 41.94946146,
#             "nbRecipes": 50,
#             "avg_nutrition_folate_amount": 66.51275544,
#             "avg_servings": 7.82,
#             "geo_identifier": "Philadelphia",
#             "avg_nutrition_cholesterol_amount": 91.16037164,
#             "avg_submitter_favoritesCount": 221.14,
#             "avg_nutrition_vitaminC_amount": 18.4969734301,
#             "avg_submitter_madeRecipesCount": 61.18,
#             "avg_similarRecipes_metaData_totalCount": 14.5,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 42.76173593,
#             "avg_nutrition_iron_amount": 3.120636906,
#             "avg_submitter_ratingsCount": 59.68,
#             "avg_reviewCount": 36.82,
#             "avg_nutrition_vitaminB6_amount": 0.3141011734,
#             "database_name": "philadelphia",
#             "avg_nutrition_caloriesFromFat_amount": 241.1907634
#         },
#         {
#             "avg_nutrition_fat_amount": 24.3226906923,
#             "avg_readyInMinutes": 65.3846153846,
#             "avg_submitter_personalRecipeSharedCount": 4.7692307692,
#             "avg_nutrition_protein_amount": 22.2931578462,
#             "avg_submitter_reviewsCount": 10.5384615385,
#             "avg_submitter_followersCount": 3.5,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 37.6923076923,
#             "avg_nutrition_vitaminA_amount": 1532.4941,
#             "avg_nutrition_niacin_amount": 8.3302825088,
#             "avg_nutrition_potassium_amount": 579.9714888462,
#             "avg_nutrition_calories_amount": 448.8614230769,
#             "avg_prepMinutes": 16.9230769231,
#             "avg_submitter_reciepesCount": 1.3846153846,
#             "avg_nutrition_saturatedFat_amount": 7.0818176654,
#             "geo_name": "Oakland",
#             "avg_nutrition_calcium_amount": 145.6520065385,
#             "avg_nutrition_thiamin_amount": 0.2790700631,
#             "avg_ratingCount": 22.1538461538,
#             "avg_similarRecipes_metaData_pagesize": 12.0769230769,
#             "avg_nutrition_fiber_amount": 2.8158160346,
#             "avg_nutrition_sodium_amount": 706.4344396154,
#             "avg_nutrition_sugars_amount": 14.7109440923,
#             "avg_ratingAverage": 4.0684482792,
#             "avg_nutrition_carbohydrates_amount": 35.2154799923,
#             "nbRecipes": 26,
#             "avg_nutrition_folate_amount": 65.1093506538,
#             "avg_servings": 8.4230769231,
#             "geo_identifier": "San Francisco",
#             "avg_nutrition_cholesterol_amount": 79.1141545462,
#             "avg_submitter_favoritesCount": 127.2692307692,
#             "avg_nutrition_vitaminC_amount": 17.7529579577,
#             "avg_submitter_madeRecipesCount": 11.4615384615,
#             "avg_similarRecipes_metaData_totalCount": 12.0769230769,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 60.1629373077,
#             "avg_nutrition_iron_amount": 3.6042783192,
#             "avg_submitter_ratingsCount": 11.1538461538,
#             "avg_reviewCount": 18.3076923077,
#             "avg_nutrition_vitaminB6_amount": 0.3636194046,
#             "database_name": "oakland",
#             "avg_nutrition_caloriesFromFat_amount": 218.9042311538
#         },
#         {
#             "avg_nutrition_fat_amount": 19.4823559003,
#             "avg_readyInMinutes": 117.8,
#             "avg_submitter_personalRecipeSharedCount": 9.4333333333,
#             "avg_nutrition_protein_amount": 19.6331104167,
#             "avg_submitter_reviewsCount": 5.1333333333,
#             "avg_submitter_followersCount": 206368.8333333333,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 53.9666666667,
#             "avg_nutrition_vitaminA_amount": 1701.4872813333,
#             "avg_nutrition_niacin_amount": 7.9396035703,
#             "avg_nutrition_potassium_amount": 614.5194593333,
#             "avg_nutrition_calories_amount": 374.2129283333,
#             "avg_prepMinutes": 21.0,
#             "avg_submitter_reciepesCount": 17.1333333333,
#             "avg_nutrition_saturatedFat_amount": 6.9379219367,
#             "geo_name": "Los Angeles",
#             "avg_nutrition_calcium_amount": 144.626957,
#             "avg_nutrition_thiamin_amount": 0.2499014367,
#             "avg_ratingCount": 48.8333333333,
#             "avg_similarRecipes_metaData_pagesize": 12.9666666667,
#             "avg_nutrition_fiber_amount": 4.5759873967,
#             "avg_nutrition_sodium_amount": 671.3785358,
#             "avg_nutrition_sugars_amount": 5.8711526333,
#             "avg_ratingAverage": 3.8786580587,
#             "avg_nutrition_carbohydrates_amount": 27.0084856667,
#             "nbRecipes": 30,
#             "avg_nutrition_folate_amount": 67.6437203333,
#             "avg_servings": 6.7333333333,
#             "geo_identifier": "Los Angeles",
#             "avg_nutrition_cholesterol_amount": 70.7815406667,
#             "avg_submitter_favoritesCount": 262.6,
#             "avg_nutrition_vitaminC_amount": 51.5466371667,
#             "avg_submitter_madeRecipesCount": 12.0,
#             "avg_similarRecipes_metaData_totalCount": 12.9666666667,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 55.4423327333,
#             "avg_nutrition_iron_amount": 2.9128851667,
#             "avg_submitter_ratingsCount": 5.5333333333,
#             "avg_reviewCount": 36.3666666667,
#             "avg_nutrition_vitaminB6_amount": 0.5078947378,
#             "database_name": "los-angeles",
#             "avg_nutrition_caloriesFromFat_amount": 175.34119787
#         },
#         {
#             "avg_nutrition_fat_amount": 15.0364464455,
#             "avg_readyInMinutes": 42.7083333333,
#             "avg_submitter_personalRecipeSharedCount": 3.0416666667,
#             "avg_nutrition_protein_amount": 9.5829484818,
#             "avg_submitter_reviewsCount": 18.125,
#             "avg_submitter_followersCount": 2.0416666667,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 25.125,
#             "avg_nutrition_vitaminA_amount": 1676.5504568182,
#             "avg_nutrition_niacin_amount": 3.974544735,
#             "avg_nutrition_potassium_amount": 243.5239927273,
#             "avg_nutrition_calories_amount": 300.2158104545,
#             "avg_prepMinutes": 10.9166666667,
#             "avg_submitter_reciepesCount": 1.4583333333,
#             "avg_nutrition_saturatedFat_amount": 6.1034923091,
#             "geo_name": "Kansas City",
#             "avg_nutrition_calcium_amount": 88.0432716818,
#             "avg_nutrition_thiamin_amount": 0.1217278914,
#             "avg_ratingCount": 76.25,
#             "avg_similarRecipes_metaData_pagesize": 12.5416666667,
#             "avg_nutrition_fiber_amount": 2.1658508545,
#             "avg_nutrition_sodium_amount": 421.2166277273,
#             "avg_nutrition_sugars_amount": 11.7726006045,
#             "avg_ratingAverage": 4.2158064117,
#             "avg_nutrition_carbohydrates_amount": 33.1955072273,
#             "nbRecipes": 24,
#             "avg_nutrition_folate_amount": 47.5829189091,
#             "avg_servings": 13.6666666667,
#             "geo_identifier": "Kansas City",
#             "avg_nutrition_cholesterol_amount": 42.0874889091,
#             "avg_submitter_favoritesCount": 98.4166666667,
#             "avg_nutrition_vitaminC_amount": 7.8234801123,
#             "avg_submitter_madeRecipesCount": 19.625,
#             "avg_similarRecipes_metaData_totalCount": 12.5416666667,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 32.0467021364,
#             "avg_nutrition_iron_amount": 1.7319653,
#             "avg_submitter_ratingsCount": 19.125,
#             "avg_reviewCount": 60.625,
#             "avg_nutrition_vitaminB6_amount": 0.1577434245,
#             "database_name": "kansas-city",
#             "avg_nutrition_caloriesFromFat_amount": 135.3280215909
#         },
#         {
#             "avg_nutrition_fat_amount": 28.6261497778,
#             "avg_readyInMinutes": 113.4074074074,
#             "avg_submitter_personalRecipeSharedCount": 3.5925925926,
#             "avg_nutrition_protein_amount": 17.6499616778,
#             "avg_submitter_reviewsCount": 104.7777777778,
#             "avg_submitter_followersCount": 24.5555555556,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 84.0,
#             "avg_nutrition_vitaminA_amount": 1428.0750611111,
#             "avg_nutrition_niacin_amount": 8.2253497778,
#             "avg_nutrition_potassium_amount": 473.9753051852,
#             "avg_nutrition_calories_amount": 485.8434666667,
#             "avg_prepMinutes": 16.2592592593,
#             "avg_submitter_reciepesCount": 1.2962962963,
#             "avg_nutrition_saturatedFat_amount": 10.6463396704,
#             "geo_name": "St. Louis",
#             "avg_nutrition_calcium_amount": 108.1172686296,
#             "avg_nutrition_thiamin_amount": 0.5404099809,
#             "avg_ratingCount": 92.0740740741,
#             "avg_similarRecipes_metaData_pagesize": 15.8888888889,
#             "avg_nutrition_fiber_amount": 2.7868702321,
#             "avg_nutrition_sodium_amount": 1665.9185703704,
#             "avg_nutrition_sugars_amount": 20.0582743259,
#             "avg_ratingAverage": 4.3339577211,
#             "avg_nutrition_carbohydrates_amount": 39.3335362222,
#             "nbRecipes": 27,
#             "avg_nutrition_folate_amount": 58.530613,
#             "avg_servings": 10.6296296296,
#             "geo_identifier": "St. Louis",
#             "avg_nutrition_cholesterol_amount": 87.1776358148,
#             "avg_submitter_favoritesCount": 297.5185185185,
#             "avg_nutrition_vitaminC_amount": 11.8623023581,
#             "avg_submitter_madeRecipesCount": 106.2222222222,
#             "avg_similarRecipes_metaData_totalCount": 15.8888888889,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 41.3972659259,
#             "avg_nutrition_iron_amount": 3.1187290704,
#             "avg_submitter_ratingsCount": 105.8148148148,
#             "avg_reviewCount": 72.1481481481,
#             "avg_nutrition_vitaminB6_amount": 0.4252018348,
#             "database_name": "st-louis",
#             "avg_nutrition_caloriesFromFat_amount": 257.6353418519
#         },
#         {
#             "avg_nutrition_fat_amount": 21.9647443719,
#             "avg_readyInMinutes": 160.368,
#             "avg_submitter_personalRecipeSharedCount": 6.608,
#             "avg_nutrition_protein_amount": 17.8896237174,
#             "avg_submitter_reviewsCount": 24.2,
#             "avg_submitter_followersCount": 70765.312,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 35.288,
#             "avg_nutrition_vitaminA_amount": 1417.0557266223,
#             "avg_nutrition_niacin_amount": 7.206435757,
#             "avg_nutrition_potassium_amount": 418.2511784711,
#             "avg_nutrition_calories_amount": 411.8799015702,
#             "avg_prepMinutes": 16.76,
#             "avg_submitter_reciepesCount": 104.256,
#             "avg_nutrition_saturatedFat_amount": 8.9740257264,
#             "geo_name": "New York City",
#             "avg_nutrition_calcium_amount": 95.5071747438,
#             "avg_nutrition_thiamin_amount": 0.1932303072,
#             "avg_ratingCount": 111.336,
#             "avg_similarRecipes_metaData_pagesize": 15.072,
#             "avg_nutrition_fiber_amount": 2.2644520866,
#             "avg_nutrition_sodium_amount": 700.8915924711,
#             "avg_nutrition_sugars_amount": 13.1172453805,
#             "avg_ratingAverage": 4.1732518509,
#             "avg_nutrition_carbohydrates_amount": 33.5271574231,
#             "nbRecipes": 125,
#             "avg_nutrition_folate_amount": 50.1536934959,
#             "avg_servings": 9.48,
#             "geo_identifier": "New York City",
#             "avg_nutrition_cholesterol_amount": 85.2771413719,
#             "avg_submitter_favoritesCount": 199.608,
#             "avg_nutrition_vitaminC_amount": 16.3531299945,
#             "avg_submitter_madeRecipesCount": 57.272,
#             "avg_similarRecipes_metaData_totalCount": 15.072,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 36.3795383471,
#             "avg_nutrition_iron_amount": 2.4951306835,
#             "avg_submitter_ratingsCount": 55.24,
#             "avg_reviewCount": 88.52,
#             "avg_nutrition_vitaminB6_amount": 0.3385195889,
#             "database_name": "new-york-city",
#             "avg_nutrition_caloriesFromFat_amount": 197.6827069587
#         },
#         {
#             "avg_nutrition_fat_amount": 16.9143911333,
#             "avg_readyInMinutes": 69.5483870968,
#             "avg_submitter_personalRecipeSharedCount": 5.7741935484,
#             "avg_nutrition_protein_amount": 22.6181271967,
#             "avg_submitter_reviewsCount": 12.0322580645,
#             "avg_submitter_followersCount": 2748.935483871,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 19.3870967742,
#             "avg_nutrition_vitaminA_amount": 2641.551526,
#             "avg_nutrition_niacin_amount": 7.2018205693,
#             "avg_nutrition_potassium_amount": 711.033659,
#             "avg_nutrition_calories_amount": 401.5872333333,
#             "avg_prepMinutes": 22.4193548387,
#             "avg_submitter_reciepesCount": 16.0322580645,
#             "avg_nutrition_saturatedFat_amount": 3.8838472067,
#             "geo_name": "San Diego",
#             "avg_nutrition_calcium_amount": 123.9850940333,
#             "avg_nutrition_thiamin_amount": 0.2542885452,
#             "avg_ratingCount": 176.4516129032,
#             "avg_similarRecipes_metaData_pagesize": 17.5483870968,
#             "avg_nutrition_fiber_amount": 5.1018845483,
#             "avg_nutrition_sodium_amount": 743.090265,
#             "avg_nutrition_sugars_amount": 8.9109309767,
#             "avg_ratingAverage": 3.8715675723,
#             "avg_nutrition_carbohydrates_amount": 41.5719148133,
#             "nbRecipes": 31,
#             "avg_nutrition_folate_amount": 73.1248744333,
#             "avg_servings": 7.7419354839,
#             "geo_identifier": "San Diego",
#             "avg_nutrition_cholesterol_amount": 55.5185,
#             "avg_submitter_favoritesCount": 99.4838709677,
#             "avg_nutrition_vitaminC_amount": 35.2134353,
#             "avg_submitter_madeRecipesCount": 14.3225806452,
#             "avg_similarRecipes_metaData_totalCount": 17.5483870968,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 71.6664576667,
#             "avg_nutrition_iron_amount": 2.6139855823,
#             "avg_submitter_ratingsCount": 12.8709677419,
#             "avg_reviewCount": 131.2258064516,
#             "avg_nutrition_vitaminB6_amount": 0.4836998991,
#             "database_name": "san-diego",
#             "avg_nutrition_caloriesFromFat_amount": 152.2295126667
#         },
#         {
#             "avg_nutrition_fat_amount": 20.78013555,
#             "avg_readyInMinutes": 66.8666666667,
#             "avg_submitter_personalRecipeSharedCount": 6.2666666667,
#             "avg_nutrition_protein_amount": 20.4746948193,
#             "avg_submitter_reviewsCount": 30.8666666667,
#             "avg_submitter_followersCount": 13.4666666667,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 51.0,
#             "avg_nutrition_vitaminA_amount": 877.3949448714,
#             "avg_nutrition_niacin_amount": 7.5555770779,
#             "avg_nutrition_potassium_amount": 432.0371707143,
#             "avg_nutrition_calories_amount": 425.4122357143,
#             "avg_prepMinutes": 10.8666666667,
#             "avg_submitter_reciepesCount": 22.2,
#             "avg_nutrition_saturatedFat_amount": 7.5749152914,
#             "geo_name": "Indianapolis",
#             "avg_nutrition_calcium_amount": 106.6231562143,
#             "avg_nutrition_thiamin_amount": 0.4542568831,
#             "avg_ratingCount": 87.0666666667,
#             "avg_similarRecipes_metaData_pagesize": 15.2,
#             "avg_nutrition_fiber_amount": 1.8113013571,
#             "avg_nutrition_sodium_amount": 641.9893585714,
#             "avg_nutrition_sugars_amount": 15.7910325714,
#             "avg_ratingAverage": 3.8851282473,
#             "avg_nutrition_carbohydrates_amount": 35.2995767143,
#             "nbRecipes": 15,
#             "avg_nutrition_folate_amount": 38.1160503714,
#             "avg_servings": 7.9333333333,
#             "geo_identifier": "Indianapolis",
#             "avg_nutrition_cholesterol_amount": 77.7785842857,
#             "avg_submitter_favoritesCount": 95.2666666667,
#             "avg_nutrition_vitaminC_amount": 7.7831920016,
#             "avg_submitter_madeRecipesCount": 34.4,
#             "avg_similarRecipes_metaData_totalCount": 15.2,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 32.4746160714,
#             "avg_nutrition_iron_amount": 2.8803651857,
#             "avg_submitter_ratingsCount": 34.0,
#             "avg_reviewCount": 67.6666666667,
#             "avg_nutrition_vitaminB6_amount": 0.3967395311,
#             "database_name": "indianapolis",
#             "avg_nutrition_caloriesFromFat_amount": 187.0212205714
#         },
#         {
#             "avg_nutrition_fat_amount": 23.1051369091,
#             "avg_readyInMinutes": 91.7575757576,
#             "avg_submitter_personalRecipeSharedCount": 2.4242424242,
#             "avg_nutrition_protein_amount": 16.4890986364,
#             "avg_submitter_reviewsCount": 8.2424242424,
#             "avg_submitter_followersCount": 2.696969697,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 36.1515151515,
#             "avg_nutrition_vitaminA_amount": 1103.2204585961,
#             "avg_nutrition_niacin_amount": 7.0798285636,
#             "avg_nutrition_potassium_amount": 344.2120930303,
#             "avg_nutrition_calories_amount": 429.2601442424,
#             "avg_prepMinutes": 12.9393939394,
#             "avg_submitter_reciepesCount": 1.6060606061,
#             "avg_nutrition_saturatedFat_amount": 9.2561569848,
#             "geo_name": "Cleveland",
#             "avg_nutrition_calcium_amount": 100.1309782121,
#             "avg_nutrition_thiamin_amount": 0.3449261991,
#             "avg_ratingCount": 76.3636363636,
#             "avg_similarRecipes_metaData_pagesize": 14.9696969697,
#             "avg_nutrition_fiber_amount": 3.0080272485,
#             "avg_nutrition_sodium_amount": 523.6588359697,
#             "avg_nutrition_sugars_amount": 14.4876601697,
#             "avg_ratingAverage": 4.2665948664,
#             "avg_nutrition_carbohydrates_amount": 39.4166334545,
#             "nbRecipes": 33,
#             "avg_nutrition_folate_amount": 70.7054735152,
#             "avg_servings": 11.3636363636,
#             "geo_identifier": "Cleveland",
#             "avg_nutrition_cholesterol_amount": 99.5148733636,
#             "avg_submitter_favoritesCount": 27.6666666667,
#             "avg_nutrition_vitaminC_amount": 11.7181878182,
#             "avg_submitter_madeRecipesCount": 8.4242424242,
#             "avg_similarRecipes_metaData_totalCount": 14.9696969697,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 33.3385739697,
#             "avg_nutrition_iron_amount": 2.7811271091,
#             "avg_submitter_ratingsCount": 8.3333333333,
#             "avg_reviewCount": 63.0909090909,
#             "avg_nutrition_vitaminB6_amount": 0.2845104261,
#             "database_name": "cleveland",
#             "avg_nutrition_caloriesFromFat_amount": 207.9462324242
#         },
#         {
#             "avg_nutrition_fat_amount": 22.267603107,
#             "avg_readyInMinutes": 1050.3260869565,
#             "avg_submitter_personalRecipeSharedCount": 6.8260869565,
#             "avg_nutrition_protein_amount": 17.4942017521,
#             "avg_submitter_reviewsCount": 7.5217391304,
#             "avg_submitter_followersCount": 137098.2173913044,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 28.5434782609,
#             "avg_nutrition_vitaminA_amount": 992.4081416279,
#             "avg_nutrition_niacin_amount": 6.4543105844,
#             "avg_nutrition_potassium_amount": 395.3045097674,
#             "avg_nutrition_calories_amount": 445.9402834884,
#             "avg_prepMinutes": 21.4565217391,
#             "avg_submitter_reciepesCount": 75.3695652174,
#             "avg_nutrition_saturatedFat_amount": 9.5023519814,
#             "geo_name": "New Orleans",
#             "avg_nutrition_calcium_amount": 128.9259451163,
#             "avg_nutrition_thiamin_amount": 0.3470168237,
#             "avg_ratingCount": 40.6086956522,
#             "avg_similarRecipes_metaData_pagesize": 14.152173913,
#             "avg_nutrition_fiber_amount": 2.5569047091,
#             "avg_nutrition_sodium_amount": 845.9362781395,
#             "avg_nutrition_sugars_amount": 10.9223112407,
#             "avg_ratingAverage": 4.3605372796,
#             "avg_nutrition_carbohydrates_amount": 37.0686305279,
#             "nbRecipes": 46,
#             "avg_nutrition_folate_amount": 78.3735415814,
#             "avg_servings": 10.347826087,
#             "geo_identifier": "New Orleans",
#             "avg_nutrition_cholesterol_amount": 112.8882237209,
#             "avg_submitter_favoritesCount": 258.3043478261,
#             "avg_nutrition_vitaminC_amount": 18.2565974605,
#             "avg_submitter_madeRecipesCount": 56.4347826087,
#             "avg_similarRecipes_metaData_totalCount": 14.152173913,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 46.5328142558,
#             "avg_nutrition_iron_amount": 3.7052496693,
#             "avg_submitter_ratingsCount": 52.4565217391,
#             "avg_reviewCount": 32.3913043478,
#             "avg_nutrition_vitaminB6_amount": 0.2601072309,
#             "database_name": "new-orleans",
#             "avg_nutrition_caloriesFromFat_amount": 200.4084444419
#         },
#         {
#             "avg_nutrition_fat_amount": 12.0556219332,
#             "avg_readyInMinutes": 98.9756097561,
#             "avg_submitter_personalRecipeSharedCount": 6.2926829268,
#             "avg_nutrition_protein_amount": 17.9521666288,
#             "avg_submitter_reviewsCount": 18.0487804878,
#             "avg_submitter_followersCount": 11199.1219512195,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 39.8780487805,
#             "avg_nutrition_vitaminA_amount": 1177.7962191463,
#             "avg_nutrition_niacin_amount": 6.4557232849,
#             "avg_nutrition_potassium_amount": 498.6124517317,
#             "avg_nutrition_calories_amount": 291.9175343171,
#             "avg_prepMinutes": 18.4146341463,
#             "avg_submitter_reciepesCount": 269.3170731707,
#             "avg_nutrition_saturatedFat_amount": 4.4407462082,
#             "geo_name": "San Francisco",
#             "avg_nutrition_calcium_amount": 85.1226340244,
#             "avg_nutrition_thiamin_amount": 0.1696685185,
#             "avg_ratingCount": 88.1463414634,
#             "avg_similarRecipes_metaData_pagesize": 15.8536585366,
#             "avg_nutrition_fiber_amount": 2.9773086473,
#             "avg_nutrition_sodium_amount": 575.5371249512,
#             "avg_nutrition_sugars_amount": 8.0171513306,
#             "avg_ratingAverage": 3.8753884834,
#             "avg_nutrition_carbohydrates_amount": 25.6473037854,
#             "nbRecipes": 41,
#             "avg_nutrition_folate_amount": 58.5151527912,
#             "avg_servings": 12.6829268293,
#             "geo_identifier": "San Francisco",
#             "avg_nutrition_cholesterol_amount": 66.2578526171,
#             "avg_submitter_favoritesCount": 164.0731707317,
#             "avg_nutrition_vitaminC_amount": 19.2749906017,
#             "avg_submitter_madeRecipesCount": 111.9756097561,
#             "avg_similarRecipes_metaData_totalCount": 15.8536585366,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 58.4659303537,
#             "avg_nutrition_iron_amount": 3.743290641,
#             "avg_submitter_ratingsCount": 108.7073170732,
#             "avg_reviewCount": 68.8780487805,
#             "avg_nutrition_vitaminB6_amount": 0.2709673187,
#             "database_name": "san-francisco",
#             "avg_nutrition_caloriesFromFat_amount": 108.500598678
#         },
#         {
#             "avg_nutrition_fat_amount": 23.7871666814,
#             "avg_readyInMinutes": 115.3571428571,
#             "avg_submitter_personalRecipeSharedCount": 4.0357142857,
#             "avg_nutrition_protein_amount": 14.9179720036,
#             "avg_submitter_reviewsCount": 20.8571428571,
#             "avg_submitter_followersCount": 2.4642857143,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 72.6785714286,
#             "avg_nutrition_vitaminA_amount": 3036.5497525,
#             "avg_nutrition_niacin_amount": 6.04422843,
#             "avg_nutrition_potassium_amount": 440.0926471429,
#             "avg_nutrition_calories_amount": 424.3144992857,
#             "avg_prepMinutes": 19.8214285714,
#             "avg_submitter_reciepesCount": 1.5714285714,
#             "avg_nutrition_saturatedFat_amount": 7.8238756717,
#             "geo_name": "Atlanta",
#             "avg_nutrition_calcium_amount": 102.0047476071,
#             "avg_nutrition_thiamin_amount": 0.2052050258,
#             "avg_ratingCount": 167.6428571429,
#             "avg_similarRecipes_metaData_pagesize": 15.1785714286,
#             "avg_nutrition_fiber_amount": 3.0967039829,
#             "avg_nutrition_sodium_amount": 512.9678246429,
#             "avg_nutrition_sugars_amount": 20.341919475,
#             "avg_ratingAverage": 4.4145081739,
#             "avg_nutrition_carbohydrates_amount": 39.3647434143,
#             "nbRecipes": 28,
#             "avg_nutrition_folate_amount": 48.5445705714,
#             "avg_servings": 19.6785714286,
#             "geo_identifier": "Atlanta",
#             "avg_nutrition_cholesterol_amount": 78.3939721071,
#             "avg_submitter_favoritesCount": 114.1071428571,
#             "avg_nutrition_vitaminC_amount": 11.3826714225,
#             "avg_submitter_madeRecipesCount": 21.6785714286,
#             "avg_similarRecipes_metaData_totalCount": 15.1785714286,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 44.0108625,
#             "avg_nutrition_iron_amount": 2.1804457757,
#             "avg_submitter_ratingsCount": 21.6785714286,
#             "avg_reviewCount": 132.3571428571,
#             "avg_nutrition_vitaminB6_amount": 0.2941749989,
#             "database_name": "atlanta",
#             "avg_nutrition_caloriesFromFat_amount": 214.0845010821
#         },
#         {
#             "avg_nutrition_fat_amount": 19.7759342727,
#             "avg_readyInMinutes": 130.0,
#             "avg_submitter_personalRecipeSharedCount": 10.9090909091,
#             "avg_nutrition_protein_amount": 22.7507469091,
#             "avg_submitter_reviewsCount": 2.0909090909,
#             "avg_submitter_followersCount": 3476.1818181818,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 45.9090909091,
#             "avg_nutrition_vitaminA_amount": 1159.4425090909,
#             "avg_nutrition_niacin_amount": 8.4149930909,
#             "avg_nutrition_potassium_amount": 406.8057072727,
#             "avg_nutrition_calories_amount": 403.8004090909,
#             "avg_prepMinutes": 21.3636363636,
#             "avg_submitter_reciepesCount": 84.5454545455,
#             "avg_nutrition_saturatedFat_amount": 6.2244856364,
#             "geo_name": "Chicago",
#             "avg_nutrition_calcium_amount": 145.0406539091,
#             "avg_nutrition_thiamin_amount": 0.3377867473,
#             "avg_ratingCount": 126.1818181818,
#             "avg_similarRecipes_metaData_pagesize": 17.0,
#             "avg_nutrition_fiber_amount": 3.3221818182,
#             "avg_nutrition_sodium_amount": 1152.7164454545,
#             "avg_nutrition_sugars_amount": 5.8000551273,
#             "avg_ratingAverage": 4.2650518455,
#             "avg_nutrition_carbohydrates_amount": 32.4189234545,
#             "nbRecipes": 11,
#             "avg_nutrition_folate_amount": 78.5223227273,
#             "avg_servings": 5.8181818182,
#             "geo_identifier": "Chicago",
#             "avg_nutrition_cholesterol_amount": 57.7919054545,
# ...
#             "avg_nutrition_protein_amount": 10.8253929809,
#             "avg_submitter_reviewsCount": 44.0531914894,
#             "avg_submitter_followersCount": 822.4361702128,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 48.6914893617,
#             "avg_nutrition_vitaminA_amount": 1333.2055973085,
#             "avg_nutrition_niacin_amount": 4.7214952019,
#             "avg_nutrition_potassium_amount": 436.1803558511,
#             "avg_nutrition_calories_amount": 277.5671625532,
#             "avg_prepMinutes": 23.2978723404,
#             "avg_submitter_reciepesCount": 30.4787234043,
#             "avg_nutrition_saturatedFat_amount": 5.6835040883,
#             "geo_name": "Russia",
#             "avg_nutrition_calcium_amount": 79.9881396596,
#             "avg_nutrition_thiamin_amount": 0.1977025838,
#             "avg_ratingCount": 93.9787234043,
#             "avg_similarRecipes_metaData_pagesize": 14.1382978723,
#             "avg_nutrition_fiber_amount": 2.9850211027,
#             "avg_nutrition_sodium_amount": 502.8633804255,
#             "avg_nutrition_sugars_amount": 7.1214450872,
#             "avg_ratingAverage": 4.1057047294,
#             "avg_nutrition_carbohydrates_amount": 25.4901278723,
#             "nbRecipes": 94,
#             "avg_nutrition_folate_amount": 59.6879734681,
#             "avg_servings": 12.9042553191,
#             "geo_identifier": "RUS",
#             "avg_nutrition_cholesterol_amount": 55.3204548298,
#             "avg_submitter_favoritesCount": 280.6382978723,
#             "avg_nutrition_vitaminC_amount": 18.7078812405,
#             "avg_submitter_madeRecipesCount": 51.8510638298,
#             "avg_similarRecipes_metaData_totalCount": 14.1382978723,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 33.5708366915,
#             "avg_nutrition_iron_amount": 2.1206101745,
#             "avg_submitter_ratingsCount": 51.8404255319,
#             "avg_reviewCount": 72.2765957447,
#             "avg_nutrition_vitaminB6_amount": 0.285977207,
#             "database_name": "russian",
#             "avg_nutrition_caloriesFromFat_amount": 135.6159146064
#         },
#         {
#             "avg_nutrition_fat_amount": 18.8495914579,
#             "avg_readyInMinutes": 215.3474955277,
#             "avg_submitter_personalRecipeSharedCount": 6.2182468694,
#             "avg_nutrition_protein_amount": 16.5121222649,
#             "avg_submitter_reviewsCount": 20.7766100179,
#             "avg_submitter_followersCount": 13218.9669051878,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 49.1071109123,
#             "avg_nutrition_vitaminA_amount": 1331.4620572249,
#             "avg_nutrition_niacin_amount": 6.4611394332,
#             "avg_nutrition_potassium_amount": 420.4647907525,
#             "avg_nutrition_calories_amount": 363.2577449477,
#             "avg_prepMinutes": 18.9022808587,
#             "avg_submitter_reciepesCount": 20.8271466905,
#             "avg_nutrition_saturatedFat_amount": 6.9645937415,
#             "geo_name": "United States of America",
#             "avg_nutrition_calcium_amount": 103.7083135597,
#             "avg_nutrition_thiamin_amount": 0.2477236884,
#             "avg_ratingCount": 104.521019678,
#             "avg_similarRecipes_metaData_pagesize": 14.998881932,
#             "avg_nutrition_fiber_amount": 2.7419771588,
#             "avg_nutrition_sodium_amount": 702.2476481914,
#             "avg_nutrition_sugars_amount": 11.9582956658,
#             "avg_ratingAverage": 4.1673508411,
#             "avg_nutrition_carbohydrates_amount": 31.7584583977,
#             "nbRecipes": 4472,
#             "avg_nutrition_folate_amount": 55.5373908558,
#             "avg_servings": 11.2459749553,
#             "geo_identifier": "USA",
#             "avg_nutrition_cholesterol_amount": 74.4257488803,
#             "avg_submitter_favoritesCount": 135.989490161,
#             "avg_nutrition_vitaminC_amount": 15.5485757656,
#             "avg_submitter_madeRecipesCount": 27.9136851521,
#             "avg_similarRecipes_metaData_totalCount": 14.998881932,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 39.9246426565,
#             "avg_nutrition_iron_amount": 2.6356862249,
#             "avg_submitter_ratingsCount": 27.2028175313,
#             "avg_reviewCount": 80.7652057245,
#             "avg_nutrition_vitaminB6_amount": 0.3058045321,
#             "database_name": "us-recipes",
#             "avg_nutrition_caloriesFromFat_amount": 169.6463244048
#         },
#         {
#             "avg_nutrition_fat_amount": 14.7139821333,
#             "avg_readyInMinutes": 79.6666666667,
#             "avg_submitter_personalRecipeSharedCount": 2.375,
#             "avg_nutrition_protein_amount": 9.1230362167,
#             "avg_submitter_reviewsCount": 43.4166666667,
#             "avg_submitter_followersCount": 4.4166666667,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 27.375,
#             "avg_nutrition_vitaminA_amount": 1027.7780685833,
#             "avg_nutrition_niacin_amount": 3.1528025312,
#             "avg_nutrition_potassium_amount": 429.3871920833,
#             "avg_nutrition_calories_amount": 255.634929125,
#             "avg_prepMinutes": 18.125,
#             "avg_submitter_reciepesCount": 1.6666666667,
#             "avg_nutrition_saturatedFat_amount": 3.0285494979,
#             "geo_name": "Israel",
#             "avg_nutrition_calcium_amount": 80.8358850417,
#             "avg_nutrition_thiamin_amount": 0.1726528607,
#             "avg_ratingCount": 43.3333333333,
#             "avg_similarRecipes_metaData_pagesize": 13.4166666667,
#             "avg_nutrition_fiber_amount": 3.5416252375,
#             "avg_nutrition_sodium_amount": 336.33116325,
#             "avg_nutrition_sugars_amount": 8.5437866763,
#             "avg_ratingAverage": 4.3260393783,
#             "avg_nutrition_carbohydrates_amount": 23.5659823083,
#             "nbRecipes": 24,
#             "avg_nutrition_folate_amount": 64.0085154292,
#             "avg_servings": 11.2916666667,
#             "geo_identifier": "ISR",
#             "avg_nutrition_cholesterol_amount": 65.9163235417,
#             "avg_submitter_favoritesCount": 95.4166666667,
#             "avg_nutrition_vitaminC_amount": 30.0749629979,
#             "avg_submitter_madeRecipesCount": 47.9166666667,
#             "avg_similarRecipes_metaData_totalCount": 13.4166666667,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 43.53317025,
#             "avg_nutrition_iron_amount": 2.17022705,
#             "avg_submitter_ratingsCount": 48.9166666667,
#             "avg_reviewCount": 33.2916666667,
#             "avg_nutrition_vitaminB6_amount": 0.2930112785,
#             "database_name": "israeli",
#             "avg_nutrition_caloriesFromFat_amount": 132.4258379167
#         },
#         {
#             "avg_nutrition_fat_amount": 10.1142079,
#             "avg_readyInMinutes": 142.2631578947,
#             "avg_submitter_personalRecipeSharedCount": 7.6842105263,
#             "avg_nutrition_protein_amount": 6.4513989211,
#             "avg_submitter_reviewsCount": 17.8947368421,
#             "avg_submitter_followersCount": 4.3684210526,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 24.0,
#             "avg_nutrition_vitaminA_amount": 576.7132803158,
#             "avg_nutrition_niacin_amount": 2.5546692842,
#             "avg_nutrition_potassium_amount": 260.3091382632,
#             "avg_nutrition_calories_amount": 218.8282947368,
#             "avg_prepMinutes": 12.4736842105,
#             "avg_submitter_reciepesCount": 7.4736842105,
#             "avg_nutrition_saturatedFat_amount": 5.3202393947,
#             "geo_name": "Wales",
#             "avg_nutrition_calcium_amount": 137.2850237895,
#             "avg_nutrition_thiamin_amount": 0.1475069547,
#             "avg_ratingCount": 28.5789473684,
#             "avg_similarRecipes_metaData_pagesize": 11.0526315789,
#             "avg_nutrition_fiber_amount": 1.6426686947,
#             "avg_nutrition_sodium_amount": 356.5464036842,
#             "avg_nutrition_sugars_amount": 9.3221911053,
#             "avg_ratingAverage": 3.7727422668,
#             "avg_nutrition_carbohydrates_amount": 26.2079576842,
#             "nbRecipes": 19,
#             "avg_nutrition_folate_amount": 42.3256924737,
#             "avg_servings": 16.3684210526,
#             "geo_identifier": "GBR",
#             "avg_nutrition_cholesterol_amount": 47.7937722632,
#             "avg_submitter_favoritesCount": 87.6842105263,
#             "avg_nutrition_vitaminC_amount": 9.4016888561,
#             "avg_submitter_madeRecipesCount": 18.1052631579,
#             "avg_similarRecipes_metaData_totalCount": 11.0526315789,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 20.5799014737,
#             "avg_nutrition_iron_amount": 1.4857696526,
#             "avg_submitter_ratingsCount": 18.1052631579,
#             "avg_reviewCount": 23.8947368421,
#             "avg_nutrition_vitaminB6_amount": 0.1510957242,
#             "database_name": "welsh",
#             "avg_nutrition_caloriesFromFat_amount": 91.0278777895
#         },
#         {
#             "avg_nutrition_fat_amount": 10.2400933187,
#             "avg_readyInMinutes": 170.625,
#             "avg_submitter_personalRecipeSharedCount": 3.0,
#             "avg_nutrition_protein_amount": 6.4763929125,
#             "avg_submitter_reviewsCount": 4.375,
#             "avg_submitter_followersCount": 6.9375,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 26.09375,
#             "avg_nutrition_vitaminA_amount": 263.3729210313,
#             "avg_nutrition_niacin_amount": 3.3017093,
#             "avg_nutrition_potassium_amount": 304.6095653438,
#             "avg_nutrition_calories_amount": 243.1596253125,
#             "avg_prepMinutes": 64.21875,
#             "avg_submitter_reciepesCount": 10.8125,
#             "avg_nutrition_saturatedFat_amount": 4.8621847562,
#             "geo_name": "Norway",
#             "avg_nutrition_calcium_amount": 46.7142410625,
#             "avg_nutrition_thiamin_amount": 0.2134740994,
#             "avg_ratingCount": 22.34375,
#             "avg_similarRecipes_metaData_pagesize": 12.53125,
#             "avg_nutrition_fiber_amount": 2.3058666844,
#             "avg_nutrition_sodium_amount": 220.5499889375,
#             "avg_nutrition_sugars_amount": 10.1958599438,
#             "avg_ratingAverage": 4.2613533756,
#             "avg_nutrition_carbohydrates_amount": 32.2381809375,
#             "nbRecipes": 32,
#             "avg_nutrition_folate_amount": 47.543088,
#             "avg_servings": 18.46875,
#             "geo_identifier": "NOR",
#             "avg_nutrition_cholesterol_amount": 44.6811227094,
#             "avg_submitter_favoritesCount": 83.90625,
#             "avg_nutrition_vitaminC_amount": 13.161945106,
#             "avg_submitter_madeRecipesCount": 4.75,
#             "avg_similarRecipes_metaData_totalCount": 12.53125,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 28.0759452188,
#             "avg_nutrition_iron_amount": 1.548799275,
#             "avg_submitter_ratingsCount": 4.59375,
#             "avg_reviewCount": 18.8125,
#             "avg_nutrition_vitaminB6_amount": 0.2072634797,
#             "database_name": "norwegian",
#             "avg_nutrition_caloriesFromFat_amount": 92.1608389687
#         },
#         {
#             "avg_nutrition_fat_amount": 23.959894514,
#             "avg_readyInMinutes": 92.7222222222,
#             "avg_submitter_personalRecipeSharedCount": 1.7777777778,
#             "avg_nutrition_protein_amount": 26.3205296914,
#             "avg_submitter_reviewsCount": 2.4444444444,
#             "avg_submitter_followersCount": 0.4722222222,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 30.3611111111,
#             "avg_nutrition_vitaminA_amount": 1219.778522,
#             "avg_nutrition_niacin_amount": 12.2652535114,
#             "avg_nutrition_potassium_amount": 597.8085382857,
#             "avg_nutrition_calories_amount": 436.4189191429,
#             "avg_prepMinutes": 18.4722222222,
#             "avg_submitter_reciepesCount": 1.0,
#             "avg_nutrition_saturatedFat_amount": 9.114782804,
#             "geo_name": "Malaysia",
#             "avg_nutrition_calcium_amount": 103.7015715714,
#             "avg_nutrition_thiamin_amount": 0.1924883836,
#             "avg_ratingCount": 19.8055555556,
#             "avg_similarRecipes_metaData_pagesize": 11.6666666667,
#             "avg_nutrition_fiber_amount": 3.5330481371,
#             "avg_nutrition_sodium_amount": 540.31081,
#             "avg_nutrition_sugars_amount": 6.3174138286,
#             "avg_ratingAverage": 3.6616234322,
#             "avg_nutrition_carbohydrates_amount": 30.7149828571,
#             "nbRecipes": 36,
#             "avg_nutrition_folate_amount": 65.2355061714,
#             "avg_servings": 9.25,
#             "geo_identifier": "MYS",
#             "avg_nutrition_cholesterol_amount": 88.0255116114,
#             "avg_submitter_favoritesCount": 41.3333333333,
#             "avg_nutrition_vitaminC_amount": 29.9233142257,
#             "avg_submitter_madeRecipesCount": 3.1944444444,
#             "avg_similarRecipes_metaData_totalCount": 11.6666666667,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 69.0709488,
#             "avg_nutrition_iron_amount": 3.8592344829,
#             "avg_submitter_ratingsCount": 3.1388888889,
#             "avg_reviewCount": 15.2222222222,
#             "avg_nutrition_vitaminB6_amount": 0.5810206314,
#             "database_name": "malaysian",
#             "avg_nutrition_caloriesFromFat_amount": 215.6390485714
#         }
#     ],
#     "global": {
#         "Global aggregation": {
#             "avg_nutrition_fat_amount": 17.7817337376,
#             "avg_readyInMinutes": 157.1372367935,
#             "avg_submitter_personalRecipeSharedCount": 8.0709272257,
#             "avg_nutrition_protein_amount": 16.2278095183,
#             "avg_submitter_reviewsCount": 23.1030045561,
#             "avg_submitter_followersCount": 7870.611685753,
#             "avg_similarRecipes_metaData_page": 1.0,
#             "avg_cookMinutes": 41.1077453516,
#             "avg_nutrition_vitaminA_amount": 1418.1540015684,
#             "avg_nutrition_niacin_amount": 6.5819486949,
#             "avg_nutrition_potassium_amount": 434.1991336157,
#             "avg_nutrition_calories_amount": 350.2467986302,
#             "avg_prepMinutes": 20.2409186061,
#             "avg_submitter_reciepesCount": 22.6657431351,
#             "avg_nutrition_saturatedFat_amount": 6.5396016803,
#             "avg_nutrition_calcium_amount": 114.9318745406,
#             "avg_nutrition_thiamin_amount": 0.2271286606,
#             "avg_ratingCount": 102.3711981283,
#             "avg_similarRecipes_metaData_pagesize": 14.7297130895,
#             "avg_nutrition_fiber_amount": 3.1178096283,
#             "avg_nutrition_sodium_amount": 661.4516873115,
#             "avg_nutrition_sugars_amount": 9.8466210198,
#             "avg_ratingAverage": 4.0803297995,
#             "avg_nutrition_carbohydrates_amount": 31.5380632211,
#             "nbRecipes": 16242,
#             "avg_nutrition_folate_amount": 60.2745651289,
#             "avg_servings": 10.2102573575,
#             "avg_nutrition_cholesterol_amount": 66.2203374766,
#             "avg_submitter_favoritesCount": 151.0502401182,
#             "avg_nutrition_vitaminC_amount": 18.3412098224,
#             "avg_submitter_madeRecipesCount": 30.7689939663,
#             "avg_similarRecipes_metaData_totalCount": 14.7297130895,
#             "avg_submitter_followingCount": 0.0,
#             "avg_nutrition_magnesium_amount": 42.7467841021,
#             "avg_nutrition_iron_amount": 2.6678069684,
#             "avg_submitter_ratingsCount": 29.7984238394,
#             "avg_reviewCount": 77.7717029922,
#             "avg_nutrition_vitaminB6_amount": 0.3188769283,
#             "avg_nutrition_caloriesFromFat_amount": 160.0322171934
#         }
#     }
# }

# %% [markdown]
# Idea: We can use other column to recommend what to eat

# %% [markdown]
# # Stubs

# %%
dailyIntake = {
    'calcium': 
    'caloriesFromFat':
    'calories':
    'carbohydrates':
    'cholesterol':
    'fat':
    'fiber':
    'folate':
    'iron':
    'magnesium':
    'niacin':
    'potassium':
    'protein':
    'saturatedFat':
    'sodium':
    'sugars':
    'thiamin':
    'vitaminA': 3000 # ug (microgram)
    'vitaminB6':
    'vitaminC': 
}
# Out:
#   File "<ipython-input-18-d763b8d7b9c7>", line 3
#     'caloriesFromFat':
#                      ^
# SyntaxError: invalid syntax
